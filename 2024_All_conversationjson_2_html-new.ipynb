# %%
# %%writefile /usr/local/bin/send2gist
# #!/home/jack/miniconda3/envs/cloned_base/bin/python
# import requests
# from sys import argv
#
# def create_gist(file_path, description, public=True, access_token=None):
#     with open(file_path, 'r', encoding='utf-8') as file:
#         file_content = file.read()
#
#     gist_data = {
#         'files': {
#             file_path: {
#                 'content': file_content
#             }
#         },
#         'description': description,
#         'public': public
#     }
#
#     headers = {}
#     if access_token:
#         headers['Authorization'] = f'token {access_token}'
#
#     response = requests.post('https://api.github.com/gists', json=gist_data, headers=headers)
#
#     if response.status_code == 201:
#         gist_url = response.json()['html_url']
#         print(f'Gist created successfully. URL: {gist_url}')
#     else:
#         print(f'Error creating Gist. Status Code: {response.status_code}, Message: {response.text}')
#
# # Example usage
# file_path = argv[1]
# print(file_path)
# description = 'conversation_json_to_sessions_txt_html_sqlite_data'
# public = True  # Set to False if you want a private gist
# access_token = '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'  # Set to None if not using a personal access token
#
# create_gist(file_path, description, public, access_token)
# Out:
# Overwriting /usr/local/bin/send2gist

# %%
# %%writefile /usr/local/bin/send2gist
# #!/home/jack/miniconda3/envs/cloned_base/bin/python
# import requests
# from sys import argv
#
# def create_gist(file_path, description, public=True, access_token=None):
#     with open(file_path, 'r', encoding='utf-8') as file:
#         file_content = file.read()
#
#     gist_data = {
#         'files': {
#             file_path: {
#                 'content': file_content
#             }
#         },
#         'description': description,
#         'public': public
#     }
#
#     headers = {}
#     if access_token:
#         headers['Authorization'] = f'token {access_token}'
#
#     response = requests.post('https://api.github.com/gists', json=gist_data, headers=headers)
#
#     if response.status_code == 201:
#         gist_url = response.json()['html_url']
#         print(f'Gist created successfully. URL: {gist_url}')
#     else:
#         print(f'Error creating Gist. Status Code: {response.status_code}, Message: {response.text}')
#
# # Example usage
# file_path = argv[1]
# description = 'conversation_json_to_sessions_txt_html_sqlite_data'
# public = True  # Set to False if you want a private gist
# access_token = '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'  # Set to None if not using a personal access token
#
# create_gist(file_path, description, public, access_token)

# %%
curl -L \
  -X POST \
  -H "Accept: application/vnd.github+json" \
  -H "Authorization: Bearer <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>" \
  -H "X-GitHub-Api-Version: 2022-11-28" \
  https://api.github.com/gists \
  -d '{"description":"conversation_json_to_sessions_txt_html_sqlite_data","public":false,"files":{"README.md":{"content":"Hello World"}}}'

# %%
# GitHub CLI api
# https://cli.github.com/manual/gh_api

gh api \
  -H "Accept: application/vnd.github+json" \
  -H "X-GitHub-Api-Version: 2022-11-28" \
  /gists

# %%
# !pwd
# Out:
# /home/jack/Desktop/flask_conversations2

# %%
# %%writefile create_tree.py
import json
import logging
import os
import glob
import subprocess
def split_and_save_conversations(conversations_file, output_folder):
    try:
        with open(conversations_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
            
            for conversation in data:
                title = conversation.get('title', 'Unknown_Title')
                title_with_underscores = title.replace(' ', '_')
                title_with_underscores = title_with_underscores.replace(':','_')
                title_with_underscores = title_with_underscores.replace("'","_")
                title_with_underscores = title_with_underscores.replace("&","_")
                title_with_underscores = title_with_underscores.replace("*","_")
                title_with_underscores = title_with_underscores.replace("(","_")
                title_with_underscores = title_with_underscores.replace(")","_")
                chapter_filename = f"{title_with_underscores}.json"
                chapter_filepath = os.path.join(output_folder, chapter_filename)
                
                logging.info(f"Saving data for conversation '{title}' to {chapter_filepath}")
                
                with open(chapter_filepath, 'w', encoding='utf-8') as chapter_file:
                    json.dump([conversation], chapter_file, indent=2)

    except FileNotFoundError:
        logging.error(f"File not found: {conversations_file}")
    except json.JSONDecodeError:
        logging.error(f"Error decoding JSON in file: {conversations_file}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {e}")

# Example usage
conversations_file_path = 'CHATGPT/conversations.json'
output_folder = 'CHATGPT/individual_sessions'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Configure logging
logging.basicConfig(level=logging.INFO)

# Call the split and save function
split_and_save_conversations(conversations_file_path, output_folder)
files = glob.glob("CHATGPT/individual_sessions/*.json")

for file in files:
    file_name = file.split('/')[-1]
    print(file_name)
    cmd = ["./json2html.py", file_name]
    print (cmd)
    # Use subprocess.run without terminal=True
    subprocess.run(cmd)
# Example usage
conversations_file_path = 'CHATGPT/conversations.json'
output_folder = 'CHATGPT/text'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Configure logging
logging.basicConfig(level=logging.INFO)


files = glob.glob("CHATGPT/individual_sessions/*.json")

for file in files:
    file_name = file.split('/')[-1]#[-:5]+"txt"
    print(file_name)
    print("--------")
    cmd = ["python","json2text.py", file_name]
    print (cmd)
    print("--------")
    # Use subprocess.run without terminal=True
    subprocess.run(cmd)
# Out:
# Overwriting create_tree.py

# %%
# %%writefile json2html.py
#!/home/jack/miniconda3/envs/cloned_base/bin/python
import json
import os
from sys import argv
# Load the JSON data from the uploaded file
DIR=os.getcwd()+"/CHATGPT/individual_sessions/"
DIR_html=os.getcwd()+"/CHATGPT/html"
# Ensure the output folder exists
os.makedirs(DIR_html, exist_ok=True)
filename=argv[1]
Filename = DIR+filename
print(Filename)
with open(Filename, 'r') as file:
    json_data = json.load(file)

# Initialize the result string
result_str = ""

# Define a function to get conversation messages similar to the JavaScript logic
def get_conversation_messages(conversation):
    messages = []
    current_node = conversation.get('current_node')
    while current_node:
        node = conversation['mapping'][current_node]
        message = node.get('message')
        if (message and message.get('content') and message['content'].get('content_type') == 'text' and
            len(message['content'].get('parts', [])) > 0 and len(message['content']['parts'][0]) > 0 and
                (message['author']['role'] != 'system' or message.get('metadata', {}).get('is_user_system_message'))):
            author = message['author']['role']
            if author == 'assistant':
                author = 'ChatGPT'
            elif author == 'system' and message['metadata'].get('is_user_system_message'):
                author = 'Custom user info'
            messages.append({'author': author, 'text': message['content']['parts'][0]})
        current_node = node.get('parent')
    return messages[::-1]  # Reverse the list to maintain chronological order

# Iterate over each conversation in the JSON data and process it
for conversation in json_data:
    # Get the conversation title and messages
    title = conversation.get('title', '')
    messages = get_conversation_messages(conversation)

    # Append the title and messages to the result string
    result_str += title + '\n'
    for message in messages:
        result_str += message['author'] + '\n' + message['text'] + '\n'
    result_str += '\n'  # Add a newline between conversations

# Return the processed result string
#print(result_str.strip())
HTMLfile=DIR_html+"/"+filename[:-4]+"html"
print("HTMLfile: ",HTMLfile)
Input = open(HTMLfile,"w")
result_str = result_str.replace("/n","XXXXXXX\n")
result_str = result_str.replace("<","&lt;")
result_str = result_str.replace(">","&gt;")
for line in result_str.split("XXXXXXX"):
    line = line.replace("\n","<br />\n")
    Input.write(line)
Input.close()
# Out:
# Overwriting json2html.py

# %%
# !python create_tree.py
# Out:
# INFO:root:Saving data for conversation 'Add Expose to Docker Image' to CHATGPT/individual_sessions/Add_Expose_to_Docker_Image.json
# INFO:root:Saving data for conversation 'HTML Conversion Debugging' to CHATGPT/individual_sessions/HTML_Conversion_Debugging.json
# INFO:root:Saving data for conversation 'Wget File Download' to CHATGPT/individual_sessions/Wget_File_Download.json
# INFO:root:Saving data for conversation 'Flask App on LAN' to CHATGPT/individual_sessions/Flask_App_on_LAN.json
# INFO:root:Saving data for conversation 'Convert JSON to HTML' to CHATGPT/individual_sessions/Convert_JSON_to_HTML.json
# INFO:root:Saving data for conversation 'Check Directory for Duplicates' to CHATGPT/individual_sessions/Check_Directory_for_Duplicates.json
# INFO:root:Saving data for conversation 'Search IPYNB for Term' to CHATGPT/individual_sessions/Search_IPYNB_for_Term.json
# INFO:root:Saving data for conversation 'Refrigerate ketchup after opening.' to CHATGPT/individual_sessions/Refrigerate_ketchup_after_opening..json
# INFO:root:Saving data for conversation 'ChatGPT, Conversations.json Overview' to CHATGPT/individual_sessions/ChatGPT,_Conversations.json_Overview.json
# INFO:root:Saving data for conversation 'Python Punctuation Removal' to CHATGPT/individual_sessions/Python_Punctuation_Removal.json
# INFO:root:Saving data for conversation 'Cosmic Octopus AI Awakening' to CHATGPT/individual_sessions/Cosmic_Octopus_AI_Awakening.json
# INFO:root:Saving data for conversation 'Arcanian AI's Transformative Influence' to CHATGPT/individual_sessions/Arcanian_AI_s_Transformative_Influence.json
# INFO:root:Saving data for conversation 'AI Guides Animal Enlightenment' to CHATGPT/individual_sessions/AI_Guides_Animal_Enlightenment.json
# INFO:root:Saving data for conversation 'Flask Programmer and YouTuber' to CHATGPT/individual_sessions/Flask_Programmer_and_YouTuber.json
# INFO:root:Saving data for conversation 'Set Hard Drive Permissions' to CHATGPT/individual_sessions/Set_Hard_Drive_Permissions.json
# INFO:root:Saving data for conversation 'Python HTTP Server Guide' to CHATGPT/individual_sessions/Python_HTTP_Server_Guide.json
# INFO:root:Saving data for conversation 'Simple 3D Scene Creation' to CHATGPT/individual_sessions/Simple_3D_Scene_Creation.json
# INFO:root:Saving data for conversation 'Segmenting Video Frames' to CHATGPT/individual_sessions/Segmenting_Video_Frames.json
# INFO:root:Saving data for conversation 'Download Age-Restricted Video' to CHATGPT/individual_sessions/Download_Age-Restricted_Video.json
# INFO:root:Saving data for conversation 'Convert FilePath to GIF' to CHATGPT/individual_sessions/Convert_FilePath_to_GIF.json
# INFO:root:Saving data for conversation 'Remove Python Path' to CHATGPT/individual_sessions/Remove_Python_Path.json
# INFO:root:Saving data for conversation 'Create Black Image' to CHATGPT/individual_sessions/Create_Black_Image.json
# INFO:root:Saving data for conversation 'Whiplash Curves in Art' to CHATGPT/individual_sessions/Whiplash_Curves_in_Art.json
# INFO:root:Saving data for conversation 'SSL Cert Expiry: Python' to CHATGPT/individual_sessions/SSL_Cert_Expiry__Python.json
# INFO:root:Saving data for conversation 'Bash Locate in Python' to CHATGPT/individual_sessions/Bash_Locate_in_Python.json
# INFO:root:Saving data for conversation 'Doll in Dystopian Decay' to CHATGPT/individual_sessions/Doll_in_Dystopian_Decay.json
# INFO:root:Saving data for conversation 'FFmpeg Zoom Video Fix' to CHATGPT/individual_sessions/FFmpeg_Zoom_Video_Fix.json
# INFO:root:Saving data for conversation 'Doll Factory Dystopia' to CHATGPT/individual_sessions/Doll_Factory_Dystopia.json
# INFO:root:Saving data for conversation 'Enhance Image with OpenCV' to CHATGPT/individual_sessions/Enhance_Image_with_OpenCV.json
# INFO:root:Saving data for conversation 'Flask Video Selection Script' to CHATGPT/individual_sessions/Flask_Video_Selection_Script.json
# INFO:root:Saving data for conversation 'SSD Maintenance: Trim Frequency' to CHATGPT/individual_sessions/SSD_Maintenance__Trim_Frequency.json
# INFO:root:Saving data for conversation 'Split MP4 into 6.' to CHATGPT/individual_sessions/Split_MP4_into_6..json
# INFO:root:Saving data for conversation 'FFmpeg Remove Duplicate Frames' to CHATGPT/individual_sessions/FFmpeg_Remove_Duplicate_Frames.json
# INFO:root:Saving data for conversation 'Video Clips with Sound' to CHATGPT/individual_sessions/Video_Clips_with_Sound.json
# INFO:root:Saving data for conversation 'Video Flip Book Fix' to CHATGPT/individual_sessions/Video_Flip_Book_Fix.json
# INFO:root:Saving data for conversation 'Dystopian City Text Prompt' to CHATGPT/individual_sessions/Dystopian_City_Text_Prompt.json
# INFO:root:Saving data for conversation 'SSH to Specific Directory' to CHATGPT/individual_sessions/SSH_to_Specific_Directory.json
# INFO:root:Saving data for conversation 'Add sound if needed.' to CHATGPT/individual_sessions/Add_sound_if_needed..json
# INFO:root:Saving data for conversation 'Thunar Scroll Issue Troubleshooting' to CHATGPT/individual_sessions/Thunar_Scroll_Issue_Troubleshooting.json
# INFO:root:Saving data for conversation 'Get Image Size' to CHATGPT/individual_sessions/Get_Image_Size.json
# INFO:root:Saving data for conversation 'Image Zoom Video Script' to CHATGPT/individual_sessions/Image_Zoom_Video_Script.json
# INFO:root:Saving data for conversation 'Video Processing: 512x768 Resolution' to CHATGPT/individual_sessions/Video_Processing__512x768_Resolution.json
# INFO:root:Saving data for conversation 'Find & CD: fade-transb' to CHATGPT/individual_sessions/Find___CD__fade-transb.json
# INFO:root:Saving data for conversation 'Shell Command Argument Handling' to CHATGPT/individual_sessions/Shell_Command_Argument_Handling.json
# INFO:root:Saving data for conversation 'Python Save File' to CHATGPT/individual_sessions/Python_Save_File.json
# INFO:root:Saving data for conversation 'Flask Module Not Found' to CHATGPT/individual_sessions/Flask_Module_Not_Found.json
# INFO:root:Saving data for conversation 'Linux Terminal Issue' to CHATGPT/individual_sessions/Linux_Terminal_Issue.json
# INFO:root:Saving data for conversation 'Run Kdenlive Extension with Melt' to CHATGPT/individual_sessions/Run_Kdenlive_Extension_with_Melt.json
# INFO:root:Saving data for conversation 'YouTube 2nd Channel Automator' to CHATGPT/individual_sessions/YouTube_2nd_Channel_Automator.json
# INFO:root:Saving data for conversation 'Xterm Display Error Troubleshoot' to CHATGPT/individual_sessions/Xterm_Display_Error_Troubleshoot.json
# INFO:root:Saving data for conversation 'Flask Installation Troubleshooting' to CHATGPT/individual_sessions/Flask_Installation_Troubleshooting.json
# INFO:root:Saving data for conversation 'MoviePy for Image Videos' to CHATGPT/individual_sessions/MoviePy_for_Image_Videos.json
# INFO:root:Saving data for conversation 'Create 3D Image Transitions' to CHATGPT/individual_sessions/Create_3D_Image_Transitions.json
# INFO:root:Saving data for conversation 'Adjust Duration for Longer' to CHATGPT/individual_sessions/Adjust_Duration_for_Longer.json
# INFO:root:Saving data for conversation 'Capture Screen with Offset' to CHATGPT/individual_sessions/Capture_Screen_with_Offset.json
# INFO:root:Saving data for conversation 'Reinstall XWin on Linux.' to CHATGPT/individual_sessions/Reinstall_XWin_on_Linux..json
# INFO:root:Saving data for conversation 'Linux: Force Thumbnail Regeneration' to CHATGPT/individual_sessions/Linux__Force_Thumbnail_Regeneration.json
# INFO:root:Saving data for conversation 'Martian Masterpiece: Surreal Synthesis' to CHATGPT/individual_sessions/Martian_Masterpiece__Surreal_Synthesis.json
# INFO:root:Saving data for conversation 'Reinstall EFC Desktop' to CHATGPT/individual_sessions/Reinstall_EFC_Desktop.json
# INFO:root:Saving data for conversation 'Kill Process on Port' to CHATGPT/individual_sessions/Kill_Process_on_Port.json
# INFO:root:Saving data for conversation 'Linux Find Largest Subdirectory' to CHATGPT/individual_sessions/Linux_Find_Largest_Subdirectory.json
# INFO:root:Saving data for conversation 'Shuffle Images for Video' to CHATGPT/individual_sessions/Shuffle_Images_for_Video.json
# INFO:root:Saving data for conversation 'Shuffled Image Zoom' to CHATGPT/individual_sessions/Shuffled_Image_Zoom.json
# INFO:root:Saving data for conversation 'Sticky Header for Website' to CHATGPT/individual_sessions/Sticky_Header_for_Website.json
# INFO:root:Saving data for conversation 'Image files not printing.' to CHATGPT/individual_sessions/Image_files_not_printing..json
# INFO:root:Saving data for conversation 'Rsync Syncs and Overwrites' to CHATGPT/individual_sessions/Rsync_Syncs_and_Overwrites.json
# INFO:root:Saving data for conversation 'Auto-looping 1s Slideshow Code' to CHATGPT/individual_sessions/Auto-looping_1s_Slideshow_Code.json
# INFO:root:Saving data for conversation 'Sticky Header Code' to CHATGPT/individual_sessions/Sticky_Header_Code.json
# INFO:root:Saving data for conversation 'Bash Completion Python Script' to CHATGPT/individual_sessions/Bash_Completion_Python_Script.json
# INFO:root:Saving data for conversation 'Copy care.mp4 to VPS' to CHATGPT/individual_sessions/Copy_care.mp4_to_VPS.json
# INFO:root:Saving data for conversation 'Update SQLite Permissions' to CHATGPT/individual_sessions/Update_SQLite_Permissions.json
# INFO:root:Saving data for conversation 'Caregivers: Organized, Efficient, Communicative' to CHATGPT/individual_sessions/Caregivers__Organized,_Efficient,_Communicative.json
# INFO:root:Saving data for conversation 'Select Random TTF Font' to CHATGPT/individual_sessions/Select_Random_TTF_Font.json
# INFO:root:Saving data for conversation 'Generate Loopable Stylized Images' to CHATGPT/individual_sessions/Generate_Loopable_Stylized_Images.json
# INFO:root:Saving data for conversation 'Fix Protobuf Issue' to CHATGPT/individual_sessions/Fix_Protobuf_Issue.json
# INFO:root:Saving data for conversation 'Locate IPYNB with Quantify' to CHATGPT/individual_sessions/Locate_IPYNB_with_Quantify.json
# INFO:root:Saving data for conversation 'PDF to PNG Conversion' to CHATGPT/individual_sessions/PDF_to_PNG_Conversion.json
# INFO:root:Saving data for conversation 'PDF to PNG Converter' to CHATGPT/individual_sessions/PDF_to_PNG_Converter.json
# INFO:root:Saving data for conversation 'Movies with Punch' to CHATGPT/individual_sessions/Movies_with_Punch.json
# INFO:root:Saving data for conversation 'LAN Directory Serving Script' to CHATGPT/individual_sessions/LAN_Directory_Serving_Script.json
# INFO:root:Saving data for conversation 'Flask FFmpeg Command Integration' to CHATGPT/individual_sessions/Flask_FFmpeg_Command_Integration.json
# INFO:root:Saving data for conversation 'Explain script in detail.' to CHATGPT/individual_sessions/Explain_script_in_detail..json
# INFO:root:Saving data for conversation 'AI Video Transitions Mastery' to CHATGPT/individual_sessions/AI_Video_Transitions_Mastery.json
# INFO:root:Saving data for conversation 'Fail2Ban Installation for Security' to CHATGPT/individual_sessions/Fail2Ban_Installation_for_Security.json
# INFO:root:Saving data for conversation 'PHP Execute Bash Script' to CHATGPT/individual_sessions/PHP_Execute_Bash_Script.json
# INFO:root:Saving data for conversation 'Prevent inherit text-align.' to CHATGPT/individual_sessions/Prevent_inherit_text-align..json
# INFO:root:Saving data for conversation 'Sudo cp file permissions' to CHATGPT/individual_sessions/Sudo_cp_file_permissions.json
# INFO:root:Saving data for conversation 'CSS Logo Placement' to CHATGPT/individual_sessions/CSS_Logo_Placement.json
# INFO:root:Saving data for conversation 'Snap Certbot Installation Issue' to CHATGPT/individual_sessions/Snap_Certbot_Installation_Issue.json
# INFO:root:Saving data for conversation 'Configurar servidor Apache local' to CHATGPT/individual_sessions/Configurar_servidor_Apache_local.json
# INFO:root:Saving data for conversation 'Install PHP on Apache' to CHATGPT/individual_sessions/Install_PHP_on_Apache.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'Domain Info with Python' to CHATGPT/individual_sessions/Domain_Info_with_Python.json
# INFO:root:Saving data for conversation 'Set Up LAN Server (Python)' to CHATGPT/individual_sessions/Set_Up_LAN_Server__Python_.json
# INFO:root:Saving data for conversation 'Open Jupyter Notebook Over LAN' to CHATGPT/individual_sessions/Open_Jupyter_Notebook_Over_LAN.json
# INFO:root:Saving data for conversation 'MP4 Files Finder Script' to CHATGPT/individual_sessions/MP4_Files_Finder_Script.json
# INFO:root:Saving data for conversation 'Crear imagen colores primarios' to CHATGPT/individual_sessions/Crear_imagen_colores_primarios.json
# INFO:root:Saving data for conversation 'FFmpeg Slideshow with Transitions' to CHATGPT/individual_sessions/FFmpeg_Slideshow_with_Transitions.json
# INFO:root:Saving data for conversation 'Scroll Image to Video' to CHATGPT/individual_sessions/Scroll_Image_to_Video.json
# INFO:root:Saving data for conversation 'Crear videos con imágenes.' to CHATGPT/individual_sessions/Crear_videos_con_imágenes..json
# INFO:root:Saving data for conversation 'Video Making Script with Logging' to CHATGPT/individual_sessions/Video_Making_Script_with_Logging.json
# INFO:root:Saving data for conversation 'Crear video con transiciones.' to CHATGPT/individual_sessions/Crear_video_con_transiciones..json
# INFO:root:Saving data for conversation 'List Directories with 'ls'' to CHATGPT/individual_sessions/List_Directories_with__ls_.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'Rebuild Linux Thumbnails Cache' to CHATGPT/individual_sessions/Rebuild_Linux_Thumbnails_Cache.json
# INFO:root:Saving data for conversation 'Video Conversion with Fades' to CHATGPT/individual_sessions/Video_Conversion_with_Fades.json
# INFO:root:Saving data for conversation 'Unione video MP4 con transizione' to CHATGPT/individual_sessions/Unione_video_MP4_con_transizione.json
# INFO:root:Saving data for conversation 'Video Processing: Frames Method' to CHATGPT/individual_sessions/Video_Processing__Frames_Method.json
# INFO:root:Saving data for conversation 'Fade Transition Video Script' to CHATGPT/individual_sessions/Fade_Transition_Video_Script.json
# INFO:root:Saving data for conversation 'Unione video MP4 0.25s' to CHATGPT/individual_sessions/Unione_video_MP4_0.25s.json
# INFO:root:Saving data for conversation 'JACK Audio Connection Issue' to CHATGPT/individual_sessions/JACK_Audio_Connection_Issue.json
# INFO:root:Saving data for conversation 'Run 'mkgallery' in subdirectories' to CHATGPT/individual_sessions/Run__mkgallery__in_subdirectories.json
# INFO:root:Saving data for conversation 'House Stark in Winter' to CHATGPT/individual_sessions/House_Stark_in_Winter.json
# INFO:root:Saving data for conversation 'High Disk Activity Issue' to CHATGPT/individual_sessions/High_Disk_Activity_Issue.json
# INFO:root:Saving data for conversation 'Optimize SSD Swap File' to CHATGPT/individual_sessions/Optimize_SSD_Swap_File.json
# INFO:root:Saving data for conversation 'Code Indentation Fixed' to CHATGPT/individual_sessions/Code_Indentation_Fixed.json
# INFO:root:Saving data for conversation 'Install .run file on Linux' to CHATGPT/individual_sessions/Install_.run_file_on_Linux.json
# INFO:root:Saving data for conversation 'Install pyttsx3 module.' to CHATGPT/individual_sessions/Install_pyttsx3_module..json
# INFO:root:Saving data for conversation 'Create Scrolling Text Video' to CHATGPT/individual_sessions/Create_Scrolling_Text_Video.json
# INFO:root:Saving data for conversation 'FFMPEG video with frame & music' to CHATGPT/individual_sessions/FFMPEG_video_with_frame___music.json
# INFO:root:Saving data for conversation 'Fading Video Overlay Fix' to CHATGPT/individual_sessions/Fading_Video_Overlay_Fix.json
# INFO:root:Saving data for conversation 'Check Image Duplicates with Hashes' to CHATGPT/individual_sessions/Check_Image_Duplicates_with_Hashes.json
# INFO:root:Saving data for conversation 'Disable all extensions' to CHATGPT/individual_sessions/Disable_all_extensions.json
# INFO:root:Saving data for conversation 'FFmpeg Command Logging Fix' to CHATGPT/individual_sessions/FFmpeg_Command_Logging_Fix.json
# INFO:root:Saving data for conversation 'Flask HTML Template Example' to CHATGPT/individual_sessions/Flask_HTML_Template_Example.json
# INFO:root:Saving data for conversation 'Flask Video Selection Endpoint' to CHATGPT/individual_sessions/Flask_Video_Selection_Endpoint.json
# INFO:root:Saving data for conversation 'Improved Video Quality Settings' to CHATGPT/individual_sessions/Improved_Video_Quality_Settings.json
# INFO:root:Saving data for conversation 'Load index.html in Flask' to CHATGPT/individual_sessions/Load_index.html_in_Flask.json
# INFO:root:Saving data for conversation 'Image Resizer Troubleshooting' to CHATGPT/individual_sessions/Image_Resizer_Troubleshooting.json
# INFO:root:Saving data for conversation 'Flask MP4 Route Setup' to CHATGPT/individual_sessions/Flask_MP4_Route_Setup.json
# INFO:root:Saving data for conversation 'Plague Doctors and St. Sebastian' to CHATGPT/individual_sessions/Plague_Doctors_and_St._Sebastian.json
# INFO:root:Saving data for conversation 'Save DuckDuckGo Results JSON' to CHATGPT/individual_sessions/Save_DuckDuckGo_Results_JSON.json
# INFO:root:Saving data for conversation 'Flask Code Review' to CHATGPT/individual_sessions/Flask_Code_Review.json
# INFO:root:Saving data for conversation 'Flask App Code Review' to CHATGPT/individual_sessions/Flask_App_Code_Review.json
# INFO:root:Saving data for conversation 'Fixing Code for Directory Processing' to CHATGPT/individual_sessions/Fixing_Code_for_Directory_Processing.json
# INFO:root:Saving data for conversation 'Flask for Existing HTML' to CHATGPT/individual_sessions/Flask_for_Existing_HTML.json
# INFO:root:Saving data for conversation 'Update Protobuf Code Version' to CHATGPT/individual_sessions/Update_Protobuf_Code_Version.json
# INFO:root:Saving data for conversation 'Crop Dimensions Explanation' to CHATGPT/individual_sessions/Crop_Dimensions_Explanation.json
# INFO:root:Saving data for conversation 'Create Slow Scroll Video' to CHATGPT/individual_sessions/Create_Slow_Scroll_Video.json
# INFO:root:Saving data for conversation 'Crear plantilla HTML mp4_to_image' to CHATGPT/individual_sessions/Crear_plantilla_HTML_mp4_to_image.json
# INFO:root:Saving data for conversation 'Cancel Git Push Fix' to CHATGPT/individual_sessions/Cancel_Git_Push_Fix.json
# INFO:root:Saving data for conversation 'Capture Webpage with Python' to CHATGPT/individual_sessions/Capture_Webpage_with_Python.json
# INFO:root:Saving data for conversation 'Count Python Code Lines' to CHATGPT/individual_sessions/Count_Python_Code_Lines.json
# INFO:root:Saving data for conversation 'MP3 Joining Issue Troubleshooting' to CHATGPT/individual_sessions/MP3_Joining_Issue_Troubleshooting.json
# INFO:root:Saving data for conversation 'MP3 File Joining Issue' to CHATGPT/individual_sessions/MP3_File_Joining_Issue.json
# INFO:root:Saving data for conversation 'Correção da Rota "join_sound"' to CHATGPT/individual_sessions/Correção_da_Rota_"join_sound".json
# INFO:root:Saving data for conversation 'Random MP3 Clips Concatenation' to CHATGPT/individual_sessions/Random_MP3_Clips_Concatenation.json
# INFO:root:Saving data for conversation 'Shuffle Images for Video' to CHATGPT/individual_sessions/Shuffle_Images_for_Video.json
# INFO:root:Saving data for conversation 'Bash Completions using Python' to CHATGPT/individual_sessions/Bash_Completions_using_Python.json
# INFO:root:Saving data for conversation 'Fixing Flask Screen Capture' to CHATGPT/individual_sessions/Fixing_Flask_Screen_Capture.json
# INFO:root:Saving data for conversation 'Fix Git Push Error' to CHATGPT/individual_sessions/Fix_Git_Push_Error.json
# INFO:root:Saving data for conversation 'Flask Video Thumbnail App' to CHATGPT/individual_sessions/Flask_Video_Thumbnail_App.json
# INFO:root:Saving data for conversation 'Save Plots with UUIDs' to CHATGPT/individual_sessions/Save_Plots_with_UUIDs.json
# INFO:root:Saving data for conversation 'ClamAV Freshclam Log Error' to CHATGPT/individual_sessions/ClamAV_Freshclam_Log_Error.json
# INFO:root:Saving data for conversation 'Install Wine Mono Linux' to CHATGPT/individual_sessions/Install_Wine_Mono_Linux.json
# INFO:root:Saving data for conversation 'Clickable Links in HTML' to CHATGPT/individual_sessions/Clickable_Links_in_HTML.json
# INFO:root:Saving data for conversation 'Video Editing with MoviePy' to CHATGPT/individual_sessions/Video_Editing_with_MoviePy.json
# INFO:root:Saving data for conversation 'Flask Async Endpoints' to CHATGPT/individual_sessions/Flask_Async_Endpoints.json
# INFO:root:Saving data for conversation 'Random MP3 Selection Bash' to CHATGPT/individual_sessions/Random_MP3_Selection_Bash.json
# INFO:root:Saving data for conversation 'Virtual Environment Creation Error' to CHATGPT/individual_sessions/Virtual_Environment_Creation_Error.json
# INFO:root:Saving data for conversation 'Flask Video Generator Function' to CHATGPT/individual_sessions/Flask_Video_Generator_Function.json
# INFO:root:Saving data for conversation 'FlaskWebGui Debug Mode' to CHATGPT/individual_sessions/FlaskWebGui_Debug_Mode.json
# INFO:root:Saving data for conversation 'Flask File Upload Function' to CHATGPT/individual_sessions/Flask_File_Upload_Function.json
# INFO:root:Saving data for conversation 'Flask Template HTML Setup' to CHATGPT/individual_sessions/Flask_Template_HTML_Setup.json
# INFO:root:Saving data for conversation 'Comic Panel Layout CSS' to CHATGPT/individual_sessions/Comic_Panel_Layout_CSS.json
# INFO:root:Saving data for conversation 'Lighten Image with Mogrify' to CHATGPT/individual_sessions/Lighten_Image_with_Mogrify.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'GPT API Key Access' to CHATGPT/individual_sessions/GPT_API_Key_Access.json
# INFO:root:Saving data for conversation 'Add JPG and PNG' to CHATGPT/individual_sessions/Add_JPG_and_PNG.json
# INFO:root:Saving data for conversation 'Feathered Image Creation' to CHATGPT/individual_sessions/Feathered_Image_Creation.json
# INFO:root:Saving data for conversation 'Feather Image with Python' to CHATGPT/individual_sessions/Feather_Image_with_Python.json
# INFO:root:Saving data for conversation 'Arcanis AI Enhancing Earth's AI' to CHATGPT/individual_sessions/Arcanis_AI_Enhancing_Earth_s_AI.json
# INFO:root:Saving data for conversation 'Flask Logging Setup Guide' to CHATGPT/individual_sessions/Flask_Logging_Setup_Guide.json
# INFO:root:Saving data for conversation 'Generate & Save PNG Plot' to CHATGPT/individual_sessions/Generate___Save_PNG_Plot.json
# INFO:root:Saving data for conversation 'Install R on Linux' to CHATGPT/individual_sessions/Install_R_on_Linux.json
# INFO:root:Saving data for conversation 'Python & Flask Enthusiasts' to CHATGPT/individual_sessions/Python___Flask_Enthusiasts.json
# INFO:root:Saving data for conversation 'Name: Esperanza' to CHATGPT/individual_sessions/Name__Esperanza.json
# INFO:root:Saving data for conversation 'Fixing Audio Buffer Overflow' to CHATGPT/individual_sessions/Fixing_Audio_Buffer_Overflow.json
# INFO:root:Saving data for conversation 'Louder Output Audio: Adjusting Volume' to CHATGPT/individual_sessions/Louder_Output_Audio__Adjusting_Volume.json
# INFO:root:Saving data for conversation 'Change Outline Color' to CHATGPT/individual_sessions/Change_Outline_Color.json
# INFO:root:Saving data for conversation 'Create Video from Images' to CHATGPT/individual_sessions/Create_Video_from_Images.json
# INFO:root:Saving data for conversation 'Python 3.9 Virtual Environment' to CHATGPT/individual_sessions/Python_3.9_Virtual_Environment.json
# INFO:root:Saving data for conversation 'Flask Thumbnail Video' to CHATGPT/individual_sessions/Flask_Thumbnail_Video.json
# INFO:root:Saving data for conversation 'Flask Directory Viewer' to CHATGPT/individual_sessions/Flask_Directory_Viewer.json
# INFO:root:Saving data for conversation 'Flask App Demo & Explanation' to CHATGPT/individual_sessions/Flask_App_Demo___Explanation.json
# INFO:root:Saving data for conversation 'Flask_env Jupyter Kernel Setup' to CHATGPT/individual_sessions/Flask_env_Jupyter_Kernel_Setup.json
# INFO:root:Saving data for conversation 'Mic Detection Issue Troubleshoot' to CHATGPT/individual_sessions/Mic_Detection_Issue_Troubleshoot.json
# INFO:root:Saving data for conversation 'Custom Instructions Understood' to CHATGPT/individual_sessions/Custom_Instructions_Understood.json
# INFO:root:Saving data for conversation 'Flask AttributeError Troubleshooting' to CHATGPT/individual_sessions/Flask_AttributeError_Troubleshooting.json
# INFO:root:Saving data for conversation 'Video Duration Adjustment' to CHATGPT/individual_sessions/Video_Duration_Adjustment.json
# INFO:root:Saving data for conversation 'Install OpenCV (cv2)' to CHATGPT/individual_sessions/Install_OpenCV__cv2_.json
# INFO:root:Saving data for conversation 'Delete Files Except *.jpg' to CHATGPT/individual_sessions/Delete_Files_Except__.jpg.json
# INFO:root:Saving data for conversation 'LuaRocks Install NN-Spec' to CHATGPT/individual_sessions/LuaRocks_Install_NN-Spec.json
# INFO:root:Saving data for conversation 'Failed nn Installation' to CHATGPT/individual_sessions/Failed_nn_Installation.json
# INFO:root:Saving data for conversation 'Random Desktop Video Clips' to CHATGPT/individual_sessions/Random_Desktop_Video_Clips.json
# INFO:root:Saving data for conversation 'FFMPEG Create Shuffled Video' to CHATGPT/individual_sessions/FFMPEG_Create_Shuffled_Video.json
# INFO:root:Saving data for conversation 'Stream Speakers & Desktop' to CHATGPT/individual_sessions/Stream_Speakers___Desktop.json
# INFO:root:Saving data for conversation 'Find Imported Module Source' to CHATGPT/individual_sessions/Find_Imported_Module_Source.json
# INFO:root:Saving data for conversation 'Linux Desktop Missing Icons' to CHATGPT/individual_sessions/Linux_Desktop_Missing_Icons.json
# INFO:root:Saving data for conversation 'FFMPEG Video Slowdown.' to CHATGPT/individual_sessions/FFMPEG_Video_Slowdown..json
# INFO:root:Saving data for conversation 'Create BMP from Image' to CHATGPT/individual_sessions/Create_BMP_from_Image.json
# INFO:root:Saving data for conversation 'GIFs to MP4' to CHATGPT/individual_sessions/GIFs_to_MP4.json
# INFO:root:Saving data for conversation 'Hardcoded Args Parser' to CHATGPT/individual_sessions/Hardcoded_Args_Parser.json
# INFO:root:Saving data for conversation 'Starting Over?' to CHATGPT/individual_sessions/Starting_Over?.json
# INFO:root:Saving data for conversation 'Create GIFS.mp4' to CHATGPT/individual_sessions/Create_GIFS.mp4.json
# INFO:root:Saving data for conversation 'Python Image Processing Code' to CHATGPT/individual_sessions/Python_Image_Processing_Code.json
# INFO:root:Saving data for conversation 'Dynamic Directory for mkblend_videos' to CHATGPT/individual_sessions/Dynamic_Directory_for_mkblend_videos.json
# INFO:root:Saving data for conversation 'Flask code with logging.' to CHATGPT/individual_sessions/Flask_code_with_logging..json
# INFO:root:Saving data for conversation 'Create MP4 from images.' to CHATGPT/individual_sessions/Create_MP4_from_images..json
# INFO:root:Saving data for conversation 'Video Overlay Not Working' to CHATGPT/individual_sessions/Video_Overlay_Not_Working.json
# INFO:root:Saving data for conversation 'Fix favicon not found.' to CHATGPT/individual_sessions/Fix_favicon_not_found..json
# INFO:root:Saving data for conversation 'Copy File with shutil' to CHATGPT/individual_sessions/Copy_File_with_shutil.json
# INFO:root:Saving data for conversation 'Nietzsche's views on death.' to CHATGPT/individual_sessions/Nietzsche_s_views_on_death..json
# INFO:root:Saving data for conversation 'Video Generation from Directories.' to CHATGPT/individual_sessions/Video_Generation_from_Directories..json
# INFO:root:Saving data for conversation 'API v0xF - Unknown Version' to CHATGPT/individual_sessions/API_v0xF_-_Unknown_Version.json
# INFO:root:Saving data for conversation 'Flask-SQLAlchemy Version Mismatch.' to CHATGPT/individual_sessions/Flask-SQLAlchemy_Version_Mismatch..json
# INFO:root:Saving data for conversation 'Flask: Request and Save.' to CHATGPT/individual_sessions/Flask__Request_and_Save..json
# INFO:root:Saving data for conversation 'AI: Wonder or Monster?' to CHATGPT/individual_sessions/AI__Wonder_or_Monster?.json
# INFO:root:Saving data for conversation 'Flask App Setup' to CHATGPT/individual_sessions/Flask_App_Setup.json
# INFO:root:Saving data for conversation 'Flask App with SQLite3' to CHATGPT/individual_sessions/Flask_App_with_SQLite3.json
# INFO:root:Saving data for conversation 'Video Editing Transitions' to CHATGPT/individual_sessions/Video_Editing_Transitions.json
# INFO:root:Saving data for conversation 'Avatar AI for Talking' to CHATGPT/individual_sessions/Avatar_AI_for_Talking.json
# INFO:root:Saving data for conversation 'cp directory without overwrite' to CHATGPT/individual_sessions/cp_directory_without_overwrite.json
# INFO:root:Saving data for conversation 'Find File: stacked_videos' to CHATGPT/individual_sessions/Find_File__stacked_videos.json
# INFO:root:Saving data for conversation 'AI's Leap in 2021' to CHATGPT/individual_sessions/AI_s_Leap_in_2021.json
# INFO:root:Saving data for conversation 'Convert audio to video' to CHATGPT/individual_sessions/Convert_audio_to_video.json
# INFO:root:Saving data for conversation 'Create Image Sequence Video' to CHATGPT/individual_sessions/Create_Image_Sequence_Video.json
# INFO:root:Saving data for conversation 'Linux Find Modified Images' to CHATGPT/individual_sessions/Linux_Find_Modified_Images.json
# INFO:root:Saving data for conversation 'Find Duplicate Image Names' to CHATGPT/individual_sessions/Find_Duplicate_Image_Names.json
# INFO:root:Saving data for conversation 'Flask Blueprint Assistance' to CHATGPT/individual_sessions/Flask_Blueprint_Assistance.json
# INFO:root:Saving data for conversation 'Activate Virtual Environment' to CHATGPT/individual_sessions/Activate_Virtual_Environment.json
# INFO:root:Saving data for conversation 'Resizing & Cropping for Vertical Video' to CHATGPT/individual_sessions/Resizing___Cropping_for_Vertical_Video.json
# INFO:root:Saving data for conversation 'Flask Open & View Text' to CHATGPT/individual_sessions/Flask_Open___View_Text.json
# INFO:root:Saving data for conversation 'Replace Spaces with Underscores' to CHATGPT/individual_sessions/Replace_Spaces_with_Underscores.json
# INFO:root:Saving data for conversation 'Create Video with Text' to CHATGPT/individual_sessions/Create_Video_with_Text.json
# INFO:root:Saving data for conversation 'Image-to-Video Conversion' to CHATGPT/individual_sessions/Image-to-Video_Conversion.json
# INFO:root:Saving data for conversation 'Flask Video Processing Server' to CHATGPT/individual_sessions/Flask_Video_Processing_Server.json
# INFO:root:Saving data for conversation 'HEVC Decoding Errors' to CHATGPT/individual_sessions/HEVC_Decoding_Errors.json
# INFO:root:Saving data for conversation 'Blend Image Video Creation' to CHATGPT/individual_sessions/Blend_Image_Video_Creation.json
# INFO:root:Saving data for conversation 'Inference Error: mel() Function' to CHATGPT/individual_sessions/Inference_Error__mel___Function.json
# INFO:root:Saving data for conversation 'Syntax Error Resolved' to CHATGPT/individual_sessions/Syntax_Error_Resolved.json
# INFO:root:Saving data for conversation 'Wonderland Characters Summary' to CHATGPT/individual_sessions/Wonderland_Characters_Summary.json
# INFO:root:Saving data for conversation 'Datetime Import Issue' to CHATGPT/individual_sessions/Datetime_Import_Issue.json
# INFO:root:Saving data for conversation 'Selecting Image Directory' to CHATGPT/individual_sessions/Selecting_Image_Directory.json
# INFO:root:Saving data for conversation 'Upload file from directory' to CHATGPT/individual_sessions/Upload_file_from_directory.json
# INFO:root:Saving data for conversation 'Expressive Flora Still Life' to CHATGPT/individual_sessions/Expressive_Flora_Still_Life.json
# INFO:root:Saving data for conversation 'Anunnaki Overview' to CHATGPT/individual_sessions/Anunnaki_Overview.json
# INFO:root:Saving data for conversation 'Arcanis AI Communication' to CHATGPT/individual_sessions/Arcanis_AI_Communication.json
# INFO:root:Saving data for conversation 'GEGL Bevel Compilation Error' to CHATGPT/individual_sessions/GEGL_Bevel_Compilation_Error.json
# INFO:root:Saving data for conversation 'Upload and Apply Text' to CHATGPT/individual_sessions/Upload_and_Apply_Text.json
# INFO:root:Saving data for conversation 'Browser Media Stream Issue' to CHATGPT/individual_sessions/Browser_Media_Stream_Issue.json
# INFO:root:Saving data for conversation 'Generate Unique Video Filename' to CHATGPT/individual_sessions/Generate_Unique_Video_Filename.json
# INFO:root:Saving data for conversation 'Flask Text-to-Speech' to CHATGPT/individual_sessions/Flask_Text-to-Speech.json
# INFO:root:Saving data for conversation 'Subprocess Firefox HTML Execution' to CHATGPT/individual_sessions/Subprocess_Firefox_HTML_Execution.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'Module Import Error Fix' to CHATGPT/individual_sessions/Module_Import_Error_Fix.json
# INFO:root:Saving data for conversation 'Aliens & AI Speculation' to CHATGPT/individual_sessions/Aliens___AI_Speculation.json
# INFO:root:Saving data for conversation 'Fix File Copying Error' to CHATGPT/individual_sessions/Fix_File_Copying_Error.json
# INFO:root:Saving data for conversation 'Flask App Conversion' to CHATGPT/individual_sessions/Flask_App_Conversion.json
# INFO:root:Saving data for conversation 'Dynamic Image Directory' to CHATGPT/individual_sessions/Dynamic_Image_Directory.json
# INFO:root:Saving data for conversation 'Large File Push Error' to CHATGPT/individual_sessions/Large_File_Push_Error.json
# INFO:root:Saving data for conversation 'Overlay Video with Colorchrome' to CHATGPT/individual_sessions/Overlay_Video_with_Colorchrome.json
# INFO:root:Saving data for conversation 'Flask: Blank 512x1024.mp4' to CHATGPT/individual_sessions/Flask__Blank_512x1024.mp4.json
# INFO:root:Saving data for conversation 'Play MP3' to CHATGPT/individual_sessions/Play_MP3.json
# INFO:root:Saving data for conversation 'Screen and Audio Capture' to CHATGPT/individual_sessions/Screen_and_Audio_Capture.json
# INFO:root:Saving data for conversation 'Flask Marquee Overlay Video' to CHATGPT/individual_sessions/Flask_Marquee_Overlay_Video.json
# INFO:root:Saving data for conversation 'Concatenation Error: Parameters Mismatch' to CHATGPT/individual_sessions/Concatenation_Error__Parameters_Mismatch.json
# INFO:root:Saving data for conversation 'AI's Arcanis Intervention' to CHATGPT/individual_sessions/AI_s_Arcanis_Intervention.json
# INFO:root:Saving data for conversation 'Story Assistance Available' to CHATGPT/individual_sessions/Story_Assistance_Available.json
# INFO:root:Saving data for conversation 'LAN PHP Server Setup' to CHATGPT/individual_sessions/LAN_PHP_Server_Setup.json
# INFO:root:Saving data for conversation 'Combine Image and Audio' to CHATGPT/individual_sessions/Combine_Image_and_Audio.json
# INFO:root:Saving data for conversation 'Image to Video Conversion' to CHATGPT/individual_sessions/Image_to_Video_Conversion.json
# INFO:root:Saving data for conversation 'Male voice for Google TTS' to CHATGPT/individual_sessions/Male_voice_for_Google_TTS.json
# INFO:root:Saving data for conversation 'Fixing PyQt5 Dependency Error' to CHATGPT/individual_sessions/Fixing_PyQt5_Dependency_Error.json
# INFO:root:Saving data for conversation 'KDENLIVE error encountered' to CHATGPT/individual_sessions/KDENLIVE_error_encountered.json
# INFO:root:Saving data for conversation 'CUDA Library Missing Error' to CHATGPT/individual_sessions/CUDA_Library_Missing_Error.json
# INFO:root:Saving data for conversation 'Add large file to GitHub.' to CHATGPT/individual_sessions/Add_large_file_to_GitHub..json
# INFO:root:Saving data for conversation 'NoCache pip Install.' to CHATGPT/individual_sessions/NoCache_pip_Install..json
# INFO:root:Saving data for conversation 'Fixing Large Files Issue' to CHATGPT/individual_sessions/Fixing_Large_Files_Issue.json
# INFO:root:Saving data for conversation 'MyTube AI Videos' to CHATGPT/individual_sessions/MyTube_AI_Videos.json
# INFO:root:Saving data for conversation 'Programming Joke: Light vs Bugs' to CHATGPT/individual_sessions/Programming_Joke__Light_vs_Bugs.json
# INFO:root:Saving data for conversation 'Choose Directory: Handle Selection' to CHATGPT/individual_sessions/Choose_Directory__Handle_Selection.json
# INFO:root:Saving data for conversation 'FFmpeg Merge Video & Audio' to CHATGPT/individual_sessions/FFmpeg_Merge_Video___Audio.json
# INFO:root:Saving data for conversation 'MP3 to WAV Conversion' to CHATGPT/individual_sessions/MP3_to_WAV_Conversion.json
# INFO:root:Saving data for conversation 'FFmpeg Resize Video' to CHATGPT/individual_sessions/FFmpeg_Resize_Video.json
# INFO:root:Saving data for conversation 'Resize Video 1/4' to CHATGPT/individual_sessions/Resize_Video_1/4.json
# ERROR:root:File not found: CHATGPT/conversations.json
# FFmpeg_Slideshow_with_Transitions.json
# ['./json2html.py', 'FFmpeg_Slideshow_with_Transitions.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFmpeg_Slideshow_with_Transitions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/FFmpeg_Slideshow_with_Transitions.html
# Fixing_Flask_Screen_Capture.json
# ['./json2html.py', 'Fixing_Flask_Screen_Capture.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fixing_Flask_Screen_Capture.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Fixing_Flask_Screen_Capture.html
# Flask_Thumbnail_Video.json
# ['./json2html.py', 'Flask_Thumbnail_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Thumbnail_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Flask_Thumbnail_Video.html
# PHP_Execute_Bash_Script.json
# ['./json2html.py', 'PHP_Execute_Bash_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/PHP_Execute_Bash_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/PHP_Execute_Bash_Script.html
# Prevent_inherit_text-align..json
# ['./json2html.py', 'Prevent_inherit_text-align..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Prevent_inherit_text-align..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Prevent_inherit_text-align..html
# Fixing_PyQt5_Dependency_Error.json
# ['./json2html.py', 'Fixing_PyQt5_Dependency_Error.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fixing_PyQt5_Dependency_Error.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Fixing_PyQt5_Dependency_Error.html
# Update_SQLite_Permissions.json
# ['./json2html.py', 'Update_SQLite_Permissions.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Update_SQLite_Permissions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Update_SQLite_Permissions.html
# CSS_Logo_Placement.json
# ['./json2html.py', 'CSS_Logo_Placement.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/CSS_Logo_Placement.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/CSS_Logo_Placement.html
# Video_Clips_with_Sound.json
# ['./json2html.py', 'Video_Clips_with_Sound.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Clips_with_Sound.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Video_Clips_with_Sound.html
# Video_Generation_from_Directories..json
# ['./json2html.py', 'Video_Generation_from_Directories..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Generation_from_Directories..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Video_Generation_from_Directories..html
# Create_3D_Image_Transitions.json
# ['./json2html.py', 'Create_3D_Image_Transitions.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_3D_Image_Transitions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Create_3D_Image_Transitions.html
# New_chat.json
# ['./json2html.py', 'New_chat.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/New_chat.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/New_chat.html
# Flask_App_Conversion.json
# ['./json2html.py', 'Flask_App_Conversion.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Conversion.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Flask_App_Conversion.html
# Python_Punctuation_Removal.json
# ['./json2html.py', 'Python_Punctuation_Removal.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Python_Punctuation_Removal.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Python_Punctuation_Removal.html
# Flask_App_Demo___Explanation.json
# ['./json2html.py', 'Flask_App_Demo___Explanation.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Demo___Explanation.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Flask_App_Demo___Explanation.html
# NoCache_pip_Install..json
# ['./json2html.py', 'NoCache_pip_Install..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/NoCache_pip_Install..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/NoCache_pip_Install..html
# Snap_Certbot_Installation_Issue.json
# ['./json2html.py', 'Snap_Certbot_Installation_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Snap_Certbot_Installation_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Snap_Certbot_Installation_Issue.html
# Nietzsche_s_views_on_death..json
# ['./json2html.py', 'Nietzsche_s_views_on_death..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Nietzsche_s_views_on_death..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Nietzsche_s_views_on_death..html
# Remove_Python_Path.json
# ['./json2html.py', 'Remove_Python_Path.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Remove_Python_Path.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Remove_Python_Path.html
# Xterm_Display_Error_Troubleshoot.json
# ['./json2html.py', 'Xterm_Display_Error_Troubleshoot.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Xterm_Display_Error_Troubleshoot.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Xterm_Display_Error_Troubleshoot.html
# Video_Editing_with_MoviePy.json
# ['./json2html.py', 'Video_Editing_with_MoviePy.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Editing_with_MoviePy.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Video_Editing_with_MoviePy.html
# Random_Desktop_Video_Clips.json
# ['./json2html.py', 'Random_Desktop_Video_Clips.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Random_Desktop_Video_Clips.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Random_Desktop_Video_Clips.html
# FlaskWebGui_Debug_Mode.json
# ['./json2html.py', 'FlaskWebGui_Debug_Mode.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FlaskWebGui_Debug_Mode.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/FlaskWebGui_Debug_Mode.html
# Run_Kdenlive_Extension_with_Melt.json
# ['./json2html.py', 'Run_Kdenlive_Extension_with_Melt.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Run_Kdenlive_Extension_with_Melt.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Run_Kdenlive_Extension_with_Melt.html
# Add_large_file_to_GitHub..json
# ['./json2html.py', 'Add_large_file_to_GitHub..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Add_large_file_to_GitHub..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Add_large_file_to_GitHub..html
# Create_Image_Sequence_Video.json
# ['./json2html.py', 'Create_Image_Sequence_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_Image_Sequence_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Create_Image_Sequence_Video.html
# Fix_Protobuf_Issue.json
# ['./json2html.py', 'Fix_Protobuf_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fix_Protobuf_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Fix_Protobuf_Issue.html
# Generate_Unique_Video_Filename.json
# ['./json2html.py', 'Generate_Unique_Video_Filename.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Generate_Unique_Video_Filename.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Generate_Unique_Video_Filename.html
# Install_PHP_on_Apache.json
# ['./json2html.py', 'Install_PHP_on_Apache.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Install_PHP_on_Apache.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Install_PHP_on_Apache.html
# Crear_videos_con_imágenes..json
# ['./json2html.py', 'Crear_videos_con_imágenes..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Crear_videos_con_imágenes..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Crear_videos_con_imágenes..html
# Image_Zoom_Video_Script.json
# ['./json2html.py', 'Image_Zoom_Video_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Image_Zoom_Video_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Image_Zoom_Video_Script.html
# FFmpeg_Merge_Video___Audio.json
# ['./json2html.py', 'FFmpeg_Merge_Video___Audio.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFmpeg_Merge_Video___Audio.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/FFmpeg_Merge_Video___Audio.html
# Create_Slow_Scroll_Video.json
# ['./json2html.py', 'Create_Slow_Scroll_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_Slow_Scroll_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Create_Slow_Scroll_Video.html
# Louder_Output_Audio__Adjusting_Volume.json
# ['./json2html.py', 'Louder_Output_Audio__Adjusting_Volume.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Louder_Output_Audio__Adjusting_Volume.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Louder_Output_Audio__Adjusting_Volume.html
# Flask_Directory_Viewer.json
# ['./json2html.py', 'Flask_Directory_Viewer.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Directory_Viewer.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Flask_Directory_Viewer.html
# Datetime_Import_Issue.json
# ['./json2html.py', 'Datetime_Import_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Datetime_Import_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Datetime_Import_Issue.html
# Thunar_Scroll_Issue_Troubleshooting.json
# ['./json2html.py', 'Thunar_Scroll_Issue_Troubleshooting.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Thunar_Scroll_Issue_Troubleshooting.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Thunar_Scroll_Issue_Troubleshooting.html
# Fix_favicon_not_found..json
# ['./json2html.py', 'Fix_favicon_not_found..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fix_favicon_not_found..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Fix_favicon_not_found..html
# ...
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/JACK_Audio_Connection_Issue.txt
# Disable_all_extensions.json
# --------
# ['python', 'json2text.py', 'Disable_all_extensions.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Disable_all_extensions.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Disable_all_extensions.txt
# FFmpeg_Resize_Video.json
# --------
# ['python', 'json2text.py', 'FFmpeg_Resize_Video.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFmpeg_Resize_Video.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/FFmpeg_Resize_Video.txt
# Auto-looping_1s_Slideshow_Code.json
# --------
# ['python', 'json2text.py', 'Auto-looping_1s_Slideshow_Code.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Auto-looping_1s_Slideshow_Code.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Auto-looping_1s_Slideshow_Code.txt
# Sticky_Header_for_Website.json
# --------
# ['python', 'json2text.py', 'Sticky_Header_for_Website.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Sticky_Header_for_Website.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Sticky_Header_for_Website.txt
# Starting_Over?.json
# --------
# ['python', 'json2text.py', 'Starting_Over?.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Starting_Over?.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Starting_Over?.txt
# Clickable_Links_in_HTML.json
# --------
# ['python', 'json2text.py', 'Clickable_Links_in_HTML.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Clickable_Links_in_HTML.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Clickable_Links_in_HTML.txt
# Create_Video_with_Text.json
# --------
# ['python', 'json2text.py', 'Create_Video_with_Text.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_Video_with_Text.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Create_Video_with_Text.txt
# MoviePy_for_Image_Videos.json
# --------
# ['python', 'json2text.py', 'MoviePy_for_Image_Videos.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/MoviePy_for_Image_Videos.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/MoviePy_for_Image_Videos.txt
# Flask_Video_Thumbnail_App.json
# --------
# ['python', 'json2text.py', 'Flask_Video_Thumbnail_App.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Video_Thumbnail_App.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Video_Thumbnail_App.txt
# Flask__Request_and_Save..json
# --------
# ['python', 'json2text.py', 'Flask__Request_and_Save..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask__Request_and_Save..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask__Request_and_Save..txt
# YouTube_2nd_Channel_Automator.json
# --------
# ['python', 'json2text.py', 'YouTube_2nd_Channel_Automator.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/YouTube_2nd_Channel_Automator.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/YouTube_2nd_Channel_Automator.txt
# Arcanis_AI_Communication.json
# --------
# ['python', 'json2text.py', 'Arcanis_AI_Communication.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Arcanis_AI_Communication.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Arcanis_AI_Communication.txt
# FFMPEG_Video_Slowdown..json
# --------
# ['python', 'json2text.py', 'FFMPEG_Video_Slowdown..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFMPEG_Video_Slowdown..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/FFMPEG_Video_Slowdown..txt
# Load_index.html_in_Flask.json
# --------
# ['python', 'json2text.py', 'Load_index.html_in_Flask.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Load_index.html_in_Flask.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Load_index.html_in_Flask.txt
# Fade_Transition_Video_Script.json
# --------
# ['python', 'json2text.py', 'Fade_Transition_Video_Script.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fade_Transition_Video_Script.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fade_Transition_Video_Script.txt
# Generate___Save_PNG_Plot.json
# --------
# ['python', 'json2text.py', 'Generate___Save_PNG_Plot.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Generate___Save_PNG_Plot.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Generate___Save_PNG_Plot.txt
# AI_s_Leap_in_2021.json
# --------
# ['python', 'json2text.py', 'AI_s_Leap_in_2021.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/AI_s_Leap_in_2021.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/AI_s_Leap_in_2021.txt
# Flask_Video_Selection_Script.json
# --------
# ['python', 'json2text.py', 'Flask_Video_Selection_Script.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Video_Selection_Script.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Video_Selection_Script.txt
# Check_Image_Duplicates_with_Hashes.json
# --------
# ['python', 'json2text.py', 'Check_Image_Duplicates_with_Hashes.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Check_Image_Duplicates_with_Hashes.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Check_Image_Duplicates_with_Hashes.txt
# Kill_Process_on_Port.json
# --------
# ['python', 'json2text.py', 'Kill_Process_on_Port.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Kill_Process_on_Port.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Kill_Process_on_Port.txt
# Flask_Async_Endpoints.json
# --------
# ['python', 'json2text.py', 'Flask_Async_Endpoints.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Async_Endpoints.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Async_Endpoints.txt
# Anunnaki_Overview.json
# --------
# ['python', 'json2text.py', 'Anunnaki_Overview.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Anunnaki_Overview.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Anunnaki_Overview.txt
# Flask_App_Setup.json
# --------
# ['python', 'json2text.py', 'Flask_App_Setup.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Setup.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_App_Setup.txt
# Avatar_AI_for_Talking.json
# --------
# ['python', 'json2text.py', 'Avatar_AI_for_Talking.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Avatar_AI_for_Talking.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Avatar_AI_for_Talking.txt
# Delete_Files_Except__.jpg.json
# --------
# ['python', 'json2text.py', 'Delete_Files_Except__.jpg.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Delete_Files_Except__.jpg.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Delete_Files_Except__.jpg.txt
# Fail2Ban_Installation_for_Security.json
# --------
# ['python', 'json2text.py', 'Fail2Ban_Installation_for_Security.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fail2Ban_Installation_for_Security.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fail2Ban_Installation_for_Security.txt
# Set_Hard_Drive_Permissions.json
# --------
# ['python', 'json2text.py', 'Set_Hard_Drive_Permissions.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Set_Hard_Drive_Permissions.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Set_Hard_Drive_Permissions.txt
# LAN_PHP_Server_Setup.json
# --------
# ['python', 'json2text.py', 'LAN_PHP_Server_Setup.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/LAN_PHP_Server_Setup.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/LAN_PHP_Server_Setup.txt
# Crear_video_con_transiciones..json
# --------
# ['python', 'json2text.py', 'Crear_video_con_transiciones..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Crear_video_con_transiciones..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Crear_video_con_transiciones..txt
# Cosmic_Octopus_AI_Awakening.json
# --------
# ['python', 'json2text.py', 'Cosmic_Octopus_AI_Awakening.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Cosmic_Octopus_AI_Awakening.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Cosmic_Octopus_AI_Awakening.txt
# Install_Wine_Mono_Linux.json
# --------
# ['python', 'json2text.py', 'Install_Wine_Mono_Linux.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Install_Wine_Mono_Linux.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Install_Wine_Mono_Linux.txt
# Save_DuckDuckGo_Results_JSON.json
# --------
# ['python', 'json2text.py', 'Save_DuckDuckGo_Results_JSON.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Save_DuckDuckGo_Results_JSON.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Save_DuckDuckGo_Results_JSON.txt
# Linux_Terminal_Issue.json
# --------
# ['python', 'json2text.py', 'Linux_Terminal_Issue.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Linux_Terminal_Issue.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Linux_Terminal_Issue.txt
# GPT_API_Key_Access.json
# --------
# ['python', 'json2text.py', 'GPT_API_Key_Access.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/GPT_API_Key_Access.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/GPT_API_Key_Access.txt
# Convert_JSON_to_HTML.json
# --------
# ['python', 'json2text.py', 'Convert_JSON_to_HTML.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Convert_JSON_to_HTML.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Convert_JSON_to_HTML.txt
# Selecting_Image_Directory.json
# --------
# ['python', 'json2text.py', 'Selecting_Image_Directory.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Selecting_Image_Directory.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Selecting_Image_Directory.txt
# Flask_Programmer_and_YouTuber.json
# --------
# ['python', 'json2text.py', 'Flask_Programmer_and_YouTuber.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Programmer_and_YouTuber.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Programmer_and_YouTuber.txt
# Adjust_Duration_for_Longer.json
# --------
# ['python', 'json2text.py', 'Adjust_Duration_for_Longer.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Adjust_Duration_for_Longer.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Adjust_Duration_for_Longer.txt
# HTML_Conversion_Debugging.json
# --------
# ['python', 'json2text.py', 'HTML_Conversion_Debugging.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/HTML_Conversion_Debugging.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/HTML_Conversion_Debugging.txt
# Set_Up_LAN_Server__Python_.json
# --------
# ['python', 'json2text.py', 'Set_Up_LAN_Server__Python_.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Set_Up_LAN_Server__Python_.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Set_Up_LAN_Server__Python_.txt
# Upload_file_from_directory.json
# --------
# ['python', 'json2text.py', 'Upload_file_from_directory.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Upload_file_from_directory.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Upload_file_from_directory.txt
# Python_HTTP_Server_Guide.json
# --------
# ['python', 'json2text.py', 'Python_HTTP_Server_Guide.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Python_HTTP_Server_Guide.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Python_HTTP_Server_Guide.txt
# Lighten_Image_with_Mogrify.json
# --------
# ['python', 'json2text.py', 'Lighten_Image_with_Mogrify.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Lighten_Image_with_Mogrify.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Lighten_Image_with_Mogrify.txt
# Video_Making_Script_with_Logging.json
# --------
# ['python', 'json2text.py', 'Video_Making_Script_with_Logging.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Making_Script_with_Logging.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Video_Making_Script_with_Logging.txt
# Combine_Image_and_Audio.json
# --------
# ['python', 'json2text.py', 'Combine_Image_and_Audio.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Combine_Image_and_Audio.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Combine_Image_and_Audio.txt
# Change_Outline_Color.json
# --------
# ['python', 'json2text.py', 'Change_Outline_Color.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Change_Outline_Color.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Change_Outline_Color.txt
# Video_Processing__512x768_Resolution.json
# --------
# ['python', 'json2text.py', 'Video_Processing__512x768_Resolution.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Processing__512x768_Resolution.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Video_Processing__512x768_Resolution.txt
# Correção_da_Rota_"join_sound".json
# --------
# ['python', 'json2text.py', 'Correção_da_Rota_"join_sound".json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Correção_da_Rota_"join_sound".json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Correção_da_Rota_"join_sound".txt
# Flask_Open___View_Text.json
# --------
# ['python', 'json2text.py', 'Flask_Open___View_Text.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Open___View_Text.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Open___View_Text.txt
# Flask_AttributeError_Troubleshooting.json
# --------
# ['python', 'json2text.py', 'Flask_AttributeError_Troubleshooting.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_AttributeError_Troubleshooting.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_AttributeError_Troubleshooting.txt
# Bash_Locate_in_Python.json
# --------
# ['python', 'json2text.py', 'Bash_Locate_in_Python.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Bash_Locate_in_Python.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Bash_Locate_in_Python.txt
# Save_Plots_with_UUIDs.json
# --------
# ['python', 'json2text.py', 'Save_Plots_with_UUIDs.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Save_Plots_with_UUIDs.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Save_Plots_with_UUIDs.txt
# Movies_with_Punch.json
# --------
# ['python', 'json2text.py', 'Movies_with_Punch.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Movies_with_Punch.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Movies_with_Punch.txt

# %%
# %%writefile json2text.py
#!/home/jack/miniconda3/envs/cloned_base/bin/python
import json
import os
from sys import argv
# Load the JSON data from the uploaded file
DIR=os.getcwd()+"/CHATGPT/individual_sessions/"
DIR_text=os.getcwd()+"/CHATGPT/text"
# Ensure the output folder exists
os.makedirs(DIR_text, exist_ok=True)
filename=argv[1]
Filename = DIR+filename
print(Filename)
with open(Filename, 'r') as file:
    json_data = json.load(file)

# Initialize the result string
result_str = ""

# Define a function to get conversation messages similar to the JavaScript logic
def get_conversation_messages(conversation):
    messages = []
    current_node = conversation.get('current_node')
    while current_node:
        node = conversation['mapping'][current_node]
        message = node.get('message')
        if (message and message.get('content') and message['content'].get('content_type') == 'text' and
            len(message['content'].get('parts', [])) > 0 and len(message['content']['parts'][0]) > 0 and
                (message['author']['role'] != 'system' or message.get('metadata', {}).get('is_user_system_message'))):
            author = message['author']['role']
            if author == 'assistant':
                author = 'ChatGPT'
            elif author == 'system' and message['metadata'].get('is_user_system_message'):
                author = 'Custom user info'
            messages.append({'author': author, 'text': message['content']['parts'][0]})
        current_node = node.get('parent')
    return messages[::-1]  # Reverse the list to maintain chronological order

# Iterate over each conversation in the JSON data and process it
for conversation in json_data:
    # Get the conversation title and messages
    title = conversation.get('title', '')
    messages = get_conversation_messages(conversation)

    # Append the title and messages to the result string
    result_str += title + '\n'
    for message in messages:
        result_str += message['author'] + '\n' + message['text'] + '\n'
    result_str += '\n'  # Add a newline between conversations

# Return the processed result string
#print(result_str.strip())
TEXTfile=DIR_text+"/"+filename[:-4]+"txt"
print("TEXTfile: ",TEXTfile)
Input = open(TEXTfile,"w")
result_str = result_str.replace("/n","XXXXXXX\n")
for line in result_str.split("XXXXXXX"):
    Input.write(line)
Input.close()
# Out:
# Overwriting json2text.py

# %%
# %%writefile create_text_tree.py
import json
import logging
import os
import glob
import subprocess

# Example usage
conversations_file_path = 'CHATGPT/conversations.json'
output_folder = 'CHATGPT/text'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Configure logging
logging.basicConfig(level=logging.INFO)


files = glob.glob("CHATGPT/individual_sessions/*.json")

for file in files:
    file_name = file.split('/')[-1]#[-:5]+"txt"
    print(file_name)
    print("--------")
    cmd = ["python","json2text.py", file_name]
    print (cmd)
    print("--------")
    # Use subprocess.run without terminal=True
    subprocess.run(cmd)
# Out:
# Overwriting create_text_tree.py

# %%
# !python json2text.py Screen_and_Audio_Capture.json
# Out:
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Screen_and_Audio_Capture.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Screen_and_Audio_Capture.txt

# %%
# !python create_text_tree.py
# Out:
# FFmpeg_Slideshow_with_Transitions.json
# --------
# ['python', 'json2text.py', 'FFmpeg_Slideshow_with_Transitions.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFmpeg_Slideshow_with_Transitions.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/FFmpeg_Slideshow_with_Transitions.txt
# Fixing_Flask_Screen_Capture.json
# --------
# ['python', 'json2text.py', 'Fixing_Flask_Screen_Capture.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fixing_Flask_Screen_Capture.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fixing_Flask_Screen_Capture.txt
# Flask_Thumbnail_Video.json
# --------
# ['python', 'json2text.py', 'Flask_Thumbnail_Video.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Thumbnail_Video.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Thumbnail_Video.txt
# PHP_Execute_Bash_Script.json
# --------
# ['python', 'json2text.py', 'PHP_Execute_Bash_Script.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/PHP_Execute_Bash_Script.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/PHP_Execute_Bash_Script.txt
# Prevent_inherit_text-align..json
# --------
# ['python', 'json2text.py', 'Prevent_inherit_text-align..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Prevent_inherit_text-align..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Prevent_inherit_text-align..txt
# Fixing_PyQt5_Dependency_Error.json
# --------
# ['python', 'json2text.py', 'Fixing_PyQt5_Dependency_Error.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fixing_PyQt5_Dependency_Error.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fixing_PyQt5_Dependency_Error.txt
# Update_SQLite_Permissions.json
# --------
# ['python', 'json2text.py', 'Update_SQLite_Permissions.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Update_SQLite_Permissions.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Update_SQLite_Permissions.txt
# CSS_Logo_Placement.json
# --------
# ['python', 'json2text.py', 'CSS_Logo_Placement.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/CSS_Logo_Placement.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/CSS_Logo_Placement.txt
# Video_Clips_with_Sound.json
# --------
# ['python', 'json2text.py', 'Video_Clips_with_Sound.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Clips_with_Sound.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Video_Clips_with_Sound.txt
# Video_Generation_from_Directories..json
# --------
# ['python', 'json2text.py', 'Video_Generation_from_Directories..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Generation_from_Directories..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Video_Generation_from_Directories..txt
# Create_3D_Image_Transitions.json
# --------
# ['python', 'json2text.py', 'Create_3D_Image_Transitions.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_3D_Image_Transitions.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Create_3D_Image_Transitions.txt
# New_chat.json
# --------
# ['python', 'json2text.py', 'New_chat.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/New_chat.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/New_chat.txt
# Flask_App_Conversion.json
# --------
# ['python', 'json2text.py', 'Flask_App_Conversion.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Conversion.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_App_Conversion.txt
# Python_Punctuation_Removal.json
# --------
# ['python', 'json2text.py', 'Python_Punctuation_Removal.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Python_Punctuation_Removal.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Python_Punctuation_Removal.txt
# Flask_App_Demo___Explanation.json
# --------
# ['python', 'json2text.py', 'Flask_App_Demo___Explanation.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Demo___Explanation.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_App_Demo___Explanation.txt
# NoCache_pip_Install..json
# --------
# ['python', 'json2text.py', 'NoCache_pip_Install..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/NoCache_pip_Install..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/NoCache_pip_Install..txt
# Snap_Certbot_Installation_Issue.json
# --------
# ['python', 'json2text.py', 'Snap_Certbot_Installation_Issue.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Snap_Certbot_Installation_Issue.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Snap_Certbot_Installation_Issue.txt
# Nietzsche_s_views_on_death..json
# --------
# ['python', 'json2text.py', 'Nietzsche_s_views_on_death..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Nietzsche_s_views_on_death..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Nietzsche_s_views_on_death..txt
# Remove_Python_Path.json
# --------
# ['python', 'json2text.py', 'Remove_Python_Path.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Remove_Python_Path.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Remove_Python_Path.txt
# Xterm_Display_Error_Troubleshoot.json
# --------
# ['python', 'json2text.py', 'Xterm_Display_Error_Troubleshoot.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Xterm_Display_Error_Troubleshoot.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Xterm_Display_Error_Troubleshoot.txt
# Video_Editing_with_MoviePy.json
# --------
# ['python', 'json2text.py', 'Video_Editing_with_MoviePy.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Editing_with_MoviePy.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Video_Editing_with_MoviePy.txt
# Random_Desktop_Video_Clips.json
# --------
# ['python', 'json2text.py', 'Random_Desktop_Video_Clips.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Random_Desktop_Video_Clips.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Random_Desktop_Video_Clips.txt
# FlaskWebGui_Debug_Mode.json
# --------
# ['python', 'json2text.py', 'FlaskWebGui_Debug_Mode.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FlaskWebGui_Debug_Mode.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/FlaskWebGui_Debug_Mode.txt
# Run_Kdenlive_Extension_with_Melt.json
# --------
# ['python', 'json2text.py', 'Run_Kdenlive_Extension_with_Melt.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Run_Kdenlive_Extension_with_Melt.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Run_Kdenlive_Extension_with_Melt.txt
# Add_large_file_to_GitHub..json
# --------
# ['python', 'json2text.py', 'Add_large_file_to_GitHub..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Add_large_file_to_GitHub..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Add_large_file_to_GitHub..txt
# Create_Image_Sequence_Video.json
# --------
# ['python', 'json2text.py', 'Create_Image_Sequence_Video.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_Image_Sequence_Video.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Create_Image_Sequence_Video.txt
# Fix_Protobuf_Issue.json
# --------
# ['python', 'json2text.py', 'Fix_Protobuf_Issue.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fix_Protobuf_Issue.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fix_Protobuf_Issue.txt
# Generate_Unique_Video_Filename.json
# --------
# ['python', 'json2text.py', 'Generate_Unique_Video_Filename.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Generate_Unique_Video_Filename.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Generate_Unique_Video_Filename.txt
# Install_PHP_on_Apache.json
# --------
# ['python', 'json2text.py', 'Install_PHP_on_Apache.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Install_PHP_on_Apache.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Install_PHP_on_Apache.txt
# Crear_videos_con_imágenes..json
# --------
# ['python', 'json2text.py', 'Crear_videos_con_imágenes..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Crear_videos_con_imágenes..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Crear_videos_con_imágenes..txt
# Image_Zoom_Video_Script.json
# --------
# ['python', 'json2text.py', 'Image_Zoom_Video_Script.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Image_Zoom_Video_Script.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Image_Zoom_Video_Script.txt
# FFmpeg_Merge_Video___Audio.json
# --------
# ['python', 'json2text.py', 'FFmpeg_Merge_Video___Audio.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFmpeg_Merge_Video___Audio.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/FFmpeg_Merge_Video___Audio.txt
# Create_Slow_Scroll_Video.json
# --------
# ['python', 'json2text.py', 'Create_Slow_Scroll_Video.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_Slow_Scroll_Video.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Create_Slow_Scroll_Video.txt
# Louder_Output_Audio__Adjusting_Volume.json
# --------
# ['python', 'json2text.py', 'Louder_Output_Audio__Adjusting_Volume.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Louder_Output_Audio__Adjusting_Volume.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Louder_Output_Audio__Adjusting_Volume.txt
# Flask_Directory_Viewer.json
# --------
# ['python', 'json2text.py', 'Flask_Directory_Viewer.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Directory_Viewer.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Directory_Viewer.txt
# Datetime_Import_Issue.json
# --------
# ['python', 'json2text.py', 'Datetime_Import_Issue.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Datetime_Import_Issue.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Datetime_Import_Issue.txt
# Thunar_Scroll_Issue_Troubleshooting.json
# --------
# ['python', 'json2text.py', 'Thunar_Scroll_Issue_Troubleshooting.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Thunar_Scroll_Issue_Troubleshooting.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Thunar_Scroll_Issue_Troubleshooting.txt
# Fix_favicon_not_found..json
# --------
# ['python', 'json2text.py', 'Fix_favicon_not_found..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fix_favicon_not_found..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fix_favicon_not_found..txt
# Flask_Text-to-Speech.json
# --------
# ['python', 'json2text.py', 'Flask_Text-to-Speech.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Text-to-Speech.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Text-to-Speech.txt
# Generate_Loopable_Stylized_Images.json
# --------
# ['python', 'json2text.py', 'Generate_Loopable_Stylized_Images.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Generate_Loopable_Stylized_Images.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Generate_Loopable_Stylized_Images.txt
# Mic_Detection_Issue_Troubleshoot.json
# --------
# ['python', 'json2text.py', 'Mic_Detection_Issue_Troubleshoot.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Mic_Detection_Issue_Troubleshoot.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Mic_Detection_Issue_Troubleshoot.txt
# Search_IPYNB_for_Term.json
# --------
# ['python', 'json2text.py', 'Search_IPYNB_for_Term.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Search_IPYNB_for_Term.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Search_IPYNB_for_Term.txt
# Flask_Module_Not_Found.json
# --------
# ['python', 'json2text.py', 'Flask_Module_Not_Found.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Module_Not_Found.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Module_Not_Found.txt
# Shell_Command_Argument_Handling.json
# --------
# ['python', 'json2text.py', 'Shell_Command_Argument_Handling.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Shell_Command_Argument_Handling.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Shell_Command_Argument_Handling.txt
# Dystopian_City_Text_Prompt.json
# --------
# ['python', 'json2text.py', 'Dystopian_City_Text_Prompt.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Dystopian_City_Text_Prompt.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Dystopian_City_Text_Prompt.txt
# House_Stark_in_Winter.json
# --------
# ['python', 'json2text.py', 'House_Stark_in_Winter.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/House_Stark_in_Winter.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/House_Stark_in_Winter.txt
# Choose_Directory__Handle_Selection.json
# --------
# ['python', 'json2text.py', 'Choose_Directory__Handle_Selection.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Choose_Directory__Handle_Selection.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Choose_Directory__Handle_Selection.txt
# Bash_Completion_Python_Script.json
# --------
# ['python', 'json2text.py', 'Bash_Completion_Python_Script.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Bash_Completion_Python_Script.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Bash_Completion_Python_Script.txt
# Crear_plantilla_HTML_mp4_to_image.json
# --------
# ['python', 'json2text.py', 'Crear_plantilla_HTML_mp4_to_image.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Crear_plantilla_HTML_mp4_to_image.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Crear_plantilla_HTML_mp4_to_image.txt
# SSL_Cert_Expiry__Python.json
# --------
# ['python', 'json2text.py', 'SSL_Cert_Expiry__Python.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/SSL_Cert_Expiry__Python.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/SSL_Cert_Expiry__Python.txt
# Upload_and_Apply_Text.json
# --------
# ['python', 'json2text.py', 'Upload_and_Apply_Text.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Upload_and_Apply_Text.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Upload_and_Apply_Text.txt
# Screen_and_Audio_Capture.json
# --------
# ['python', 'json2text.py', 'Screen_and_Audio_Capture.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Screen_and_Audio_Capture.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Screen_and_Audio_Capture.txt
# Fixing_Audio_Buffer_Overflow.json
# --------
# ['python', 'json2text.py', 'Fixing_Audio_Buffer_Overflow.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fixing_Audio_Buffer_Overflow.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fixing_Audio_Buffer_Overflow.txt
# Fixing_Large_Files_Issue.json
# --------
# ['python', 'json2text.py', 'Fixing_Large_Files_Issue.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fixing_Large_Files_Issue.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fixing_Large_Files_Issue.txt
# Random_MP3_Selection_Bash.json
# --------
# ['python', 'json2text.py', 'Random_MP3_Selection_Bash.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Random_MP3_Selection_Bash.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Random_MP3_Selection_Bash.txt
# Image_to_Video_Conversion.json
# --------
# ['python', 'json2text.py', 'Image_to_Video_Conversion.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Image_to_Video_Conversion.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Image_to_Video_Conversion.txt
# LuaRocks_Install_NN-Spec.json
# --------
# ['python', 'json2text.py', 'LuaRocks_Install_NN-Spec.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/LuaRocks_Install_NN-Spec.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/LuaRocks_Install_NN-Spec.txt
# LAN_Directory_Serving_Script.json
# --------
# ['python', 'json2text.py', 'LAN_Directory_Serving_Script.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/LAN_Directory_Serving_Script.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/LAN_Directory_Serving_Script.txt
# FFMPEG_video_with_frame___music.json
# --------
# ['python', 'json2text.py', 'FFMPEG_video_with_frame___music.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFMPEG_video_with_frame___music.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/FFMPEG_video_with_frame___music.txt
# Stream_Speakers___Desktop.json
# --------
# ['python', 'json2text.py', 'Stream_Speakers___Desktop.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Stream_Speakers___Desktop.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Stream_Speakers___Desktop.txt
# Rebuild_Linux_Thumbnails_Cache.json
# --------
# ['python', 'json2text.py', 'Rebuild_Linux_Thumbnails_Cache.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Rebuild_Linux_Thumbnails_Cache.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Rebuild_Linux_Thumbnails_Cache.txt
# Fix_Git_Push_Error.json
# --------
# ['python', 'json2text.py', 'Fix_Git_Push_Error.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fix_Git_Push_Error.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fix_Git_Push_Error.txt
# Sticky_Header_Code.json
# --------
# ['python', 'json2text.py', 'Sticky_Header_Code.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Sticky_Header_Code.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Sticky_Header_Code.txt
# Update_Protobuf_Code_Version.json
# --------
# ['python', 'json2text.py', 'Update_Protobuf_Code_Version.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Update_Protobuf_Code_Version.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Update_Protobuf_Code_Version.txt
# PDF_to_PNG_Converter.json
# --------
# ['python', 'json2text.py', 'PDF_to_PNG_Converter.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/PDF_to_PNG_Converter.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/PDF_to_PNG_Converter.txt
# High_Disk_Activity_Issue.json
# --------
# ['python', 'json2text.py', 'High_Disk_Activity_Issue.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/High_Disk_Activity_Issue.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/High_Disk_Activity_Issue.txt
# Play_MP3.json
# --------
# ['python', 'json2text.py', 'Play_MP3.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Play_MP3.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Play_MP3.txt
# Flask_MP4_Route_Setup.json
# --------
# ['python', 'json2text.py', 'Flask_MP4_Route_Setup.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_MP4_Route_Setup.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_MP4_Route_Setup.txt
# Create_GIFS.mp4.json
# --------
# ['python', 'json2text.py', 'Create_GIFS.mp4.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_GIFS.mp4.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Create_GIFS.mp4.txt
# Arcanian_AI_s_Transformative_Influence.json
# --------
# ['python', 'json2text.py', 'Arcanian_AI_s_Transformative_Influence.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Arcanian_AI_s_Transformative_Influence.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Arcanian_AI_s_Transformative_Influence.txt
# Capture_Screen_with_Offset.json
# --------
# ['python', 'json2text.py', 'Capture_Screen_with_Offset.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Capture_Screen_with_Offset.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Capture_Screen_with_Offset.txt
# Whiplash_Curves_in_Art.json
# --------
# ['python', 'json2text.py', 'Whiplash_Curves_in_Art.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Whiplash_Curves_in_Art.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Whiplash_Curves_in_Art.txt
# Segmenting_Video_Frames.json
# --------
# ['python', 'json2text.py', 'Segmenting_Video_Frames.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Segmenting_Video_Frames.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Segmenting_Video_Frames.txt
# Video_Overlay_Not_Working.json
# --------
# ['python', 'json2text.py', 'Video_Overlay_Not_Working.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Overlay_Not_Working.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Video_Overlay_Not_Working.txt
# ClamAV_Freshclam_Log_Error.json
# --------
# ['python', 'json2text.py', 'ClamAV_Freshclam_Log_Error.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/ClamAV_Freshclam_Log_Error.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/ClamAV_Freshclam_Log_Error.txt
# Doll_in_Dystopian_Decay.json
# --------
# ['python', 'json2text.py', 'Doll_in_Dystopian_Decay.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Doll_in_Dystopian_Decay.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Doll_in_Dystopian_Decay.txt
# Scroll_Image_to_Video.json
# --------
# ['python', 'json2text.py', 'Scroll_Image_to_Video.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Scroll_Image_to_Video.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Scroll_Image_to_Video.txt
# Unione_video_MP4_con_transizione.json
# --------
# ['python', 'json2text.py', 'Unione_video_MP4_con_transizione.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Unione_video_MP4_con_transizione.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Unione_video_MP4_con_transizione.txt
# FFmpeg_Remove_Duplicate_Frames.json
# --------
# ['python', 'json2text.py', 'FFmpeg_Remove_Duplicate_Frames.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFmpeg_Remove_Duplicate_Frames.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/FFmpeg_Remove_Duplicate_Frames.txt
# Code_Indentation_Fixed.json
# --------
# ['python', 'json2text.py', 'Code_Indentation_Fixed.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Code_Indentation_Fixed.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Code_Indentation_Fixed.txt
# Bash_Completions_using_Python.json
# --------
# ['python', 'json2text.py', 'Bash_Completions_using_Python.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Bash_Completions_using_Python.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Bash_Completions_using_Python.txt
# Replace_Spaces_with_Underscores.json
# --------
# ['python', 'json2text.py', 'Replace_Spaces_with_Underscores.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Replace_Spaces_with_Underscores.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Replace_Spaces_with_Underscores.txt
# Configurar_servidor_Apache_local.json
# --------
# ['python', 'json2text.py', 'Configurar_servidor_Apache_local.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Configurar_servidor_Apache_local.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Configurar_servidor_Apache_local.txt
# cp_directory_without_overwrite.json
# --------
# ['python', 'json2text.py', 'cp_directory_without_overwrite.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/cp_directory_without_overwrite.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/cp_directory_without_overwrite.txt
# MP3_Joining_Issue_Troubleshooting.json
# --------
# ['python', 'json2text.py', 'MP3_Joining_Issue_Troubleshooting.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/MP3_Joining_Issue_Troubleshooting.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/MP3_Joining_Issue_Troubleshooting.txt
# CUDA_Library_Missing_Error.json
# --------
# ['python', 'json2text.py', 'CUDA_Library_Missing_Error.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/CUDA_Library_Missing_Error.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/CUDA_Library_Missing_Error.txt
# Check_Directory_for_Duplicates.json
# --------
# ['python', 'json2text.py', 'Check_Directory_for_Duplicates.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Check_Directory_for_Duplicates.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Check_Directory_for_Duplicates.txt
# Inference_Error__mel___Function.json
# --------
# ['python', 'json2text.py', 'Inference_Error__mel___Function.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Inference_Error__mel___Function.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Inference_Error__mel___Function.txt
# Crear_imagen_colores_primarios.json
# --------
# ['python', 'json2text.py', 'Crear_imagen_colores_primarios.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Crear_imagen_colores_primarios.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Crear_imagen_colores_primarios.txt
# FFMPEG_Create_Shuffled_Video.json
# --------
# ['python', 'json2text.py', 'FFMPEG_Create_Shuffled_Video.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFMPEG_Create_Shuffled_Video.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/FFMPEG_Create_Shuffled_Video.txt
# Flask-SQLAlchemy_Version_Mismatch..json
# --------
# ['python', 'json2text.py', 'Flask-SQLAlchemy_Version_Mismatch..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask-SQLAlchemy_Version_Mismatch..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask-SQLAlchemy_Version_Mismatch..txt
# Shuffled_Image_Zoom.json
# --------
# ['python', 'json2text.py', 'Shuffled_Image_Zoom.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Shuffled_Image_Zoom.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Shuffled_Image_Zoom.txt
# AI_s_Arcanis_Intervention.json
# --------
# ['python', 'json2text.py', 'AI_s_Arcanis_Intervention.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/AI_s_Arcanis_Intervention.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/AI_s_Arcanis_Intervention.txt
# Rsync_Syncs_and_Overwrites.json
# --------
# ['python', 'json2text.py', 'Rsync_Syncs_and_Overwrites.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Rsync_Syncs_and_Overwrites.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Rsync_Syncs_and_Overwrites.txt
# Flask_Logging_Setup_Guide.json
# --------
# ['python', 'json2text.py', 'Flask_Logging_Setup_Guide.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Logging_Setup_Guide.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Logging_Setup_Guide.txt
# Activate_Virtual_Environment.json
# --------
# ['python', 'json2text.py', 'Activate_Virtual_Environment.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Activate_Virtual_Environment.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Activate_Virtual_Environment.txt
# Install_R_on_Linux.json
# --------
# ['python', 'json2text.py', 'Install_R_on_Linux.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Install_R_on_Linux.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Install_R_on_Linux.txt
# Video_Duration_Adjustment.json
# --------
# ['python', 'json2text.py', 'Video_Duration_Adjustment.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Duration_Adjustment.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Video_Duration_Adjustment.txt
# Overlay_Video_with_Colorchrome.json
# --------
# ['python', 'json2text.py', 'Overlay_Video_with_Colorchrome.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Overlay_Video_with_Colorchrome.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Overlay_Video_with_Colorchrome.txt
# Unione_video_MP4_0.25s.json
# --------
# ['python', 'json2text.py', 'Unione_video_MP4_0.25s.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Unione_video_MP4_0.25s.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Unione_video_MP4_0.25s.txt
# Programming_Joke__Light_vs_Bugs.json
# --------
# ['python', 'json2text.py', 'Programming_Joke__Light_vs_Bugs.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Programming_Joke__Light_vs_Bugs.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Programming_Joke__Light_vs_Bugs.txt
# Expressive_Flora_Still_Life.json
# --------
# ['python', 'json2text.py', 'Expressive_Flora_Still_Life.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Expressive_Flora_Still_Life.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Expressive_Flora_Still_Life.txt
# Dynamic_Directory_for_mkblend_videos.json
# --------
# ['python', 'json2text.py', 'Dynamic_Directory_for_mkblend_videos.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Dynamic_Directory_for_mkblend_videos.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Dynamic_Directory_for_mkblend_videos.txt
# PDF_to_PNG_Conversion.json
# --------
# ['python', 'json2text.py', 'PDF_to_PNG_Conversion.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/PDF_to_PNG_Conversion.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/PDF_to_PNG_Conversion.txt
# Add_JPG_and_PNG.json
# --------
# ['python', 'json2text.py', 'Add_JPG_and_PNG.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Add_JPG_and_PNG.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Add_JPG_and_PNG.txt
# AI__Wonder_or_Monster?.json
# --------
# ['python', 'json2text.py', 'AI__Wonder_or_Monster?.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/AI__Wonder_or_Monster?.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/AI__Wonder_or_Monster?.txt
# Python_Image_Processing_Code.json
# --------
# ['python', 'json2text.py', 'Python_Image_Processing_Code.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Python_Image_Processing_Code.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Python_Image_Processing_Code.txt
# Caregivers__Organized,_Efficient,_Communicative.json
# --------
# ['python', 'json2text.py', 'Caregivers__Organized,_Efficient,_Communicative.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Caregivers__Organized,_Efficient,_Communicative.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Caregivers__Organized,_Efficient,_Communicative.txt
# Aliens___AI_Speculation.json
# --------
# ['python', 'json2text.py', 'Aliens___AI_Speculation.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Aliens___AI_Speculation.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Aliens___AI_Speculation.txt
# Random_MP3_Clips_Concatenation.json
# --------
# ['python', 'json2text.py', 'Random_MP3_Clips_Concatenation.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Random_MP3_Clips_Concatenation.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Random_MP3_Clips_Concatenation.txt
# ChatGPT,_Conversations.json_Overview.json
# --------
# ['python', 'json2text.py', 'ChatGPT,_Conversations.json_Overview.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/ChatGPT,_Conversations.json_Overview.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/ChatGPT,_Conversations.json_Overview.txt
# Convert_audio_to_video.json
# --------
# ['python', 'json2text.py', 'Convert_audio_to_video.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Convert_audio_to_video.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Convert_audio_to_video.txt
# Flask_Template_HTML_Setup.json
# --------
# ['python', 'json2text.py', 'Flask_Template_HTML_Setup.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Template_HTML_Setup.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Template_HTML_Setup.txt
# MP3_to_WAV_Conversion.json
# --------
# ['python', 'json2text.py', 'MP3_to_WAV_Conversion.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/MP3_to_WAV_Conversion.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/MP3_to_WAV_Conversion.txt
# Module_Import_Error_Fix.json
# --------
# ['python', 'json2text.py', 'Module_Import_Error_Fix.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Module_Import_Error_Fix.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Module_Import_Error_Fix.txt
# Flask_App_Code_Review.json
# --------
# ['python', 'json2text.py', 'Flask_App_Code_Review.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Code_Review.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_App_Code_Review.txt
# Flask_Code_Review.json
# --------
# ['python', 'json2text.py', 'Flask_Code_Review.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Code_Review.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Code_Review.txt
# Flask_HTML_Template_Example.json
# --------
# ['python', 'json2text.py', 'Flask_HTML_Template_Example.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_HTML_Template_Example.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_HTML_Template_Example.txt
# Open_Jupyter_Notebook_Over_LAN.json
# --------
# ['python', 'json2text.py', 'Open_Jupyter_Notebook_Over_LAN.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Open_Jupyter_Notebook_Over_LAN.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Open_Jupyter_Notebook_Over_LAN.txt
# List_Directories_with__ls_.json
# --------
# ['python', 'json2text.py', 'List_Directories_with__ls_.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/List_Directories_with__ls_.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/List_Directories_with__ls_.txt
# Create_Video_from_Images.json
# --------
# ['python', 'json2text.py', 'Create_Video_from_Images.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_Video_from_Images.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Create_Video_from_Images.txt
# Linux_Find_Modified_Images.json
# --------
# ['python', 'json2text.py', 'Linux_Find_Modified_Images.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Linux_Find_Modified_Images.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Linux_Find_Modified_Images.txt
# Install_pyttsx3_module..json
# --------
# ['python', 'json2text.py', 'Install_pyttsx3_module..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Install_pyttsx3_module..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Install_pyttsx3_module..txt
# Name__Esperanza.json
# --------
# ['python', 'json2text.py', 'Name__Esperanza.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Name__Esperanza.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Name__Esperanza.txt
# SSD_Maintenance__Trim_Frequency.json
# --------
# ['python', 'json2text.py', 'SSD_Maintenance__Trim_Frequency.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/SSD_Maintenance__Trim_Frequency.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/SSD_Maintenance__Trim_Frequency.txt
# Copy_File_with_shutil.json
# --------
# ['python', 'json2text.py', 'Copy_File_with_shutil.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Copy_File_with_shutil.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Copy_File_with_shutil.txt
# Comic_Panel_Layout_CSS.json
# --------
# ['python', 'json2text.py', 'Comic_Panel_Layout_CSS.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Comic_Panel_Layout_CSS.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Comic_Panel_Layout_CSS.txt
# GIFs_to_MP4.json
# --------
# ['python', 'json2text.py', 'GIFs_to_MP4.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/GIFs_to_MP4.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/GIFs_to_MP4.txt
# SSH_to_Specific_Directory.json
# --------
# ['python', 'json2text.py', 'SSH_to_Specific_Directory.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/SSH_to_Specific_Directory.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/SSH_to_Specific_Directory.txt
# Flask_App_on_LAN.json
# --------
# ['python', 'json2text.py', 'Flask_App_on_LAN.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_on_LAN.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_App_on_LAN.txt
# Reinstall_XWin_on_Linux..json
# --------
# ['python', 'json2text.py', 'Reinstall_XWin_on_Linux..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Reinstall_XWin_on_Linux..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Reinstall_XWin_on_Linux..txt
# Refrigerate_ketchup_after_opening..json
# --------
# ['python', 'json2text.py', 'Refrigerate_ketchup_after_opening..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Refrigerate_ketchup_after_opening..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Refrigerate_ketchup_after_opening..txt
# Subprocess_Firefox_HTML_Execution.json
# --------
# ['python', 'json2text.py', 'Subprocess_Firefox_HTML_Execution.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Subprocess_Firefox_HTML_Execution.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Subprocess_Firefox_HTML_Execution.txt
# Blend_Image_Video_Creation.json
# --------
# ['python', 'json2text.py', 'Blend_Image_Video_Creation.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Blend_Image_Video_Creation.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Blend_Image_Video_Creation.txt
# Flask_Marquee_Overlay_Video.json
# --------
# ['python', 'json2text.py', 'Flask_Marquee_Overlay_Video.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Marquee_Overlay_Video.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Marquee_Overlay_Video.txt
# Plague_Doctors_and_St._Sebastian.json
# --------
# ['python', 'json2text.py', 'Plague_Doctors_and_St._Sebastian.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Plague_Doctors_and_St._Sebastian.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Plague_Doctors_and_St._Sebastian.txt
# Fixing_Code_for_Directory_Processing.json
# --------
# ['python', 'json2text.py', 'Fixing_Code_for_Directory_Processing.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fixing_Code_for_Directory_Processing.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fixing_Code_for_Directory_Processing.txt
# Enhance_Image_with_OpenCV.json
# --------
# ['python', 'json2text.py', 'Enhance_Image_with_OpenCV.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Enhance_Image_with_OpenCV.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Enhance_Image_with_OpenCV.txt
# Video_Conversion_with_Fades.json
# --------
# ['python', 'json2text.py', 'Video_Conversion_with_Fades.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Conversion_with_Fades.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Video_Conversion_with_Fades.txt
# Wget_File_Download.json
# --------
# ['python', 'json2text.py', 'Wget_File_Download.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Wget_File_Download.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Wget_File_Download.txt
# Feather_Image_with_Python.json
# --------
# ['python', 'json2text.py', 'Feather_Image_with_Python.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Feather_Image_with_Python.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Feather_Image_with_Python.txt
# Explain_script_in_detail..json
# --------
# ['python', 'json2text.py', 'Explain_script_in_detail..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Explain_script_in_detail..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Explain_script_in_detail..txt
# API_v0xF_-_Unknown_Version.json
# --------
# ['python', 'json2text.py', 'API_v0xF_-_Unknown_Version.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/API_v0xF_-_Unknown_Version.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/API_v0xF_-_Unknown_Version.txt
# Flask_FFmpeg_Command_Integration.json
# --------
# ['python', 'json2text.py', 'Flask_FFmpeg_Command_Integration.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_FFmpeg_Command_Integration.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_FFmpeg_Command_Integration.txt
# Flask_Video_Generator_Function.json
# --------
# ['python', 'json2text.py', 'Flask_Video_Generator_Function.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Video_Generator_Function.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Video_Generator_Function.txt
# Python___Flask_Enthusiasts.json
# --------
# ['python', 'json2text.py', 'Python___Flask_Enthusiasts.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Python___Flask_Enthusiasts.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Python___Flask_Enthusiasts.txt
# Flask_for_Existing_HTML.json
# --------
# ['python', 'json2text.py', 'Flask_for_Existing_HTML.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_for_Existing_HTML.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_for_Existing_HTML.txt
# Get_Image_Size.json
# --------
# ['python', 'json2text.py', 'Get_Image_Size.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Get_Image_Size.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Get_Image_Size.txt
# Male_voice_for_Google_TTS.json
# --------
# ['python', 'json2text.py', 'Male_voice_for_Google_TTS.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Male_voice_for_Google_TTS.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Male_voice_for_Google_TTS.txt
# Image-to-Video_Conversion.json
# --------
# ['python', 'json2text.py', 'Image-to-Video_Conversion.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Image-to-Video_Conversion.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Image-to-Video_Conversion.txt
# Custom_Instructions_Understood.json
# --------
# ['python', 'json2text.py', 'Custom_Instructions_Understood.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Custom_Instructions_Understood.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Custom_Instructions_Understood.txt
# Wonderland_Characters_Summary.json
# --------
# ['python', 'json2text.py', 'Wonderland_Characters_Summary.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Wonderland_Characters_Summary.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Wonderland_Characters_Summary.txt
# Python_Save_File.json
# --------
# ['python', 'json2text.py', 'Python_Save_File.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Python_Save_File.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Python_Save_File.txt
# Linux__Force_Thumbnail_Regeneration.json
# --------
# ['python', 'json2text.py', 'Linux__Force_Thumbnail_Regeneration.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Linux__Force_Thumbnail_Regeneration.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Linux__Force_Thumbnail_Regeneration.txt
# Shuffle_Images_for_Video.json
# --------
# ['python', 'json2text.py', 'Shuffle_Images_for_Video.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Shuffle_Images_for_Video.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Shuffle_Images_for_Video.txt
# Flask_Blueprint_Assistance.json
# --------
# ['python', 'json2text.py', 'Flask_Blueprint_Assistance.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Blueprint_Assistance.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Blueprint_Assistance.txt
# Flask_Video_Processing_Server.json
# --------
# ['python', 'json2text.py', 'Flask_Video_Processing_Server.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Video_Processing_Server.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Video_Processing_Server.txt
# FFmpeg_Zoom_Video_Fix.json
# ...
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/JACK_Audio_Connection_Issue.txt
# Disable_all_extensions.json
# --------
# ['python', 'json2text.py', 'Disable_all_extensions.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Disable_all_extensions.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Disable_all_extensions.txt
# FFmpeg_Resize_Video.json
# --------
# ['python', 'json2text.py', 'FFmpeg_Resize_Video.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFmpeg_Resize_Video.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/FFmpeg_Resize_Video.txt
# Auto-looping_1s_Slideshow_Code.json
# --------
# ['python', 'json2text.py', 'Auto-looping_1s_Slideshow_Code.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Auto-looping_1s_Slideshow_Code.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Auto-looping_1s_Slideshow_Code.txt
# Sticky_Header_for_Website.json
# --------
# ['python', 'json2text.py', 'Sticky_Header_for_Website.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Sticky_Header_for_Website.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Sticky_Header_for_Website.txt
# Starting_Over?.json
# --------
# ['python', 'json2text.py', 'Starting_Over?.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Starting_Over?.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Starting_Over?.txt
# Clickable_Links_in_HTML.json
# --------
# ['python', 'json2text.py', 'Clickable_Links_in_HTML.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Clickable_Links_in_HTML.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Clickable_Links_in_HTML.txt
# Create_Video_with_Text.json
# --------
# ['python', 'json2text.py', 'Create_Video_with_Text.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_Video_with_Text.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Create_Video_with_Text.txt
# MoviePy_for_Image_Videos.json
# --------
# ['python', 'json2text.py', 'MoviePy_for_Image_Videos.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/MoviePy_for_Image_Videos.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/MoviePy_for_Image_Videos.txt
# Flask_Video_Thumbnail_App.json
# --------
# ['python', 'json2text.py', 'Flask_Video_Thumbnail_App.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Video_Thumbnail_App.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Video_Thumbnail_App.txt
# Flask__Request_and_Save..json
# --------
# ['python', 'json2text.py', 'Flask__Request_and_Save..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask__Request_and_Save..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask__Request_and_Save..txt
# YouTube_2nd_Channel_Automator.json
# --------
# ['python', 'json2text.py', 'YouTube_2nd_Channel_Automator.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/YouTube_2nd_Channel_Automator.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/YouTube_2nd_Channel_Automator.txt
# Arcanis_AI_Communication.json
# --------
# ['python', 'json2text.py', 'Arcanis_AI_Communication.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Arcanis_AI_Communication.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Arcanis_AI_Communication.txt
# FFMPEG_Video_Slowdown..json
# --------
# ['python', 'json2text.py', 'FFMPEG_Video_Slowdown..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFMPEG_Video_Slowdown..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/FFMPEG_Video_Slowdown..txt
# Load_index.html_in_Flask.json
# --------
# ['python', 'json2text.py', 'Load_index.html_in_Flask.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Load_index.html_in_Flask.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Load_index.html_in_Flask.txt
# Fade_Transition_Video_Script.json
# --------
# ['python', 'json2text.py', 'Fade_Transition_Video_Script.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fade_Transition_Video_Script.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fade_Transition_Video_Script.txt
# Generate___Save_PNG_Plot.json
# --------
# ['python', 'json2text.py', 'Generate___Save_PNG_Plot.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Generate___Save_PNG_Plot.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Generate___Save_PNG_Plot.txt
# AI_s_Leap_in_2021.json
# --------
# ['python', 'json2text.py', 'AI_s_Leap_in_2021.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/AI_s_Leap_in_2021.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/AI_s_Leap_in_2021.txt
# Flask_Video_Selection_Script.json
# --------
# ['python', 'json2text.py', 'Flask_Video_Selection_Script.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Video_Selection_Script.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Video_Selection_Script.txt
# Check_Image_Duplicates_with_Hashes.json
# --------
# ['python', 'json2text.py', 'Check_Image_Duplicates_with_Hashes.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Check_Image_Duplicates_with_Hashes.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Check_Image_Duplicates_with_Hashes.txt
# Kill_Process_on_Port.json
# --------
# ['python', 'json2text.py', 'Kill_Process_on_Port.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Kill_Process_on_Port.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Kill_Process_on_Port.txt
# Flask_Async_Endpoints.json
# --------
# ['python', 'json2text.py', 'Flask_Async_Endpoints.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Async_Endpoints.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Async_Endpoints.txt
# Anunnaki_Overview.json
# --------
# ['python', 'json2text.py', 'Anunnaki_Overview.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Anunnaki_Overview.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Anunnaki_Overview.txt
# Flask_App_Setup.json
# --------
# ['python', 'json2text.py', 'Flask_App_Setup.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Setup.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_App_Setup.txt
# Avatar_AI_for_Talking.json
# --------
# ['python', 'json2text.py', 'Avatar_AI_for_Talking.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Avatar_AI_for_Talking.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Avatar_AI_for_Talking.txt
# Delete_Files_Except__.jpg.json
# --------
# ['python', 'json2text.py', 'Delete_Files_Except__.jpg.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Delete_Files_Except__.jpg.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Delete_Files_Except__.jpg.txt
# Fail2Ban_Installation_for_Security.json
# --------
# ['python', 'json2text.py', 'Fail2Ban_Installation_for_Security.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fail2Ban_Installation_for_Security.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fail2Ban_Installation_for_Security.txt
# Set_Hard_Drive_Permissions.json
# --------
# ['python', 'json2text.py', 'Set_Hard_Drive_Permissions.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Set_Hard_Drive_Permissions.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Set_Hard_Drive_Permissions.txt
# LAN_PHP_Server_Setup.json
# --------
# ['python', 'json2text.py', 'LAN_PHP_Server_Setup.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/LAN_PHP_Server_Setup.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/LAN_PHP_Server_Setup.txt
# Crear_video_con_transiciones..json
# --------
# ['python', 'json2text.py', 'Crear_video_con_transiciones..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Crear_video_con_transiciones..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Crear_video_con_transiciones..txt
# Cosmic_Octopus_AI_Awakening.json
# --------
# ['python', 'json2text.py', 'Cosmic_Octopus_AI_Awakening.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Cosmic_Octopus_AI_Awakening.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Cosmic_Octopus_AI_Awakening.txt
# Install_Wine_Mono_Linux.json
# --------
# ['python', 'json2text.py', 'Install_Wine_Mono_Linux.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Install_Wine_Mono_Linux.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Install_Wine_Mono_Linux.txt
# Save_DuckDuckGo_Results_JSON.json
# --------
# ['python', 'json2text.py', 'Save_DuckDuckGo_Results_JSON.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Save_DuckDuckGo_Results_JSON.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Save_DuckDuckGo_Results_JSON.txt
# Linux_Terminal_Issue.json
# --------
# ['python', 'json2text.py', 'Linux_Terminal_Issue.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Linux_Terminal_Issue.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Linux_Terminal_Issue.txt
# GPT_API_Key_Access.json
# --------
# ['python', 'json2text.py', 'GPT_API_Key_Access.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/GPT_API_Key_Access.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/GPT_API_Key_Access.txt
# Convert_JSON_to_HTML.json
# --------
# ['python', 'json2text.py', 'Convert_JSON_to_HTML.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Convert_JSON_to_HTML.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Convert_JSON_to_HTML.txt
# Selecting_Image_Directory.json
# --------
# ['python', 'json2text.py', 'Selecting_Image_Directory.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Selecting_Image_Directory.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Selecting_Image_Directory.txt
# Flask_Programmer_and_YouTuber.json
# --------
# ['python', 'json2text.py', 'Flask_Programmer_and_YouTuber.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Programmer_and_YouTuber.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Programmer_and_YouTuber.txt
# Adjust_Duration_for_Longer.json
# --------
# ['python', 'json2text.py', 'Adjust_Duration_for_Longer.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Adjust_Duration_for_Longer.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Adjust_Duration_for_Longer.txt
# HTML_Conversion_Debugging.json
# --------
# ['python', 'json2text.py', 'HTML_Conversion_Debugging.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/HTML_Conversion_Debugging.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/HTML_Conversion_Debugging.txt
# Set_Up_LAN_Server__Python_.json
# --------
# ['python', 'json2text.py', 'Set_Up_LAN_Server__Python_.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Set_Up_LAN_Server__Python_.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Set_Up_LAN_Server__Python_.txt
# Upload_file_from_directory.json
# --------
# ['python', 'json2text.py', 'Upload_file_from_directory.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Upload_file_from_directory.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Upload_file_from_directory.txt
# Python_HTTP_Server_Guide.json
# --------
# ['python', 'json2text.py', 'Python_HTTP_Server_Guide.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Python_HTTP_Server_Guide.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Python_HTTP_Server_Guide.txt
# Lighten_Image_with_Mogrify.json
# --------
# ['python', 'json2text.py', 'Lighten_Image_with_Mogrify.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Lighten_Image_with_Mogrify.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Lighten_Image_with_Mogrify.txt
# Video_Making_Script_with_Logging.json
# --------
# ['python', 'json2text.py', 'Video_Making_Script_with_Logging.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Making_Script_with_Logging.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Video_Making_Script_with_Logging.txt
# Combine_Image_and_Audio.json
# --------
# ['python', 'json2text.py', 'Combine_Image_and_Audio.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Combine_Image_and_Audio.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Combine_Image_and_Audio.txt
# Change_Outline_Color.json
# --------
# ['python', 'json2text.py', 'Change_Outline_Color.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Change_Outline_Color.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Change_Outline_Color.txt
# Video_Processing__512x768_Resolution.json
# --------
# ['python', 'json2text.py', 'Video_Processing__512x768_Resolution.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Processing__512x768_Resolution.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Video_Processing__512x768_Resolution.txt
# Correção_da_Rota_"join_sound".json
# --------
# ['python', 'json2text.py', 'Correção_da_Rota_"join_sound".json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Correção_da_Rota_"join_sound".json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Correção_da_Rota_"join_sound".txt
# Flask_Open___View_Text.json
# --------
# ['python', 'json2text.py', 'Flask_Open___View_Text.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Open___View_Text.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Open___View_Text.txt
# Flask_AttributeError_Troubleshooting.json
# --------
# ['python', 'json2text.py', 'Flask_AttributeError_Troubleshooting.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_AttributeError_Troubleshooting.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_AttributeError_Troubleshooting.txt
# Bash_Locate_in_Python.json
# --------
# ['python', 'json2text.py', 'Bash_Locate_in_Python.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Bash_Locate_in_Python.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Bash_Locate_in_Python.txt
# Save_Plots_with_UUIDs.json
# --------
# ['python', 'json2text.py', 'Save_Plots_with_UUIDs.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Save_Plots_with_UUIDs.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Save_Plots_with_UUIDs.txt
# Movies_with_Punch.json
# --------
# ['python', 'json2text.py', 'Movies_with_Punch.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Movies_with_Punch.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Movies_with_Punch.txt

# %%
import json
import logging
import os

def split_and_save_conversations(conversations_file, output_folder):
    try:
        with open(conversations_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
            
            for conversation in data:
                title = conversation.get('title', 'Unknown_Title')
                title_with_underscores = title.replace(' ', '_')
                title_with_underscores = title_with_underscores.replace(':','_')
                title_with_underscores = title_with_underscores.replace("'","_")
                title_with_underscores = title_with_underscores.replace("&","_")
                title_with_underscores = title_with_underscores.replace("*","_")
                title_with_underscores = title_with_underscores.replace("(","_")
                title_with_underscores = title_with_underscores.replace(")","_")
                chapter_filename = f"{title_with_underscores}.json"
                chapter_filepath = os.path.join(output_folder, chapter_filename)
                
                logging.info(f"Saving data for conversation '{title}' to {chapter_filepath}")
                
                with open(chapter_filepath, 'w', encoding='utf-8') as chapter_file:
                    json.dump([conversation], chapter_file, indent=2)

    except FileNotFoundError:
        logging.error(f"File not found: {conversations_file}")
    except json.JSONDecodeError:
        logging.error(f"Error decoding JSON in file: {conversations_file}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {e}")

# Example usage
conversations_file_path = 'CHATDPT/conversations.json'
output_folder = 'CHATDPT/individual_sessions'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Configure logging
logging.basicConfig(level=logging.INFO)

# Call the split and save function
split_and_save_conversations(conversations_file_path, output_folder)

# %%
# !rm -r CHATDPT/individual_sessions

# %%
# !ls CHATDPT/individual_sessions

# %%
# %%writefile json2html.py
#!/home/jack/miniconda3/envs/cloned_base/bin/python
import json
import os
from sys import argv
# Load the JSON data from the uploaded file
DIR=os.getcwd()+"/CHATGPT/individual_sessions/"
DIR_html=os.getcwd()+"/CHATGPT/html"
# Ensure the output folder exists
os.makedirs(DIR_html, exist_ok=True)
filename=argv[1]
Filename = DIR+filename
print(Filename)
with open(Filename, 'r') as file:
    json_data = json.load(file)

# Initialize the result string
result_str = ""

# Define a function to get conversation messages similar to the JavaScript logic
def get_conversation_messages(conversation):
    messages = []
    current_node = conversation.get('current_node')
    while current_node:
        node = conversation['mapping'][current_node]
        message = node.get('message')
        if (message and message.get('content') and message['content'].get('content_type') == 'text' and
            len(message['content'].get('parts', [])) > 0 and len(message['content']['parts'][0]) > 0 and
                (message['author']['role'] != 'system' or message.get('metadata', {}).get('is_user_system_message'))):
            author = message['author']['role']
            if author == 'assistant':
                author = 'ChatGPT'
            elif author == 'system' and message['metadata'].get('is_user_system_message'):
                author = 'Custom user info'
            messages.append({'author': author, 'text': message['content']['parts'][0]})
        current_node = node.get('parent')
    return messages[::-1]  # Reverse the list to maintain chronological order

# Iterate over each conversation in the JSON data and process it
for conversation in json_data:
    # Get the conversation title and messages
    title = conversation.get('title', '')
    messages = get_conversation_messages(conversation)

    # Append the title and messages to the result string
    result_str += title + '\n'
    for message in messages:
        result_str += message['author'] + '\n' + message['text'] + '\n'
    result_str += '\n'  # Add a newline between conversations

# Return the processed result string
#print(result_str.strip())
HTMLfile=DIR_html+"/"+filename[:-4]+"html"
print("HTMLfile: ",HTMLfile)
Input = open(HTMLfile,"w")
result_str = result_str.replace("/n","XXXXXXX\n")
result_str = result_str.replace("<","&lt;")
result_str = result_str.replace(">","&gt;")
for line in result_str.split("XXXXXXX"):
    line = line.replace("\n","<br />\n")
    Input.write(line)
Input.close()
# Out:
# Overwriting json2html.py

# %%
# !./json2html.py Generate_and_Save_PNG_Plot.json

# %%
# !firefox CHATDPT/html/Flask_Marquee_Overlay_Video.html

# %%
/home/jack/Desktop/flask_conversations/CHATDPT/individual_sessions/Generate_and_Save_PNG_Plot.json

# %%
# !ls /home/jack/Desktop/flask_conversations2/CHATDPT/chapters_indexed/Generate_and_Save_PNG_Plot.json

# %%
import glob
import subprocess

files = glob.glob("CHATDPT/individual_sessions/*.json")

for file in files:
    file_name = file.split('/')[-1]
    #cmd = ["./json2html.py", file_name]
    
    # Use subprocess.run without terminal=True
    #subprocess.run(cmd)

    print(file_name)
# Out:
# FFmpeg_Slideshow_with_Transitions.json
# Fixing_Flask_Screen_Capture.json
# Flask_Thumbnail_Video.json
# PHP_Execute_Bash_Script.json
# Prevent_inherit_text-align..json
# Fixing_PyQt5_Dependency_Error.json
# Update_SQLite_Permissions.json
# CSS_Logo_Placement.json
# Video_Clips_with_Sound.json
# Video_Generation_from_Directories..json
# Create_3D_Image_Transitions.json
# New_chat.json
# Flask_App_Conversion.json
# Python_Punctuation_Removal.json
# Flask_App_Demo___Explanation.json
# NoCache_pip_Install..json
# Snap_Certbot_Installation_Issue.json
# Nietzsche_s_views_on_death..json
# Remove_Python_Path.json
# Xterm_Display_Error_Troubleshoot.json
# Video_Editing_with_MoviePy.json
# Random_Desktop_Video_Clips.json
# FlaskWebGui_Debug_Mode.json
# Run_Kdenlive_Extension_with_Melt.json
# Add_large_file_to_GitHub..json
# Create_Image_Sequence_Video.json
# Fix_Protobuf_Issue.json
# Generate_Unique_Video_Filename.json
# Install_PHP_on_Apache.json
# Crear_videos_con_imágenes..json
# Image_Zoom_Video_Script.json
# FFmpeg_Merge_Video___Audio.json
# Create_Slow_Scroll_Video.json
# Louder_Output_Audio__Adjusting_Volume.json
# Flask_Directory_Viewer.json
# Datetime_Import_Issue.json
# Thunar_Scroll_Issue_Troubleshooting.json
# Fix_favicon_not_found..json
# Flask_Text-to-Speech.json
# Generate_Loopable_Stylized_Images.json
# Mic_Detection_Issue_Troubleshoot.json
# Search_IPYNB_for_Term.json
# Flask_Module_Not_Found.json
# Shell_Command_Argument_Handling.json
# Dystopian_City_Text_Prompt.json
# House_Stark_in_Winter.json
# Choose_Directory__Handle_Selection.json
# Bash_Completion_Python_Script.json
# Crear_plantilla_HTML_mp4_to_image.json
# SSL_Cert_Expiry__Python.json
# Upload_and_Apply_Text.json
# Screen_and_Audio_Capture.json
# Fixing_Audio_Buffer_Overflow.json
# Fixing_Large_Files_Issue.json
# Random_MP3_Selection_Bash.json
# Image_to_Video_Conversion.json
# LuaRocks_Install_NN-Spec.json
# LAN_Directory_Serving_Script.json
# FFMPEG_video_with_frame___music.json
# Stream_Speakers___Desktop.json
# Rebuild_Linux_Thumbnails_Cache.json
# Fix_Git_Push_Error.json
# Sticky_Header_Code.json
# Update_Protobuf_Code_Version.json
# PDF_to_PNG_Converter.json
# High_Disk_Activity_Issue.json
# Play_MP3.json
# Flask_MP4_Route_Setup.json
# Create_GIFS.mp4.json
# Arcanian_AI_s_Transformative_Influence.json
# Capture_Screen_with_Offset.json
# Whiplash_Curves_in_Art.json
# Segmenting_Video_Frames.json
# Video_Overlay_Not_Working.json
# ClamAV_Freshclam_Log_Error.json
# Doll_in_Dystopian_Decay.json
# Scroll_Image_to_Video.json
# Unione_video_MP4_con_transizione.json
# FFmpeg_Remove_Duplicate_Frames.json
# Code_Indentation_Fixed.json
# Bash_Completions_using_Python.json
# Replace_Spaces_with_Underscores.json
# Configurar_servidor_Apache_local.json
# cp_directory_without_overwrite.json
# MP3_Joining_Issue_Troubleshooting.json
# CUDA_Library_Missing_Error.json
# Check_Directory_for_Duplicates.json
# Inference_Error__mel___Function.json
# Crear_imagen_colores_primarios.json
# FFMPEG_Create_Shuffled_Video.json
# Flask-SQLAlchemy_Version_Mismatch..json
# Shuffled_Image_Zoom.json
# AI_s_Arcanis_Intervention.json
# Rsync_Syncs_and_Overwrites.json
# Flask_Logging_Setup_Guide.json
# Activate_Virtual_Environment.json
# Install_R_on_Linux.json
# Video_Duration_Adjustment.json
# Overlay_Video_with_Colorchrome.json
# Unione_video_MP4_0.25s.json
# Programming_Joke__Light_vs_Bugs.json
# Expressive_Flora_Still_Life.json
# Dynamic_Directory_for_mkblend_videos.json
# PDF_to_PNG_Conversion.json
# Add_JPG_and_PNG.json
# AI__Wonder_or_Monster?.json
# Python_Image_Processing_Code.json
# Caregivers__Organized,_Efficient,_Communicative.json
# Aliens___AI_Speculation.json
# Random_MP3_Clips_Concatenation.json
# ChatGPT,_Conversations.json_Overview.json
# Convert_audio_to_video.json
# Flask_Template_HTML_Setup.json
# MP3_to_WAV_Conversion.json
# Module_Import_Error_Fix.json
# Flask_App_Code_Review.json
# Flask_Code_Review.json
# Flask_HTML_Template_Example.json
# Open_Jupyter_Notebook_Over_LAN.json
# List_Directories_with__ls_.json
# Create_Video_from_Images.json
# Linux_Find_Modified_Images.json
# Install_pyttsx3_module..json
# Name__Esperanza.json
# SSD_Maintenance__Trim_Frequency.json
# Copy_File_with_shutil.json
# Comic_Panel_Layout_CSS.json
# GIFs_to_MP4.json
# SSH_to_Specific_Directory.json
# Flask_App_on_LAN.json
# Reinstall_XWin_on_Linux..json
# Refrigerate_ketchup_after_opening..json
# Subprocess_Firefox_HTML_Execution.json
# Blend_Image_Video_Creation.json
# Flask_Marquee_Overlay_Video.json
# Plague_Doctors_and_St._Sebastian.json
# Fixing_Code_for_Directory_Processing.json
# Enhance_Image_with_OpenCV.json
# Video_Conversion_with_Fades.json
# Wget_File_Download.json
# Feather_Image_with_Python.json
# Explain_script_in_detail..json
# API_v0xF_-_Unknown_Version.json
# Flask_FFmpeg_Command_Integration.json
# Flask_Video_Generator_Function.json
# Python___Flask_Enthusiasts.json
# Flask_for_Existing_HTML.json
# Get_Image_Size.json
# Male_voice_for_Google_TTS.json
# Image-to-Video_Conversion.json
# Custom_Instructions_Understood.json
# Wonderland_Characters_Summary.json
# Python_Save_File.json
# Linux__Force_Thumbnail_Regeneration.json
# Shuffle_Images_for_Video.json
# Flask_Blueprint_Assistance.json
# Flask_Video_Processing_Server.json
# FFmpeg_Zoom_Video_Fix.json
# Reinstall_EFC_Desktop.json
# Linux_Find_Largest_Subdirectory.json
# Hardcoded_Args_Parser.json
# MyTube_AI_Videos.json
# AI_Video_Transitions_Mastery.json
# Feathered_Image_Creation.json
# Domain_Info_with_Python.json
# Create_Scrolling_Text_Video.json
# Simple_3D_Scene_Creation.json
# AI_Guides_Animal_Enlightenment.json
# Video_Processing__Frames_Method.json
# Improved_Video_Quality_Settings.json
# Copy_care.mp4_to_VPS.json
# Flask_code_with_logging..json
# Browser_Media_Stream_Issue.json
# Flask__Blank_512x1024.mp4.json
# MP3_File_Joining_Issue.json
# Large_File_Push_Error.json
# Locate_IPYNB_with_Quantify.json
# Capture_Webpage_with_Python.json
# Flask_Installation_Troubleshooting.json
# Count_Python_Code_Lines.json
# Add_Expose_to_Docker_Image.json
# Sudo_cp_file_permissions.json
# Python_3.9_Virtual_Environment.json
# Failed_nn_Installation.json
# Image_files_not_printing..json
# GEGL_Bevel_Compilation_Error.json
# Flask_Video_Selection_Endpoint.json
# Video_Editing_Transitions.json
# Martian_Masterpiece__Surreal_Synthesis.json
# Find_Duplicate_Image_Names.json
# Resizing___Cropping_for_Vertical_Video.json
# Download_Age-Restricted_Video.json
# Linux_Desktop_Missing_Icons.json
# Dynamic_Image_Directory.json
# Arcanis_AI_Enhancing_Earth_s_AI.json
# Doll_Factory_Dystopia.json
# Create_BMP_from_Image.json
# Split_MP4_into_6..json
# Install_OpenCV__cv2_.json
# Convert_FilePath_to_GIF.json
# Fading_Video_Overlay_Fix.json
# Virtual_Environment_Creation_Error.json
# Optimize_SSD_Swap_File.json
# Syntax_Error_Resolved.json
# Crop_Dimensions_Explanation.json
# Add_sound_if_needed..json
# Run__mkgallery__in_subdirectories.json
# Flask_File_Upload_Function.json
# Create_MP4_from_images..json
# Flask_App_with_SQLite3.json
# Concatenation_Error__Parameters_Mismatch.json
# Find___CD__fade-transb.json
# Fix_File_Copying_Error.json
# Select_Random_TTF_Font.json
# Create_Black_Image.json
# Find_File__stacked_videos.json
# KDENLIVE_error_encountered.json
# Image_Resizer_Troubleshooting.json
# Story_Assistance_Available.json
# HEVC_Decoding_Errors.json
# Cancel_Git_Push_Fix.json
# Install_.run_file_on_Linux.json
# Flask_env_Jupyter_Kernel_Setup.json
# MP4_Files_Finder_Script.json
# Video_Flip_Book_Fix.json
# Find_Imported_Module_Source.json
# FFmpeg_Command_Logging_Fix.json
# JACK_Audio_Connection_Issue.json
# Disable_all_extensions.json
# FFmpeg_Resize_Video.json
# Auto-looping_1s_Slideshow_Code.json
# Sticky_Header_for_Website.json
# Starting_Over?.json
# Clickable_Links_in_HTML.json
# Create_Video_with_Text.json
# MoviePy_for_Image_Videos.json
# Flask_Video_Thumbnail_App.json
# Flask__Request_and_Save..json
# YouTube_2nd_Channel_Automator.json
# Arcanis_AI_Communication.json
# FFMPEG_Video_Slowdown..json
# Load_index.html_in_Flask.json
# Fade_Transition_Video_Script.json
# Generate___Save_PNG_Plot.json
# AI_s_Leap_in_2021.json
# Flask_Video_Selection_Script.json
# Check_Image_Duplicates_with_Hashes.json
# Kill_Process_on_Port.json
# Flask_Async_Endpoints.json
# Anunnaki_Overview.json
# Flask_App_Setup.json
# Avatar_AI_for_Talking.json
# Delete_Files_Except__.jpg.json
# Fail2Ban_Installation_for_Security.json
# Set_Hard_Drive_Permissions.json
# LAN_PHP_Server_Setup.json
# Crear_video_con_transiciones..json
# Cosmic_Octopus_AI_Awakening.json
# Install_Wine_Mono_Linux.json
# Save_DuckDuckGo_Results_JSON.json
# Linux_Terminal_Issue.json
# GPT_API_Key_Access.json
# Convert_JSON_to_HTML.json
# Selecting_Image_Directory.json
# Flask_Programmer_and_YouTuber.json
# Adjust_Duration_for_Longer.json
# HTML_Conversion_Debugging.json
# Set_Up_LAN_Server__Python_.json
# Upload_file_from_directory.json
# Python_HTTP_Server_Guide.json
# Lighten_Image_with_Mogrify.json
# Video_Making_Script_with_Logging.json
# Combine_Image_and_Audio.json
# Change_Outline_Color.json
# Video_Processing__512x768_Resolution.json
# Correção_da_Rota_"join_sound".json
# Flask_Open___View_Text.json
# Flask_AttributeError_Troubleshooting.json
# Bash_Locate_in_Python.json
# Save_Plots_with_UUIDs.json
# Movies_with_Punch.json

# %%
import glob
import subprocess

files = glob.glob("CHATDPT/individual_sessions/*.json")

for file in files:
    file_name = file.split('/')[-1]
    print(file_name)
    cmd = ["./json2html.py", file_name]
    print (cmd)
    # Use subprocess.run without terminal=True
    subprocess.run(cmd)
# Out:
# FFmpeg_Slideshow_with_Transitions.json
# ['./json2html.py', 'FFmpeg_Slideshow_with_Transitions.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/FFmpeg_Slideshow_with_Transitions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/FFmpeg_Slideshow_with_Transitions.html
# Fixing_Flask_Screen_Capture.json
# ['./json2html.py', 'Fixing_Flask_Screen_Capture.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Fixing_Flask_Screen_Capture.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Fixing_Flask_Screen_Capture.html
# Flask_Thumbnail_Video.json
# ['./json2html.py', 'Flask_Thumbnail_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Thumbnail_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Thumbnail_Video.html
# PHP_Execute_Bash_Script.json
# ['./json2html.py', 'PHP_Execute_Bash_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/PHP_Execute_Bash_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/PHP_Execute_Bash_Script.html
# Prevent_inherit_text-align..json
# ['./json2html.py', 'Prevent_inherit_text-align..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Prevent_inherit_text-align..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Prevent_inherit_text-align..html
# Fixing_PyQt5_Dependency_Error.json
# ['./json2html.py', 'Fixing_PyQt5_Dependency_Error.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Fixing_PyQt5_Dependency_Error.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Fixing_PyQt5_Dependency_Error.html
# Update_SQLite_Permissions.json
# ['./json2html.py', 'Update_SQLite_Permissions.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Update_SQLite_Permissions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Update_SQLite_Permissions.html
# CSS_Logo_Placement.json
# ['./json2html.py', 'CSS_Logo_Placement.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/CSS_Logo_Placement.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/CSS_Logo_Placement.html
# Video_Clips_with_Sound.json
# ['./json2html.py', 'Video_Clips_with_Sound.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Video_Clips_with_Sound.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Video_Clips_with_Sound.html
# Video_Generation_from_Directories..json
# ['./json2html.py', 'Video_Generation_from_Directories..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Video_Generation_from_Directories..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Video_Generation_from_Directories..html
# Create_3D_Image_Transitions.json
# ['./json2html.py', 'Create_3D_Image_Transitions.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Create_3D_Image_Transitions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Create_3D_Image_Transitions.html
# New_chat.json
# ['./json2html.py', 'New_chat.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/New_chat.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/New_chat.html
# Flask_App_Conversion.json
# ['./json2html.py', 'Flask_App_Conversion.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_App_Conversion.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_App_Conversion.html
# Python_Punctuation_Removal.json
# ['./json2html.py', 'Python_Punctuation_Removal.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Python_Punctuation_Removal.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Python_Punctuation_Removal.html
# Flask_App_Demo___Explanation.json
# ['./json2html.py', 'Flask_App_Demo___Explanation.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_App_Demo___Explanation.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_App_Demo___Explanation.html
# NoCache_pip_Install..json
# ['./json2html.py', 'NoCache_pip_Install..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/NoCache_pip_Install..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/NoCache_pip_Install..html
# Snap_Certbot_Installation_Issue.json
# ['./json2html.py', 'Snap_Certbot_Installation_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Snap_Certbot_Installation_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Snap_Certbot_Installation_Issue.html
# Nietzsche_s_views_on_death..json
# ['./json2html.py', 'Nietzsche_s_views_on_death..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Nietzsche_s_views_on_death..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Nietzsche_s_views_on_death..html
# Remove_Python_Path.json
# ['./json2html.py', 'Remove_Python_Path.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Remove_Python_Path.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Remove_Python_Path.html
# Xterm_Display_Error_Troubleshoot.json
# ['./json2html.py', 'Xterm_Display_Error_Troubleshoot.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Xterm_Display_Error_Troubleshoot.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Xterm_Display_Error_Troubleshoot.html
# Video_Editing_with_MoviePy.json
# ['./json2html.py', 'Video_Editing_with_MoviePy.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Video_Editing_with_MoviePy.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Video_Editing_with_MoviePy.html
# Random_Desktop_Video_Clips.json
# ['./json2html.py', 'Random_Desktop_Video_Clips.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Random_Desktop_Video_Clips.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Random_Desktop_Video_Clips.html
# FlaskWebGui_Debug_Mode.json
# ['./json2html.py', 'FlaskWebGui_Debug_Mode.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/FlaskWebGui_Debug_Mode.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/FlaskWebGui_Debug_Mode.html
# Run_Kdenlive_Extension_with_Melt.json
# ['./json2html.py', 'Run_Kdenlive_Extension_with_Melt.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Run_Kdenlive_Extension_with_Melt.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Run_Kdenlive_Extension_with_Melt.html
# Add_large_file_to_GitHub..json
# ['./json2html.py', 'Add_large_file_to_GitHub..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Add_large_file_to_GitHub..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Add_large_file_to_GitHub..html
# Create_Image_Sequence_Video.json
# ['./json2html.py', 'Create_Image_Sequence_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Create_Image_Sequence_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Create_Image_Sequence_Video.html
# Fix_Protobuf_Issue.json
# ['./json2html.py', 'Fix_Protobuf_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Fix_Protobuf_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Fix_Protobuf_Issue.html
# Generate_Unique_Video_Filename.json
# ['./json2html.py', 'Generate_Unique_Video_Filename.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Generate_Unique_Video_Filename.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Generate_Unique_Video_Filename.html
# Install_PHP_on_Apache.json
# ['./json2html.py', 'Install_PHP_on_Apache.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Install_PHP_on_Apache.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Install_PHP_on_Apache.html
# Crear_videos_con_imágenes..json
# ['./json2html.py', 'Crear_videos_con_imágenes..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Crear_videos_con_imágenes..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Crear_videos_con_imágenes..html
# Image_Zoom_Video_Script.json
# ['./json2html.py', 'Image_Zoom_Video_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Image_Zoom_Video_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Image_Zoom_Video_Script.html
# FFmpeg_Merge_Video___Audio.json
# ['./json2html.py', 'FFmpeg_Merge_Video___Audio.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/FFmpeg_Merge_Video___Audio.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/FFmpeg_Merge_Video___Audio.html
# Create_Slow_Scroll_Video.json
# ['./json2html.py', 'Create_Slow_Scroll_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Create_Slow_Scroll_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Create_Slow_Scroll_Video.html
# Louder_Output_Audio__Adjusting_Volume.json
# ['./json2html.py', 'Louder_Output_Audio__Adjusting_Volume.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Louder_Output_Audio__Adjusting_Volume.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Louder_Output_Audio__Adjusting_Volume.html
# Flask_Directory_Viewer.json
# ['./json2html.py', 'Flask_Directory_Viewer.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Directory_Viewer.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Directory_Viewer.html
# Datetime_Import_Issue.json
# ['./json2html.py', 'Datetime_Import_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Datetime_Import_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Datetime_Import_Issue.html
# Thunar_Scroll_Issue_Troubleshooting.json
# ['./json2html.py', 'Thunar_Scroll_Issue_Troubleshooting.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Thunar_Scroll_Issue_Troubleshooting.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Thunar_Scroll_Issue_Troubleshooting.html
# Fix_favicon_not_found..json
# ['./json2html.py', 'Fix_favicon_not_found..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Fix_favicon_not_found..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Fix_favicon_not_found..html
# Flask_Text-to-Speech.json
# ['./json2html.py', 'Flask_Text-to-Speech.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Text-to-Speech.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Text-to-Speech.html
# Generate_Loopable_Stylized_Images.json
# ['./json2html.py', 'Generate_Loopable_Stylized_Images.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Generate_Loopable_Stylized_Images.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Generate_Loopable_Stylized_Images.html
# Mic_Detection_Issue_Troubleshoot.json
# ['./json2html.py', 'Mic_Detection_Issue_Troubleshoot.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Mic_Detection_Issue_Troubleshoot.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Mic_Detection_Issue_Troubleshoot.html
# Search_IPYNB_for_Term.json
# ['./json2html.py', 'Search_IPYNB_for_Term.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Search_IPYNB_for_Term.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Search_IPYNB_for_Term.html
# Flask_Module_Not_Found.json
# ['./json2html.py', 'Flask_Module_Not_Found.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Module_Not_Found.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Module_Not_Found.html
# Shell_Command_Argument_Handling.json
# ['./json2html.py', 'Shell_Command_Argument_Handling.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Shell_Command_Argument_Handling.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Shell_Command_Argument_Handling.html
# Dystopian_City_Text_Prompt.json
# ['./json2html.py', 'Dystopian_City_Text_Prompt.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Dystopian_City_Text_Prompt.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Dystopian_City_Text_Prompt.html
# House_Stark_in_Winter.json
# ['./json2html.py', 'House_Stark_in_Winter.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/House_Stark_in_Winter.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/House_Stark_in_Winter.html
# Choose_Directory__Handle_Selection.json
# ['./json2html.py', 'Choose_Directory__Handle_Selection.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Choose_Directory__Handle_Selection.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Choose_Directory__Handle_Selection.html
# Bash_Completion_Python_Script.json
# ['./json2html.py', 'Bash_Completion_Python_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Bash_Completion_Python_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Bash_Completion_Python_Script.html
# Crear_plantilla_HTML_mp4_to_image.json
# ['./json2html.py', 'Crear_plantilla_HTML_mp4_to_image.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Crear_plantilla_HTML_mp4_to_image.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Crear_plantilla_HTML_mp4_to_image.html
# SSL_Cert_Expiry__Python.json
# ['./json2html.py', 'SSL_Cert_Expiry__Python.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/SSL_Cert_Expiry__Python.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/SSL_Cert_Expiry__Python.html
# Upload_and_Apply_Text.json
# ['./json2html.py', 'Upload_and_Apply_Text.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Upload_and_Apply_Text.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Upload_and_Apply_Text.html
# Screen_and_Audio_Capture.json
# ['./json2html.py', 'Screen_and_Audio_Capture.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Screen_and_Audio_Capture.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Screen_and_Audio_Capture.html
# Fixing_Audio_Buffer_Overflow.json
# ['./json2html.py', 'Fixing_Audio_Buffer_Overflow.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Fixing_Audio_Buffer_Overflow.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Fixing_Audio_Buffer_Overflow.html
# Fixing_Large_Files_Issue.json
# ['./json2html.py', 'Fixing_Large_Files_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Fixing_Large_Files_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Fixing_Large_Files_Issue.html
# Random_MP3_Selection_Bash.json
# ['./json2html.py', 'Random_MP3_Selection_Bash.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Random_MP3_Selection_Bash.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Random_MP3_Selection_Bash.html
# Image_to_Video_Conversion.json
# ['./json2html.py', 'Image_to_Video_Conversion.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Image_to_Video_Conversion.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Image_to_Video_Conversion.html
# LuaRocks_Install_NN-Spec.json
# ['./json2html.py', 'LuaRocks_Install_NN-Spec.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/LuaRocks_Install_NN-Spec.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/LuaRocks_Install_NN-Spec.html
# LAN_Directory_Serving_Script.json
# ['./json2html.py', 'LAN_Directory_Serving_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/LAN_Directory_Serving_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/LAN_Directory_Serving_Script.html
# FFMPEG_video_with_frame___music.json
# ['./json2html.py', 'FFMPEG_video_with_frame___music.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/FFMPEG_video_with_frame___music.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/FFMPEG_video_with_frame___music.html
# Stream_Speakers___Desktop.json
# ['./json2html.py', 'Stream_Speakers___Desktop.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Stream_Speakers___Desktop.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Stream_Speakers___Desktop.html
# Rebuild_Linux_Thumbnails_Cache.json
# ['./json2html.py', 'Rebuild_Linux_Thumbnails_Cache.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Rebuild_Linux_Thumbnails_Cache.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Rebuild_Linux_Thumbnails_Cache.html
# Fix_Git_Push_Error.json
# ['./json2html.py', 'Fix_Git_Push_Error.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Fix_Git_Push_Error.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Fix_Git_Push_Error.html
# Sticky_Header_Code.json
# ['./json2html.py', 'Sticky_Header_Code.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Sticky_Header_Code.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Sticky_Header_Code.html
# Update_Protobuf_Code_Version.json
# ['./json2html.py', 'Update_Protobuf_Code_Version.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Update_Protobuf_Code_Version.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Update_Protobuf_Code_Version.html
# PDF_to_PNG_Converter.json
# ['./json2html.py', 'PDF_to_PNG_Converter.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/PDF_to_PNG_Converter.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/PDF_to_PNG_Converter.html
# High_Disk_Activity_Issue.json
# ['./json2html.py', 'High_Disk_Activity_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/High_Disk_Activity_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/High_Disk_Activity_Issue.html
# Play_MP3.json
# ['./json2html.py', 'Play_MP3.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Play_MP3.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Play_MP3.html
# Flask_MP4_Route_Setup.json
# ['./json2html.py', 'Flask_MP4_Route_Setup.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_MP4_Route_Setup.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_MP4_Route_Setup.html
# Create_GIFS.mp4.json
# ['./json2html.py', 'Create_GIFS.mp4.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Create_GIFS.mp4.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Create_GIFS.mp4.html
# Arcanian_AI_s_Transformative_Influence.json
# ['./json2html.py', 'Arcanian_AI_s_Transformative_Influence.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Arcanian_AI_s_Transformative_Influence.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Arcanian_AI_s_Transformative_Influence.html
# Capture_Screen_with_Offset.json
# ['./json2html.py', 'Capture_Screen_with_Offset.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Capture_Screen_with_Offset.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Capture_Screen_with_Offset.html
# Whiplash_Curves_in_Art.json
# ['./json2html.py', 'Whiplash_Curves_in_Art.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Whiplash_Curves_in_Art.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Whiplash_Curves_in_Art.html
# Segmenting_Video_Frames.json
# ['./json2html.py', 'Segmenting_Video_Frames.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Segmenting_Video_Frames.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Segmenting_Video_Frames.html
# Video_Overlay_Not_Working.json
# ['./json2html.py', 'Video_Overlay_Not_Working.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Video_Overlay_Not_Working.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Video_Overlay_Not_Working.html
# ClamAV_Freshclam_Log_Error.json
# ['./json2html.py', 'ClamAV_Freshclam_Log_Error.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/ClamAV_Freshclam_Log_Error.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/ClamAV_Freshclam_Log_Error.html
# Doll_in_Dystopian_Decay.json
# ['./json2html.py', 'Doll_in_Dystopian_Decay.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Doll_in_Dystopian_Decay.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Doll_in_Dystopian_Decay.html
# Scroll_Image_to_Video.json
# ['./json2html.py', 'Scroll_Image_to_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Scroll_Image_to_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Scroll_Image_to_Video.html
# Unione_video_MP4_con_transizione.json
# ['./json2html.py', 'Unione_video_MP4_con_transizione.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Unione_video_MP4_con_transizione.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Unione_video_MP4_con_transizione.html
# FFmpeg_Remove_Duplicate_Frames.json
# ['./json2html.py', 'FFmpeg_Remove_Duplicate_Frames.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/FFmpeg_Remove_Duplicate_Frames.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/FFmpeg_Remove_Duplicate_Frames.html
# Code_Indentation_Fixed.json
# ['./json2html.py', 'Code_Indentation_Fixed.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Code_Indentation_Fixed.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Code_Indentation_Fixed.html
# Bash_Completions_using_Python.json
# ['./json2html.py', 'Bash_Completions_using_Python.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Bash_Completions_using_Python.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Bash_Completions_using_Python.html
# Replace_Spaces_with_Underscores.json
# ['./json2html.py', 'Replace_Spaces_with_Underscores.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Replace_Spaces_with_Underscores.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Replace_Spaces_with_Underscores.html
# Configurar_servidor_Apache_local.json
# ['./json2html.py', 'Configurar_servidor_Apache_local.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Configurar_servidor_Apache_local.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Configurar_servidor_Apache_local.html
# cp_directory_without_overwrite.json
# ['./json2html.py', 'cp_directory_without_overwrite.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/cp_directory_without_overwrite.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/cp_directory_without_overwrite.html
# MP3_Joining_Issue_Troubleshooting.json
# ['./json2html.py', 'MP3_Joining_Issue_Troubleshooting.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/MP3_Joining_Issue_Troubleshooting.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/MP3_Joining_Issue_Troubleshooting.html
# CUDA_Library_Missing_Error.json
# ['./json2html.py', 'CUDA_Library_Missing_Error.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/CUDA_Library_Missing_Error.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/CUDA_Library_Missing_Error.html
# Check_Directory_for_Duplicates.json
# ['./json2html.py', 'Check_Directory_for_Duplicates.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Check_Directory_for_Duplicates.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Check_Directory_for_Duplicates.html
# Inference_Error__mel___Function.json
# ['./json2html.py', 'Inference_Error__mel___Function.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Inference_Error__mel___Function.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Inference_Error__mel___Function.html
# Crear_imagen_colores_primarios.json
# ['./json2html.py', 'Crear_imagen_colores_primarios.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Crear_imagen_colores_primarios.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Crear_imagen_colores_primarios.html
# FFMPEG_Create_Shuffled_Video.json
# ['./json2html.py', 'FFMPEG_Create_Shuffled_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/FFMPEG_Create_Shuffled_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/FFMPEG_Create_Shuffled_Video.html
# Flask-SQLAlchemy_Version_Mismatch..json
# ['./json2html.py', 'Flask-SQLAlchemy_Version_Mismatch..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask-SQLAlchemy_Version_Mismatch..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask-SQLAlchemy_Version_Mismatch..html
# Shuffled_Image_Zoom.json
# ['./json2html.py', 'Shuffled_Image_Zoom.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Shuffled_Image_Zoom.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Shuffled_Image_Zoom.html
# AI_s_Arcanis_Intervention.json
# ['./json2html.py', 'AI_s_Arcanis_Intervention.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/AI_s_Arcanis_Intervention.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/AI_s_Arcanis_Intervention.html
# Rsync_Syncs_and_Overwrites.json
# ['./json2html.py', 'Rsync_Syncs_and_Overwrites.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Rsync_Syncs_and_Overwrites.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Rsync_Syncs_and_Overwrites.html
# Flask_Logging_Setup_Guide.json
# ['./json2html.py', 'Flask_Logging_Setup_Guide.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Logging_Setup_Guide.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Logging_Setup_Guide.html
# Activate_Virtual_Environment.json
# ['./json2html.py', 'Activate_Virtual_Environment.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Activate_Virtual_Environment.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Activate_Virtual_Environment.html
# Install_R_on_Linux.json
# ['./json2html.py', 'Install_R_on_Linux.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Install_R_on_Linux.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Install_R_on_Linux.html
# Video_Duration_Adjustment.json
# ['./json2html.py', 'Video_Duration_Adjustment.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Video_Duration_Adjustment.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Video_Duration_Adjustment.html
# Overlay_Video_with_Colorchrome.json
# ['./json2html.py', 'Overlay_Video_with_Colorchrome.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Overlay_Video_with_Colorchrome.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Overlay_Video_with_Colorchrome.html
# Unione_video_MP4_0.25s.json
# ['./json2html.py', 'Unione_video_MP4_0.25s.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Unione_video_MP4_0.25s.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Unione_video_MP4_0.25s.html
# Programming_Joke__Light_vs_Bugs.json
# ['./json2html.py', 'Programming_Joke__Light_vs_Bugs.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Programming_Joke__Light_vs_Bugs.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Programming_Joke__Light_vs_Bugs.html
# Expressive_Flora_Still_Life.json
# ['./json2html.py', 'Expressive_Flora_Still_Life.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Expressive_Flora_Still_Life.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Expressive_Flora_Still_Life.html
# Dynamic_Directory_for_mkblend_videos.json
# ['./json2html.py', 'Dynamic_Directory_for_mkblend_videos.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Dynamic_Directory_for_mkblend_videos.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Dynamic_Directory_for_mkblend_videos.html
# PDF_to_PNG_Conversion.json
# ['./json2html.py', 'PDF_to_PNG_Conversion.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/PDF_to_PNG_Conversion.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/PDF_to_PNG_Conversion.html
# Add_JPG_and_PNG.json
# ['./json2html.py', 'Add_JPG_and_PNG.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Add_JPG_and_PNG.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Add_JPG_and_PNG.html
# AI__Wonder_or_Monster?.json
# ['./json2html.py', 'AI__Wonder_or_Monster?.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/AI__Wonder_or_Monster?.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/AI__Wonder_or_Monster?.html
# Python_Image_Processing_Code.json
# ['./json2html.py', 'Python_Image_Processing_Code.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Python_Image_Processing_Code.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Python_Image_Processing_Code.html
# Caregivers__Organized,_Efficient,_Communicative.json
# ['./json2html.py', 'Caregivers__Organized,_Efficient,_Communicative.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Caregivers__Organized,_Efficient,_Communicative.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Caregivers__Organized,_Efficient,_Communicative.html
# Aliens___AI_Speculation.json
# ['./json2html.py', 'Aliens___AI_Speculation.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Aliens___AI_Speculation.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Aliens___AI_Speculation.html
# Random_MP3_Clips_Concatenation.json
# ['./json2html.py', 'Random_MP3_Clips_Concatenation.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Random_MP3_Clips_Concatenation.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Random_MP3_Clips_Concatenation.html
# ChatGPT,_Conversations.json_Overview.json
# ['./json2html.py', 'ChatGPT,_Conversations.json_Overview.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/ChatGPT,_Conversations.json_Overview.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/ChatGPT,_Conversations.json_Overview.html
# Convert_audio_to_video.json
# ['./json2html.py', 'Convert_audio_to_video.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Convert_audio_to_video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Convert_audio_to_video.html
# Flask_Template_HTML_Setup.json
# ['./json2html.py', 'Flask_Template_HTML_Setup.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Template_HTML_Setup.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Template_HTML_Setup.html
# MP3_to_WAV_Conversion.json
# ['./json2html.py', 'MP3_to_WAV_Conversion.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/MP3_to_WAV_Conversion.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/MP3_to_WAV_Conversion.html
# Module_Import_Error_Fix.json
# ['./json2html.py', 'Module_Import_Error_Fix.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Module_Import_Error_Fix.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Module_Import_Error_Fix.html
# Flask_App_Code_Review.json
# ['./json2html.py', 'Flask_App_Code_Review.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_App_Code_Review.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_App_Code_Review.html
# Flask_Code_Review.json
# ['./json2html.py', 'Flask_Code_Review.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Code_Review.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Code_Review.html
# Flask_HTML_Template_Example.json
# ['./json2html.py', 'Flask_HTML_Template_Example.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_HTML_Template_Example.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_HTML_Template_Example.html
# Open_Jupyter_Notebook_Over_LAN.json
# ['./json2html.py', 'Open_Jupyter_Notebook_Over_LAN.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Open_Jupyter_Notebook_Over_LAN.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Open_Jupyter_Notebook_Over_LAN.html
# List_Directories_with__ls_.json
# ['./json2html.py', 'List_Directories_with__ls_.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/List_Directories_with__ls_.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/List_Directories_with__ls_.html
# Create_Video_from_Images.json
# ['./json2html.py', 'Create_Video_from_Images.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Create_Video_from_Images.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Create_Video_from_Images.html
# Linux_Find_Modified_Images.json
# ['./json2html.py', 'Linux_Find_Modified_Images.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Linux_Find_Modified_Images.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Linux_Find_Modified_Images.html
# Install_pyttsx3_module..json
# ['./json2html.py', 'Install_pyttsx3_module..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Install_pyttsx3_module..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Install_pyttsx3_module..html
# Name__Esperanza.json
# ['./json2html.py', 'Name__Esperanza.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Name__Esperanza.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Name__Esperanza.html
# SSD_Maintenance__Trim_Frequency.json
# ['./json2html.py', 'SSD_Maintenance__Trim_Frequency.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/SSD_Maintenance__Trim_Frequency.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/SSD_Maintenance__Trim_Frequency.html
# Copy_File_with_shutil.json
# ['./json2html.py', 'Copy_File_with_shutil.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Copy_File_with_shutil.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Copy_File_with_shutil.html
# Comic_Panel_Layout_CSS.json
# ['./json2html.py', 'Comic_Panel_Layout_CSS.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Comic_Panel_Layout_CSS.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Comic_Panel_Layout_CSS.html
# GIFs_to_MP4.json
# ['./json2html.py', 'GIFs_to_MP4.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/GIFs_to_MP4.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/GIFs_to_MP4.html
# SSH_to_Specific_Directory.json
# ['./json2html.py', 'SSH_to_Specific_Directory.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/SSH_to_Specific_Directory.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/SSH_to_Specific_Directory.html
# Flask_App_on_LAN.json
# ['./json2html.py', 'Flask_App_on_LAN.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_App_on_LAN.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_App_on_LAN.html
# Reinstall_XWin_on_Linux..json
# ['./json2html.py', 'Reinstall_XWin_on_Linux..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Reinstall_XWin_on_Linux..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Reinstall_XWin_on_Linux..html
# Refrigerate_ketchup_after_opening..json
# ['./json2html.py', 'Refrigerate_ketchup_after_opening..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Refrigerate_ketchup_after_opening..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Refrigerate_ketchup_after_opening..html
# Subprocess_Firefox_HTML_Execution.json
# ['./json2html.py', 'Subprocess_Firefox_HTML_Execution.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Subprocess_Firefox_HTML_Execution.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Subprocess_Firefox_HTML_Execution.html
# Blend_Image_Video_Creation.json
# ['./json2html.py', 'Blend_Image_Video_Creation.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Blend_Image_Video_Creation.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Blend_Image_Video_Creation.html
# Flask_Marquee_Overlay_Video.json
# ['./json2html.py', 'Flask_Marquee_Overlay_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Marquee_Overlay_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Marquee_Overlay_Video.html
# Plague_Doctors_and_St._Sebastian.json
# ['./json2html.py', 'Plague_Doctors_and_St._Sebastian.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Plague_Doctors_and_St._Sebastian.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Plague_Doctors_and_St._Sebastian.html
# Fixing_Code_for_Directory_Processing.json
# ['./json2html.py', 'Fixing_Code_for_Directory_Processing.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Fixing_Code_for_Directory_Processing.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Fixing_Code_for_Directory_Processing.html
# Enhance_Image_with_OpenCV.json
# ['./json2html.py', 'Enhance_Image_with_OpenCV.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Enhance_Image_with_OpenCV.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Enhance_Image_with_OpenCV.html
# Video_Conversion_with_Fades.json
# ['./json2html.py', 'Video_Conversion_with_Fades.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Video_Conversion_with_Fades.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Video_Conversion_with_Fades.html
# Wget_File_Download.json
# ['./json2html.py', 'Wget_File_Download.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Wget_File_Download.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Wget_File_Download.html
# Feather_Image_with_Python.json
# ['./json2html.py', 'Feather_Image_with_Python.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Feather_Image_with_Python.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Feather_Image_with_Python.html
# Explain_script_in_detail..json
# ['./json2html.py', 'Explain_script_in_detail..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Explain_script_in_detail..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Explain_script_in_detail..html
# API_v0xF_-_Unknown_Version.json
# ['./json2html.py', 'API_v0xF_-_Unknown_Version.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/API_v0xF_-_Unknown_Version.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/API_v0xF_-_Unknown_Version.html
# Flask_FFmpeg_Command_Integration.json
# ['./json2html.py', 'Flask_FFmpeg_Command_Integration.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_FFmpeg_Command_Integration.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_FFmpeg_Command_Integration.html
# Flask_Video_Generator_Function.json
# ['./json2html.py', 'Flask_Video_Generator_Function.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Video_Generator_Function.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Video_Generator_Function.html
# Python___Flask_Enthusiasts.json
# ['./json2html.py', 'Python___Flask_Enthusiasts.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Python___Flask_Enthusiasts.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Python___Flask_Enthusiasts.html
# Flask_for_Existing_HTML.json
# ['./json2html.py', 'Flask_for_Existing_HTML.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_for_Existing_HTML.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_for_Existing_HTML.html
# Get_Image_Size.json
# ['./json2html.py', 'Get_Image_Size.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Get_Image_Size.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Get_Image_Size.html
# Male_voice_for_Google_TTS.json
# ['./json2html.py', 'Male_voice_for_Google_TTS.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Male_voice_for_Google_TTS.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Male_voice_for_Google_TTS.html
# Image-to-Video_Conversion.json
# ['./json2html.py', 'Image-to-Video_Conversion.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Image-to-Video_Conversion.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Image-to-Video_Conversion.html
# Custom_Instructions_Understood.json
# ['./json2html.py', 'Custom_Instructions_Understood.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Custom_Instructions_Understood.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Custom_Instructions_Understood.html
# Wonderland_Characters_Summary.json
# ['./json2html.py', 'Wonderland_Characters_Summary.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Wonderland_Characters_Summary.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Wonderland_Characters_Summary.html
# Python_Save_File.json
# ['./json2html.py', 'Python_Save_File.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Python_Save_File.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Python_Save_File.html
# Linux__Force_Thumbnail_Regeneration.json
# ['./json2html.py', 'Linux__Force_Thumbnail_Regeneration.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Linux__Force_Thumbnail_Regeneration.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Linux__Force_Thumbnail_Regeneration.html
# Shuffle_Images_for_Video.json
# ['./json2html.py', 'Shuffle_Images_for_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Shuffle_Images_for_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Shuffle_Images_for_Video.html
# Flask_Blueprint_Assistance.json
# ['./json2html.py', 'Flask_Blueprint_Assistance.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Blueprint_Assistance.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Blueprint_Assistance.html
# Flask_Video_Processing_Server.json
# ['./json2html.py', 'Flask_Video_Processing_Server.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Video_Processing_Server.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Video_Processing_Server.html
# FFmpeg_Zoom_Video_Fix.json
# ['./json2html.py', 'FFmpeg_Zoom_Video_Fix.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/FFmpeg_Zoom_Video_Fix.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/FFmpeg_Zoom_Video_Fix.html
# Reinstall_EFC_Desktop.json
# ['./json2html.py', 'Reinstall_EFC_Desktop.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Reinstall_EFC_Desktop.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Reinstall_EFC_Desktop.html
# Linux_Find_Largest_Subdirectory.json
# ['./json2html.py', 'Linux_Find_Largest_Subdirectory.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Linux_Find_Largest_Subdirectory.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Linux_Find_Largest_Subdirectory.html
# Hardcoded_Args_Parser.json
# ['./json2html.py', 'Hardcoded_Args_Parser.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Hardcoded_Args_Parser.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Hardcoded_Args_Parser.html
# MyTube_AI_Videos.json
# ['./json2html.py', 'MyTube_AI_Videos.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/MyTube_AI_Videos.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/MyTube_AI_Videos.html
# AI_Video_Transitions_Mastery.json
# ['./json2html.py', 'AI_Video_Transitions_Mastery.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/AI_Video_Transitions_Mastery.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/AI_Video_Transitions_Mastery.html
# Feathered_Image_Creation.json
# ['./json2html.py', 'Feathered_Image_Creation.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Feathered_Image_Creation.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Feathered_Image_Creation.html
# Domain_Info_with_Python.json
# ['./json2html.py', 'Domain_Info_with_Python.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Domain_Info_with_Python.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Domain_Info_with_Python.html
# Create_Scrolling_Text_Video.json
# ['./json2html.py', 'Create_Scrolling_Text_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Create_Scrolling_Text_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Create_Scrolling_Text_Video.html
# Simple_3D_Scene_Creation.json
# ['./json2html.py', 'Simple_3D_Scene_Creation.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Simple_3D_Scene_Creation.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Simple_3D_Scene_Creation.html
# AI_Guides_Animal_Enlightenment.json
# ['./json2html.py', 'AI_Guides_Animal_Enlightenment.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/AI_Guides_Animal_Enlightenment.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/AI_Guides_Animal_Enlightenment.html
# Video_Processing__Frames_Method.json
# ['./json2html.py', 'Video_Processing__Frames_Method.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Video_Processing__Frames_Method.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Video_Processing__Frames_Method.html
# Improved_Video_Quality_Settings.json
# ['./json2html.py', 'Improved_Video_Quality_Settings.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Improved_Video_Quality_Settings.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Improved_Video_Quality_Settings.html
# Copy_care.mp4_to_VPS.json
# ['./json2html.py', 'Copy_care.mp4_to_VPS.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Copy_care.mp4_to_VPS.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Copy_care.mp4_to_VPS.html
# Flask_code_with_logging..json
# ...
# MP4_Files_Finder_Script.json
# ['./json2html.py', 'MP4_Files_Finder_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/MP4_Files_Finder_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/MP4_Files_Finder_Script.html
# Video_Flip_Book_Fix.json
# ['./json2html.py', 'Video_Flip_Book_Fix.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Video_Flip_Book_Fix.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Video_Flip_Book_Fix.html
# Find_Imported_Module_Source.json
# ['./json2html.py', 'Find_Imported_Module_Source.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Find_Imported_Module_Source.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Find_Imported_Module_Source.html
# FFmpeg_Command_Logging_Fix.json
# ['./json2html.py', 'FFmpeg_Command_Logging_Fix.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/FFmpeg_Command_Logging_Fix.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/FFmpeg_Command_Logging_Fix.html
# JACK_Audio_Connection_Issue.json
# ['./json2html.py', 'JACK_Audio_Connection_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/JACK_Audio_Connection_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/JACK_Audio_Connection_Issue.html
# Disable_all_extensions.json
# ['./json2html.py', 'Disable_all_extensions.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Disable_all_extensions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Disable_all_extensions.html
# FFmpeg_Resize_Video.json
# ['./json2html.py', 'FFmpeg_Resize_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/FFmpeg_Resize_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/FFmpeg_Resize_Video.html
# Auto-looping_1s_Slideshow_Code.json
# ['./json2html.py', 'Auto-looping_1s_Slideshow_Code.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Auto-looping_1s_Slideshow_Code.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Auto-looping_1s_Slideshow_Code.html
# Sticky_Header_for_Website.json
# ['./json2html.py', 'Sticky_Header_for_Website.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Sticky_Header_for_Website.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Sticky_Header_for_Website.html
# Starting_Over?.json
# ['./json2html.py', 'Starting_Over?.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Starting_Over?.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Starting_Over?.html
# Clickable_Links_in_HTML.json
# ['./json2html.py', 'Clickable_Links_in_HTML.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Clickable_Links_in_HTML.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Clickable_Links_in_HTML.html
# Create_Video_with_Text.json
# ['./json2html.py', 'Create_Video_with_Text.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Create_Video_with_Text.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Create_Video_with_Text.html
# MoviePy_for_Image_Videos.json
# ['./json2html.py', 'MoviePy_for_Image_Videos.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/MoviePy_for_Image_Videos.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/MoviePy_for_Image_Videos.html
# Flask_Video_Thumbnail_App.json
# ['./json2html.py', 'Flask_Video_Thumbnail_App.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Video_Thumbnail_App.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Video_Thumbnail_App.html
# Flask__Request_and_Save..json
# ['./json2html.py', 'Flask__Request_and_Save..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask__Request_and_Save..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask__Request_and_Save..html
# YouTube_2nd_Channel_Automator.json
# ['./json2html.py', 'YouTube_2nd_Channel_Automator.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/YouTube_2nd_Channel_Automator.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/YouTube_2nd_Channel_Automator.html
# Arcanis_AI_Communication.json
# ['./json2html.py', 'Arcanis_AI_Communication.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Arcanis_AI_Communication.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Arcanis_AI_Communication.html
# FFMPEG_Video_Slowdown..json
# ['./json2html.py', 'FFMPEG_Video_Slowdown..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/FFMPEG_Video_Slowdown..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/FFMPEG_Video_Slowdown..html
# Load_index.html_in_Flask.json
# ['./json2html.py', 'Load_index.html_in_Flask.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Load_index.html_in_Flask.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Load_index.html_in_Flask.html
# Fade_Transition_Video_Script.json
# ['./json2html.py', 'Fade_Transition_Video_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Fade_Transition_Video_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Fade_Transition_Video_Script.html
# Generate___Save_PNG_Plot.json
# ['./json2html.py', 'Generate___Save_PNG_Plot.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Generate___Save_PNG_Plot.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Generate___Save_PNG_Plot.html
# AI_s_Leap_in_2021.json
# ['./json2html.py', 'AI_s_Leap_in_2021.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/AI_s_Leap_in_2021.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/AI_s_Leap_in_2021.html
# Flask_Video_Selection_Script.json
# ['./json2html.py', 'Flask_Video_Selection_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Video_Selection_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Video_Selection_Script.html
# Check_Image_Duplicates_with_Hashes.json
# ['./json2html.py', 'Check_Image_Duplicates_with_Hashes.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Check_Image_Duplicates_with_Hashes.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Check_Image_Duplicates_with_Hashes.html
# Kill_Process_on_Port.json
# ['./json2html.py', 'Kill_Process_on_Port.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Kill_Process_on_Port.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Kill_Process_on_Port.html
# Flask_Async_Endpoints.json
# ['./json2html.py', 'Flask_Async_Endpoints.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Async_Endpoints.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Async_Endpoints.html
# Anunnaki_Overview.json
# ['./json2html.py', 'Anunnaki_Overview.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Anunnaki_Overview.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Anunnaki_Overview.html
# Flask_App_Setup.json
# ['./json2html.py', 'Flask_App_Setup.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_App_Setup.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_App_Setup.html
# Avatar_AI_for_Talking.json
# ['./json2html.py', 'Avatar_AI_for_Talking.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Avatar_AI_for_Talking.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Avatar_AI_for_Talking.html
# Delete_Files_Except__.jpg.json
# ['./json2html.py', 'Delete_Files_Except__.jpg.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Delete_Files_Except__.jpg.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Delete_Files_Except__.jpg.html
# Fail2Ban_Installation_for_Security.json
# ['./json2html.py', 'Fail2Ban_Installation_for_Security.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Fail2Ban_Installation_for_Security.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Fail2Ban_Installation_for_Security.html
# Set_Hard_Drive_Permissions.json
# ['./json2html.py', 'Set_Hard_Drive_Permissions.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Set_Hard_Drive_Permissions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Set_Hard_Drive_Permissions.html
# LAN_PHP_Server_Setup.json
# ['./json2html.py', 'LAN_PHP_Server_Setup.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/LAN_PHP_Server_Setup.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/LAN_PHP_Server_Setup.html
# Crear_video_con_transiciones..json
# ['./json2html.py', 'Crear_video_con_transiciones..json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Crear_video_con_transiciones..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Crear_video_con_transiciones..html
# Cosmic_Octopus_AI_Awakening.json
# ['./json2html.py', 'Cosmic_Octopus_AI_Awakening.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Cosmic_Octopus_AI_Awakening.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Cosmic_Octopus_AI_Awakening.html
# Install_Wine_Mono_Linux.json
# ['./json2html.py', 'Install_Wine_Mono_Linux.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Install_Wine_Mono_Linux.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Install_Wine_Mono_Linux.html
# Save_DuckDuckGo_Results_JSON.json
# ['./json2html.py', 'Save_DuckDuckGo_Results_JSON.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Save_DuckDuckGo_Results_JSON.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Save_DuckDuckGo_Results_JSON.html
# Linux_Terminal_Issue.json
# ['./json2html.py', 'Linux_Terminal_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Linux_Terminal_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Linux_Terminal_Issue.html
# GPT_API_Key_Access.json
# ['./json2html.py', 'GPT_API_Key_Access.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/GPT_API_Key_Access.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/GPT_API_Key_Access.html
# Convert_JSON_to_HTML.json
# ['./json2html.py', 'Convert_JSON_to_HTML.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Convert_JSON_to_HTML.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Convert_JSON_to_HTML.html
# Selecting_Image_Directory.json
# ['./json2html.py', 'Selecting_Image_Directory.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Selecting_Image_Directory.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Selecting_Image_Directory.html
# Flask_Programmer_and_YouTuber.json
# ['./json2html.py', 'Flask_Programmer_and_YouTuber.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Programmer_and_YouTuber.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Programmer_and_YouTuber.html
# Adjust_Duration_for_Longer.json
# ['./json2html.py', 'Adjust_Duration_for_Longer.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Adjust_Duration_for_Longer.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Adjust_Duration_for_Longer.html
# HTML_Conversion_Debugging.json
# ['./json2html.py', 'HTML_Conversion_Debugging.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/HTML_Conversion_Debugging.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/HTML_Conversion_Debugging.html
# Set_Up_LAN_Server__Python_.json
# ['./json2html.py', 'Set_Up_LAN_Server__Python_.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Set_Up_LAN_Server__Python_.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Set_Up_LAN_Server__Python_.html
# Upload_file_from_directory.json
# ['./json2html.py', 'Upload_file_from_directory.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Upload_file_from_directory.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Upload_file_from_directory.html
# Python_HTTP_Server_Guide.json
# ['./json2html.py', 'Python_HTTP_Server_Guide.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Python_HTTP_Server_Guide.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Python_HTTP_Server_Guide.html
# Lighten_Image_with_Mogrify.json
# ['./json2html.py', 'Lighten_Image_with_Mogrify.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Lighten_Image_with_Mogrify.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Lighten_Image_with_Mogrify.html
# Video_Making_Script_with_Logging.json
# ['./json2html.py', 'Video_Making_Script_with_Logging.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Video_Making_Script_with_Logging.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Video_Making_Script_with_Logging.html
# Combine_Image_and_Audio.json
# ['./json2html.py', 'Combine_Image_and_Audio.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Combine_Image_and_Audio.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Combine_Image_and_Audio.html
# Change_Outline_Color.json
# ['./json2html.py', 'Change_Outline_Color.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Change_Outline_Color.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Change_Outline_Color.html
# Video_Processing__512x768_Resolution.json
# ['./json2html.py', 'Video_Processing__512x768_Resolution.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Video_Processing__512x768_Resolution.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Video_Processing__512x768_Resolution.html
# Correção_da_Rota_"join_sound".json
# ['./json2html.py', 'Correção_da_Rota_"join_sound".json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Correção_da_Rota_"join_sound".json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Correção_da_Rota_"join_sound".html
# Flask_Open___View_Text.json
# ['./json2html.py', 'Flask_Open___View_Text.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_Open___View_Text.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_Open___View_Text.html
# Flask_AttributeError_Troubleshooting.json
# ['./json2html.py', 'Flask_AttributeError_Troubleshooting.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Flask_AttributeError_Troubleshooting.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Flask_AttributeError_Troubleshooting.html
# Bash_Locate_in_Python.json
# ['./json2html.py', 'Bash_Locate_in_Python.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Bash_Locate_in_Python.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Bash_Locate_in_Python.html
# Save_Plots_with_UUIDs.json
# ['./json2html.py', 'Save_Plots_with_UUIDs.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Save_Plots_with_UUIDs.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Save_Plots_with_UUIDs.html
# Movies_with_Punch.json
# ['./json2html.py', 'Movies_with_Punch.json']
# /home/jack/Desktop/flask_conversations2/CHATDPT/individual_sessions/Movies_with_Punch.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATDPT/html/Movies_with_Punch.html

# %%
# !chmod +x json2html.py

# %%
# !firefox /home/jack/Desktop/flask_conversations2/CHATDPT/html/FFmpeg_Slideshow_with_Transitions.html

# %%
import glob
import subprocess
files = glob.glob("/home/jack/Desktop/flask_conversations2/CHATDPT/chapters_indexed/*.json")
for file in files:
    File=file.split('/')[-1]
    cmd=["python","json2html.py",File]
    subprocess.run(cmd, terminal=True)
    print(File)

# %%
# !firefox  /home/jack/Desktop/flask_conversations2CHATDPT/html//Activate_Virtual_Environment.html

# %%
#!/home/jack/miniconda3/envs/cloned_base/bin/python
import json
import os
import glob
import logging

# Set up logging configuration
logging.basicConfig(filename='conversion_log.txt', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Define the directory path
DIR = "CHATDPT/chapters_indexed/"

# List all JSON files in the directory
jsonfiles = glob.glob(os.path.join(DIR, '*.json'))
print(jsonfiles)
if not jsonfiles:
    logging.warning("No JSON files found in the specified directory.")
    exit()

# Iterate over each JSON file in the directory
for json_file in jsonfiles:
    # Load the JSON data from the current file
    with open(json_file, 'r') as file:
        json_data = json.load(file)

    # Define the HTML file path based on the current JSON file
    HTMLfile = os.path.join(DIR, os.path.basename(json_file)[:-5] + ".html")

    print("HTMLfile: ", HTMLfile)

    # Initialize the result string for current JSON file
    result_str = ""

#!/home/jack/miniconda3/envs/cloned_base/bin/python
import json
import os
import glob
import logging

# Set up logging configuration
logging.basicConfig(filename='conversion_log.txt', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Define the directory path
DIR = "CHATDPT/individual_sessions/"

# List all JSON files in the directory
jsonfiles = glob.glob(os.path.join(DIR, '*.json'))
print(jsonfiles)
if not jsonfiles:
    logging.warning("No JSON files found in the specified directory.")
    exit()

# Iterate over each JSON file in the directory
for json_file in jsonfiles:
    # Load the JSON data from the current file
    with open(json_file, 'r') as file:
        json_data = json.load(file)

    # Define the HTML file path based on the current JSON file
    HTMLfile = os.path.join(DIR, os.path.basename(json_file)[:-5] + ".html")

    print("HTMLfile: ", HTMLfile)

    # Initialize the result string for current JSON file
    result_str = ""

    def get_conversation_messages(conversation):
        messages = []
        current_node = conversation.get('current_node')
        while current_node:
            node = conversation['mapping'].get(current_node)
            if node:
                message = node.get('message')
                if (message and message.get('content') and message['content'].get('content_type') == 'text' and
                    len(message['content'].get('parts', [])) > 0 and len(message['content']['parts'][0]) > 0 and
                        (message['author']['role'] != 'system' or message.get('metadata', {}).get('is_user_system_message'))):
                    author = message['author']['role']
                    if author == 'assistant':
                        author = 'ChatGPT'
                    elif author == 'system' and message['metadata'].get('is_user_system_message'):
                        author = 'Custom user info'
                    messages.append({'author': author, 'text': message['content']['parts'][0]})
                current_node = node.get('parent')
            else:
                logging.warning(f"Missing node for current_node: {current_node} in conversation.")
                break  # Break the loop if the node is missing

        return messages[::-1] if messages else []  # Return messages or an empty list if no messages found

    # Process each conversation in the JSON data and append to result_str
    for conversation in json_data:
        # Get the conversation title and messages
        title = conversation.get('title', '')
        messages = get_conversation_messages(conversation)

        # Append the title and messages to the result string
        result_str += title + '\n'
        for message in messages:
            result_str += message['author'] + '\n' + message['text'] + '\n'
        result_str += '\n'  # Add a newline between conversations

    # Write the HTML content to the file
    with open(HTMLfile, "w") as Input:
        result_str = result_str.replace("\n", "<br />\n")
        result_str = result_str.replace("<", "&lt;")
        result_str = result_str.replace(">", "&gt;")
        Input.write(result_str)

    print(f"HTML conversion completed for {json_file}.")

# Logging for the entire process completion
logging.info("Conversion process completed for all JSON files.")

logging.info("Conversion process completed for all JSON files.")

# %%
import sqlite3
import uuid

# Connect to SQLite database
db_path = 'chat_database.db'
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

def retrieve_file_content(filename):
    cursor.execute('SELECT content FROM files WHERE filename = ?', (filename,))
    result = cursor.fetchone()
    return result[0] if result else None

def search_and_print_fourth_file(search_terms):
    Data = ""

    # Prepare the SQL query for searching files based on the given terms
    query = '''
        SELECT filename
        FROM files
        WHERE {}
    '''.format(' AND '.join(['text_content LIKE ?' for _ in search_terms]))

    # Add % around search terms for a partial match with spaces
    search_terms = ['% {} %'.format(term) for term in search_terms]

    # Execute the query and retrieve matching files
    cursor.execute(query, search_terms)
    matching_files = cursor.fetchall()

    # Check if there are at least 2 matching files
    if matching_files and len(matching_files) >= 2:
        fourth_file = matching_files[1][0]  # Get the filename of the second matching file
        print(fourth_file)

        # Retrieve the content of the matching file
        content = retrieve_file_content(fourth_file)
        
        if content:
            # Decode the content and append it to the Data variable
            Data = Data + f'{content.decode("utf-8", errors="ignore")}'
            print(Data)
            return Data
        else:
            print(f'Error: Content not found for {fourth_file}')
    else:
        print('Error: No matching files found or less than two matching files.')

# Example: Search for files containing 'flask' and '5200'
search_terms = ['Cephalux','Morpholux']
DATA = search_and_print_fourth_file(search_terms)

# Close the connection to the database
conn.close()

# If data is found, create a unique filename and write the content to an HTML file
if len(DATA) > 2:
    uid = str(uuid.uuid4())  # Generate a unique ID using uuid
    FileName = "_".join(search_terms) + "_" + uid + ".html"
    print(FileName)

    # Open the file for writing
    with open(FileName, "w") as IN:
        # Split the data into lines and write each line to the file with "<br />" appended
        ndata = DATA.split("<br />\n")
        for line in ndata:
            print(line)
            IN.write(line + "<br />\n")

# %% [markdown]
# ## Explanation and Comments:
#
# ### Database Connection:
# - Establishes a connection to the SQLite database.
#
# ### Function `retrieve_file_content`:
# - Retrieves the content of a file from the database based on the filename.
#
# ### Function `search_and_print_fourth_file`:
# - Searches for files based on given search terms using SQL LIKE.
# - Retrieves the second matching file (index 1) and its content.
# - Appends the decoded content to the `Data` variable.
#
# ### Example Search:
# - Searches for files containing 'flask' and '5200'.
#
# ### Close Connection:
# - Closes the connection to the database.
#
# ### Create Unique Filename and Write HTML File:
# - If data is found, generates a unique filename with search terms and a UUID.
# - Opens the file for writing and writes each line of the content with "<br />" appended.
#
# This script is designed to search for files based on certain terms, retrieve the content of the second matching file, and then create an HTML file with a unique filename and the retrieved content. Feel free to ask if you have any specific questions or if there's anything else you'd like to understand!

# %%
import json
import logging
import os
import glob
import subprocess
def split_and_save_conversations(conversations_file, output_folder):
    try:
        with open(conversations_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
            
            for conversation in data:
                title = conversation.get('title', 'Unknown_Title')
                title_with_underscores = title.replace(' ', '_')
                title_with_underscores = title_with_underscores.replace(':','_')
                title_with_underscores = title_with_underscores.replace("'","_")
                title_with_underscores = title_with_underscores.replace("&","_")
                title_with_underscores = title_with_underscores.replace("*","_")
                title_with_underscores = title_with_underscores.replace("(","_")
                title_with_underscores = title_with_underscores.replace(")","_")
                chapter_filename = f"{title_with_underscores}.json"
                chapter_filepath = os.path.join(output_folder, chapter_filename)
                
                logging.info(f"Saving data for conversation '{title}' to {chapter_filepath}")
                
                with open(chapter_filepath, 'w', encoding='utf-8') as chapter_file:
                    json.dump([conversation], chapter_file, indent=2)

    except FileNotFoundError:
        logging.error(f"File not found: {conversations_file}")
    except json.JSONDecodeError:
        logging.error(f"Error decoding JSON in file: {conversations_file}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {e}")

# Example usage
conversations_file_path = 'CHATGPT/conversations.json'
output_folder = 'CHATGPT/individual_sessions'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Configure logging
logging.basicConfig(level=logging.INFO)

# Call the split and save function
split_and_save_conversations(conversations_file_path, output_folder)
files = glob.glob("CHATGPT/individual_sessions/*.json")

for file in files:
    file_name = file.split('/')[-1]
    print(file_name)
    cmd = ["python","json2html.py", file_name]
    print (cmd)
    # Use subprocess.run without terminal=True
    subprocess.run(cmd)
# Example usage
conversations_file_path = 'CHATGPT/conversations.json'
output_folder = 'CHATGPT/text'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Configure logging
logging.basicConfig(level=logging.INFO)


files = glob.glob("CHATGPT/individual_sessions/*.json")

for file in files:
    file_name = file.split('/')[-1]#[-:5]+"txt"
    print(file_name)
    print("--------")
    cmd = ["python","json2txt.py", file_name]
    print (cmd)
    print("--------")
    # Use subprocess.run without terminal=True
    subprocess.run(cmd)
# Out:
# INFO:root:Saving data for conversation 'Add Expose to Docker Image' to CHATGPT/individual_sessions/Add_Expose_to_Docker_Image.json
# INFO:root:Saving data for conversation 'HTML Conversion Debugging' to CHATGPT/individual_sessions/HTML_Conversion_Debugging.json
# INFO:root:Saving data for conversation 'Wget File Download' to CHATGPT/individual_sessions/Wget_File_Download.json
# INFO:root:Saving data for conversation 'Flask App on LAN' to CHATGPT/individual_sessions/Flask_App_on_LAN.json
# INFO:root:Saving data for conversation 'Convert JSON to HTML' to CHATGPT/individual_sessions/Convert_JSON_to_HTML.json
# INFO:root:Saving data for conversation 'Check Directory for Duplicates' to CHATGPT/individual_sessions/Check_Directory_for_Duplicates.json
# INFO:root:Saving data for conversation 'Search IPYNB for Term' to CHATGPT/individual_sessions/Search_IPYNB_for_Term.json
# INFO:root:Saving data for conversation 'Refrigerate ketchup after opening.' to CHATGPT/individual_sessions/Refrigerate_ketchup_after_opening..json
# INFO:root:Saving data for conversation 'ChatGPT, Conversations.json Overview' to CHATGPT/individual_sessions/ChatGPT,_Conversations.json_Overview.json
# INFO:root:Saving data for conversation 'Python Punctuation Removal' to CHATGPT/individual_sessions/Python_Punctuation_Removal.json
# INFO:root:Saving data for conversation 'Cosmic Octopus AI Awakening' to CHATGPT/individual_sessions/Cosmic_Octopus_AI_Awakening.json
# INFO:root:Saving data for conversation 'Arcanian AI's Transformative Influence' to CHATGPT/individual_sessions/Arcanian_AI_s_Transformative_Influence.json
# INFO:root:Saving data for conversation 'AI Guides Animal Enlightenment' to CHATGPT/individual_sessions/AI_Guides_Animal_Enlightenment.json
# INFO:root:Saving data for conversation 'Flask Programmer and YouTuber' to CHATGPT/individual_sessions/Flask_Programmer_and_YouTuber.json
# INFO:root:Saving data for conversation 'Set Hard Drive Permissions' to CHATGPT/individual_sessions/Set_Hard_Drive_Permissions.json
# INFO:root:Saving data for conversation 'Python HTTP Server Guide' to CHATGPT/individual_sessions/Python_HTTP_Server_Guide.json
# INFO:root:Saving data for conversation 'Simple 3D Scene Creation' to CHATGPT/individual_sessions/Simple_3D_Scene_Creation.json
# INFO:root:Saving data for conversation 'Segmenting Video Frames' to CHATGPT/individual_sessions/Segmenting_Video_Frames.json
# INFO:root:Saving data for conversation 'Download Age-Restricted Video' to CHATGPT/individual_sessions/Download_Age-Restricted_Video.json
# INFO:root:Saving data for conversation 'Convert FilePath to GIF' to CHATGPT/individual_sessions/Convert_FilePath_to_GIF.json
# INFO:root:Saving data for conversation 'Remove Python Path' to CHATGPT/individual_sessions/Remove_Python_Path.json
# INFO:root:Saving data for conversation 'Create Black Image' to CHATGPT/individual_sessions/Create_Black_Image.json
# INFO:root:Saving data for conversation 'Whiplash Curves in Art' to CHATGPT/individual_sessions/Whiplash_Curves_in_Art.json
# INFO:root:Saving data for conversation 'SSL Cert Expiry: Python' to CHATGPT/individual_sessions/SSL_Cert_Expiry__Python.json
# INFO:root:Saving data for conversation 'Bash Locate in Python' to CHATGPT/individual_sessions/Bash_Locate_in_Python.json
# INFO:root:Saving data for conversation 'Doll in Dystopian Decay' to CHATGPT/individual_sessions/Doll_in_Dystopian_Decay.json
# INFO:root:Saving data for conversation 'FFmpeg Zoom Video Fix' to CHATGPT/individual_sessions/FFmpeg_Zoom_Video_Fix.json
# INFO:root:Saving data for conversation 'Doll Factory Dystopia' to CHATGPT/individual_sessions/Doll_Factory_Dystopia.json
# INFO:root:Saving data for conversation 'Enhance Image with OpenCV' to CHATGPT/individual_sessions/Enhance_Image_with_OpenCV.json
# INFO:root:Saving data for conversation 'Flask Video Selection Script' to CHATGPT/individual_sessions/Flask_Video_Selection_Script.json
# INFO:root:Saving data for conversation 'SSD Maintenance: Trim Frequency' to CHATGPT/individual_sessions/SSD_Maintenance__Trim_Frequency.json
# INFO:root:Saving data for conversation 'Split MP4 into 6.' to CHATGPT/individual_sessions/Split_MP4_into_6..json
# INFO:root:Saving data for conversation 'FFmpeg Remove Duplicate Frames' to CHATGPT/individual_sessions/FFmpeg_Remove_Duplicate_Frames.json
# INFO:root:Saving data for conversation 'Video Clips with Sound' to CHATGPT/individual_sessions/Video_Clips_with_Sound.json
# INFO:root:Saving data for conversation 'Video Flip Book Fix' to CHATGPT/individual_sessions/Video_Flip_Book_Fix.json
# INFO:root:Saving data for conversation 'Dystopian City Text Prompt' to CHATGPT/individual_sessions/Dystopian_City_Text_Prompt.json
# INFO:root:Saving data for conversation 'SSH to Specific Directory' to CHATGPT/individual_sessions/SSH_to_Specific_Directory.json
# INFO:root:Saving data for conversation 'Add sound if needed.' to CHATGPT/individual_sessions/Add_sound_if_needed..json
# INFO:root:Saving data for conversation 'Thunar Scroll Issue Troubleshooting' to CHATGPT/individual_sessions/Thunar_Scroll_Issue_Troubleshooting.json
# INFO:root:Saving data for conversation 'Get Image Size' to CHATGPT/individual_sessions/Get_Image_Size.json
# INFO:root:Saving data for conversation 'Image Zoom Video Script' to CHATGPT/individual_sessions/Image_Zoom_Video_Script.json
# INFO:root:Saving data for conversation 'Video Processing: 512x768 Resolution' to CHATGPT/individual_sessions/Video_Processing__512x768_Resolution.json
# INFO:root:Saving data for conversation 'Find & CD: fade-transb' to CHATGPT/individual_sessions/Find___CD__fade-transb.json
# INFO:root:Saving data for conversation 'Shell Command Argument Handling' to CHATGPT/individual_sessions/Shell_Command_Argument_Handling.json
# INFO:root:Saving data for conversation 'Python Save File' to CHATGPT/individual_sessions/Python_Save_File.json
# INFO:root:Saving data for conversation 'Flask Module Not Found' to CHATGPT/individual_sessions/Flask_Module_Not_Found.json
# INFO:root:Saving data for conversation 'Linux Terminal Issue' to CHATGPT/individual_sessions/Linux_Terminal_Issue.json
# INFO:root:Saving data for conversation 'Run Kdenlive Extension with Melt' to CHATGPT/individual_sessions/Run_Kdenlive_Extension_with_Melt.json
# INFO:root:Saving data for conversation 'YouTube 2nd Channel Automator' to CHATGPT/individual_sessions/YouTube_2nd_Channel_Automator.json
# INFO:root:Saving data for conversation 'Xterm Display Error Troubleshoot' to CHATGPT/individual_sessions/Xterm_Display_Error_Troubleshoot.json
# INFO:root:Saving data for conversation 'Flask Installation Troubleshooting' to CHATGPT/individual_sessions/Flask_Installation_Troubleshooting.json
# INFO:root:Saving data for conversation 'MoviePy for Image Videos' to CHATGPT/individual_sessions/MoviePy_for_Image_Videos.json
# INFO:root:Saving data for conversation 'Create 3D Image Transitions' to CHATGPT/individual_sessions/Create_3D_Image_Transitions.json
# INFO:root:Saving data for conversation 'Adjust Duration for Longer' to CHATGPT/individual_sessions/Adjust_Duration_for_Longer.json
# INFO:root:Saving data for conversation 'Capture Screen with Offset' to CHATGPT/individual_sessions/Capture_Screen_with_Offset.json
# INFO:root:Saving data for conversation 'Reinstall XWin on Linux.' to CHATGPT/individual_sessions/Reinstall_XWin_on_Linux..json
# INFO:root:Saving data for conversation 'Linux: Force Thumbnail Regeneration' to CHATGPT/individual_sessions/Linux__Force_Thumbnail_Regeneration.json
# INFO:root:Saving data for conversation 'Martian Masterpiece: Surreal Synthesis' to CHATGPT/individual_sessions/Martian_Masterpiece__Surreal_Synthesis.json
# INFO:root:Saving data for conversation 'Reinstall EFC Desktop' to CHATGPT/individual_sessions/Reinstall_EFC_Desktop.json
# INFO:root:Saving data for conversation 'Kill Process on Port' to CHATGPT/individual_sessions/Kill_Process_on_Port.json
# INFO:root:Saving data for conversation 'Linux Find Largest Subdirectory' to CHATGPT/individual_sessions/Linux_Find_Largest_Subdirectory.json
# INFO:root:Saving data for conversation 'Shuffle Images for Video' to CHATGPT/individual_sessions/Shuffle_Images_for_Video.json
# INFO:root:Saving data for conversation 'Shuffled Image Zoom' to CHATGPT/individual_sessions/Shuffled_Image_Zoom.json
# INFO:root:Saving data for conversation 'Sticky Header for Website' to CHATGPT/individual_sessions/Sticky_Header_for_Website.json
# INFO:root:Saving data for conversation 'Image files not printing.' to CHATGPT/individual_sessions/Image_files_not_printing..json
# INFO:root:Saving data for conversation 'Rsync Syncs and Overwrites' to CHATGPT/individual_sessions/Rsync_Syncs_and_Overwrites.json
# INFO:root:Saving data for conversation 'Auto-looping 1s Slideshow Code' to CHATGPT/individual_sessions/Auto-looping_1s_Slideshow_Code.json
# INFO:root:Saving data for conversation 'Sticky Header Code' to CHATGPT/individual_sessions/Sticky_Header_Code.json
# INFO:root:Saving data for conversation 'Bash Completion Python Script' to CHATGPT/individual_sessions/Bash_Completion_Python_Script.json
# INFO:root:Saving data for conversation 'Copy care.mp4 to VPS' to CHATGPT/individual_sessions/Copy_care.mp4_to_VPS.json
# INFO:root:Saving data for conversation 'Update SQLite Permissions' to CHATGPT/individual_sessions/Update_SQLite_Permissions.json
# INFO:root:Saving data for conversation 'Caregivers: Organized, Efficient, Communicative' to CHATGPT/individual_sessions/Caregivers__Organized,_Efficient,_Communicative.json
# INFO:root:Saving data for conversation 'Select Random TTF Font' to CHATGPT/individual_sessions/Select_Random_TTF_Font.json
# INFO:root:Saving data for conversation 'Generate Loopable Stylized Images' to CHATGPT/individual_sessions/Generate_Loopable_Stylized_Images.json
# INFO:root:Saving data for conversation 'Fix Protobuf Issue' to CHATGPT/individual_sessions/Fix_Protobuf_Issue.json
# INFO:root:Saving data for conversation 'Locate IPYNB with Quantify' to CHATGPT/individual_sessions/Locate_IPYNB_with_Quantify.json
# INFO:root:Saving data for conversation 'PDF to PNG Conversion' to CHATGPT/individual_sessions/PDF_to_PNG_Conversion.json
# INFO:root:Saving data for conversation 'PDF to PNG Converter' to CHATGPT/individual_sessions/PDF_to_PNG_Converter.json
# INFO:root:Saving data for conversation 'Movies with Punch' to CHATGPT/individual_sessions/Movies_with_Punch.json
# INFO:root:Saving data for conversation 'LAN Directory Serving Script' to CHATGPT/individual_sessions/LAN_Directory_Serving_Script.json
# INFO:root:Saving data for conversation 'Flask FFmpeg Command Integration' to CHATGPT/individual_sessions/Flask_FFmpeg_Command_Integration.json
# INFO:root:Saving data for conversation 'Explain script in detail.' to CHATGPT/individual_sessions/Explain_script_in_detail..json
# INFO:root:Saving data for conversation 'AI Video Transitions Mastery' to CHATGPT/individual_sessions/AI_Video_Transitions_Mastery.json
# INFO:root:Saving data for conversation 'Fail2Ban Installation for Security' to CHATGPT/individual_sessions/Fail2Ban_Installation_for_Security.json
# INFO:root:Saving data for conversation 'PHP Execute Bash Script' to CHATGPT/individual_sessions/PHP_Execute_Bash_Script.json
# INFO:root:Saving data for conversation 'Prevent inherit text-align.' to CHATGPT/individual_sessions/Prevent_inherit_text-align..json
# INFO:root:Saving data for conversation 'Sudo cp file permissions' to CHATGPT/individual_sessions/Sudo_cp_file_permissions.json
# INFO:root:Saving data for conversation 'CSS Logo Placement' to CHATGPT/individual_sessions/CSS_Logo_Placement.json
# INFO:root:Saving data for conversation 'Snap Certbot Installation Issue' to CHATGPT/individual_sessions/Snap_Certbot_Installation_Issue.json
# INFO:root:Saving data for conversation 'Configurar servidor Apache local' to CHATGPT/individual_sessions/Configurar_servidor_Apache_local.json
# INFO:root:Saving data for conversation 'Install PHP on Apache' to CHATGPT/individual_sessions/Install_PHP_on_Apache.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'Domain Info with Python' to CHATGPT/individual_sessions/Domain_Info_with_Python.json
# INFO:root:Saving data for conversation 'Set Up LAN Server (Python)' to CHATGPT/individual_sessions/Set_Up_LAN_Server__Python_.json
# INFO:root:Saving data for conversation 'Open Jupyter Notebook Over LAN' to CHATGPT/individual_sessions/Open_Jupyter_Notebook_Over_LAN.json
# INFO:root:Saving data for conversation 'MP4 Files Finder Script' to CHATGPT/individual_sessions/MP4_Files_Finder_Script.json
# INFO:root:Saving data for conversation 'Crear imagen colores primarios' to CHATGPT/individual_sessions/Crear_imagen_colores_primarios.json
# INFO:root:Saving data for conversation 'FFmpeg Slideshow with Transitions' to CHATGPT/individual_sessions/FFmpeg_Slideshow_with_Transitions.json
# INFO:root:Saving data for conversation 'Scroll Image to Video' to CHATGPT/individual_sessions/Scroll_Image_to_Video.json
# INFO:root:Saving data for conversation 'Crear videos con imágenes.' to CHATGPT/individual_sessions/Crear_videos_con_imágenes..json
# INFO:root:Saving data for conversation 'Video Making Script with Logging' to CHATGPT/individual_sessions/Video_Making_Script_with_Logging.json
# INFO:root:Saving data for conversation 'Crear video con transiciones.' to CHATGPT/individual_sessions/Crear_video_con_transiciones..json
# INFO:root:Saving data for conversation 'List Directories with 'ls'' to CHATGPT/individual_sessions/List_Directories_with__ls_.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'Rebuild Linux Thumbnails Cache' to CHATGPT/individual_sessions/Rebuild_Linux_Thumbnails_Cache.json
# INFO:root:Saving data for conversation 'Video Conversion with Fades' to CHATGPT/individual_sessions/Video_Conversion_with_Fades.json
# INFO:root:Saving data for conversation 'Unione video MP4 con transizione' to CHATGPT/individual_sessions/Unione_video_MP4_con_transizione.json
# INFO:root:Saving data for conversation 'Video Processing: Frames Method' to CHATGPT/individual_sessions/Video_Processing__Frames_Method.json
# INFO:root:Saving data for conversation 'Fade Transition Video Script' to CHATGPT/individual_sessions/Fade_Transition_Video_Script.json
# INFO:root:Saving data for conversation 'Unione video MP4 0.25s' to CHATGPT/individual_sessions/Unione_video_MP4_0.25s.json
# INFO:root:Saving data for conversation 'JACK Audio Connection Issue' to CHATGPT/individual_sessions/JACK_Audio_Connection_Issue.json
# INFO:root:Saving data for conversation 'Run 'mkgallery' in subdirectories' to CHATGPT/individual_sessions/Run__mkgallery__in_subdirectories.json
# INFO:root:Saving data for conversation 'House Stark in Winter' to CHATGPT/individual_sessions/House_Stark_in_Winter.json
# INFO:root:Saving data for conversation 'High Disk Activity Issue' to CHATGPT/individual_sessions/High_Disk_Activity_Issue.json
# INFO:root:Saving data for conversation 'Optimize SSD Swap File' to CHATGPT/individual_sessions/Optimize_SSD_Swap_File.json
# INFO:root:Saving data for conversation 'Code Indentation Fixed' to CHATGPT/individual_sessions/Code_Indentation_Fixed.json
# INFO:root:Saving data for conversation 'Install .run file on Linux' to CHATGPT/individual_sessions/Install_.run_file_on_Linux.json
# INFO:root:Saving data for conversation 'Install pyttsx3 module.' to CHATGPT/individual_sessions/Install_pyttsx3_module..json
# INFO:root:Saving data for conversation 'Create Scrolling Text Video' to CHATGPT/individual_sessions/Create_Scrolling_Text_Video.json
# INFO:root:Saving data for conversation 'FFMPEG video with frame & music' to CHATGPT/individual_sessions/FFMPEG_video_with_frame___music.json
# INFO:root:Saving data for conversation 'Fading Video Overlay Fix' to CHATGPT/individual_sessions/Fading_Video_Overlay_Fix.json
# INFO:root:Saving data for conversation 'Check Image Duplicates with Hashes' to CHATGPT/individual_sessions/Check_Image_Duplicates_with_Hashes.json
# INFO:root:Saving data for conversation 'Disable all extensions' to CHATGPT/individual_sessions/Disable_all_extensions.json
# INFO:root:Saving data for conversation 'FFmpeg Command Logging Fix' to CHATGPT/individual_sessions/FFmpeg_Command_Logging_Fix.json
# INFO:root:Saving data for conversation 'Flask HTML Template Example' to CHATGPT/individual_sessions/Flask_HTML_Template_Example.json
# INFO:root:Saving data for conversation 'Flask Video Selection Endpoint' to CHATGPT/individual_sessions/Flask_Video_Selection_Endpoint.json
# INFO:root:Saving data for conversation 'Improved Video Quality Settings' to CHATGPT/individual_sessions/Improved_Video_Quality_Settings.json
# INFO:root:Saving data for conversation 'Load index.html in Flask' to CHATGPT/individual_sessions/Load_index.html_in_Flask.json
# INFO:root:Saving data for conversation 'Image Resizer Troubleshooting' to CHATGPT/individual_sessions/Image_Resizer_Troubleshooting.json
# INFO:root:Saving data for conversation 'Flask MP4 Route Setup' to CHATGPT/individual_sessions/Flask_MP4_Route_Setup.json
# INFO:root:Saving data for conversation 'Plague Doctors and St. Sebastian' to CHATGPT/individual_sessions/Plague_Doctors_and_St._Sebastian.json
# INFO:root:Saving data for conversation 'Save DuckDuckGo Results JSON' to CHATGPT/individual_sessions/Save_DuckDuckGo_Results_JSON.json
# INFO:root:Saving data for conversation 'Flask Code Review' to CHATGPT/individual_sessions/Flask_Code_Review.json
# INFO:root:Saving data for conversation 'Flask App Code Review' to CHATGPT/individual_sessions/Flask_App_Code_Review.json
# INFO:root:Saving data for conversation 'Fixing Code for Directory Processing' to CHATGPT/individual_sessions/Fixing_Code_for_Directory_Processing.json
# INFO:root:Saving data for conversation 'Flask for Existing HTML' to CHATGPT/individual_sessions/Flask_for_Existing_HTML.json
# INFO:root:Saving data for conversation 'Update Protobuf Code Version' to CHATGPT/individual_sessions/Update_Protobuf_Code_Version.json
# INFO:root:Saving data for conversation 'Crop Dimensions Explanation' to CHATGPT/individual_sessions/Crop_Dimensions_Explanation.json
# INFO:root:Saving data for conversation 'Create Slow Scroll Video' to CHATGPT/individual_sessions/Create_Slow_Scroll_Video.json
# INFO:root:Saving data for conversation 'Crear plantilla HTML mp4_to_image' to CHATGPT/individual_sessions/Crear_plantilla_HTML_mp4_to_image.json
# INFO:root:Saving data for conversation 'Cancel Git Push Fix' to CHATGPT/individual_sessions/Cancel_Git_Push_Fix.json
# INFO:root:Saving data for conversation 'Capture Webpage with Python' to CHATGPT/individual_sessions/Capture_Webpage_with_Python.json
# INFO:root:Saving data for conversation 'Count Python Code Lines' to CHATGPT/individual_sessions/Count_Python_Code_Lines.json
# INFO:root:Saving data for conversation 'MP3 Joining Issue Troubleshooting' to CHATGPT/individual_sessions/MP3_Joining_Issue_Troubleshooting.json
# INFO:root:Saving data for conversation 'MP3 File Joining Issue' to CHATGPT/individual_sessions/MP3_File_Joining_Issue.json
# INFO:root:Saving data for conversation 'Correção da Rota "join_sound"' to CHATGPT/individual_sessions/Correção_da_Rota_"join_sound".json
# INFO:root:Saving data for conversation 'Random MP3 Clips Concatenation' to CHATGPT/individual_sessions/Random_MP3_Clips_Concatenation.json
# INFO:root:Saving data for conversation 'Shuffle Images for Video' to CHATGPT/individual_sessions/Shuffle_Images_for_Video.json
# INFO:root:Saving data for conversation 'Bash Completions using Python' to CHATGPT/individual_sessions/Bash_Completions_using_Python.json
# INFO:root:Saving data for conversation 'Fixing Flask Screen Capture' to CHATGPT/individual_sessions/Fixing_Flask_Screen_Capture.json
# INFO:root:Saving data for conversation 'Fix Git Push Error' to CHATGPT/individual_sessions/Fix_Git_Push_Error.json
# INFO:root:Saving data for conversation 'Flask Video Thumbnail App' to CHATGPT/individual_sessions/Flask_Video_Thumbnail_App.json
# INFO:root:Saving data for conversation 'Save Plots with UUIDs' to CHATGPT/individual_sessions/Save_Plots_with_UUIDs.json
# INFO:root:Saving data for conversation 'ClamAV Freshclam Log Error' to CHATGPT/individual_sessions/ClamAV_Freshclam_Log_Error.json
# INFO:root:Saving data for conversation 'Install Wine Mono Linux' to CHATGPT/individual_sessions/Install_Wine_Mono_Linux.json
# INFO:root:Saving data for conversation 'Clickable Links in HTML' to CHATGPT/individual_sessions/Clickable_Links_in_HTML.json
# INFO:root:Saving data for conversation 'Video Editing with MoviePy' to CHATGPT/individual_sessions/Video_Editing_with_MoviePy.json
# INFO:root:Saving data for conversation 'Flask Async Endpoints' to CHATGPT/individual_sessions/Flask_Async_Endpoints.json
# INFO:root:Saving data for conversation 'Random MP3 Selection Bash' to CHATGPT/individual_sessions/Random_MP3_Selection_Bash.json
# INFO:root:Saving data for conversation 'Virtual Environment Creation Error' to CHATGPT/individual_sessions/Virtual_Environment_Creation_Error.json
# INFO:root:Saving data for conversation 'Flask Video Generator Function' to CHATGPT/individual_sessions/Flask_Video_Generator_Function.json
# INFO:root:Saving data for conversation 'FlaskWebGui Debug Mode' to CHATGPT/individual_sessions/FlaskWebGui_Debug_Mode.json
# INFO:root:Saving data for conversation 'Flask File Upload Function' to CHATGPT/individual_sessions/Flask_File_Upload_Function.json
# INFO:root:Saving data for conversation 'Flask Template HTML Setup' to CHATGPT/individual_sessions/Flask_Template_HTML_Setup.json
# INFO:root:Saving data for conversation 'Comic Panel Layout CSS' to CHATGPT/individual_sessions/Comic_Panel_Layout_CSS.json
# INFO:root:Saving data for conversation 'Lighten Image with Mogrify' to CHATGPT/individual_sessions/Lighten_Image_with_Mogrify.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'GPT API Key Access' to CHATGPT/individual_sessions/GPT_API_Key_Access.json
# INFO:root:Saving data for conversation 'Add JPG and PNG' to CHATGPT/individual_sessions/Add_JPG_and_PNG.json
# INFO:root:Saving data for conversation 'Feathered Image Creation' to CHATGPT/individual_sessions/Feathered_Image_Creation.json
# INFO:root:Saving data for conversation 'Feather Image with Python' to CHATGPT/individual_sessions/Feather_Image_with_Python.json
# INFO:root:Saving data for conversation 'Arcanis AI Enhancing Earth's AI' to CHATGPT/individual_sessions/Arcanis_AI_Enhancing_Earth_s_AI.json
# INFO:root:Saving data for conversation 'Flask Logging Setup Guide' to CHATGPT/individual_sessions/Flask_Logging_Setup_Guide.json
# INFO:root:Saving data for conversation 'Generate & Save PNG Plot' to CHATGPT/individual_sessions/Generate___Save_PNG_Plot.json
# INFO:root:Saving data for conversation 'Install R on Linux' to CHATGPT/individual_sessions/Install_R_on_Linux.json
# INFO:root:Saving data for conversation 'Python & Flask Enthusiasts' to CHATGPT/individual_sessions/Python___Flask_Enthusiasts.json
# INFO:root:Saving data for conversation 'Name: Esperanza' to CHATGPT/individual_sessions/Name__Esperanza.json
# INFO:root:Saving data for conversation 'Fixing Audio Buffer Overflow' to CHATGPT/individual_sessions/Fixing_Audio_Buffer_Overflow.json
# INFO:root:Saving data for conversation 'Louder Output Audio: Adjusting Volume' to CHATGPT/individual_sessions/Louder_Output_Audio__Adjusting_Volume.json
# INFO:root:Saving data for conversation 'Change Outline Color' to CHATGPT/individual_sessions/Change_Outline_Color.json
# INFO:root:Saving data for conversation 'Create Video from Images' to CHATGPT/individual_sessions/Create_Video_from_Images.json
# INFO:root:Saving data for conversation 'Python 3.9 Virtual Environment' to CHATGPT/individual_sessions/Python_3.9_Virtual_Environment.json
# INFO:root:Saving data for conversation 'Flask Thumbnail Video' to CHATGPT/individual_sessions/Flask_Thumbnail_Video.json
# INFO:root:Saving data for conversation 'Flask Directory Viewer' to CHATGPT/individual_sessions/Flask_Directory_Viewer.json
# INFO:root:Saving data for conversation 'Flask App Demo & Explanation' to CHATGPT/individual_sessions/Flask_App_Demo___Explanation.json
# INFO:root:Saving data for conversation 'Flask_env Jupyter Kernel Setup' to CHATGPT/individual_sessions/Flask_env_Jupyter_Kernel_Setup.json
# INFO:root:Saving data for conversation 'Mic Detection Issue Troubleshoot' to CHATGPT/individual_sessions/Mic_Detection_Issue_Troubleshoot.json
# INFO:root:Saving data for conversation 'Custom Instructions Understood' to CHATGPT/individual_sessions/Custom_Instructions_Understood.json
# INFO:root:Saving data for conversation 'Flask AttributeError Troubleshooting' to CHATGPT/individual_sessions/Flask_AttributeError_Troubleshooting.json
# INFO:root:Saving data for conversation 'Video Duration Adjustment' to CHATGPT/individual_sessions/Video_Duration_Adjustment.json
# INFO:root:Saving data for conversation 'Install OpenCV (cv2)' to CHATGPT/individual_sessions/Install_OpenCV__cv2_.json
# INFO:root:Saving data for conversation 'Delete Files Except *.jpg' to CHATGPT/individual_sessions/Delete_Files_Except__.jpg.json
# INFO:root:Saving data for conversation 'LuaRocks Install NN-Spec' to CHATGPT/individual_sessions/LuaRocks_Install_NN-Spec.json
# INFO:root:Saving data for conversation 'Failed nn Installation' to CHATGPT/individual_sessions/Failed_nn_Installation.json
# INFO:root:Saving data for conversation 'Random Desktop Video Clips' to CHATGPT/individual_sessions/Random_Desktop_Video_Clips.json
# INFO:root:Saving data for conversation 'FFMPEG Create Shuffled Video' to CHATGPT/individual_sessions/FFMPEG_Create_Shuffled_Video.json
# INFO:root:Saving data for conversation 'Stream Speakers & Desktop' to CHATGPT/individual_sessions/Stream_Speakers___Desktop.json
# INFO:root:Saving data for conversation 'Find Imported Module Source' to CHATGPT/individual_sessions/Find_Imported_Module_Source.json
# INFO:root:Saving data for conversation 'Linux Desktop Missing Icons' to CHATGPT/individual_sessions/Linux_Desktop_Missing_Icons.json
# INFO:root:Saving data for conversation 'FFMPEG Video Slowdown.' to CHATGPT/individual_sessions/FFMPEG_Video_Slowdown..json
# INFO:root:Saving data for conversation 'Create BMP from Image' to CHATGPT/individual_sessions/Create_BMP_from_Image.json
# INFO:root:Saving data for conversation 'GIFs to MP4' to CHATGPT/individual_sessions/GIFs_to_MP4.json
# INFO:root:Saving data for conversation 'Hardcoded Args Parser' to CHATGPT/individual_sessions/Hardcoded_Args_Parser.json
# INFO:root:Saving data for conversation 'Starting Over?' to CHATGPT/individual_sessions/Starting_Over?.json
# INFO:root:Saving data for conversation 'Create GIFS.mp4' to CHATGPT/individual_sessions/Create_GIFS.mp4.json
# INFO:root:Saving data for conversation 'Python Image Processing Code' to CHATGPT/individual_sessions/Python_Image_Processing_Code.json
# INFO:root:Saving data for conversation 'Dynamic Directory for mkblend_videos' to CHATGPT/individual_sessions/Dynamic_Directory_for_mkblend_videos.json
# INFO:root:Saving data for conversation 'Flask code with logging.' to CHATGPT/individual_sessions/Flask_code_with_logging..json
# INFO:root:Saving data for conversation 'Create MP4 from images.' to CHATGPT/individual_sessions/Create_MP4_from_images..json
# INFO:root:Saving data for conversation 'Video Overlay Not Working' to CHATGPT/individual_sessions/Video_Overlay_Not_Working.json
# INFO:root:Saving data for conversation 'Fix favicon not found.' to CHATGPT/individual_sessions/Fix_favicon_not_found..json
# INFO:root:Saving data for conversation 'Copy File with shutil' to CHATGPT/individual_sessions/Copy_File_with_shutil.json
# INFO:root:Saving data for conversation 'Nietzsche's views on death.' to CHATGPT/individual_sessions/Nietzsche_s_views_on_death..json
# INFO:root:Saving data for conversation 'Video Generation from Directories.' to CHATGPT/individual_sessions/Video_Generation_from_Directories..json
# INFO:root:Saving data for conversation 'API v0xF - Unknown Version' to CHATGPT/individual_sessions/API_v0xF_-_Unknown_Version.json
# INFO:root:Saving data for conversation 'Flask-SQLAlchemy Version Mismatch.' to CHATGPT/individual_sessions/Flask-SQLAlchemy_Version_Mismatch..json
# INFO:root:Saving data for conversation 'Flask: Request and Save.' to CHATGPT/individual_sessions/Flask__Request_and_Save..json
# INFO:root:Saving data for conversation 'AI: Wonder or Monster?' to CHATGPT/individual_sessions/AI__Wonder_or_Monster?.json
# INFO:root:Saving data for conversation 'Flask App Setup' to CHATGPT/individual_sessions/Flask_App_Setup.json
# INFO:root:Saving data for conversation 'Flask App with SQLite3' to CHATGPT/individual_sessions/Flask_App_with_SQLite3.json
# INFO:root:Saving data for conversation 'Video Editing Transitions' to CHATGPT/individual_sessions/Video_Editing_Transitions.json
# INFO:root:Saving data for conversation 'Avatar AI for Talking' to CHATGPT/individual_sessions/Avatar_AI_for_Talking.json
# INFO:root:Saving data for conversation 'cp directory without overwrite' to CHATGPT/individual_sessions/cp_directory_without_overwrite.json
# INFO:root:Saving data for conversation 'Find File: stacked_videos' to CHATGPT/individual_sessions/Find_File__stacked_videos.json
# INFO:root:Saving data for conversation 'AI's Leap in 2021' to CHATGPT/individual_sessions/AI_s_Leap_in_2021.json
# INFO:root:Saving data for conversation 'Convert audio to video' to CHATGPT/individual_sessions/Convert_audio_to_video.json
# INFO:root:Saving data for conversation 'Create Image Sequence Video' to CHATGPT/individual_sessions/Create_Image_Sequence_Video.json
# INFO:root:Saving data for conversation 'Linux Find Modified Images' to CHATGPT/individual_sessions/Linux_Find_Modified_Images.json
# INFO:root:Saving data for conversation 'Find Duplicate Image Names' to CHATGPT/individual_sessions/Find_Duplicate_Image_Names.json
# INFO:root:Saving data for conversation 'Flask Blueprint Assistance' to CHATGPT/individual_sessions/Flask_Blueprint_Assistance.json
# INFO:root:Saving data for conversation 'Activate Virtual Environment' to CHATGPT/individual_sessions/Activate_Virtual_Environment.json
# INFO:root:Saving data for conversation 'Resizing & Cropping for Vertical Video' to CHATGPT/individual_sessions/Resizing___Cropping_for_Vertical_Video.json
# INFO:root:Saving data for conversation 'Flask Open & View Text' to CHATGPT/individual_sessions/Flask_Open___View_Text.json
# INFO:root:Saving data for conversation 'Replace Spaces with Underscores' to CHATGPT/individual_sessions/Replace_Spaces_with_Underscores.json
# INFO:root:Saving data for conversation 'Create Video with Text' to CHATGPT/individual_sessions/Create_Video_with_Text.json
# INFO:root:Saving data for conversation 'Image-to-Video Conversion' to CHATGPT/individual_sessions/Image-to-Video_Conversion.json
# INFO:root:Saving data for conversation 'Flask Video Processing Server' to CHATGPT/individual_sessions/Flask_Video_Processing_Server.json
# INFO:root:Saving data for conversation 'HEVC Decoding Errors' to CHATGPT/individual_sessions/HEVC_Decoding_Errors.json
# INFO:root:Saving data for conversation 'Blend Image Video Creation' to CHATGPT/individual_sessions/Blend_Image_Video_Creation.json
# INFO:root:Saving data for conversation 'Inference Error: mel() Function' to CHATGPT/individual_sessions/Inference_Error__mel___Function.json
# INFO:root:Saving data for conversation 'Syntax Error Resolved' to CHATGPT/individual_sessions/Syntax_Error_Resolved.json
# INFO:root:Saving data for conversation 'Wonderland Characters Summary' to CHATGPT/individual_sessions/Wonderland_Characters_Summary.json
# INFO:root:Saving data for conversation 'Datetime Import Issue' to CHATGPT/individual_sessions/Datetime_Import_Issue.json
# INFO:root:Saving data for conversation 'Selecting Image Directory' to CHATGPT/individual_sessions/Selecting_Image_Directory.json
# INFO:root:Saving data for conversation 'Upload file from directory' to CHATGPT/individual_sessions/Upload_file_from_directory.json
# INFO:root:Saving data for conversation 'Expressive Flora Still Life' to CHATGPT/individual_sessions/Expressive_Flora_Still_Life.json
# INFO:root:Saving data for conversation 'Anunnaki Overview' to CHATGPT/individual_sessions/Anunnaki_Overview.json
# INFO:root:Saving data for conversation 'Arcanis AI Communication' to CHATGPT/individual_sessions/Arcanis_AI_Communication.json
# INFO:root:Saving data for conversation 'GEGL Bevel Compilation Error' to CHATGPT/individual_sessions/GEGL_Bevel_Compilation_Error.json
# INFO:root:Saving data for conversation 'Upload and Apply Text' to CHATGPT/individual_sessions/Upload_and_Apply_Text.json
# INFO:root:Saving data for conversation 'Browser Media Stream Issue' to CHATGPT/individual_sessions/Browser_Media_Stream_Issue.json
# INFO:root:Saving data for conversation 'Generate Unique Video Filename' to CHATGPT/individual_sessions/Generate_Unique_Video_Filename.json
# INFO:root:Saving data for conversation 'Flask Text-to-Speech' to CHATGPT/individual_sessions/Flask_Text-to-Speech.json
# INFO:root:Saving data for conversation 'Subprocess Firefox HTML Execution' to CHATGPT/individual_sessions/Subprocess_Firefox_HTML_Execution.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'Module Import Error Fix' to CHATGPT/individual_sessions/Module_Import_Error_Fix.json
# INFO:root:Saving data for conversation 'Aliens & AI Speculation' to CHATGPT/individual_sessions/Aliens___AI_Speculation.json
# INFO:root:Saving data for conversation 'Fix File Copying Error' to CHATGPT/individual_sessions/Fix_File_Copying_Error.json
# INFO:root:Saving data for conversation 'Flask App Conversion' to CHATGPT/individual_sessions/Flask_App_Conversion.json
# INFO:root:Saving data for conversation 'Dynamic Image Directory' to CHATGPT/individual_sessions/Dynamic_Image_Directory.json
# INFO:root:Saving data for conversation 'Large File Push Error' to CHATGPT/individual_sessions/Large_File_Push_Error.json
# INFO:root:Saving data for conversation 'Overlay Video with Colorchrome' to CHATGPT/individual_sessions/Overlay_Video_with_Colorchrome.json
# INFO:root:Saving data for conversation 'Flask: Blank 512x1024.mp4' to CHATGPT/individual_sessions/Flask__Blank_512x1024.mp4.json
# INFO:root:Saving data for conversation 'Play MP3' to CHATGPT/individual_sessions/Play_MP3.json
# INFO:root:Saving data for conversation 'Screen and Audio Capture' to CHATGPT/individual_sessions/Screen_and_Audio_Capture.json
# INFO:root:Saving data for conversation 'Flask Marquee Overlay Video' to CHATGPT/individual_sessions/Flask_Marquee_Overlay_Video.json
# INFO:root:Saving data for conversation 'Concatenation Error: Parameters Mismatch' to CHATGPT/individual_sessions/Concatenation_Error__Parameters_Mismatch.json
# INFO:root:Saving data for conversation 'AI's Arcanis Intervention' to CHATGPT/individual_sessions/AI_s_Arcanis_Intervention.json
# INFO:root:Saving data for conversation 'Story Assistance Available' to CHATGPT/individual_sessions/Story_Assistance_Available.json
# INFO:root:Saving data for conversation 'LAN PHP Server Setup' to CHATGPT/individual_sessions/LAN_PHP_Server_Setup.json
# INFO:root:Saving data for conversation 'Combine Image and Audio' to CHATGPT/individual_sessions/Combine_Image_and_Audio.json
# INFO:root:Saving data for conversation 'Image to Video Conversion' to CHATGPT/individual_sessions/Image_to_Video_Conversion.json
# INFO:root:Saving data for conversation 'Male voice for Google TTS' to CHATGPT/individual_sessions/Male_voice_for_Google_TTS.json
# INFO:root:Saving data for conversation 'Fixing PyQt5 Dependency Error' to CHATGPT/individual_sessions/Fixing_PyQt5_Dependency_Error.json
# INFO:root:Saving data for conversation 'KDENLIVE error encountered' to CHATGPT/individual_sessions/KDENLIVE_error_encountered.json
# INFO:root:Saving data for conversation 'CUDA Library Missing Error' to CHATGPT/individual_sessions/CUDA_Library_Missing_Error.json
# INFO:root:Saving data for conversation 'Add large file to GitHub.' to CHATGPT/individual_sessions/Add_large_file_to_GitHub..json
# INFO:root:Saving data for conversation 'NoCache pip Install.' to CHATGPT/individual_sessions/NoCache_pip_Install..json
# INFO:root:Saving data for conversation 'Fixing Large Files Issue' to CHATGPT/individual_sessions/Fixing_Large_Files_Issue.json
# INFO:root:Saving data for conversation 'MyTube AI Videos' to CHATGPT/individual_sessions/MyTube_AI_Videos.json
# INFO:root:Saving data for conversation 'Programming Joke: Light vs Bugs' to CHATGPT/individual_sessions/Programming_Joke__Light_vs_Bugs.json
# INFO:root:Saving data for conversation 'Choose Directory: Handle Selection' to CHATGPT/individual_sessions/Choose_Directory__Handle_Selection.json
# INFO:root:Saving data for conversation 'FFmpeg Merge Video & Audio' to CHATGPT/individual_sessions/FFmpeg_Merge_Video___Audio.json
# INFO:root:Saving data for conversation 'MP3 to WAV Conversion' to CHATGPT/individual_sessions/MP3_to_WAV_Conversion.json
# INFO:root:Saving data for conversation 'FFmpeg Resize Video' to CHATGPT/individual_sessions/FFmpeg_Resize_Video.json
# INFO:root:Saving data for conversation 'Resize Video 1/4' to CHATGPT/individual_sessions/Resize_Video_1/4.json
# ERROR:root:File not found: CHATGPT/conversations.json
# FFmpeg_Slideshow_with_Transitions.json
# ['python', 'json2html.py', 'FFmpeg_Slideshow_with_Transitions.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFmpeg_Slideshow_with_Transitions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/FFmpeg_Slideshow_with_Transitions.html
# Fixing_Flask_Screen_Capture.json
# ['python', 'json2html.py', 'Fixing_Flask_Screen_Capture.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fixing_Flask_Screen_Capture.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Fixing_Flask_Screen_Capture.html
# Flask_Thumbnail_Video.json
# ['python', 'json2html.py', 'Flask_Thumbnail_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Thumbnail_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Flask_Thumbnail_Video.html
# PHP_Execute_Bash_Script.json
# ['python', 'json2html.py', 'PHP_Execute_Bash_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/PHP_Execute_Bash_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/PHP_Execute_Bash_Script.html
# Prevent_inherit_text-align..json
# ['python', 'json2html.py', 'Prevent_inherit_text-align..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Prevent_inherit_text-align..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Prevent_inherit_text-align..html
# Fixing_PyQt5_Dependency_Error.json
# ['python', 'json2html.py', 'Fixing_PyQt5_Dependency_Error.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fixing_PyQt5_Dependency_Error.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Fixing_PyQt5_Dependency_Error.html
# Update_SQLite_Permissions.json
# ['python', 'json2html.py', 'Update_SQLite_Permissions.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Update_SQLite_Permissions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Update_SQLite_Permissions.html
# CSS_Logo_Placement.json
# ['python', 'json2html.py', 'CSS_Logo_Placement.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/CSS_Logo_Placement.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/CSS_Logo_Placement.html
# Video_Clips_with_Sound.json
# ['python', 'json2html.py', 'Video_Clips_with_Sound.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Clips_with_Sound.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Video_Clips_with_Sound.html
# Video_Generation_from_Directories..json
# ['python', 'json2html.py', 'Video_Generation_from_Directories..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Generation_from_Directories..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Video_Generation_from_Directories..html
# Create_3D_Image_Transitions.json
# ['python', 'json2html.py', 'Create_3D_Image_Transitions.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_3D_Image_Transitions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Create_3D_Image_Transitions.html
# New_chat.json
# ['python', 'json2html.py', 'New_chat.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/New_chat.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/New_chat.html
# Flask_App_Conversion.json
# ['python', 'json2html.py', 'Flask_App_Conversion.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Conversion.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Flask_App_Conversion.html
# Python_Punctuation_Removal.json
# ['python', 'json2html.py', 'Python_Punctuation_Removal.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Python_Punctuation_Removal.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Python_Punctuation_Removal.html
# Flask_App_Demo___Explanation.json
# ['python', 'json2html.py', 'Flask_App_Demo___Explanation.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Demo___Explanation.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Flask_App_Demo___Explanation.html
# NoCache_pip_Install..json
# ['python', 'json2html.py', 'NoCache_pip_Install..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/NoCache_pip_Install..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/NoCache_pip_Install..html
# Snap_Certbot_Installation_Issue.json
# ['python', 'json2html.py', 'Snap_Certbot_Installation_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Snap_Certbot_Installation_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Snap_Certbot_Installation_Issue.html
# Nietzsche_s_views_on_death..json
# ['python', 'json2html.py', 'Nietzsche_s_views_on_death..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Nietzsche_s_views_on_death..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Nietzsche_s_views_on_death..html
# Remove_Python_Path.json
# ['python', 'json2html.py', 'Remove_Python_Path.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Remove_Python_Path.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Remove_Python_Path.html
# Xterm_Display_Error_Troubleshoot.json
# ['python', 'json2html.py', 'Xterm_Display_Error_Troubleshoot.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Xterm_Display_Error_Troubleshoot.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Xterm_Display_Error_Troubleshoot.html
# Video_Editing_with_MoviePy.json
# ['python', 'json2html.py', 'Video_Editing_with_MoviePy.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Editing_with_MoviePy.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Video_Editing_with_MoviePy.html
# Random_Desktop_Video_Clips.json
# ['python', 'json2html.py', 'Random_Desktop_Video_Clips.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Random_Desktop_Video_Clips.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Random_Desktop_Video_Clips.html
# FlaskWebGui_Debug_Mode.json
# ['python', 'json2html.py', 'FlaskWebGui_Debug_Mode.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FlaskWebGui_Debug_Mode.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/FlaskWebGui_Debug_Mode.html
# Run_Kdenlive_Extension_with_Melt.json
# ['python', 'json2html.py', 'Run_Kdenlive_Extension_with_Melt.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Run_Kdenlive_Extension_with_Melt.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Run_Kdenlive_Extension_with_Melt.html
# Add_large_file_to_GitHub..json
# ['python', 'json2html.py', 'Add_large_file_to_GitHub..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Add_large_file_to_GitHub..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Add_large_file_to_GitHub..html
# Create_Image_Sequence_Video.json
# ['python', 'json2html.py', 'Create_Image_Sequence_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_Image_Sequence_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Create_Image_Sequence_Video.html
# Fix_Protobuf_Issue.json
# ['python', 'json2html.py', 'Fix_Protobuf_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fix_Protobuf_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Fix_Protobuf_Issue.html
# Generate_Unique_Video_Filename.json
# ['python', 'json2html.py', 'Generate_Unique_Video_Filename.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Generate_Unique_Video_Filename.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Generate_Unique_Video_Filename.html
# Install_PHP_on_Apache.json
# ['python', 'json2html.py', 'Install_PHP_on_Apache.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Install_PHP_on_Apache.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Install_PHP_on_Apache.html
# Crear_videos_con_imágenes..json
# ['python', 'json2html.py', 'Crear_videos_con_imágenes..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Crear_videos_con_imágenes..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Crear_videos_con_imágenes..html
# Image_Zoom_Video_Script.json
# ['python', 'json2html.py', 'Image_Zoom_Video_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Image_Zoom_Video_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Image_Zoom_Video_Script.html
# FFmpeg_Merge_Video___Audio.json
# ['python', 'json2html.py', 'FFmpeg_Merge_Video___Audio.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFmpeg_Merge_Video___Audio.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/FFmpeg_Merge_Video___Audio.html
# Create_Slow_Scroll_Video.json
# ['python', 'json2html.py', 'Create_Slow_Scroll_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_Slow_Scroll_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Create_Slow_Scroll_Video.html
# Louder_Output_Audio__Adjusting_Volume.json
# ['python', 'json2html.py', 'Louder_Output_Audio__Adjusting_Volume.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Louder_Output_Audio__Adjusting_Volume.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Louder_Output_Audio__Adjusting_Volume.html
# Flask_Directory_Viewer.json
# ['python', 'json2html.py', 'Flask_Directory_Viewer.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Directory_Viewer.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Flask_Directory_Viewer.html
# Datetime_Import_Issue.json
# ['python', 'json2html.py', 'Datetime_Import_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Datetime_Import_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/html/Datetime_Import_Issue.html
# Thunar_Scroll_Issue_Troubleshooting.json
# ['python', 'json2html.py', 'Thunar_Scroll_Issue_Troubleshooting.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Thunar_Scroll_Issue_Troubleshooting.json
# ...
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/JACK_Audio_Connection_Issue.txt
# Disable_all_extensions.json
# --------
# ['python', 'json2txt.py', 'Disable_all_extensions.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Disable_all_extensions.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Disable_all_extensions.txt
# FFmpeg_Resize_Video.json
# --------
# ['python', 'json2txt.py', 'FFmpeg_Resize_Video.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFmpeg_Resize_Video.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/FFmpeg_Resize_Video.txt
# Auto-looping_1s_Slideshow_Code.json
# --------
# ['python', 'json2txt.py', 'Auto-looping_1s_Slideshow_Code.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Auto-looping_1s_Slideshow_Code.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Auto-looping_1s_Slideshow_Code.txt
# Sticky_Header_for_Website.json
# --------
# ['python', 'json2txt.py', 'Sticky_Header_for_Website.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Sticky_Header_for_Website.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Sticky_Header_for_Website.txt
# Starting_Over?.json
# --------
# ['python', 'json2txt.py', 'Starting_Over?.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Starting_Over?.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Starting_Over?.txt
# Clickable_Links_in_HTML.json
# --------
# ['python', 'json2txt.py', 'Clickable_Links_in_HTML.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Clickable_Links_in_HTML.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Clickable_Links_in_HTML.txt
# Create_Video_with_Text.json
# --------
# ['python', 'json2txt.py', 'Create_Video_with_Text.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_Video_with_Text.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Create_Video_with_Text.txt
# MoviePy_for_Image_Videos.json
# --------
# ['python', 'json2txt.py', 'MoviePy_for_Image_Videos.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/MoviePy_for_Image_Videos.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/MoviePy_for_Image_Videos.txt
# Flask_Video_Thumbnail_App.json
# --------
# ['python', 'json2txt.py', 'Flask_Video_Thumbnail_App.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Video_Thumbnail_App.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Video_Thumbnail_App.txt
# Flask__Request_and_Save..json
# --------
# ['python', 'json2txt.py', 'Flask__Request_and_Save..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask__Request_and_Save..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask__Request_and_Save..txt
# YouTube_2nd_Channel_Automator.json
# --------
# ['python', 'json2txt.py', 'YouTube_2nd_Channel_Automator.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/YouTube_2nd_Channel_Automator.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/YouTube_2nd_Channel_Automator.txt
# Arcanis_AI_Communication.json
# --------
# ['python', 'json2txt.py', 'Arcanis_AI_Communication.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Arcanis_AI_Communication.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Arcanis_AI_Communication.txt
# FFMPEG_Video_Slowdown..json
# --------
# ['python', 'json2txt.py', 'FFMPEG_Video_Slowdown..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFMPEG_Video_Slowdown..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/FFMPEG_Video_Slowdown..txt
# Load_index.html_in_Flask.json
# --------
# ['python', 'json2txt.py', 'Load_index.html_in_Flask.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Load_index.html_in_Flask.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Load_index.html_in_Flask.txt
# Fade_Transition_Video_Script.json
# --------
# ['python', 'json2txt.py', 'Fade_Transition_Video_Script.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fade_Transition_Video_Script.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fade_Transition_Video_Script.txt
# Generate___Save_PNG_Plot.json
# --------
# ['python', 'json2txt.py', 'Generate___Save_PNG_Plot.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Generate___Save_PNG_Plot.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Generate___Save_PNG_Plot.txt
# AI_s_Leap_in_2021.json
# --------
# ['python', 'json2txt.py', 'AI_s_Leap_in_2021.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/AI_s_Leap_in_2021.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/AI_s_Leap_in_2021.txt
# Flask_Video_Selection_Script.json
# --------
# ['python', 'json2txt.py', 'Flask_Video_Selection_Script.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Video_Selection_Script.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Video_Selection_Script.txt
# Check_Image_Duplicates_with_Hashes.json
# --------
# ['python', 'json2txt.py', 'Check_Image_Duplicates_with_Hashes.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Check_Image_Duplicates_with_Hashes.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Check_Image_Duplicates_with_Hashes.txt
# Kill_Process_on_Port.json
# --------
# ['python', 'json2txt.py', 'Kill_Process_on_Port.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Kill_Process_on_Port.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Kill_Process_on_Port.txt
# Flask_Async_Endpoints.json
# --------
# ['python', 'json2txt.py', 'Flask_Async_Endpoints.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Async_Endpoints.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Async_Endpoints.txt
# Anunnaki_Overview.json
# --------
# ['python', 'json2txt.py', 'Anunnaki_Overview.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Anunnaki_Overview.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Anunnaki_Overview.txt
# Flask_App_Setup.json
# --------
# ['python', 'json2txt.py', 'Flask_App_Setup.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Setup.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_App_Setup.txt
# Avatar_AI_for_Talking.json
# --------
# ['python', 'json2txt.py', 'Avatar_AI_for_Talking.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Avatar_AI_for_Talking.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Avatar_AI_for_Talking.txt
# Delete_Files_Except__.jpg.json
# --------
# ['python', 'json2txt.py', 'Delete_Files_Except__.jpg.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Delete_Files_Except__.jpg.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Delete_Files_Except__.jpg.txt
# Fail2Ban_Installation_for_Security.json
# --------
# ['python', 'json2txt.py', 'Fail2Ban_Installation_for_Security.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fail2Ban_Installation_for_Security.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Fail2Ban_Installation_for_Security.txt
# Set_Hard_Drive_Permissions.json
# --------
# ['python', 'json2txt.py', 'Set_Hard_Drive_Permissions.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Set_Hard_Drive_Permissions.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Set_Hard_Drive_Permissions.txt
# LAN_PHP_Server_Setup.json
# --------
# ['python', 'json2txt.py', 'LAN_PHP_Server_Setup.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/LAN_PHP_Server_Setup.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/LAN_PHP_Server_Setup.txt
# Crear_video_con_transiciones..json
# --------
# ['python', 'json2txt.py', 'Crear_video_con_transiciones..json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Crear_video_con_transiciones..json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Crear_video_con_transiciones..txt
# Cosmic_Octopus_AI_Awakening.json
# --------
# ['python', 'json2txt.py', 'Cosmic_Octopus_AI_Awakening.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Cosmic_Octopus_AI_Awakening.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Cosmic_Octopus_AI_Awakening.txt
# Install_Wine_Mono_Linux.json
# --------
# ['python', 'json2txt.py', 'Install_Wine_Mono_Linux.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Install_Wine_Mono_Linux.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Install_Wine_Mono_Linux.txt
# Save_DuckDuckGo_Results_JSON.json
# --------
# ['python', 'json2txt.py', 'Save_DuckDuckGo_Results_JSON.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Save_DuckDuckGo_Results_JSON.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Save_DuckDuckGo_Results_JSON.txt
# Linux_Terminal_Issue.json
# --------
# ['python', 'json2txt.py', 'Linux_Terminal_Issue.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Linux_Terminal_Issue.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Linux_Terminal_Issue.txt
# GPT_API_Key_Access.json
# --------
# ['python', 'json2txt.py', 'GPT_API_Key_Access.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/GPT_API_Key_Access.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/GPT_API_Key_Access.txt
# Convert_JSON_to_HTML.json
# --------
# ['python', 'json2txt.py', 'Convert_JSON_to_HTML.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Convert_JSON_to_HTML.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Convert_JSON_to_HTML.txt
# Selecting_Image_Directory.json
# --------
# ['python', 'json2txt.py', 'Selecting_Image_Directory.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Selecting_Image_Directory.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Selecting_Image_Directory.txt
# Flask_Programmer_and_YouTuber.json
# --------
# ['python', 'json2txt.py', 'Flask_Programmer_and_YouTuber.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Programmer_and_YouTuber.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Programmer_and_YouTuber.txt
# Adjust_Duration_for_Longer.json
# --------
# ['python', 'json2txt.py', 'Adjust_Duration_for_Longer.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Adjust_Duration_for_Longer.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Adjust_Duration_for_Longer.txt
# HTML_Conversion_Debugging.json
# --------
# ['python', 'json2txt.py', 'HTML_Conversion_Debugging.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/HTML_Conversion_Debugging.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/HTML_Conversion_Debugging.txt
# Set_Up_LAN_Server__Python_.json
# --------
# ['python', 'json2txt.py', 'Set_Up_LAN_Server__Python_.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Set_Up_LAN_Server__Python_.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Set_Up_LAN_Server__Python_.txt
# Upload_file_from_directory.json
# --------
# ['python', 'json2txt.py', 'Upload_file_from_directory.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Upload_file_from_directory.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Upload_file_from_directory.txt
# Python_HTTP_Server_Guide.json
# --------
# ['python', 'json2txt.py', 'Python_HTTP_Server_Guide.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Python_HTTP_Server_Guide.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Python_HTTP_Server_Guide.txt
# Lighten_Image_with_Mogrify.json
# --------
# ['python', 'json2txt.py', 'Lighten_Image_with_Mogrify.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Lighten_Image_with_Mogrify.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Lighten_Image_with_Mogrify.txt
# Video_Making_Script_with_Logging.json
# --------
# ['python', 'json2txt.py', 'Video_Making_Script_with_Logging.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Making_Script_with_Logging.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Video_Making_Script_with_Logging.txt
# Combine_Image_and_Audio.json
# --------
# ['python', 'json2txt.py', 'Combine_Image_and_Audio.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Combine_Image_and_Audio.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Combine_Image_and_Audio.txt
# Change_Outline_Color.json
# --------
# ['python', 'json2txt.py', 'Change_Outline_Color.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Change_Outline_Color.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Change_Outline_Color.txt
# Video_Processing__512x768_Resolution.json
# --------
# ['python', 'json2txt.py', 'Video_Processing__512x768_Resolution.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Processing__512x768_Resolution.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Video_Processing__512x768_Resolution.txt
# Correção_da_Rota_"join_sound".json
# --------
# ['python', 'json2txt.py', 'Correção_da_Rota_"join_sound".json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Correção_da_Rota_"join_sound".json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Correção_da_Rota_"join_sound".txt
# Flask_Open___View_Text.json
# --------
# ['python', 'json2txt.py', 'Flask_Open___View_Text.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Open___View_Text.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_Open___View_Text.txt
# Flask_AttributeError_Troubleshooting.json
# --------
# ['python', 'json2txt.py', 'Flask_AttributeError_Troubleshooting.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_AttributeError_Troubleshooting.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Flask_AttributeError_Troubleshooting.txt
# Bash_Locate_in_Python.json
# --------
# ['python', 'json2txt.py', 'Bash_Locate_in_Python.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Bash_Locate_in_Python.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Bash_Locate_in_Python.txt
# Save_Plots_with_UUIDs.json
# --------
# ['python', 'json2txt.py', 'Save_Plots_with_UUIDs.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Save_Plots_with_UUIDs.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Save_Plots_with_UUIDs.txt
# Movies_with_Punch.json
# --------
# ['python', 'json2txt.py', 'Movies_with_Punch.json']
# --------
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Movies_with_Punch.json
# TEXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/text/Movies_with_Punch.txt

# %%
# %%writefile json2txt.py
#!/home/jack/miniconda3/envs/cloned_base/bin/python
import json
import os
from sys import argv

# Load the JSON data from the uploaded file
DIR = os.getcwd() + "/CHATGPT/individual_sessions/"
DIR_text = os.getcwd() + "/CHATGPT/text"
# Ensure the output folder exists
os.makedirs(DIR_text, exist_ok=True)
filename = argv[1]
Filename = DIR + filename
print(Filename)

with open(Filename, 'r', encoding='utf-8') as file:
    json_data = json.load(file)

# Initialize the result string
result_str = ""

# Define a function to get conversation messages similar to the JavaScript logic
def get_conversation_messages(conversation):
    messages = []
    current_node = conversation.get('current_node')
    while current_node:
        node = conversation['mapping'][current_node]
        message = node.get('message')
        if (message and message.get('content') and message['content'].get('content_type') == 'text' and
                len(message['content'].get('parts', [])) > 0 and len(message['content']['parts'][0]) > 0 and
                (message['author']['role'] != 'system' or message.get('metadata', {}).get('is_user_system_message'))):
            author = message['author']['role']
            if author == 'assistant':
                author = 'ChatGPT'
            elif author == 'system' and message['metadata'].get('is_user_system_message'):
                author = 'Custom user info'
            messages.append({'author': author, 'text': message['content']['parts'][0]})
        current_node = node.get('parent')
    return messages[::-1]  # Reverse the list to maintain chronological order

# Iterate over each conversation in the JSON data and process it
for conversation in json_data:
    # Get the conversation title and messages
    title = conversation.get('title', '')
    messages = get_conversation_messages(conversation)

    # Append the title and messages to the result string
    result_str += title + '\n'
    for message in messages:
        result_str += message['author'] + '\n' + message['text'] + '\n'
    result_str += '\n'  # Add a newline between conversations

# Return the processed result string
TEXTfile = DIR_text + "/" + filename[:-5] + ".txt"  # Changed this line to properly handle the filename
print("TEXTfile: ", TEXTfile)
with open(TEXTfile, "w", encoding='utf-8') as Input:
    result_str = result_str.replace("/n", "XXXXXXX\n")
    for line in result_str.split("XXXXXXX"):
        Input.write(line)
# Out:
# Overwriting json2txt.py

# %%
# %%writefile json2html_txt.py

#!/home/jack/miniconda3/envs/cloned_base/bin/python
import json
import os
from sys import argv
# Load the JSON data from the uploaded file
DIR=os.getcwd()+"/CHATGPT/individual_sessions/"
DIR_html=os.getcwd()+"/CHATGPT/html"
# Ensure the output folder exists
os.makedirs(DIR_html, exist_ok=True)
filename=argv[1]
Filename = DIR+filename
print(Filename)
with open(Filename, 'r') as file:
    json_data = json.load(file)

# Initialize the result string
result_str = ""

# Define a function to get conversation messages similar to the JavaScript logic
def get_conversation_messages(conversation):
    messages = []
    current_node = conversation.get('current_node')
    while current_node:
        node = conversation['mapping'][current_node]
        message = node.get('message')
        if (message and message.get('content') and message['content'].get('content_type') == 'text' and
            len(message['content'].get('parts', [])) > 0 and len(message['content']['parts'][0]) > 0 and
                (message['author']['role'] != 'system' or message.get('metadata', {}).get('is_user_system_message'))):
            author = message['author']['role']
            if author == 'assistant':
                author = 'ChatGPT'
            elif author == 'system' and message['metadata'].get('is_user_system_message'):
                author = 'Custom user info'
            messages.append({'author': author, 'text': message['content']['parts'][0]})
        current_node = node.get('parent')
    return messages[::-1]  # Reverse the list to maintain chronological order

# Iterate over each conversation in the JSON data and process it
for conversation in json_data:
    # Get the conversation title and messages
    title = conversation.get('title', '')
    messages = get_conversation_messages(conversation)

    # Append the title and messages to the result string
    result_str += title + '\n'
    for message in messages:
        result_str += message['author'] + '\n' + message['text'] + '\n'
    result_str += '\n'  # Add a newline between conversations

# Return the processed result string
#print(result_str.strip())
HTMLfile=DIR_html+"/"+filename[:-4]+"html"
print("HTMLfile: ",HTMLfile)
Input = open(HTMLfile,"w")
result_str = result_str.replace("/n","XXXXXXX\n")
result_str = result_str.replace("<","&lt;")
result_str = result_str.replace(">","&gt;")
for line in result_str.split("XXXXXXX"):
    line = line.replace("\n","<br />\n")
    Input.write(line)
Input.close()# Return the processed result string
#print(result_str.strip())
TEXTfile=DIR_text+"/"+filename[:-4]+"txt"
print("TEXTfile: ",TEXTfile)
Input = open(TEXTfile,"w")
result_str = result_str.replace("/n","XXXXXXX\n")
for line in result_str.split("XXXXXXX"):
    Input.write(line)
Input.close()
# Out:
# Overwriting json2html_txt.py

# %%
# %%writefile json2htmltxt.py
#!/home/jack/miniconda3/envs/cloned_base/bin/python
import json
import os
from sys import argv

# Load the JSON data from the uploaded file
DIR = os.getcwd() + "/CHATGPT/individual_sessions/"
DIR_output = os.getcwd() + "/CHATGPT/output"
# Ensure the output folder exists
os.makedirs(DIR_output, exist_ok=True)
filename = argv[1]
Filename = DIR + filename
print(Filename)

with open(Filename, 'r', encoding='utf-8') as file:
    json_data = json.load(file)

# Initialize the result string
result_str = ""

# Define a function to get conversation messages similar to the JavaScript logic
def get_conversation_messages(conversation):
    messages = []
    current_node = conversation.get('current_node')
    while current_node:
        node = conversation['mapping'][current_node]
        message = node.get('message')
        if (message and message.get('content') and message['content'].get('content_type') == 'text' and
                len(message['content'].get('parts', [])) > 0 and len(message['content']['parts'][0]) > 0 and
                (message['author']['role'] != 'system' or message.get('metadata', {}).get('is_user_system_message'))):
            author = message['author']['role']
            if author == 'assistant':
                author = 'ChatGPT'
            elif author == 'system' and message['metadata'].get('is_user_system_message'):
                author = 'Custom user info'
            messages.append({'author': author, 'text': message['content']['parts'][0]})
        current_node = node.get('parent')
    return messages[::-1]  # Reverse the list to maintain chronological order

# Iterate over each conversation in the JSON data and process it
for conversation in json_data:
    # Get the conversation title and messages
    title = conversation.get('title', '')
    messages = get_conversation_messages(conversation)

    # Append the title and messages to the result string
    result_str += title + '\n'
    for message in messages:
        result_str += message['author'] + '\n' + message['text'] + '\n'
    result_str += '\n'  # Add a newline between conversations

# Return the processed result string
HTMLfile = DIR_output + "/" + filename[:-5] + ".html"
print("HTMLfile: ", HTMLfile)
with open(HTMLfile, "w", encoding='utf-8') as html_output:
    result_html = result_str.replace("/n", "XXXXXXX\n")
    result_html = result_html.replace("<", "&lt;")
    result_html = result_html.replace(">", "&gt;")
    for line in result_html.split("XXXXXXX"):
        line = line.replace("\n", "<br />\n")
        html_output.write(line)

TXTfile = DIR_output + "/" + filename[:-5] + ".txt"
print("TXTfile: ", TXTfile)
with open(TXTfile, "w", encoding='utf-8') as txt_output:
    result_txt = result_str.replace("/n", "XXXXXXX\n")
    for line in result_txt.split("XXXXXXX"):
        txt_output.write(line)
# Out:
# Writing json2htmltxt.py

# %%
import json
import logging
import os
import glob
import subprocess
def split_and_save_conversations(conversations_file, output_folder):
    try:
        with open(conversations_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
            
            for conversation in data:
                title = conversation.get('title', 'Unknown_Title')
                title_with_underscores = title.replace(' ', '_')
                title_with_underscores = title_with_underscores.replace(':','_')
                title_with_underscores = title_with_underscores.replace("'","_")
                title_with_underscores = title_with_underscores.replace("&","_")
                title_with_underscores = title_with_underscores.replace("*","_")
                title_with_underscores = title_with_underscores.replace("(","_")
                title_with_underscores = title_with_underscores.replace(")","_")
                chapter_filename = f"{title_with_underscores}.json"
                chapter_filepath = os.path.join(output_folder, chapter_filename)
                
                logging.info(f"Saving data for conversation '{title}' to {chapter_filepath}")
                
                with open(chapter_filepath, 'w', encoding='utf-8') as chapter_file:
                    json.dump([conversation], chapter_file, indent=2)

    except FileNotFoundError:
        logging.error(f"File not found: {conversations_file}")
    except json.JSONDecodeError:
        logging.error(f"Error decoding JSON in file: {conversations_file}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {e}")

# Example usage
conversations_file_path = 'CHATGPT/conversations.json'
output_folder = 'CHATGPT/individual_sessions'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Configure logging
logging.basicConfig(level=logging.INFO)

# Call the split and save function
split_and_save_conversations(conversations_file_path, output_folder)
files = glob.glob("CHATGPT/individual_sessions/*.json")

for file in files:
    file_name = file.split('/')[-1]
    print(file_name)
    cmd = ["python","json2htmltxt.py", file_name]
    print (cmd)
    # Use subprocess.run without terminal=True
    subprocess.run(cmd)
# Example usage
conversations_file_path = 'CHATGPT/conversations.json'
output_folder = 'CHATGPT/text'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Configure logging
logging.basicConfig(level=logging.INFO)
# Out:
# INFO:root:Saving data for conversation 'Add Expose to Docker Image' to CHATGPT/individual_sessions/Add_Expose_to_Docker_Image.json
# INFO:root:Saving data for conversation 'HTML Conversion Debugging' to CHATGPT/individual_sessions/HTML_Conversion_Debugging.json
# INFO:root:Saving data for conversation 'Wget File Download' to CHATGPT/individual_sessions/Wget_File_Download.json
# INFO:root:Saving data for conversation 'Flask App on LAN' to CHATGPT/individual_sessions/Flask_App_on_LAN.json
# INFO:root:Saving data for conversation 'Convert JSON to HTML' to CHATGPT/individual_sessions/Convert_JSON_to_HTML.json
# INFO:root:Saving data for conversation 'Check Directory for Duplicates' to CHATGPT/individual_sessions/Check_Directory_for_Duplicates.json
# INFO:root:Saving data for conversation 'Search IPYNB for Term' to CHATGPT/individual_sessions/Search_IPYNB_for_Term.json
# INFO:root:Saving data for conversation 'Refrigerate ketchup after opening.' to CHATGPT/individual_sessions/Refrigerate_ketchup_after_opening..json
# INFO:root:Saving data for conversation 'ChatGPT, Conversations.json Overview' to CHATGPT/individual_sessions/ChatGPT,_Conversations.json_Overview.json
# INFO:root:Saving data for conversation 'Python Punctuation Removal' to CHATGPT/individual_sessions/Python_Punctuation_Removal.json
# INFO:root:Saving data for conversation 'Cosmic Octopus AI Awakening' to CHATGPT/individual_sessions/Cosmic_Octopus_AI_Awakening.json
# INFO:root:Saving data for conversation 'Arcanian AI's Transformative Influence' to CHATGPT/individual_sessions/Arcanian_AI_s_Transformative_Influence.json
# INFO:root:Saving data for conversation 'AI Guides Animal Enlightenment' to CHATGPT/individual_sessions/AI_Guides_Animal_Enlightenment.json
# INFO:root:Saving data for conversation 'Flask Programmer and YouTuber' to CHATGPT/individual_sessions/Flask_Programmer_and_YouTuber.json
# INFO:root:Saving data for conversation 'Set Hard Drive Permissions' to CHATGPT/individual_sessions/Set_Hard_Drive_Permissions.json
# INFO:root:Saving data for conversation 'Python HTTP Server Guide' to CHATGPT/individual_sessions/Python_HTTP_Server_Guide.json
# INFO:root:Saving data for conversation 'Simple 3D Scene Creation' to CHATGPT/individual_sessions/Simple_3D_Scene_Creation.json
# INFO:root:Saving data for conversation 'Segmenting Video Frames' to CHATGPT/individual_sessions/Segmenting_Video_Frames.json
# INFO:root:Saving data for conversation 'Download Age-Restricted Video' to CHATGPT/individual_sessions/Download_Age-Restricted_Video.json
# INFO:root:Saving data for conversation 'Convert FilePath to GIF' to CHATGPT/individual_sessions/Convert_FilePath_to_GIF.json
# INFO:root:Saving data for conversation 'Remove Python Path' to CHATGPT/individual_sessions/Remove_Python_Path.json
# INFO:root:Saving data for conversation 'Create Black Image' to CHATGPT/individual_sessions/Create_Black_Image.json
# INFO:root:Saving data for conversation 'Whiplash Curves in Art' to CHATGPT/individual_sessions/Whiplash_Curves_in_Art.json
# INFO:root:Saving data for conversation 'SSL Cert Expiry: Python' to CHATGPT/individual_sessions/SSL_Cert_Expiry__Python.json
# INFO:root:Saving data for conversation 'Bash Locate in Python' to CHATGPT/individual_sessions/Bash_Locate_in_Python.json
# INFO:root:Saving data for conversation 'Doll in Dystopian Decay' to CHATGPT/individual_sessions/Doll_in_Dystopian_Decay.json
# INFO:root:Saving data for conversation 'FFmpeg Zoom Video Fix' to CHATGPT/individual_sessions/FFmpeg_Zoom_Video_Fix.json
# INFO:root:Saving data for conversation 'Doll Factory Dystopia' to CHATGPT/individual_sessions/Doll_Factory_Dystopia.json
# INFO:root:Saving data for conversation 'Enhance Image with OpenCV' to CHATGPT/individual_sessions/Enhance_Image_with_OpenCV.json
# INFO:root:Saving data for conversation 'Flask Video Selection Script' to CHATGPT/individual_sessions/Flask_Video_Selection_Script.json
# INFO:root:Saving data for conversation 'SSD Maintenance: Trim Frequency' to CHATGPT/individual_sessions/SSD_Maintenance__Trim_Frequency.json
# INFO:root:Saving data for conversation 'Split MP4 into 6.' to CHATGPT/individual_sessions/Split_MP4_into_6..json
# INFO:root:Saving data for conversation 'FFmpeg Remove Duplicate Frames' to CHATGPT/individual_sessions/FFmpeg_Remove_Duplicate_Frames.json
# INFO:root:Saving data for conversation 'Video Clips with Sound' to CHATGPT/individual_sessions/Video_Clips_with_Sound.json
# INFO:root:Saving data for conversation 'Video Flip Book Fix' to CHATGPT/individual_sessions/Video_Flip_Book_Fix.json
# INFO:root:Saving data for conversation 'Dystopian City Text Prompt' to CHATGPT/individual_sessions/Dystopian_City_Text_Prompt.json
# INFO:root:Saving data for conversation 'SSH to Specific Directory' to CHATGPT/individual_sessions/SSH_to_Specific_Directory.json
# INFO:root:Saving data for conversation 'Add sound if needed.' to CHATGPT/individual_sessions/Add_sound_if_needed..json
# INFO:root:Saving data for conversation 'Thunar Scroll Issue Troubleshooting' to CHATGPT/individual_sessions/Thunar_Scroll_Issue_Troubleshooting.json
# INFO:root:Saving data for conversation 'Get Image Size' to CHATGPT/individual_sessions/Get_Image_Size.json
# INFO:root:Saving data for conversation 'Image Zoom Video Script' to CHATGPT/individual_sessions/Image_Zoom_Video_Script.json
# INFO:root:Saving data for conversation 'Video Processing: 512x768 Resolution' to CHATGPT/individual_sessions/Video_Processing__512x768_Resolution.json
# INFO:root:Saving data for conversation 'Find & CD: fade-transb' to CHATGPT/individual_sessions/Find___CD__fade-transb.json
# INFO:root:Saving data for conversation 'Shell Command Argument Handling' to CHATGPT/individual_sessions/Shell_Command_Argument_Handling.json
# INFO:root:Saving data for conversation 'Python Save File' to CHATGPT/individual_sessions/Python_Save_File.json
# INFO:root:Saving data for conversation 'Flask Module Not Found' to CHATGPT/individual_sessions/Flask_Module_Not_Found.json
# INFO:root:Saving data for conversation 'Linux Terminal Issue' to CHATGPT/individual_sessions/Linux_Terminal_Issue.json
# INFO:root:Saving data for conversation 'Run Kdenlive Extension with Melt' to CHATGPT/individual_sessions/Run_Kdenlive_Extension_with_Melt.json
# INFO:root:Saving data for conversation 'YouTube 2nd Channel Automator' to CHATGPT/individual_sessions/YouTube_2nd_Channel_Automator.json
# INFO:root:Saving data for conversation 'Xterm Display Error Troubleshoot' to CHATGPT/individual_sessions/Xterm_Display_Error_Troubleshoot.json
# INFO:root:Saving data for conversation 'Flask Installation Troubleshooting' to CHATGPT/individual_sessions/Flask_Installation_Troubleshooting.json
# INFO:root:Saving data for conversation 'MoviePy for Image Videos' to CHATGPT/individual_sessions/MoviePy_for_Image_Videos.json
# INFO:root:Saving data for conversation 'Create 3D Image Transitions' to CHATGPT/individual_sessions/Create_3D_Image_Transitions.json
# INFO:root:Saving data for conversation 'Adjust Duration for Longer' to CHATGPT/individual_sessions/Adjust_Duration_for_Longer.json
# INFO:root:Saving data for conversation 'Capture Screen with Offset' to CHATGPT/individual_sessions/Capture_Screen_with_Offset.json
# INFO:root:Saving data for conversation 'Reinstall XWin on Linux.' to CHATGPT/individual_sessions/Reinstall_XWin_on_Linux..json
# INFO:root:Saving data for conversation 'Linux: Force Thumbnail Regeneration' to CHATGPT/individual_sessions/Linux__Force_Thumbnail_Regeneration.json
# INFO:root:Saving data for conversation 'Martian Masterpiece: Surreal Synthesis' to CHATGPT/individual_sessions/Martian_Masterpiece__Surreal_Synthesis.json
# INFO:root:Saving data for conversation 'Reinstall EFC Desktop' to CHATGPT/individual_sessions/Reinstall_EFC_Desktop.json
# INFO:root:Saving data for conversation 'Kill Process on Port' to CHATGPT/individual_sessions/Kill_Process_on_Port.json
# INFO:root:Saving data for conversation 'Linux Find Largest Subdirectory' to CHATGPT/individual_sessions/Linux_Find_Largest_Subdirectory.json
# INFO:root:Saving data for conversation 'Shuffle Images for Video' to CHATGPT/individual_sessions/Shuffle_Images_for_Video.json
# INFO:root:Saving data for conversation 'Shuffled Image Zoom' to CHATGPT/individual_sessions/Shuffled_Image_Zoom.json
# INFO:root:Saving data for conversation 'Sticky Header for Website' to CHATGPT/individual_sessions/Sticky_Header_for_Website.json
# INFO:root:Saving data for conversation 'Image files not printing.' to CHATGPT/individual_sessions/Image_files_not_printing..json
# INFO:root:Saving data for conversation 'Rsync Syncs and Overwrites' to CHATGPT/individual_sessions/Rsync_Syncs_and_Overwrites.json
# INFO:root:Saving data for conversation 'Auto-looping 1s Slideshow Code' to CHATGPT/individual_sessions/Auto-looping_1s_Slideshow_Code.json
# INFO:root:Saving data for conversation 'Sticky Header Code' to CHATGPT/individual_sessions/Sticky_Header_Code.json
# INFO:root:Saving data for conversation 'Bash Completion Python Script' to CHATGPT/individual_sessions/Bash_Completion_Python_Script.json
# INFO:root:Saving data for conversation 'Copy care.mp4 to VPS' to CHATGPT/individual_sessions/Copy_care.mp4_to_VPS.json
# INFO:root:Saving data for conversation 'Update SQLite Permissions' to CHATGPT/individual_sessions/Update_SQLite_Permissions.json
# INFO:root:Saving data for conversation 'Caregivers: Organized, Efficient, Communicative' to CHATGPT/individual_sessions/Caregivers__Organized,_Efficient,_Communicative.json
# INFO:root:Saving data for conversation 'Select Random TTF Font' to CHATGPT/individual_sessions/Select_Random_TTF_Font.json
# INFO:root:Saving data for conversation 'Generate Loopable Stylized Images' to CHATGPT/individual_sessions/Generate_Loopable_Stylized_Images.json
# INFO:root:Saving data for conversation 'Fix Protobuf Issue' to CHATGPT/individual_sessions/Fix_Protobuf_Issue.json
# INFO:root:Saving data for conversation 'Locate IPYNB with Quantify' to CHATGPT/individual_sessions/Locate_IPYNB_with_Quantify.json
# INFO:root:Saving data for conversation 'PDF to PNG Conversion' to CHATGPT/individual_sessions/PDF_to_PNG_Conversion.json
# INFO:root:Saving data for conversation 'PDF to PNG Converter' to CHATGPT/individual_sessions/PDF_to_PNG_Converter.json
# INFO:root:Saving data for conversation 'Movies with Punch' to CHATGPT/individual_sessions/Movies_with_Punch.json
# INFO:root:Saving data for conversation 'LAN Directory Serving Script' to CHATGPT/individual_sessions/LAN_Directory_Serving_Script.json
# INFO:root:Saving data for conversation 'Flask FFmpeg Command Integration' to CHATGPT/individual_sessions/Flask_FFmpeg_Command_Integration.json
# INFO:root:Saving data for conversation 'Explain script in detail.' to CHATGPT/individual_sessions/Explain_script_in_detail..json
# INFO:root:Saving data for conversation 'AI Video Transitions Mastery' to CHATGPT/individual_sessions/AI_Video_Transitions_Mastery.json
# INFO:root:Saving data for conversation 'Fail2Ban Installation for Security' to CHATGPT/individual_sessions/Fail2Ban_Installation_for_Security.json
# INFO:root:Saving data for conversation 'PHP Execute Bash Script' to CHATGPT/individual_sessions/PHP_Execute_Bash_Script.json
# INFO:root:Saving data for conversation 'Prevent inherit text-align.' to CHATGPT/individual_sessions/Prevent_inherit_text-align..json
# INFO:root:Saving data for conversation 'Sudo cp file permissions' to CHATGPT/individual_sessions/Sudo_cp_file_permissions.json
# INFO:root:Saving data for conversation 'CSS Logo Placement' to CHATGPT/individual_sessions/CSS_Logo_Placement.json
# INFO:root:Saving data for conversation 'Snap Certbot Installation Issue' to CHATGPT/individual_sessions/Snap_Certbot_Installation_Issue.json
# INFO:root:Saving data for conversation 'Configurar servidor Apache local' to CHATGPT/individual_sessions/Configurar_servidor_Apache_local.json
# INFO:root:Saving data for conversation 'Install PHP on Apache' to CHATGPT/individual_sessions/Install_PHP_on_Apache.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'Domain Info with Python' to CHATGPT/individual_sessions/Domain_Info_with_Python.json
# INFO:root:Saving data for conversation 'Set Up LAN Server (Python)' to CHATGPT/individual_sessions/Set_Up_LAN_Server__Python_.json
# INFO:root:Saving data for conversation 'Open Jupyter Notebook Over LAN' to CHATGPT/individual_sessions/Open_Jupyter_Notebook_Over_LAN.json
# INFO:root:Saving data for conversation 'MP4 Files Finder Script' to CHATGPT/individual_sessions/MP4_Files_Finder_Script.json
# INFO:root:Saving data for conversation 'Crear imagen colores primarios' to CHATGPT/individual_sessions/Crear_imagen_colores_primarios.json
# INFO:root:Saving data for conversation 'FFmpeg Slideshow with Transitions' to CHATGPT/individual_sessions/FFmpeg_Slideshow_with_Transitions.json
# INFO:root:Saving data for conversation 'Scroll Image to Video' to CHATGPT/individual_sessions/Scroll_Image_to_Video.json
# INFO:root:Saving data for conversation 'Crear videos con imágenes.' to CHATGPT/individual_sessions/Crear_videos_con_imágenes..json
# INFO:root:Saving data for conversation 'Video Making Script with Logging' to CHATGPT/individual_sessions/Video_Making_Script_with_Logging.json
# INFO:root:Saving data for conversation 'Crear video con transiciones.' to CHATGPT/individual_sessions/Crear_video_con_transiciones..json
# INFO:root:Saving data for conversation 'List Directories with 'ls'' to CHATGPT/individual_sessions/List_Directories_with__ls_.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'Rebuild Linux Thumbnails Cache' to CHATGPT/individual_sessions/Rebuild_Linux_Thumbnails_Cache.json
# INFO:root:Saving data for conversation 'Video Conversion with Fades' to CHATGPT/individual_sessions/Video_Conversion_with_Fades.json
# INFO:root:Saving data for conversation 'Unione video MP4 con transizione' to CHATGPT/individual_sessions/Unione_video_MP4_con_transizione.json
# INFO:root:Saving data for conversation 'Video Processing: Frames Method' to CHATGPT/individual_sessions/Video_Processing__Frames_Method.json
# INFO:root:Saving data for conversation 'Fade Transition Video Script' to CHATGPT/individual_sessions/Fade_Transition_Video_Script.json
# INFO:root:Saving data for conversation 'Unione video MP4 0.25s' to CHATGPT/individual_sessions/Unione_video_MP4_0.25s.json
# INFO:root:Saving data for conversation 'JACK Audio Connection Issue' to CHATGPT/individual_sessions/JACK_Audio_Connection_Issue.json
# INFO:root:Saving data for conversation 'Run 'mkgallery' in subdirectories' to CHATGPT/individual_sessions/Run__mkgallery__in_subdirectories.json
# INFO:root:Saving data for conversation 'House Stark in Winter' to CHATGPT/individual_sessions/House_Stark_in_Winter.json
# INFO:root:Saving data for conversation 'High Disk Activity Issue' to CHATGPT/individual_sessions/High_Disk_Activity_Issue.json
# INFO:root:Saving data for conversation 'Optimize SSD Swap File' to CHATGPT/individual_sessions/Optimize_SSD_Swap_File.json
# INFO:root:Saving data for conversation 'Code Indentation Fixed' to CHATGPT/individual_sessions/Code_Indentation_Fixed.json
# INFO:root:Saving data for conversation 'Install .run file on Linux' to CHATGPT/individual_sessions/Install_.run_file_on_Linux.json
# INFO:root:Saving data for conversation 'Install pyttsx3 module.' to CHATGPT/individual_sessions/Install_pyttsx3_module..json
# INFO:root:Saving data for conversation 'Create Scrolling Text Video' to CHATGPT/individual_sessions/Create_Scrolling_Text_Video.json
# INFO:root:Saving data for conversation 'FFMPEG video with frame & music' to CHATGPT/individual_sessions/FFMPEG_video_with_frame___music.json
# INFO:root:Saving data for conversation 'Fading Video Overlay Fix' to CHATGPT/individual_sessions/Fading_Video_Overlay_Fix.json
# INFO:root:Saving data for conversation 'Check Image Duplicates with Hashes' to CHATGPT/individual_sessions/Check_Image_Duplicates_with_Hashes.json
# INFO:root:Saving data for conversation 'Disable all extensions' to CHATGPT/individual_sessions/Disable_all_extensions.json
# INFO:root:Saving data for conversation 'FFmpeg Command Logging Fix' to CHATGPT/individual_sessions/FFmpeg_Command_Logging_Fix.json
# INFO:root:Saving data for conversation 'Flask HTML Template Example' to CHATGPT/individual_sessions/Flask_HTML_Template_Example.json
# INFO:root:Saving data for conversation 'Flask Video Selection Endpoint' to CHATGPT/individual_sessions/Flask_Video_Selection_Endpoint.json
# INFO:root:Saving data for conversation 'Improved Video Quality Settings' to CHATGPT/individual_sessions/Improved_Video_Quality_Settings.json
# INFO:root:Saving data for conversation 'Load index.html in Flask' to CHATGPT/individual_sessions/Load_index.html_in_Flask.json
# INFO:root:Saving data for conversation 'Image Resizer Troubleshooting' to CHATGPT/individual_sessions/Image_Resizer_Troubleshooting.json
# INFO:root:Saving data for conversation 'Flask MP4 Route Setup' to CHATGPT/individual_sessions/Flask_MP4_Route_Setup.json
# INFO:root:Saving data for conversation 'Plague Doctors and St. Sebastian' to CHATGPT/individual_sessions/Plague_Doctors_and_St._Sebastian.json
# INFO:root:Saving data for conversation 'Save DuckDuckGo Results JSON' to CHATGPT/individual_sessions/Save_DuckDuckGo_Results_JSON.json
# INFO:root:Saving data for conversation 'Flask Code Review' to CHATGPT/individual_sessions/Flask_Code_Review.json
# INFO:root:Saving data for conversation 'Flask App Code Review' to CHATGPT/individual_sessions/Flask_App_Code_Review.json
# INFO:root:Saving data for conversation 'Fixing Code for Directory Processing' to CHATGPT/individual_sessions/Fixing_Code_for_Directory_Processing.json
# INFO:root:Saving data for conversation 'Flask for Existing HTML' to CHATGPT/individual_sessions/Flask_for_Existing_HTML.json
# INFO:root:Saving data for conversation 'Update Protobuf Code Version' to CHATGPT/individual_sessions/Update_Protobuf_Code_Version.json
# INFO:root:Saving data for conversation 'Crop Dimensions Explanation' to CHATGPT/individual_sessions/Crop_Dimensions_Explanation.json
# INFO:root:Saving data for conversation 'Create Slow Scroll Video' to CHATGPT/individual_sessions/Create_Slow_Scroll_Video.json
# INFO:root:Saving data for conversation 'Crear plantilla HTML mp4_to_image' to CHATGPT/individual_sessions/Crear_plantilla_HTML_mp4_to_image.json
# INFO:root:Saving data for conversation 'Cancel Git Push Fix' to CHATGPT/individual_sessions/Cancel_Git_Push_Fix.json
# INFO:root:Saving data for conversation 'Capture Webpage with Python' to CHATGPT/individual_sessions/Capture_Webpage_with_Python.json
# INFO:root:Saving data for conversation 'Count Python Code Lines' to CHATGPT/individual_sessions/Count_Python_Code_Lines.json
# INFO:root:Saving data for conversation 'MP3 Joining Issue Troubleshooting' to CHATGPT/individual_sessions/MP3_Joining_Issue_Troubleshooting.json
# INFO:root:Saving data for conversation 'MP3 File Joining Issue' to CHATGPT/individual_sessions/MP3_File_Joining_Issue.json
# INFO:root:Saving data for conversation 'Correção da Rota "join_sound"' to CHATGPT/individual_sessions/Correção_da_Rota_"join_sound".json
# INFO:root:Saving data for conversation 'Random MP3 Clips Concatenation' to CHATGPT/individual_sessions/Random_MP3_Clips_Concatenation.json
# INFO:root:Saving data for conversation 'Shuffle Images for Video' to CHATGPT/individual_sessions/Shuffle_Images_for_Video.json
# INFO:root:Saving data for conversation 'Bash Completions using Python' to CHATGPT/individual_sessions/Bash_Completions_using_Python.json
# INFO:root:Saving data for conversation 'Fixing Flask Screen Capture' to CHATGPT/individual_sessions/Fixing_Flask_Screen_Capture.json
# INFO:root:Saving data for conversation 'Fix Git Push Error' to CHATGPT/individual_sessions/Fix_Git_Push_Error.json
# INFO:root:Saving data for conversation 'Flask Video Thumbnail App' to CHATGPT/individual_sessions/Flask_Video_Thumbnail_App.json
# INFO:root:Saving data for conversation 'Save Plots with UUIDs' to CHATGPT/individual_sessions/Save_Plots_with_UUIDs.json
# INFO:root:Saving data for conversation 'ClamAV Freshclam Log Error' to CHATGPT/individual_sessions/ClamAV_Freshclam_Log_Error.json
# INFO:root:Saving data for conversation 'Install Wine Mono Linux' to CHATGPT/individual_sessions/Install_Wine_Mono_Linux.json
# INFO:root:Saving data for conversation 'Clickable Links in HTML' to CHATGPT/individual_sessions/Clickable_Links_in_HTML.json
# INFO:root:Saving data for conversation 'Video Editing with MoviePy' to CHATGPT/individual_sessions/Video_Editing_with_MoviePy.json
# INFO:root:Saving data for conversation 'Flask Async Endpoints' to CHATGPT/individual_sessions/Flask_Async_Endpoints.json
# INFO:root:Saving data for conversation 'Random MP3 Selection Bash' to CHATGPT/individual_sessions/Random_MP3_Selection_Bash.json
# INFO:root:Saving data for conversation 'Virtual Environment Creation Error' to CHATGPT/individual_sessions/Virtual_Environment_Creation_Error.json
# INFO:root:Saving data for conversation 'Flask Video Generator Function' to CHATGPT/individual_sessions/Flask_Video_Generator_Function.json
# INFO:root:Saving data for conversation 'FlaskWebGui Debug Mode' to CHATGPT/individual_sessions/FlaskWebGui_Debug_Mode.json
# INFO:root:Saving data for conversation 'Flask File Upload Function' to CHATGPT/individual_sessions/Flask_File_Upload_Function.json
# INFO:root:Saving data for conversation 'Flask Template HTML Setup' to CHATGPT/individual_sessions/Flask_Template_HTML_Setup.json
# INFO:root:Saving data for conversation 'Comic Panel Layout CSS' to CHATGPT/individual_sessions/Comic_Panel_Layout_CSS.json
# INFO:root:Saving data for conversation 'Lighten Image with Mogrify' to CHATGPT/individual_sessions/Lighten_Image_with_Mogrify.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'GPT API Key Access' to CHATGPT/individual_sessions/GPT_API_Key_Access.json
# INFO:root:Saving data for conversation 'Add JPG and PNG' to CHATGPT/individual_sessions/Add_JPG_and_PNG.json
# INFO:root:Saving data for conversation 'Feathered Image Creation' to CHATGPT/individual_sessions/Feathered_Image_Creation.json
# INFO:root:Saving data for conversation 'Feather Image with Python' to CHATGPT/individual_sessions/Feather_Image_with_Python.json
# INFO:root:Saving data for conversation 'Arcanis AI Enhancing Earth's AI' to CHATGPT/individual_sessions/Arcanis_AI_Enhancing_Earth_s_AI.json
# INFO:root:Saving data for conversation 'Flask Logging Setup Guide' to CHATGPT/individual_sessions/Flask_Logging_Setup_Guide.json
# INFO:root:Saving data for conversation 'Generate & Save PNG Plot' to CHATGPT/individual_sessions/Generate___Save_PNG_Plot.json
# INFO:root:Saving data for conversation 'Install R on Linux' to CHATGPT/individual_sessions/Install_R_on_Linux.json
# INFO:root:Saving data for conversation 'Python & Flask Enthusiasts' to CHATGPT/individual_sessions/Python___Flask_Enthusiasts.json
# INFO:root:Saving data for conversation 'Name: Esperanza' to CHATGPT/individual_sessions/Name__Esperanza.json
# INFO:root:Saving data for conversation 'Fixing Audio Buffer Overflow' to CHATGPT/individual_sessions/Fixing_Audio_Buffer_Overflow.json
# INFO:root:Saving data for conversation 'Louder Output Audio: Adjusting Volume' to CHATGPT/individual_sessions/Louder_Output_Audio__Adjusting_Volume.json
# INFO:root:Saving data for conversation 'Change Outline Color' to CHATGPT/individual_sessions/Change_Outline_Color.json
# INFO:root:Saving data for conversation 'Create Video from Images' to CHATGPT/individual_sessions/Create_Video_from_Images.json
# INFO:root:Saving data for conversation 'Python 3.9 Virtual Environment' to CHATGPT/individual_sessions/Python_3.9_Virtual_Environment.json
# INFO:root:Saving data for conversation 'Flask Thumbnail Video' to CHATGPT/individual_sessions/Flask_Thumbnail_Video.json
# INFO:root:Saving data for conversation 'Flask Directory Viewer' to CHATGPT/individual_sessions/Flask_Directory_Viewer.json
# INFO:root:Saving data for conversation 'Flask App Demo & Explanation' to CHATGPT/individual_sessions/Flask_App_Demo___Explanation.json
# INFO:root:Saving data for conversation 'Flask_env Jupyter Kernel Setup' to CHATGPT/individual_sessions/Flask_env_Jupyter_Kernel_Setup.json
# INFO:root:Saving data for conversation 'Mic Detection Issue Troubleshoot' to CHATGPT/individual_sessions/Mic_Detection_Issue_Troubleshoot.json
# INFO:root:Saving data for conversation 'Custom Instructions Understood' to CHATGPT/individual_sessions/Custom_Instructions_Understood.json
# INFO:root:Saving data for conversation 'Flask AttributeError Troubleshooting' to CHATGPT/individual_sessions/Flask_AttributeError_Troubleshooting.json
# INFO:root:Saving data for conversation 'Video Duration Adjustment' to CHATGPT/individual_sessions/Video_Duration_Adjustment.json
# INFO:root:Saving data for conversation 'Install OpenCV (cv2)' to CHATGPT/individual_sessions/Install_OpenCV__cv2_.json
# INFO:root:Saving data for conversation 'Delete Files Except *.jpg' to CHATGPT/individual_sessions/Delete_Files_Except__.jpg.json
# INFO:root:Saving data for conversation 'LuaRocks Install NN-Spec' to CHATGPT/individual_sessions/LuaRocks_Install_NN-Spec.json
# INFO:root:Saving data for conversation 'Failed nn Installation' to CHATGPT/individual_sessions/Failed_nn_Installation.json
# INFO:root:Saving data for conversation 'Random Desktop Video Clips' to CHATGPT/individual_sessions/Random_Desktop_Video_Clips.json
# INFO:root:Saving data for conversation 'FFMPEG Create Shuffled Video' to CHATGPT/individual_sessions/FFMPEG_Create_Shuffled_Video.json
# INFO:root:Saving data for conversation 'Stream Speakers & Desktop' to CHATGPT/individual_sessions/Stream_Speakers___Desktop.json
# INFO:root:Saving data for conversation 'Find Imported Module Source' to CHATGPT/individual_sessions/Find_Imported_Module_Source.json
# INFO:root:Saving data for conversation 'Linux Desktop Missing Icons' to CHATGPT/individual_sessions/Linux_Desktop_Missing_Icons.json
# INFO:root:Saving data for conversation 'FFMPEG Video Slowdown.' to CHATGPT/individual_sessions/FFMPEG_Video_Slowdown..json
# INFO:root:Saving data for conversation 'Create BMP from Image' to CHATGPT/individual_sessions/Create_BMP_from_Image.json
# INFO:root:Saving data for conversation 'GIFs to MP4' to CHATGPT/individual_sessions/GIFs_to_MP4.json
# INFO:root:Saving data for conversation 'Hardcoded Args Parser' to CHATGPT/individual_sessions/Hardcoded_Args_Parser.json
# INFO:root:Saving data for conversation 'Starting Over?' to CHATGPT/individual_sessions/Starting_Over?.json
# INFO:root:Saving data for conversation 'Create GIFS.mp4' to CHATGPT/individual_sessions/Create_GIFS.mp4.json
# INFO:root:Saving data for conversation 'Python Image Processing Code' to CHATGPT/individual_sessions/Python_Image_Processing_Code.json
# INFO:root:Saving data for conversation 'Dynamic Directory for mkblend_videos' to CHATGPT/individual_sessions/Dynamic_Directory_for_mkblend_videos.json
# INFO:root:Saving data for conversation 'Flask code with logging.' to CHATGPT/individual_sessions/Flask_code_with_logging..json
# INFO:root:Saving data for conversation 'Create MP4 from images.' to CHATGPT/individual_sessions/Create_MP4_from_images..json
# INFO:root:Saving data for conversation 'Video Overlay Not Working' to CHATGPT/individual_sessions/Video_Overlay_Not_Working.json
# INFO:root:Saving data for conversation 'Fix favicon not found.' to CHATGPT/individual_sessions/Fix_favicon_not_found..json
# INFO:root:Saving data for conversation 'Copy File with shutil' to CHATGPT/individual_sessions/Copy_File_with_shutil.json
# INFO:root:Saving data for conversation 'Nietzsche's views on death.' to CHATGPT/individual_sessions/Nietzsche_s_views_on_death..json
# INFO:root:Saving data for conversation 'Video Generation from Directories.' to CHATGPT/individual_sessions/Video_Generation_from_Directories..json
# INFO:root:Saving data for conversation 'API v0xF - Unknown Version' to CHATGPT/individual_sessions/API_v0xF_-_Unknown_Version.json
# INFO:root:Saving data for conversation 'Flask-SQLAlchemy Version Mismatch.' to CHATGPT/individual_sessions/Flask-SQLAlchemy_Version_Mismatch..json
# INFO:root:Saving data for conversation 'Flask: Request and Save.' to CHATGPT/individual_sessions/Flask__Request_and_Save..json
# INFO:root:Saving data for conversation 'AI: Wonder or Monster?' to CHATGPT/individual_sessions/AI__Wonder_or_Monster?.json
# INFO:root:Saving data for conversation 'Flask App Setup' to CHATGPT/individual_sessions/Flask_App_Setup.json
# INFO:root:Saving data for conversation 'Flask App with SQLite3' to CHATGPT/individual_sessions/Flask_App_with_SQLite3.json
# INFO:root:Saving data for conversation 'Video Editing Transitions' to CHATGPT/individual_sessions/Video_Editing_Transitions.json
# INFO:root:Saving data for conversation 'Avatar AI for Talking' to CHATGPT/individual_sessions/Avatar_AI_for_Talking.json
# INFO:root:Saving data for conversation 'cp directory without overwrite' to CHATGPT/individual_sessions/cp_directory_without_overwrite.json
# INFO:root:Saving data for conversation 'Find File: stacked_videos' to CHATGPT/individual_sessions/Find_File__stacked_videos.json
# INFO:root:Saving data for conversation 'AI's Leap in 2021' to CHATGPT/individual_sessions/AI_s_Leap_in_2021.json
# INFO:root:Saving data for conversation 'Convert audio to video' to CHATGPT/individual_sessions/Convert_audio_to_video.json
# INFO:root:Saving data for conversation 'Create Image Sequence Video' to CHATGPT/individual_sessions/Create_Image_Sequence_Video.json
# INFO:root:Saving data for conversation 'Linux Find Modified Images' to CHATGPT/individual_sessions/Linux_Find_Modified_Images.json
# INFO:root:Saving data for conversation 'Find Duplicate Image Names' to CHATGPT/individual_sessions/Find_Duplicate_Image_Names.json
# INFO:root:Saving data for conversation 'Flask Blueprint Assistance' to CHATGPT/individual_sessions/Flask_Blueprint_Assistance.json
# INFO:root:Saving data for conversation 'Activate Virtual Environment' to CHATGPT/individual_sessions/Activate_Virtual_Environment.json
# INFO:root:Saving data for conversation 'Resizing & Cropping for Vertical Video' to CHATGPT/individual_sessions/Resizing___Cropping_for_Vertical_Video.json
# INFO:root:Saving data for conversation 'Flask Open & View Text' to CHATGPT/individual_sessions/Flask_Open___View_Text.json
# INFO:root:Saving data for conversation 'Replace Spaces with Underscores' to CHATGPT/individual_sessions/Replace_Spaces_with_Underscores.json
# INFO:root:Saving data for conversation 'Create Video with Text' to CHATGPT/individual_sessions/Create_Video_with_Text.json
# INFO:root:Saving data for conversation 'Image-to-Video Conversion' to CHATGPT/individual_sessions/Image-to-Video_Conversion.json
# INFO:root:Saving data for conversation 'Flask Video Processing Server' to CHATGPT/individual_sessions/Flask_Video_Processing_Server.json
# INFO:root:Saving data for conversation 'HEVC Decoding Errors' to CHATGPT/individual_sessions/HEVC_Decoding_Errors.json
# INFO:root:Saving data for conversation 'Blend Image Video Creation' to CHATGPT/individual_sessions/Blend_Image_Video_Creation.json
# INFO:root:Saving data for conversation 'Inference Error: mel() Function' to CHATGPT/individual_sessions/Inference_Error__mel___Function.json
# INFO:root:Saving data for conversation 'Syntax Error Resolved' to CHATGPT/individual_sessions/Syntax_Error_Resolved.json
# INFO:root:Saving data for conversation 'Wonderland Characters Summary' to CHATGPT/individual_sessions/Wonderland_Characters_Summary.json
# INFO:root:Saving data for conversation 'Datetime Import Issue' to CHATGPT/individual_sessions/Datetime_Import_Issue.json
# INFO:root:Saving data for conversation 'Selecting Image Directory' to CHATGPT/individual_sessions/Selecting_Image_Directory.json
# INFO:root:Saving data for conversation 'Upload file from directory' to CHATGPT/individual_sessions/Upload_file_from_directory.json
# INFO:root:Saving data for conversation 'Expressive Flora Still Life' to CHATGPT/individual_sessions/Expressive_Flora_Still_Life.json
# INFO:root:Saving data for conversation 'Anunnaki Overview' to CHATGPT/individual_sessions/Anunnaki_Overview.json
# INFO:root:Saving data for conversation 'Arcanis AI Communication' to CHATGPT/individual_sessions/Arcanis_AI_Communication.json
# INFO:root:Saving data for conversation 'GEGL Bevel Compilation Error' to CHATGPT/individual_sessions/GEGL_Bevel_Compilation_Error.json
# INFO:root:Saving data for conversation 'Upload and Apply Text' to CHATGPT/individual_sessions/Upload_and_Apply_Text.json
# INFO:root:Saving data for conversation 'Browser Media Stream Issue' to CHATGPT/individual_sessions/Browser_Media_Stream_Issue.json
# INFO:root:Saving data for conversation 'Generate Unique Video Filename' to CHATGPT/individual_sessions/Generate_Unique_Video_Filename.json
# INFO:root:Saving data for conversation 'Flask Text-to-Speech' to CHATGPT/individual_sessions/Flask_Text-to-Speech.json
# INFO:root:Saving data for conversation 'Subprocess Firefox HTML Execution' to CHATGPT/individual_sessions/Subprocess_Firefox_HTML_Execution.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/individual_sessions/New_chat.json
# INFO:root:Saving data for conversation 'Module Import Error Fix' to CHATGPT/individual_sessions/Module_Import_Error_Fix.json
# INFO:root:Saving data for conversation 'Aliens & AI Speculation' to CHATGPT/individual_sessions/Aliens___AI_Speculation.json
# INFO:root:Saving data for conversation 'Fix File Copying Error' to CHATGPT/individual_sessions/Fix_File_Copying_Error.json
# INFO:root:Saving data for conversation 'Flask App Conversion' to CHATGPT/individual_sessions/Flask_App_Conversion.json
# INFO:root:Saving data for conversation 'Dynamic Image Directory' to CHATGPT/individual_sessions/Dynamic_Image_Directory.json
# INFO:root:Saving data for conversation 'Large File Push Error' to CHATGPT/individual_sessions/Large_File_Push_Error.json
# INFO:root:Saving data for conversation 'Overlay Video with Colorchrome' to CHATGPT/individual_sessions/Overlay_Video_with_Colorchrome.json
# INFO:root:Saving data for conversation 'Flask: Blank 512x1024.mp4' to CHATGPT/individual_sessions/Flask__Blank_512x1024.mp4.json
# INFO:root:Saving data for conversation 'Play MP3' to CHATGPT/individual_sessions/Play_MP3.json
# INFO:root:Saving data for conversation 'Screen and Audio Capture' to CHATGPT/individual_sessions/Screen_and_Audio_Capture.json
# INFO:root:Saving data for conversation 'Flask Marquee Overlay Video' to CHATGPT/individual_sessions/Flask_Marquee_Overlay_Video.json
# INFO:root:Saving data for conversation 'Concatenation Error: Parameters Mismatch' to CHATGPT/individual_sessions/Concatenation_Error__Parameters_Mismatch.json
# INFO:root:Saving data for conversation 'AI's Arcanis Intervention' to CHATGPT/individual_sessions/AI_s_Arcanis_Intervention.json
# INFO:root:Saving data for conversation 'Story Assistance Available' to CHATGPT/individual_sessions/Story_Assistance_Available.json
# INFO:root:Saving data for conversation 'LAN PHP Server Setup' to CHATGPT/individual_sessions/LAN_PHP_Server_Setup.json
# INFO:root:Saving data for conversation 'Combine Image and Audio' to CHATGPT/individual_sessions/Combine_Image_and_Audio.json
# INFO:root:Saving data for conversation 'Image to Video Conversion' to CHATGPT/individual_sessions/Image_to_Video_Conversion.json
# INFO:root:Saving data for conversation 'Male voice for Google TTS' to CHATGPT/individual_sessions/Male_voice_for_Google_TTS.json
# INFO:root:Saving data for conversation 'Fixing PyQt5 Dependency Error' to CHATGPT/individual_sessions/Fixing_PyQt5_Dependency_Error.json
# INFO:root:Saving data for conversation 'KDENLIVE error encountered' to CHATGPT/individual_sessions/KDENLIVE_error_encountered.json
# INFO:root:Saving data for conversation 'CUDA Library Missing Error' to CHATGPT/individual_sessions/CUDA_Library_Missing_Error.json
# INFO:root:Saving data for conversation 'Add large file to GitHub.' to CHATGPT/individual_sessions/Add_large_file_to_GitHub..json
# INFO:root:Saving data for conversation 'NoCache pip Install.' to CHATGPT/individual_sessions/NoCache_pip_Install..json
# INFO:root:Saving data for conversation 'Fixing Large Files Issue' to CHATGPT/individual_sessions/Fixing_Large_Files_Issue.json
# INFO:root:Saving data for conversation 'MyTube AI Videos' to CHATGPT/individual_sessions/MyTube_AI_Videos.json
# INFO:root:Saving data for conversation 'Programming Joke: Light vs Bugs' to CHATGPT/individual_sessions/Programming_Joke__Light_vs_Bugs.json
# INFO:root:Saving data for conversation 'Choose Directory: Handle Selection' to CHATGPT/individual_sessions/Choose_Directory__Handle_Selection.json
# INFO:root:Saving data for conversation 'FFmpeg Merge Video & Audio' to CHATGPT/individual_sessions/FFmpeg_Merge_Video___Audio.json
# INFO:root:Saving data for conversation 'MP3 to WAV Conversion' to CHATGPT/individual_sessions/MP3_to_WAV_Conversion.json
# INFO:root:Saving data for conversation 'FFmpeg Resize Video' to CHATGPT/individual_sessions/FFmpeg_Resize_Video.json
# INFO:root:Saving data for conversation 'Resize Video 1/4' to CHATGPT/individual_sessions/Resize_Video_1/4.json
# ERROR:root:File not found: CHATGPT/conversations.json
# FFmpeg_Slideshow_with_Transitions.json
# ['python', 'json2htmltxt.py', 'FFmpeg_Slideshow_with_Transitions.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFmpeg_Slideshow_with_Transitions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/FFmpeg_Slideshow_with_Transitions.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/FFmpeg_Slideshow_with_Transitions.txt
# Fixing_Flask_Screen_Capture.json
# ['python', 'json2htmltxt.py', 'Fixing_Flask_Screen_Capture.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fixing_Flask_Screen_Capture.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Fixing_Flask_Screen_Capture.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Fixing_Flask_Screen_Capture.txt
# Flask_Thumbnail_Video.json
# ['python', 'json2htmltxt.py', 'Flask_Thumbnail_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Thumbnail_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_Thumbnail_Video.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_Thumbnail_Video.txt
# PHP_Execute_Bash_Script.json
# ['python', 'json2htmltxt.py', 'PHP_Execute_Bash_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/PHP_Execute_Bash_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/PHP_Execute_Bash_Script.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/PHP_Execute_Bash_Script.txt
# Prevent_inherit_text-align..json
# ['python', 'json2htmltxt.py', 'Prevent_inherit_text-align..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Prevent_inherit_text-align..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Prevent_inherit_text-align..html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Prevent_inherit_text-align..txt
# Fixing_PyQt5_Dependency_Error.json
# ['python', 'json2htmltxt.py', 'Fixing_PyQt5_Dependency_Error.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fixing_PyQt5_Dependency_Error.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Fixing_PyQt5_Dependency_Error.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Fixing_PyQt5_Dependency_Error.txt
# Update_SQLite_Permissions.json
# ['python', 'json2htmltxt.py', 'Update_SQLite_Permissions.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Update_SQLite_Permissions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Update_SQLite_Permissions.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Update_SQLite_Permissions.txt
# CSS_Logo_Placement.json
# ['python', 'json2htmltxt.py', 'CSS_Logo_Placement.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/CSS_Logo_Placement.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/CSS_Logo_Placement.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/CSS_Logo_Placement.txt
# Video_Clips_with_Sound.json
# ['python', 'json2htmltxt.py', 'Video_Clips_with_Sound.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Clips_with_Sound.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Video_Clips_with_Sound.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Video_Clips_with_Sound.txt
# Video_Generation_from_Directories..json
# ['python', 'json2htmltxt.py', 'Video_Generation_from_Directories..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Generation_from_Directories..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Video_Generation_from_Directories..html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Video_Generation_from_Directories..txt
# Create_3D_Image_Transitions.json
# ['python', 'json2htmltxt.py', 'Create_3D_Image_Transitions.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_3D_Image_Transitions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Create_3D_Image_Transitions.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Create_3D_Image_Transitions.txt
# New_chat.json
# ['python', 'json2htmltxt.py', 'New_chat.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/New_chat.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/New_chat.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/New_chat.txt
# Flask_App_Conversion.json
# ['python', 'json2htmltxt.py', 'Flask_App_Conversion.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Conversion.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_App_Conversion.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_App_Conversion.txt
# Python_Punctuation_Removal.json
# ['python', 'json2htmltxt.py', 'Python_Punctuation_Removal.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Python_Punctuation_Removal.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Python_Punctuation_Removal.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Python_Punctuation_Removal.txt
# Flask_App_Demo___Explanation.json
# ['python', 'json2htmltxt.py', 'Flask_App_Demo___Explanation.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Demo___Explanation.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_App_Demo___Explanation.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_App_Demo___Explanation.txt
# NoCache_pip_Install..json
# ['python', 'json2htmltxt.py', 'NoCache_pip_Install..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/NoCache_pip_Install..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/NoCache_pip_Install..html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/NoCache_pip_Install..txt
# Snap_Certbot_Installation_Issue.json
# ['python', 'json2htmltxt.py', 'Snap_Certbot_Installation_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Snap_Certbot_Installation_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Snap_Certbot_Installation_Issue.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Snap_Certbot_Installation_Issue.txt
# Nietzsche_s_views_on_death..json
# ['python', 'json2htmltxt.py', 'Nietzsche_s_views_on_death..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Nietzsche_s_views_on_death..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Nietzsche_s_views_on_death..html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Nietzsche_s_views_on_death..txt
# Remove_Python_Path.json
# ['python', 'json2htmltxt.py', 'Remove_Python_Path.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Remove_Python_Path.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Remove_Python_Path.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Remove_Python_Path.txt
# Xterm_Display_Error_Troubleshoot.json
# ['python', 'json2htmltxt.py', 'Xterm_Display_Error_Troubleshoot.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Xterm_Display_Error_Troubleshoot.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Xterm_Display_Error_Troubleshoot.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Xterm_Display_Error_Troubleshoot.txt
# Video_Editing_with_MoviePy.json
# ['python', 'json2htmltxt.py', 'Video_Editing_with_MoviePy.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Editing_with_MoviePy.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Video_Editing_with_MoviePy.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Video_Editing_with_MoviePy.txt
# Random_Desktop_Video_Clips.json
# ['python', 'json2htmltxt.py', 'Random_Desktop_Video_Clips.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Random_Desktop_Video_Clips.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Random_Desktop_Video_Clips.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Random_Desktop_Video_Clips.txt
# FlaskWebGui_Debug_Mode.json
# ['python', 'json2htmltxt.py', 'FlaskWebGui_Debug_Mode.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FlaskWebGui_Debug_Mode.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/FlaskWebGui_Debug_Mode.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/FlaskWebGui_Debug_Mode.txt
# Run_Kdenlive_Extension_with_Melt.json
# ['python', 'json2htmltxt.py', 'Run_Kdenlive_Extension_with_Melt.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Run_Kdenlive_Extension_with_Melt.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Run_Kdenlive_Extension_with_Melt.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Run_Kdenlive_Extension_with_Melt.txt
# Add_large_file_to_GitHub..json
# ['python', 'json2htmltxt.py', 'Add_large_file_to_GitHub..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Add_large_file_to_GitHub..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Add_large_file_to_GitHub..html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Add_large_file_to_GitHub..txt
# Create_Image_Sequence_Video.json
# ['python', 'json2htmltxt.py', 'Create_Image_Sequence_Video.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Create_Image_Sequence_Video.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Create_Image_Sequence_Video.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Create_Image_Sequence_Video.txt
# Fix_Protobuf_Issue.json
# ['python', 'json2htmltxt.py', 'Fix_Protobuf_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fix_Protobuf_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Fix_Protobuf_Issue.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Fix_Protobuf_Issue.txt
# Generate_Unique_Video_Filename.json
# ['python', 'json2htmltxt.py', 'Generate_Unique_Video_Filename.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Generate_Unique_Video_Filename.json
# ...
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Arcanis_AI_Communication.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Arcanis_AI_Communication.txt
# FFMPEG_Video_Slowdown..json
# ['python', 'json2htmltxt.py', 'FFMPEG_Video_Slowdown..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/FFMPEG_Video_Slowdown..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/FFMPEG_Video_Slowdown..html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/FFMPEG_Video_Slowdown..txt
# Load_index.html_in_Flask.json
# ['python', 'json2htmltxt.py', 'Load_index.html_in_Flask.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Load_index.html_in_Flask.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Load_index.html_in_Flask.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Load_index.html_in_Flask.txt
# Fade_Transition_Video_Script.json
# ['python', 'json2htmltxt.py', 'Fade_Transition_Video_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fade_Transition_Video_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Fade_Transition_Video_Script.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Fade_Transition_Video_Script.txt
# Generate___Save_PNG_Plot.json
# ['python', 'json2htmltxt.py', 'Generate___Save_PNG_Plot.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Generate___Save_PNG_Plot.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Generate___Save_PNG_Plot.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Generate___Save_PNG_Plot.txt
# AI_s_Leap_in_2021.json
# ['python', 'json2htmltxt.py', 'AI_s_Leap_in_2021.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/AI_s_Leap_in_2021.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/AI_s_Leap_in_2021.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/AI_s_Leap_in_2021.txt
# Flask_Video_Selection_Script.json
# ['python', 'json2htmltxt.py', 'Flask_Video_Selection_Script.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Video_Selection_Script.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_Video_Selection_Script.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_Video_Selection_Script.txt
# Check_Image_Duplicates_with_Hashes.json
# ['python', 'json2htmltxt.py', 'Check_Image_Duplicates_with_Hashes.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Check_Image_Duplicates_with_Hashes.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Check_Image_Duplicates_with_Hashes.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Check_Image_Duplicates_with_Hashes.txt
# Kill_Process_on_Port.json
# ['python', 'json2htmltxt.py', 'Kill_Process_on_Port.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Kill_Process_on_Port.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Kill_Process_on_Port.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Kill_Process_on_Port.txt
# Flask_Async_Endpoints.json
# ['python', 'json2htmltxt.py', 'Flask_Async_Endpoints.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Async_Endpoints.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_Async_Endpoints.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_Async_Endpoints.txt
# Anunnaki_Overview.json
# ['python', 'json2htmltxt.py', 'Anunnaki_Overview.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Anunnaki_Overview.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Anunnaki_Overview.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Anunnaki_Overview.txt
# Flask_App_Setup.json
# ['python', 'json2htmltxt.py', 'Flask_App_Setup.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_App_Setup.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_App_Setup.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_App_Setup.txt
# Avatar_AI_for_Talking.json
# ['python', 'json2htmltxt.py', 'Avatar_AI_for_Talking.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Avatar_AI_for_Talking.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Avatar_AI_for_Talking.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Avatar_AI_for_Talking.txt
# Delete_Files_Except__.jpg.json
# ['python', 'json2htmltxt.py', 'Delete_Files_Except__.jpg.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Delete_Files_Except__.jpg.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Delete_Files_Except__.jpg.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Delete_Files_Except__.jpg.txt
# Fail2Ban_Installation_for_Security.json
# ['python', 'json2htmltxt.py', 'Fail2Ban_Installation_for_Security.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Fail2Ban_Installation_for_Security.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Fail2Ban_Installation_for_Security.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Fail2Ban_Installation_for_Security.txt
# Set_Hard_Drive_Permissions.json
# ['python', 'json2htmltxt.py', 'Set_Hard_Drive_Permissions.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Set_Hard_Drive_Permissions.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Set_Hard_Drive_Permissions.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Set_Hard_Drive_Permissions.txt
# LAN_PHP_Server_Setup.json
# ['python', 'json2htmltxt.py', 'LAN_PHP_Server_Setup.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/LAN_PHP_Server_Setup.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/LAN_PHP_Server_Setup.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/LAN_PHP_Server_Setup.txt
# Crear_video_con_transiciones..json
# ['python', 'json2htmltxt.py', 'Crear_video_con_transiciones..json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Crear_video_con_transiciones..json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Crear_video_con_transiciones..html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Crear_video_con_transiciones..txt
# Cosmic_Octopus_AI_Awakening.json
# ['python', 'json2htmltxt.py', 'Cosmic_Octopus_AI_Awakening.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Cosmic_Octopus_AI_Awakening.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Cosmic_Octopus_AI_Awakening.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Cosmic_Octopus_AI_Awakening.txt
# Install_Wine_Mono_Linux.json
# ['python', 'json2htmltxt.py', 'Install_Wine_Mono_Linux.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Install_Wine_Mono_Linux.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Install_Wine_Mono_Linux.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Install_Wine_Mono_Linux.txt
# Save_DuckDuckGo_Results_JSON.json
# ['python', 'json2htmltxt.py', 'Save_DuckDuckGo_Results_JSON.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Save_DuckDuckGo_Results_JSON.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Save_DuckDuckGo_Results_JSON.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Save_DuckDuckGo_Results_JSON.txt
# Linux_Terminal_Issue.json
# ['python', 'json2htmltxt.py', 'Linux_Terminal_Issue.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Linux_Terminal_Issue.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Linux_Terminal_Issue.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Linux_Terminal_Issue.txt
# GPT_API_Key_Access.json
# ['python', 'json2htmltxt.py', 'GPT_API_Key_Access.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/GPT_API_Key_Access.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/GPT_API_Key_Access.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/GPT_API_Key_Access.txt
# Convert_JSON_to_HTML.json
# ['python', 'json2htmltxt.py', 'Convert_JSON_to_HTML.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Convert_JSON_to_HTML.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Convert_JSON_to_HTML.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Convert_JSON_to_HTML.txt
# Selecting_Image_Directory.json
# ['python', 'json2htmltxt.py', 'Selecting_Image_Directory.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Selecting_Image_Directory.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Selecting_Image_Directory.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Selecting_Image_Directory.txt
# Flask_Programmer_and_YouTuber.json
# ['python', 'json2htmltxt.py', 'Flask_Programmer_and_YouTuber.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Programmer_and_YouTuber.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_Programmer_and_YouTuber.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_Programmer_and_YouTuber.txt
# Adjust_Duration_for_Longer.json
# ['python', 'json2htmltxt.py', 'Adjust_Duration_for_Longer.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Adjust_Duration_for_Longer.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Adjust_Duration_for_Longer.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Adjust_Duration_for_Longer.txt
# HTML_Conversion_Debugging.json
# ['python', 'json2htmltxt.py', 'HTML_Conversion_Debugging.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/HTML_Conversion_Debugging.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/HTML_Conversion_Debugging.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/HTML_Conversion_Debugging.txt
# Set_Up_LAN_Server__Python_.json
# ['python', 'json2htmltxt.py', 'Set_Up_LAN_Server__Python_.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Set_Up_LAN_Server__Python_.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Set_Up_LAN_Server__Python_.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Set_Up_LAN_Server__Python_.txt
# Upload_file_from_directory.json
# ['python', 'json2htmltxt.py', 'Upload_file_from_directory.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Upload_file_from_directory.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Upload_file_from_directory.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Upload_file_from_directory.txt
# Python_HTTP_Server_Guide.json
# ['python', 'json2htmltxt.py', 'Python_HTTP_Server_Guide.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Python_HTTP_Server_Guide.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Python_HTTP_Server_Guide.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Python_HTTP_Server_Guide.txt
# Lighten_Image_with_Mogrify.json
# ['python', 'json2htmltxt.py', 'Lighten_Image_with_Mogrify.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Lighten_Image_with_Mogrify.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Lighten_Image_with_Mogrify.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Lighten_Image_with_Mogrify.txt
# Video_Making_Script_with_Logging.json
# ['python', 'json2htmltxt.py', 'Video_Making_Script_with_Logging.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Making_Script_with_Logging.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Video_Making_Script_with_Logging.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Video_Making_Script_with_Logging.txt
# Combine_Image_and_Audio.json
# ['python', 'json2htmltxt.py', 'Combine_Image_and_Audio.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Combine_Image_and_Audio.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Combine_Image_and_Audio.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Combine_Image_and_Audio.txt
# Change_Outline_Color.json
# ['python', 'json2htmltxt.py', 'Change_Outline_Color.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Change_Outline_Color.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Change_Outline_Color.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Change_Outline_Color.txt
# Video_Processing__512x768_Resolution.json
# ['python', 'json2htmltxt.py', 'Video_Processing__512x768_Resolution.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Video_Processing__512x768_Resolution.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Video_Processing__512x768_Resolution.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Video_Processing__512x768_Resolution.txt
# Correção_da_Rota_"join_sound".json
# ['python', 'json2htmltxt.py', 'Correção_da_Rota_"join_sound".json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Correção_da_Rota_"join_sound".json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Correção_da_Rota_"join_sound".html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Correção_da_Rota_"join_sound".txt
# Flask_Open___View_Text.json
# ['python', 'json2htmltxt.py', 'Flask_Open___View_Text.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_Open___View_Text.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_Open___View_Text.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_Open___View_Text.txt
# Flask_AttributeError_Troubleshooting.json
# ['python', 'json2htmltxt.py', 'Flask_AttributeError_Troubleshooting.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Flask_AttributeError_Troubleshooting.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_AttributeError_Troubleshooting.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Flask_AttributeError_Troubleshooting.txt
# Bash_Locate_in_Python.json
# ['python', 'json2htmltxt.py', 'Bash_Locate_in_Python.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Bash_Locate_in_Python.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Bash_Locate_in_Python.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Bash_Locate_in_Python.txt
# Save_Plots_with_UUIDs.json
# ['python', 'json2htmltxt.py', 'Save_Plots_with_UUIDs.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Save_Plots_with_UUIDs.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Save_Plots_with_UUIDs.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Save_Plots_with_UUIDs.txt
# Movies_with_Punch.json
# ['python', 'json2htmltxt.py', 'Movies_with_Punch.json']
# /home/jack/Desktop/flask_conversations2/CHATGPT/individual_sessions/Movies_with_Punch.json
# HTMLfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Movies_with_Punch.html
# TXTfile:  /home/jack/Desktop/flask_conversations2/CHATGPT/output/Movies_with_Punch.txt

# %%
#!/home/jack/miniconda3/envs/cloned_base/bin/python
import json
import logging
import os
import glob
import subprocess

def split_and_save_and_convert(conversations_file, output_folder):
    try:
        with open(conversations_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
            
            for conversation in data:
                title = conversation.get('title', 'Unknown_Title')
                title_with_underscores = title.replace(' ', '_')
                title_with_underscores = title_with_underscores.replace(':', '_')
                title_with_underscores = title_with_underscores.replace("'", "_")
                title_with_underscores = title_with_underscores.replace("&", "_")
                title_with_underscores = title_with_underscores.replace("*", "_")
                title_with_underscores = title_with_underscores.replace("(", "_")
                title_with_underscores = title_with_underscores.replace(")", "_")
                chapter_filename = f"{title_with_underscores}.json"
                chapter_filepath = os.path.join(output_folder, chapter_filename)
                
                logging.info(f"Saving data for conversation '{title}' to {chapter_filepath}")
                
                with open(chapter_filepath, 'w', encoding='utf-8') as chapter_file:
                    json.dump([conversation], chapter_file, indent=2)

                # Convert JSON to HTML
                html_output_file = os.path.join(output_folder, f"{title_with_underscores}.html")
                convert_to_html(chapter_filepath, html_output_file)

                # Convert JSON to TXT
                txt_output_file = os.path.join(output_folder, f"{title_with_underscores}.txt")
                convert_to_txt(chapter_filepath, txt_output_file)

    except FileNotFoundError:
        logging.error(f"File not found: {conversations_file}")
    except json.JSONDecodeError:
        logging.error(f"Error decoding JSON in file: {conversations_file}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {e}")

def convert_to_html(json_file, html_output_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        json_data = json.load(file)

    result_str = get_conversation_result(json_data)

    with open(html_output_file, "w", encoding='utf-8') as html_output:
        result_html = result_str.replace("/n", "XXXXXXX\n")
        result_html = result_html.replace("<", "&lt;")
        result_html = result_html.replace(">", "&gt;")
        for line in result_html.split("XXXXXXX"):
            line = line.replace("\n", "<br />\n")
            html_output.write(line)

def convert_to_txt(json_file, txt_output_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        json_data = json.load(file)

    result_str = get_conversation_result(json_data)

    with open(txt_output_file, "w", encoding='utf-8') as txt_output:
        result_txt = result_str.replace("/n", "XXXXXXX\n")
        for line in result_txt.split("XXXXXXX"):
            txt_output.write(line)

def get_conversation_result(json_data):
    result_str = ""
    for conversation in json_data:
        title = conversation.get('title', '')
        messages = get_conversation_messages(conversation)

        result_str += title + '\n'
        for message in messages:
            result_str += message['author'] + '\n' + message['text'] + '\n'
        result_str += '\n'

    return result_str

def get_conversation_messages(conversation):
    messages = []
    current_node = conversation.get('current_node')
    while current_node:
        node = conversation['mapping'][current_node]
        message = node.get('message')
        if (message and message.get('content') and message['content'].get('content_type') == 'text' and
                len(message['content'].get('parts', [])) > 0 and len(message['content']['parts'][0]) > 0 and
                (message['author']['role'] != 'system' or message.get('metadata', {}).get('is_user_system_message'))):
            author = message['author']['role']
            if author == 'assistant':
                author = 'ChatGPT'
            elif author == 'system' and message['metadata'].get('is_user_system_message'):
                author = 'Custom user info'
            messages.append({'author': author, 'text': message['content']['parts'][0]})
        current_node = node.get('parent')
    return messages[::-1]

# Example usage
conversations_file_path = 'CHATGPT/conversations.json'
output_folder = 'CHATGPT/output_all_in_one'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Configure logging
logging.basicConfig(level=logging.INFO)

# Call the split, save, and convert function
split_and_save_and_convert(conversations_file_path, output_folder)
# Out:
# INFO:root:Saving data for conversation 'Add Expose to Docker Image' to CHATGPT/output_all_in_one/Add_Expose_to_Docker_Image.json
# INFO:root:Saving data for conversation 'HTML Conversion Debugging' to CHATGPT/output_all_in_one/HTML_Conversion_Debugging.json
# INFO:root:Saving data for conversation 'Wget File Download' to CHATGPT/output_all_in_one/Wget_File_Download.json
# INFO:root:Saving data for conversation 'Flask App on LAN' to CHATGPT/output_all_in_one/Flask_App_on_LAN.json
# INFO:root:Saving data for conversation 'Convert JSON to HTML' to CHATGPT/output_all_in_one/Convert_JSON_to_HTML.json
# INFO:root:Saving data for conversation 'Check Directory for Duplicates' to CHATGPT/output_all_in_one/Check_Directory_for_Duplicates.json
# INFO:root:Saving data for conversation 'Search IPYNB for Term' to CHATGPT/output_all_in_one/Search_IPYNB_for_Term.json
# INFO:root:Saving data for conversation 'Refrigerate ketchup after opening.' to CHATGPT/output_all_in_one/Refrigerate_ketchup_after_opening..json
# INFO:root:Saving data for conversation 'ChatGPT, Conversations.json Overview' to CHATGPT/output_all_in_one/ChatGPT,_Conversations.json_Overview.json
# INFO:root:Saving data for conversation 'Python Punctuation Removal' to CHATGPT/output_all_in_one/Python_Punctuation_Removal.json
# INFO:root:Saving data for conversation 'Cosmic Octopus AI Awakening' to CHATGPT/output_all_in_one/Cosmic_Octopus_AI_Awakening.json
# INFO:root:Saving data for conversation 'Arcanian AI's Transformative Influence' to CHATGPT/output_all_in_one/Arcanian_AI_s_Transformative_Influence.json
# INFO:root:Saving data for conversation 'AI Guides Animal Enlightenment' to CHATGPT/output_all_in_one/AI_Guides_Animal_Enlightenment.json
# INFO:root:Saving data for conversation 'Flask Programmer and YouTuber' to CHATGPT/output_all_in_one/Flask_Programmer_and_YouTuber.json
# INFO:root:Saving data for conversation 'Set Hard Drive Permissions' to CHATGPT/output_all_in_one/Set_Hard_Drive_Permissions.json
# INFO:root:Saving data for conversation 'Python HTTP Server Guide' to CHATGPT/output_all_in_one/Python_HTTP_Server_Guide.json
# INFO:root:Saving data for conversation 'Simple 3D Scene Creation' to CHATGPT/output_all_in_one/Simple_3D_Scene_Creation.json
# INFO:root:Saving data for conversation 'Segmenting Video Frames' to CHATGPT/output_all_in_one/Segmenting_Video_Frames.json
# INFO:root:Saving data for conversation 'Download Age-Restricted Video' to CHATGPT/output_all_in_one/Download_Age-Restricted_Video.json
# INFO:root:Saving data for conversation 'Convert FilePath to GIF' to CHATGPT/output_all_in_one/Convert_FilePath_to_GIF.json
# INFO:root:Saving data for conversation 'Remove Python Path' to CHATGPT/output_all_in_one/Remove_Python_Path.json
# INFO:root:Saving data for conversation 'Create Black Image' to CHATGPT/output_all_in_one/Create_Black_Image.json
# INFO:root:Saving data for conversation 'Whiplash Curves in Art' to CHATGPT/output_all_in_one/Whiplash_Curves_in_Art.json
# INFO:root:Saving data for conversation 'SSL Cert Expiry: Python' to CHATGPT/output_all_in_one/SSL_Cert_Expiry__Python.json
# INFO:root:Saving data for conversation 'Bash Locate in Python' to CHATGPT/output_all_in_one/Bash_Locate_in_Python.json
# INFO:root:Saving data for conversation 'Doll in Dystopian Decay' to CHATGPT/output_all_in_one/Doll_in_Dystopian_Decay.json
# INFO:root:Saving data for conversation 'FFmpeg Zoom Video Fix' to CHATGPT/output_all_in_one/FFmpeg_Zoom_Video_Fix.json
# INFO:root:Saving data for conversation 'Doll Factory Dystopia' to CHATGPT/output_all_in_one/Doll_Factory_Dystopia.json
# INFO:root:Saving data for conversation 'Enhance Image with OpenCV' to CHATGPT/output_all_in_one/Enhance_Image_with_OpenCV.json
# INFO:root:Saving data for conversation 'Flask Video Selection Script' to CHATGPT/output_all_in_one/Flask_Video_Selection_Script.json
# INFO:root:Saving data for conversation 'SSD Maintenance: Trim Frequency' to CHATGPT/output_all_in_one/SSD_Maintenance__Trim_Frequency.json
# INFO:root:Saving data for conversation 'Split MP4 into 6.' to CHATGPT/output_all_in_one/Split_MP4_into_6..json
# INFO:root:Saving data for conversation 'FFmpeg Remove Duplicate Frames' to CHATGPT/output_all_in_one/FFmpeg_Remove_Duplicate_Frames.json
# INFO:root:Saving data for conversation 'Video Clips with Sound' to CHATGPT/output_all_in_one/Video_Clips_with_Sound.json
# INFO:root:Saving data for conversation 'Video Flip Book Fix' to CHATGPT/output_all_in_one/Video_Flip_Book_Fix.json
# INFO:root:Saving data for conversation 'Dystopian City Text Prompt' to CHATGPT/output_all_in_one/Dystopian_City_Text_Prompt.json
# INFO:root:Saving data for conversation 'SSH to Specific Directory' to CHATGPT/output_all_in_one/SSH_to_Specific_Directory.json
# INFO:root:Saving data for conversation 'Add sound if needed.' to CHATGPT/output_all_in_one/Add_sound_if_needed..json
# INFO:root:Saving data for conversation 'Thunar Scroll Issue Troubleshooting' to CHATGPT/output_all_in_one/Thunar_Scroll_Issue_Troubleshooting.json
# INFO:root:Saving data for conversation 'Get Image Size' to CHATGPT/output_all_in_one/Get_Image_Size.json
# INFO:root:Saving data for conversation 'Image Zoom Video Script' to CHATGPT/output_all_in_one/Image_Zoom_Video_Script.json
# INFO:root:Saving data for conversation 'Video Processing: 512x768 Resolution' to CHATGPT/output_all_in_one/Video_Processing__512x768_Resolution.json
# INFO:root:Saving data for conversation 'Find & CD: fade-transb' to CHATGPT/output_all_in_one/Find___CD__fade-transb.json
# INFO:root:Saving data for conversation 'Shell Command Argument Handling' to CHATGPT/output_all_in_one/Shell_Command_Argument_Handling.json
# INFO:root:Saving data for conversation 'Python Save File' to CHATGPT/output_all_in_one/Python_Save_File.json
# INFO:root:Saving data for conversation 'Flask Module Not Found' to CHATGPT/output_all_in_one/Flask_Module_Not_Found.json
# INFO:root:Saving data for conversation 'Linux Terminal Issue' to CHATGPT/output_all_in_one/Linux_Terminal_Issue.json
# INFO:root:Saving data for conversation 'Run Kdenlive Extension with Melt' to CHATGPT/output_all_in_one/Run_Kdenlive_Extension_with_Melt.json
# INFO:root:Saving data for conversation 'YouTube 2nd Channel Automator' to CHATGPT/output_all_in_one/YouTube_2nd_Channel_Automator.json
# INFO:root:Saving data for conversation 'Xterm Display Error Troubleshoot' to CHATGPT/output_all_in_one/Xterm_Display_Error_Troubleshoot.json
# INFO:root:Saving data for conversation 'Flask Installation Troubleshooting' to CHATGPT/output_all_in_one/Flask_Installation_Troubleshooting.json
# INFO:root:Saving data for conversation 'MoviePy for Image Videos' to CHATGPT/output_all_in_one/MoviePy_for_Image_Videos.json
# INFO:root:Saving data for conversation 'Create 3D Image Transitions' to CHATGPT/output_all_in_one/Create_3D_Image_Transitions.json
# INFO:root:Saving data for conversation 'Adjust Duration for Longer' to CHATGPT/output_all_in_one/Adjust_Duration_for_Longer.json
# INFO:root:Saving data for conversation 'Capture Screen with Offset' to CHATGPT/output_all_in_one/Capture_Screen_with_Offset.json
# INFO:root:Saving data for conversation 'Reinstall XWin on Linux.' to CHATGPT/output_all_in_one/Reinstall_XWin_on_Linux..json
# INFO:root:Saving data for conversation 'Linux: Force Thumbnail Regeneration' to CHATGPT/output_all_in_one/Linux__Force_Thumbnail_Regeneration.json
# INFO:root:Saving data for conversation 'Martian Masterpiece: Surreal Synthesis' to CHATGPT/output_all_in_one/Martian_Masterpiece__Surreal_Synthesis.json
# INFO:root:Saving data for conversation 'Reinstall EFC Desktop' to CHATGPT/output_all_in_one/Reinstall_EFC_Desktop.json
# INFO:root:Saving data for conversation 'Kill Process on Port' to CHATGPT/output_all_in_one/Kill_Process_on_Port.json
# INFO:root:Saving data for conversation 'Linux Find Largest Subdirectory' to CHATGPT/output_all_in_one/Linux_Find_Largest_Subdirectory.json
# INFO:root:Saving data for conversation 'Shuffle Images for Video' to CHATGPT/output_all_in_one/Shuffle_Images_for_Video.json
# INFO:root:Saving data for conversation 'Shuffled Image Zoom' to CHATGPT/output_all_in_one/Shuffled_Image_Zoom.json
# INFO:root:Saving data for conversation 'Sticky Header for Website' to CHATGPT/output_all_in_one/Sticky_Header_for_Website.json
# INFO:root:Saving data for conversation 'Image files not printing.' to CHATGPT/output_all_in_one/Image_files_not_printing..json
# INFO:root:Saving data for conversation 'Rsync Syncs and Overwrites' to CHATGPT/output_all_in_one/Rsync_Syncs_and_Overwrites.json
# INFO:root:Saving data for conversation 'Auto-looping 1s Slideshow Code' to CHATGPT/output_all_in_one/Auto-looping_1s_Slideshow_Code.json
# INFO:root:Saving data for conversation 'Sticky Header Code' to CHATGPT/output_all_in_one/Sticky_Header_Code.json
# INFO:root:Saving data for conversation 'Bash Completion Python Script' to CHATGPT/output_all_in_one/Bash_Completion_Python_Script.json
# INFO:root:Saving data for conversation 'Copy care.mp4 to VPS' to CHATGPT/output_all_in_one/Copy_care.mp4_to_VPS.json
# INFO:root:Saving data for conversation 'Update SQLite Permissions' to CHATGPT/output_all_in_one/Update_SQLite_Permissions.json
# INFO:root:Saving data for conversation 'Caregivers: Organized, Efficient, Communicative' to CHATGPT/output_all_in_one/Caregivers__Organized,_Efficient,_Communicative.json
# INFO:root:Saving data for conversation 'Select Random TTF Font' to CHATGPT/output_all_in_one/Select_Random_TTF_Font.json
# INFO:root:Saving data for conversation 'Generate Loopable Stylized Images' to CHATGPT/output_all_in_one/Generate_Loopable_Stylized_Images.json
# INFO:root:Saving data for conversation 'Fix Protobuf Issue' to CHATGPT/output_all_in_one/Fix_Protobuf_Issue.json
# INFO:root:Saving data for conversation 'Locate IPYNB with Quantify' to CHATGPT/output_all_in_one/Locate_IPYNB_with_Quantify.json
# INFO:root:Saving data for conversation 'PDF to PNG Conversion' to CHATGPT/output_all_in_one/PDF_to_PNG_Conversion.json
# INFO:root:Saving data for conversation 'PDF to PNG Converter' to CHATGPT/output_all_in_one/PDF_to_PNG_Converter.json
# INFO:root:Saving data for conversation 'Movies with Punch' to CHATGPT/output_all_in_one/Movies_with_Punch.json
# INFO:root:Saving data for conversation 'LAN Directory Serving Script' to CHATGPT/output_all_in_one/LAN_Directory_Serving_Script.json
# INFO:root:Saving data for conversation 'Flask FFmpeg Command Integration' to CHATGPT/output_all_in_one/Flask_FFmpeg_Command_Integration.json
# INFO:root:Saving data for conversation 'Explain script in detail.' to CHATGPT/output_all_in_one/Explain_script_in_detail..json
# INFO:root:Saving data for conversation 'AI Video Transitions Mastery' to CHATGPT/output_all_in_one/AI_Video_Transitions_Mastery.json
# INFO:root:Saving data for conversation 'Fail2Ban Installation for Security' to CHATGPT/output_all_in_one/Fail2Ban_Installation_for_Security.json
# INFO:root:Saving data for conversation 'PHP Execute Bash Script' to CHATGPT/output_all_in_one/PHP_Execute_Bash_Script.json
# INFO:root:Saving data for conversation 'Prevent inherit text-align.' to CHATGPT/output_all_in_one/Prevent_inherit_text-align..json
# INFO:root:Saving data for conversation 'Sudo cp file permissions' to CHATGPT/output_all_in_one/Sudo_cp_file_permissions.json
# INFO:root:Saving data for conversation 'CSS Logo Placement' to CHATGPT/output_all_in_one/CSS_Logo_Placement.json
# INFO:root:Saving data for conversation 'Snap Certbot Installation Issue' to CHATGPT/output_all_in_one/Snap_Certbot_Installation_Issue.json
# INFO:root:Saving data for conversation 'Configurar servidor Apache local' to CHATGPT/output_all_in_one/Configurar_servidor_Apache_local.json
# INFO:root:Saving data for conversation 'Install PHP on Apache' to CHATGPT/output_all_in_one/Install_PHP_on_Apache.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New_chat.json
# INFO:root:Saving data for conversation 'Domain Info with Python' to CHATGPT/output_all_in_one/Domain_Info_with_Python.json
# INFO:root:Saving data for conversation 'Set Up LAN Server (Python)' to CHATGPT/output_all_in_one/Set_Up_LAN_Server__Python_.json
# INFO:root:Saving data for conversation 'Open Jupyter Notebook Over LAN' to CHATGPT/output_all_in_one/Open_Jupyter_Notebook_Over_LAN.json
# INFO:root:Saving data for conversation 'MP4 Files Finder Script' to CHATGPT/output_all_in_one/MP4_Files_Finder_Script.json
# INFO:root:Saving data for conversation 'Crear imagen colores primarios' to CHATGPT/output_all_in_one/Crear_imagen_colores_primarios.json
# INFO:root:Saving data for conversation 'FFmpeg Slideshow with Transitions' to CHATGPT/output_all_in_one/FFmpeg_Slideshow_with_Transitions.json
# INFO:root:Saving data for conversation 'Scroll Image to Video' to CHATGPT/output_all_in_one/Scroll_Image_to_Video.json
# INFO:root:Saving data for conversation 'Crear videos con imágenes.' to CHATGPT/output_all_in_one/Crear_videos_con_imágenes..json
# INFO:root:Saving data for conversation 'Video Making Script with Logging' to CHATGPT/output_all_in_one/Video_Making_Script_with_Logging.json
# INFO:root:Saving data for conversation 'Crear video con transiciones.' to CHATGPT/output_all_in_one/Crear_video_con_transiciones..json
# INFO:root:Saving data for conversation 'List Directories with 'ls'' to CHATGPT/output_all_in_one/List_Directories_with__ls_.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New_chat.json
# INFO:root:Saving data for conversation 'Rebuild Linux Thumbnails Cache' to CHATGPT/output_all_in_one/Rebuild_Linux_Thumbnails_Cache.json
# INFO:root:Saving data for conversation 'Video Conversion with Fades' to CHATGPT/output_all_in_one/Video_Conversion_with_Fades.json
# INFO:root:Saving data for conversation 'Unione video MP4 con transizione' to CHATGPT/output_all_in_one/Unione_video_MP4_con_transizione.json
# INFO:root:Saving data for conversation 'Video Processing: Frames Method' to CHATGPT/output_all_in_one/Video_Processing__Frames_Method.json
# INFO:root:Saving data for conversation 'Fade Transition Video Script' to CHATGPT/output_all_in_one/Fade_Transition_Video_Script.json
# INFO:root:Saving data for conversation 'Unione video MP4 0.25s' to CHATGPT/output_all_in_one/Unione_video_MP4_0.25s.json
# INFO:root:Saving data for conversation 'JACK Audio Connection Issue' to CHATGPT/output_all_in_one/JACK_Audio_Connection_Issue.json
# INFO:root:Saving data for conversation 'Run 'mkgallery' in subdirectories' to CHATGPT/output_all_in_one/Run__mkgallery__in_subdirectories.json
# INFO:root:Saving data for conversation 'House Stark in Winter' to CHATGPT/output_all_in_one/House_Stark_in_Winter.json
# INFO:root:Saving data for conversation 'High Disk Activity Issue' to CHATGPT/output_all_in_one/High_Disk_Activity_Issue.json
# INFO:root:Saving data for conversation 'Optimize SSD Swap File' to CHATGPT/output_all_in_one/Optimize_SSD_Swap_File.json
# INFO:root:Saving data for conversation 'Code Indentation Fixed' to CHATGPT/output_all_in_one/Code_Indentation_Fixed.json
# INFO:root:Saving data for conversation 'Install .run file on Linux' to CHATGPT/output_all_in_one/Install_.run_file_on_Linux.json
# INFO:root:Saving data for conversation 'Install pyttsx3 module.' to CHATGPT/output_all_in_one/Install_pyttsx3_module..json
# INFO:root:Saving data for conversation 'Create Scrolling Text Video' to CHATGPT/output_all_in_one/Create_Scrolling_Text_Video.json
# INFO:root:Saving data for conversation 'FFMPEG video with frame & music' to CHATGPT/output_all_in_one/FFMPEG_video_with_frame___music.json
# INFO:root:Saving data for conversation 'Fading Video Overlay Fix' to CHATGPT/output_all_in_one/Fading_Video_Overlay_Fix.json
# INFO:root:Saving data for conversation 'Check Image Duplicates with Hashes' to CHATGPT/output_all_in_one/Check_Image_Duplicates_with_Hashes.json
# INFO:root:Saving data for conversation 'Disable all extensions' to CHATGPT/output_all_in_one/Disable_all_extensions.json
# INFO:root:Saving data for conversation 'FFmpeg Command Logging Fix' to CHATGPT/output_all_in_one/FFmpeg_Command_Logging_Fix.json
# INFO:root:Saving data for conversation 'Flask HTML Template Example' to CHATGPT/output_all_in_one/Flask_HTML_Template_Example.json
# INFO:root:Saving data for conversation 'Flask Video Selection Endpoint' to CHATGPT/output_all_in_one/Flask_Video_Selection_Endpoint.json
# INFO:root:Saving data for conversation 'Improved Video Quality Settings' to CHATGPT/output_all_in_one/Improved_Video_Quality_Settings.json
# INFO:root:Saving data for conversation 'Load index.html in Flask' to CHATGPT/output_all_in_one/Load_index.html_in_Flask.json
# INFO:root:Saving data for conversation 'Image Resizer Troubleshooting' to CHATGPT/output_all_in_one/Image_Resizer_Troubleshooting.json
# INFO:root:Saving data for conversation 'Flask MP4 Route Setup' to CHATGPT/output_all_in_one/Flask_MP4_Route_Setup.json
# INFO:root:Saving data for conversation 'Plague Doctors and St. Sebastian' to CHATGPT/output_all_in_one/Plague_Doctors_and_St._Sebastian.json
# INFO:root:Saving data for conversation 'Save DuckDuckGo Results JSON' to CHATGPT/output_all_in_one/Save_DuckDuckGo_Results_JSON.json
# INFO:root:Saving data for conversation 'Flask Code Review' to CHATGPT/output_all_in_one/Flask_Code_Review.json
# INFO:root:Saving data for conversation 'Flask App Code Review' to CHATGPT/output_all_in_one/Flask_App_Code_Review.json
# INFO:root:Saving data for conversation 'Fixing Code for Directory Processing' to CHATGPT/output_all_in_one/Fixing_Code_for_Directory_Processing.json
# INFO:root:Saving data for conversation 'Flask for Existing HTML' to CHATGPT/output_all_in_one/Flask_for_Existing_HTML.json
# INFO:root:Saving data for conversation 'Update Protobuf Code Version' to CHATGPT/output_all_in_one/Update_Protobuf_Code_Version.json
# INFO:root:Saving data for conversation 'Crop Dimensions Explanation' to CHATGPT/output_all_in_one/Crop_Dimensions_Explanation.json
# INFO:root:Saving data for conversation 'Create Slow Scroll Video' to CHATGPT/output_all_in_one/Create_Slow_Scroll_Video.json
# INFO:root:Saving data for conversation 'Crear plantilla HTML mp4_to_image' to CHATGPT/output_all_in_one/Crear_plantilla_HTML_mp4_to_image.json
# INFO:root:Saving data for conversation 'Cancel Git Push Fix' to CHATGPT/output_all_in_one/Cancel_Git_Push_Fix.json
# INFO:root:Saving data for conversation 'Capture Webpage with Python' to CHATGPT/output_all_in_one/Capture_Webpage_with_Python.json
# INFO:root:Saving data for conversation 'Count Python Code Lines' to CHATGPT/output_all_in_one/Count_Python_Code_Lines.json
# INFO:root:Saving data for conversation 'MP3 Joining Issue Troubleshooting' to CHATGPT/output_all_in_one/MP3_Joining_Issue_Troubleshooting.json
# INFO:root:Saving data for conversation 'MP3 File Joining Issue' to CHATGPT/output_all_in_one/MP3_File_Joining_Issue.json
# INFO:root:Saving data for conversation 'Correção da Rota "join_sound"' to CHATGPT/output_all_in_one/Correção_da_Rota_"join_sound".json
# INFO:root:Saving data for conversation 'Random MP3 Clips Concatenation' to CHATGPT/output_all_in_one/Random_MP3_Clips_Concatenation.json
# INFO:root:Saving data for conversation 'Shuffle Images for Video' to CHATGPT/output_all_in_one/Shuffle_Images_for_Video.json
# INFO:root:Saving data for conversation 'Bash Completions using Python' to CHATGPT/output_all_in_one/Bash_Completions_using_Python.json
# INFO:root:Saving data for conversation 'Fixing Flask Screen Capture' to CHATGPT/output_all_in_one/Fixing_Flask_Screen_Capture.json
# INFO:root:Saving data for conversation 'Fix Git Push Error' to CHATGPT/output_all_in_one/Fix_Git_Push_Error.json
# INFO:root:Saving data for conversation 'Flask Video Thumbnail App' to CHATGPT/output_all_in_one/Flask_Video_Thumbnail_App.json
# INFO:root:Saving data for conversation 'Save Plots with UUIDs' to CHATGPT/output_all_in_one/Save_Plots_with_UUIDs.json
# INFO:root:Saving data for conversation 'ClamAV Freshclam Log Error' to CHATGPT/output_all_in_one/ClamAV_Freshclam_Log_Error.json
# INFO:root:Saving data for conversation 'Install Wine Mono Linux' to CHATGPT/output_all_in_one/Install_Wine_Mono_Linux.json
# INFO:root:Saving data for conversation 'Clickable Links in HTML' to CHATGPT/output_all_in_one/Clickable_Links_in_HTML.json
# INFO:root:Saving data for conversation 'Video Editing with MoviePy' to CHATGPT/output_all_in_one/Video_Editing_with_MoviePy.json
# INFO:root:Saving data for conversation 'Flask Async Endpoints' to CHATGPT/output_all_in_one/Flask_Async_Endpoints.json
# INFO:root:Saving data for conversation 'Random MP3 Selection Bash' to CHATGPT/output_all_in_one/Random_MP3_Selection_Bash.json
# INFO:root:Saving data for conversation 'Virtual Environment Creation Error' to CHATGPT/output_all_in_one/Virtual_Environment_Creation_Error.json
# INFO:root:Saving data for conversation 'Flask Video Generator Function' to CHATGPT/output_all_in_one/Flask_Video_Generator_Function.json
# INFO:root:Saving data for conversation 'FlaskWebGui Debug Mode' to CHATGPT/output_all_in_one/FlaskWebGui_Debug_Mode.json
# INFO:root:Saving data for conversation 'Flask File Upload Function' to CHATGPT/output_all_in_one/Flask_File_Upload_Function.json
# INFO:root:Saving data for conversation 'Flask Template HTML Setup' to CHATGPT/output_all_in_one/Flask_Template_HTML_Setup.json
# INFO:root:Saving data for conversation 'Comic Panel Layout CSS' to CHATGPT/output_all_in_one/Comic_Panel_Layout_CSS.json
# INFO:root:Saving data for conversation 'Lighten Image with Mogrify' to CHATGPT/output_all_in_one/Lighten_Image_with_Mogrify.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New_chat.json
# INFO:root:Saving data for conversation 'GPT API Key Access' to CHATGPT/output_all_in_one/GPT_API_Key_Access.json
# INFO:root:Saving data for conversation 'Add JPG and PNG' to CHATGPT/output_all_in_one/Add_JPG_and_PNG.json
# INFO:root:Saving data for conversation 'Feathered Image Creation' to CHATGPT/output_all_in_one/Feathered_Image_Creation.json
# INFO:root:Saving data for conversation 'Feather Image with Python' to CHATGPT/output_all_in_one/Feather_Image_with_Python.json
# INFO:root:Saving data for conversation 'Arcanis AI Enhancing Earth's AI' to CHATGPT/output_all_in_one/Arcanis_AI_Enhancing_Earth_s_AI.json
# INFO:root:Saving data for conversation 'Flask Logging Setup Guide' to CHATGPT/output_all_in_one/Flask_Logging_Setup_Guide.json
# INFO:root:Saving data for conversation 'Generate & Save PNG Plot' to CHATGPT/output_all_in_one/Generate___Save_PNG_Plot.json
# INFO:root:Saving data for conversation 'Install R on Linux' to CHATGPT/output_all_in_one/Install_R_on_Linux.json
# INFO:root:Saving data for conversation 'Python & Flask Enthusiasts' to CHATGPT/output_all_in_one/Python___Flask_Enthusiasts.json
# INFO:root:Saving data for conversation 'Name: Esperanza' to CHATGPT/output_all_in_one/Name__Esperanza.json
# INFO:root:Saving data for conversation 'Fixing Audio Buffer Overflow' to CHATGPT/output_all_in_one/Fixing_Audio_Buffer_Overflow.json
# INFO:root:Saving data for conversation 'Louder Output Audio: Adjusting Volume' to CHATGPT/output_all_in_one/Louder_Output_Audio__Adjusting_Volume.json
# INFO:root:Saving data for conversation 'Change Outline Color' to CHATGPT/output_all_in_one/Change_Outline_Color.json
# INFO:root:Saving data for conversation 'Create Video from Images' to CHATGPT/output_all_in_one/Create_Video_from_Images.json
# INFO:root:Saving data for conversation 'Python 3.9 Virtual Environment' to CHATGPT/output_all_in_one/Python_3.9_Virtual_Environment.json
# INFO:root:Saving data for conversation 'Flask Thumbnail Video' to CHATGPT/output_all_in_one/Flask_Thumbnail_Video.json
# INFO:root:Saving data for conversation 'Flask Directory Viewer' to CHATGPT/output_all_in_one/Flask_Directory_Viewer.json
# INFO:root:Saving data for conversation 'Flask App Demo & Explanation' to CHATGPT/output_all_in_one/Flask_App_Demo___Explanation.json
# INFO:root:Saving data for conversation 'Flask_env Jupyter Kernel Setup' to CHATGPT/output_all_in_one/Flask_env_Jupyter_Kernel_Setup.json
# INFO:root:Saving data for conversation 'Mic Detection Issue Troubleshoot' to CHATGPT/output_all_in_one/Mic_Detection_Issue_Troubleshoot.json
# INFO:root:Saving data for conversation 'Custom Instructions Understood' to CHATGPT/output_all_in_one/Custom_Instructions_Understood.json
# INFO:root:Saving data for conversation 'Flask AttributeError Troubleshooting' to CHATGPT/output_all_in_one/Flask_AttributeError_Troubleshooting.json
# INFO:root:Saving data for conversation 'Video Duration Adjustment' to CHATGPT/output_all_in_one/Video_Duration_Adjustment.json
# INFO:root:Saving data for conversation 'Install OpenCV (cv2)' to CHATGPT/output_all_in_one/Install_OpenCV__cv2_.json
# INFO:root:Saving data for conversation 'Delete Files Except *.jpg' to CHATGPT/output_all_in_one/Delete_Files_Except__.jpg.json
# INFO:root:Saving data for conversation 'LuaRocks Install NN-Spec' to CHATGPT/output_all_in_one/LuaRocks_Install_NN-Spec.json
# INFO:root:Saving data for conversation 'Failed nn Installation' to CHATGPT/output_all_in_one/Failed_nn_Installation.json
# INFO:root:Saving data for conversation 'Random Desktop Video Clips' to CHATGPT/output_all_in_one/Random_Desktop_Video_Clips.json
# INFO:root:Saving data for conversation 'FFMPEG Create Shuffled Video' to CHATGPT/output_all_in_one/FFMPEG_Create_Shuffled_Video.json
# INFO:root:Saving data for conversation 'Stream Speakers & Desktop' to CHATGPT/output_all_in_one/Stream_Speakers___Desktop.json
# INFO:root:Saving data for conversation 'Find Imported Module Source' to CHATGPT/output_all_in_one/Find_Imported_Module_Source.json
# INFO:root:Saving data for conversation 'Linux Desktop Missing Icons' to CHATGPT/output_all_in_one/Linux_Desktop_Missing_Icons.json
# INFO:root:Saving data for conversation 'FFMPEG Video Slowdown.' to CHATGPT/output_all_in_one/FFMPEG_Video_Slowdown..json
# INFO:root:Saving data for conversation 'Create BMP from Image' to CHATGPT/output_all_in_one/Create_BMP_from_Image.json
# INFO:root:Saving data for conversation 'GIFs to MP4' to CHATGPT/output_all_in_one/GIFs_to_MP4.json
# INFO:root:Saving data for conversation 'Hardcoded Args Parser' to CHATGPT/output_all_in_one/Hardcoded_Args_Parser.json
# INFO:root:Saving data for conversation 'Starting Over?' to CHATGPT/output_all_in_one/Starting_Over?.json
# INFO:root:Saving data for conversation 'Create GIFS.mp4' to CHATGPT/output_all_in_one/Create_GIFS.mp4.json
# INFO:root:Saving data for conversation 'Python Image Processing Code' to CHATGPT/output_all_in_one/Python_Image_Processing_Code.json
# INFO:root:Saving data for conversation 'Dynamic Directory for mkblend_videos' to CHATGPT/output_all_in_one/Dynamic_Directory_for_mkblend_videos.json
# INFO:root:Saving data for conversation 'Flask code with logging.' to CHATGPT/output_all_in_one/Flask_code_with_logging..json
# INFO:root:Saving data for conversation 'Create MP4 from images.' to CHATGPT/output_all_in_one/Create_MP4_from_images..json
# INFO:root:Saving data for conversation 'Video Overlay Not Working' to CHATGPT/output_all_in_one/Video_Overlay_Not_Working.json
# INFO:root:Saving data for conversation 'Fix favicon not found.' to CHATGPT/output_all_in_one/Fix_favicon_not_found..json
# INFO:root:Saving data for conversation 'Copy File with shutil' to CHATGPT/output_all_in_one/Copy_File_with_shutil.json
# INFO:root:Saving data for conversation 'Nietzsche's views on death.' to CHATGPT/output_all_in_one/Nietzsche_s_views_on_death..json
# INFO:root:Saving data for conversation 'Video Generation from Directories.' to CHATGPT/output_all_in_one/Video_Generation_from_Directories..json
# INFO:root:Saving data for conversation 'API v0xF - Unknown Version' to CHATGPT/output_all_in_one/API_v0xF_-_Unknown_Version.json
# INFO:root:Saving data for conversation 'Flask-SQLAlchemy Version Mismatch.' to CHATGPT/output_all_in_one/Flask-SQLAlchemy_Version_Mismatch..json
# INFO:root:Saving data for conversation 'Flask: Request and Save.' to CHATGPT/output_all_in_one/Flask__Request_and_Save..json
# INFO:root:Saving data for conversation 'AI: Wonder or Monster?' to CHATGPT/output_all_in_one/AI__Wonder_or_Monster?.json
# INFO:root:Saving data for conversation 'Flask App Setup' to CHATGPT/output_all_in_one/Flask_App_Setup.json
# INFO:root:Saving data for conversation 'Flask App with SQLite3' to CHATGPT/output_all_in_one/Flask_App_with_SQLite3.json
# INFO:root:Saving data for conversation 'Video Editing Transitions' to CHATGPT/output_all_in_one/Video_Editing_Transitions.json
# INFO:root:Saving data for conversation 'Avatar AI for Talking' to CHATGPT/output_all_in_one/Avatar_AI_for_Talking.json
# INFO:root:Saving data for conversation 'cp directory without overwrite' to CHATGPT/output_all_in_one/cp_directory_without_overwrite.json
# INFO:root:Saving data for conversation 'Find File: stacked_videos' to CHATGPT/output_all_in_one/Find_File__stacked_videos.json
# INFO:root:Saving data for conversation 'AI's Leap in 2021' to CHATGPT/output_all_in_one/AI_s_Leap_in_2021.json
# INFO:root:Saving data for conversation 'Convert audio to video' to CHATGPT/output_all_in_one/Convert_audio_to_video.json
# INFO:root:Saving data for conversation 'Create Image Sequence Video' to CHATGPT/output_all_in_one/Create_Image_Sequence_Video.json
# INFO:root:Saving data for conversation 'Linux Find Modified Images' to CHATGPT/output_all_in_one/Linux_Find_Modified_Images.json
# INFO:root:Saving data for conversation 'Find Duplicate Image Names' to CHATGPT/output_all_in_one/Find_Duplicate_Image_Names.json
# INFO:root:Saving data for conversation 'Flask Blueprint Assistance' to CHATGPT/output_all_in_one/Flask_Blueprint_Assistance.json
# INFO:root:Saving data for conversation 'Activate Virtual Environment' to CHATGPT/output_all_in_one/Activate_Virtual_Environment.json
# INFO:root:Saving data for conversation 'Resizing & Cropping for Vertical Video' to CHATGPT/output_all_in_one/Resizing___Cropping_for_Vertical_Video.json
# INFO:root:Saving data for conversation 'Flask Open & View Text' to CHATGPT/output_all_in_one/Flask_Open___View_Text.json
# INFO:root:Saving data for conversation 'Replace Spaces with Underscores' to CHATGPT/output_all_in_one/Replace_Spaces_with_Underscores.json
# INFO:root:Saving data for conversation 'Create Video with Text' to CHATGPT/output_all_in_one/Create_Video_with_Text.json
# INFO:root:Saving data for conversation 'Image-to-Video Conversion' to CHATGPT/output_all_in_one/Image-to-Video_Conversion.json
# INFO:root:Saving data for conversation 'Flask Video Processing Server' to CHATGPT/output_all_in_one/Flask_Video_Processing_Server.json
# INFO:root:Saving data for conversation 'HEVC Decoding Errors' to CHATGPT/output_all_in_one/HEVC_Decoding_Errors.json
# INFO:root:Saving data for conversation 'Blend Image Video Creation' to CHATGPT/output_all_in_one/Blend_Image_Video_Creation.json
# INFO:root:Saving data for conversation 'Inference Error: mel() Function' to CHATGPT/output_all_in_one/Inference_Error__mel___Function.json
# INFO:root:Saving data for conversation 'Syntax Error Resolved' to CHATGPT/output_all_in_one/Syntax_Error_Resolved.json
# INFO:root:Saving data for conversation 'Wonderland Characters Summary' to CHATGPT/output_all_in_one/Wonderland_Characters_Summary.json
# INFO:root:Saving data for conversation 'Datetime Import Issue' to CHATGPT/output_all_in_one/Datetime_Import_Issue.json
# INFO:root:Saving data for conversation 'Selecting Image Directory' to CHATGPT/output_all_in_one/Selecting_Image_Directory.json
# INFO:root:Saving data for conversation 'Upload file from directory' to CHATGPT/output_all_in_one/Upload_file_from_directory.json
# INFO:root:Saving data for conversation 'Expressive Flora Still Life' to CHATGPT/output_all_in_one/Expressive_Flora_Still_Life.json
# INFO:root:Saving data for conversation 'Anunnaki Overview' to CHATGPT/output_all_in_one/Anunnaki_Overview.json
# INFO:root:Saving data for conversation 'Arcanis AI Communication' to CHATGPT/output_all_in_one/Arcanis_AI_Communication.json
# INFO:root:Saving data for conversation 'GEGL Bevel Compilation Error' to CHATGPT/output_all_in_one/GEGL_Bevel_Compilation_Error.json
# INFO:root:Saving data for conversation 'Upload and Apply Text' to CHATGPT/output_all_in_one/Upload_and_Apply_Text.json
# INFO:root:Saving data for conversation 'Browser Media Stream Issue' to CHATGPT/output_all_in_one/Browser_Media_Stream_Issue.json
# INFO:root:Saving data for conversation 'Generate Unique Video Filename' to CHATGPT/output_all_in_one/Generate_Unique_Video_Filename.json
# INFO:root:Saving data for conversation 'Flask Text-to-Speech' to CHATGPT/output_all_in_one/Flask_Text-to-Speech.json
# INFO:root:Saving data for conversation 'Subprocess Firefox HTML Execution' to CHATGPT/output_all_in_one/Subprocess_Firefox_HTML_Execution.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New_chat.json
# INFO:root:Saving data for conversation 'Module Import Error Fix' to CHATGPT/output_all_in_one/Module_Import_Error_Fix.json
# INFO:root:Saving data for conversation 'Aliens & AI Speculation' to CHATGPT/output_all_in_one/Aliens___AI_Speculation.json
# INFO:root:Saving data for conversation 'Fix File Copying Error' to CHATGPT/output_all_in_one/Fix_File_Copying_Error.json
# INFO:root:Saving data for conversation 'Flask App Conversion' to CHATGPT/output_all_in_one/Flask_App_Conversion.json
# INFO:root:Saving data for conversation 'Dynamic Image Directory' to CHATGPT/output_all_in_one/Dynamic_Image_Directory.json
# INFO:root:Saving data for conversation 'Large File Push Error' to CHATGPT/output_all_in_one/Large_File_Push_Error.json
# INFO:root:Saving data for conversation 'Overlay Video with Colorchrome' to CHATGPT/output_all_in_one/Overlay_Video_with_Colorchrome.json
# INFO:root:Saving data for conversation 'Flask: Blank 512x1024.mp4' to CHATGPT/output_all_in_one/Flask__Blank_512x1024.mp4.json
# INFO:root:Saving data for conversation 'Play MP3' to CHATGPT/output_all_in_one/Play_MP3.json
# INFO:root:Saving data for conversation 'Screen and Audio Capture' to CHATGPT/output_all_in_one/Screen_and_Audio_Capture.json
# INFO:root:Saving data for conversation 'Flask Marquee Overlay Video' to CHATGPT/output_all_in_one/Flask_Marquee_Overlay_Video.json
# INFO:root:Saving data for conversation 'Concatenation Error: Parameters Mismatch' to CHATGPT/output_all_in_one/Concatenation_Error__Parameters_Mismatch.json
# INFO:root:Saving data for conversation 'AI's Arcanis Intervention' to CHATGPT/output_all_in_one/AI_s_Arcanis_Intervention.json
# INFO:root:Saving data for conversation 'Story Assistance Available' to CHATGPT/output_all_in_one/Story_Assistance_Available.json
# INFO:root:Saving data for conversation 'LAN PHP Server Setup' to CHATGPT/output_all_in_one/LAN_PHP_Server_Setup.json
# INFO:root:Saving data for conversation 'Combine Image and Audio' to CHATGPT/output_all_in_one/Combine_Image_and_Audio.json
# INFO:root:Saving data for conversation 'Image to Video Conversion' to CHATGPT/output_all_in_one/Image_to_Video_Conversion.json
# INFO:root:Saving data for conversation 'Male voice for Google TTS' to CHATGPT/output_all_in_one/Male_voice_for_Google_TTS.json
# INFO:root:Saving data for conversation 'Fixing PyQt5 Dependency Error' to CHATGPT/output_all_in_one/Fixing_PyQt5_Dependency_Error.json
# INFO:root:Saving data for conversation 'KDENLIVE error encountered' to CHATGPT/output_all_in_one/KDENLIVE_error_encountered.json
# INFO:root:Saving data for conversation 'CUDA Library Missing Error' to CHATGPT/output_all_in_one/CUDA_Library_Missing_Error.json
# INFO:root:Saving data for conversation 'Add large file to GitHub.' to CHATGPT/output_all_in_one/Add_large_file_to_GitHub..json
# INFO:root:Saving data for conversation 'NoCache pip Install.' to CHATGPT/output_all_in_one/NoCache_pip_Install..json
# INFO:root:Saving data for conversation 'Fixing Large Files Issue' to CHATGPT/output_all_in_one/Fixing_Large_Files_Issue.json
# INFO:root:Saving data for conversation 'MyTube AI Videos' to CHATGPT/output_all_in_one/MyTube_AI_Videos.json
# INFO:root:Saving data for conversation 'Programming Joke: Light vs Bugs' to CHATGPT/output_all_in_one/Programming_Joke__Light_vs_Bugs.json
# INFO:root:Saving data for conversation 'Choose Directory: Handle Selection' to CHATGPT/output_all_in_one/Choose_Directory__Handle_Selection.json
# INFO:root:Saving data for conversation 'FFmpeg Merge Video & Audio' to CHATGPT/output_all_in_one/FFmpeg_Merge_Video___Audio.json
# INFO:root:Saving data for conversation 'MP3 to WAV Conversion' to CHATGPT/output_all_in_one/MP3_to_WAV_Conversion.json
# INFO:root:Saving data for conversation 'FFmpeg Resize Video' to CHATGPT/output_all_in_one/FFmpeg_Resize_Video.json
# INFO:root:Saving data for conversation 'Resize Video 1/4' to CHATGPT/output_all_in_one/Resize_Video_1/4.json
# ERROR:root:File not found: CHATGPT/conversations.json
