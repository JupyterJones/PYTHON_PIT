# %%
#!/home/jack/miniconda3/envs/cloned_base/bin/python
import json
import logging
import os
import glob
import subprocess
import os
import string

def clean_title(title):
    valid_chars = set(string.ascii_letters + string.digits + string.whitespace)
    cleaned_title = ''.join(char if char in valid_chars else '_' for char in title)
    return cleaned_title.strip()



def split_and_save_and_convert(conversations_file, output_folder):
    try:
        with open(conversations_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
            
            for conversation in data:
                title = conversation.get('title', 'Unknown_Title')
                title_with_underscores = title.replace(' ', '_')
                title_with_underscores = title_with_underscores.replace(':', '_')
                title_with_underscores = title_with_underscores.replace("'", "_")
                title_with_underscores = title_with_underscores.replace("&", "_")
                title_with_underscores = title_with_underscores.replace("*", "_")
                title_with_underscores = title_with_underscores.replace("(", "_")
                title_with_underscores = title_with_underscores.replace(")", "_")
                chapter_filename = f"{title_with_underscores}.json"
                chapter_filepath = os.path.join(output_folder, chapter_filename)
                
                logging.info(f"Saving data for conversation '{title}' to {chapter_filepath}")
                
                with open(chapter_filepath, 'w', encoding='utf-8') as chapter_file:
                    json.dump([conversation], chapter_file, indent=2)

                # Convert JSON to HTML
                html_output_file = os.path.join(output_folder, f"{title_with_underscores}.html")
                convert_to_html(chapter_filepath, html_output_file)

                # Convert JSON to TXT
                txt_output_file = os.path.join(output_folder, f"{title_with_underscores}.txt")
                convert_to_txt(chapter_filepath, txt_output_file)

    except FileNotFoundError:
        logging.error(f"File not found: {conversations_file}")
    except json.JSONDecodeError:
        logging.error(f"Error decoding JSON in file: {conversations_file}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {e}")

def convert_to_html(json_file, html_output_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        json_data = json.load(file)

    result_str = get_conversation_result(json_data)

    with open(html_output_file, "w", encoding='utf-8') as html_output:
        result_html = result_str.replace("/n", "XXXXXXX\n")
        result_html = result_html.replace("<", "&lt;")
        result_html = result_html.replace(">", "&gt;")
        for line in result_html.split("XXXXXXX"):
            line = line.replace("\n", "<br />\n")
            html_output.write(line)

def convert_to_txt(json_file, txt_output_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        json_data = json.load(file)

    result_str = get_conversation_result(json_data)

    with open(txt_output_file, "w", encoding='utf-8') as txt_output:
        result_txt = result_str.replace("/n", "XXXXXXX\n")
        for line in result_txt.split("XXXXXXX"):
            txt_output.write(line)

def get_conversation_result(json_data):
    result_str = ""
    for conversation in json_data:
        title = conversation.get('title', '')
        messages = get_conversation_messages(conversation)

        result_str += title + '\n'
        for message in messages:
            result_str += message['author'] + '\n' + message['text'] + '\n'
        result_str += '\n'

    return result_str

def get_conversation_messages(conversation):
    messages = []
    current_node = conversation.get('current_node')
    while current_node:
        node = conversation['mapping'][current_node]
        message = node.get('message')
        if (message and message.get('content') and message['content'].get('content_type') == 'text' and
                len(message['content'].get('parts', [])) > 0 and len(message['content']['parts'][0]) > 0 and
                (message['author']['role'] != 'system' or message.get('metadata', {}).get('is_user_system_message'))):
            author = message['author']['role']
            if author == 'assistant':
                author = 'ChatGPT'
            elif author == 'system' and message['metadata'].get('is_user_system_message'):
                author = 'Custom user info'
            messages.append({'author': author, 'text': message['content']['parts'][0]})
        current_node = node.get('parent')
    return messages[::-1]

# Example usage
conversations_file_path = 'CHATGPT/conversations.json'
output_folder = 'CHATGPT/output_txt_html_json'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Configure logging
logging.basicConfig(level=logging.INFO)

# Call the split, save, and convert function
split_and_save_and_convert(conversations_file_path, output_folder)
# Out:
# INFO:root:Saving data for conversation 'Add Expose to Docker Image' to CHATGPT/output_txt_html_json/Add_Expose_to_Docker_Image.json
# INFO:root:Saving data for conversation 'HTML Conversion Debugging' to CHATGPT/output_txt_html_json/HTML_Conversion_Debugging.json
# INFO:root:Saving data for conversation 'Wget File Download' to CHATGPT/output_txt_html_json/Wget_File_Download.json
# INFO:root:Saving data for conversation 'Flask App on LAN' to CHATGPT/output_txt_html_json/Flask_App_on_LAN.json
# INFO:root:Saving data for conversation 'Convert JSON to HTML' to CHATGPT/output_txt_html_json/Convert_JSON_to_HTML.json
# INFO:root:Saving data for conversation 'Check Directory for Duplicates' to CHATGPT/output_txt_html_json/Check_Directory_for_Duplicates.json
# INFO:root:Saving data for conversation 'Search IPYNB for Term' to CHATGPT/output_txt_html_json/Search_IPYNB_for_Term.json
# INFO:root:Saving data for conversation 'Refrigerate ketchup after opening.' to CHATGPT/output_txt_html_json/Refrigerate_ketchup_after_opening..json
# INFO:root:Saving data for conversation 'ChatGPT, Conversations.json Overview' to CHATGPT/output_txt_html_json/ChatGPT,_Conversations.json_Overview.json
# INFO:root:Saving data for conversation 'Python Punctuation Removal' to CHATGPT/output_txt_html_json/Python_Punctuation_Removal.json
# INFO:root:Saving data for conversation 'Cosmic Octopus AI Awakening' to CHATGPT/output_txt_html_json/Cosmic_Octopus_AI_Awakening.json
# INFO:root:Saving data for conversation 'Arcanian AI's Transformative Influence' to CHATGPT/output_txt_html_json/Arcanian_AI_s_Transformative_Influence.json
# INFO:root:Saving data for conversation 'AI Guides Animal Enlightenment' to CHATGPT/output_txt_html_json/AI_Guides_Animal_Enlightenment.json
# INFO:root:Saving data for conversation 'Flask Programmer and YouTuber' to CHATGPT/output_txt_html_json/Flask_Programmer_and_YouTuber.json
# INFO:root:Saving data for conversation 'Set Hard Drive Permissions' to CHATGPT/output_txt_html_json/Set_Hard_Drive_Permissions.json
# INFO:root:Saving data for conversation 'Python HTTP Server Guide' to CHATGPT/output_txt_html_json/Python_HTTP_Server_Guide.json
# INFO:root:Saving data for conversation 'Simple 3D Scene Creation' to CHATGPT/output_txt_html_json/Simple_3D_Scene_Creation.json
# INFO:root:Saving data for conversation 'Segmenting Video Frames' to CHATGPT/output_txt_html_json/Segmenting_Video_Frames.json
# INFO:root:Saving data for conversation 'Download Age-Restricted Video' to CHATGPT/output_txt_html_json/Download_Age-Restricted_Video.json
# INFO:root:Saving data for conversation 'Convert FilePath to GIF' to CHATGPT/output_txt_html_json/Convert_FilePath_to_GIF.json
# INFO:root:Saving data for conversation 'Remove Python Path' to CHATGPT/output_txt_html_json/Remove_Python_Path.json
# INFO:root:Saving data for conversation 'Create Black Image' to CHATGPT/output_txt_html_json/Create_Black_Image.json
# INFO:root:Saving data for conversation 'Whiplash Curves in Art' to CHATGPT/output_txt_html_json/Whiplash_Curves_in_Art.json
# INFO:root:Saving data for conversation 'SSL Cert Expiry: Python' to CHATGPT/output_txt_html_json/SSL_Cert_Expiry__Python.json
# INFO:root:Saving data for conversation 'Bash Locate in Python' to CHATGPT/output_txt_html_json/Bash_Locate_in_Python.json
# INFO:root:Saving data for conversation 'Doll in Dystopian Decay' to CHATGPT/output_txt_html_json/Doll_in_Dystopian_Decay.json
# INFO:root:Saving data for conversation 'FFmpeg Zoom Video Fix' to CHATGPT/output_txt_html_json/FFmpeg_Zoom_Video_Fix.json
# INFO:root:Saving data for conversation 'Doll Factory Dystopia' to CHATGPT/output_txt_html_json/Doll_Factory_Dystopia.json
# INFO:root:Saving data for conversation 'Enhance Image with OpenCV' to CHATGPT/output_txt_html_json/Enhance_Image_with_OpenCV.json
# INFO:root:Saving data for conversation 'Flask Video Selection Script' to CHATGPT/output_txt_html_json/Flask_Video_Selection_Script.json
# INFO:root:Saving data for conversation 'SSD Maintenance: Trim Frequency' to CHATGPT/output_txt_html_json/SSD_Maintenance__Trim_Frequency.json
# INFO:root:Saving data for conversation 'Split MP4 into 6.' to CHATGPT/output_txt_html_json/Split_MP4_into_6..json
# INFO:root:Saving data for conversation 'FFmpeg Remove Duplicate Frames' to CHATGPT/output_txt_html_json/FFmpeg_Remove_Duplicate_Frames.json
# INFO:root:Saving data for conversation 'Video Clips with Sound' to CHATGPT/output_txt_html_json/Video_Clips_with_Sound.json
# INFO:root:Saving data for conversation 'Video Flip Book Fix' to CHATGPT/output_txt_html_json/Video_Flip_Book_Fix.json
# INFO:root:Saving data for conversation 'Dystopian City Text Prompt' to CHATGPT/output_txt_html_json/Dystopian_City_Text_Prompt.json
# INFO:root:Saving data for conversation 'SSH to Specific Directory' to CHATGPT/output_txt_html_json/SSH_to_Specific_Directory.json
# INFO:root:Saving data for conversation 'Add sound if needed.' to CHATGPT/output_txt_html_json/Add_sound_if_needed..json
# INFO:root:Saving data for conversation 'Thunar Scroll Issue Troubleshooting' to CHATGPT/output_txt_html_json/Thunar_Scroll_Issue_Troubleshooting.json
# INFO:root:Saving data for conversation 'Get Image Size' to CHATGPT/output_txt_html_json/Get_Image_Size.json
# INFO:root:Saving data for conversation 'Image Zoom Video Script' to CHATGPT/output_txt_html_json/Image_Zoom_Video_Script.json
# INFO:root:Saving data for conversation 'Video Processing: 512x768 Resolution' to CHATGPT/output_txt_html_json/Video_Processing__512x768_Resolution.json
# INFO:root:Saving data for conversation 'Find & CD: fade-transb' to CHATGPT/output_txt_html_json/Find___CD__fade-transb.json
# INFO:root:Saving data for conversation 'Shell Command Argument Handling' to CHATGPT/output_txt_html_json/Shell_Command_Argument_Handling.json
# INFO:root:Saving data for conversation 'Python Save File' to CHATGPT/output_txt_html_json/Python_Save_File.json
# INFO:root:Saving data for conversation 'Flask Module Not Found' to CHATGPT/output_txt_html_json/Flask_Module_Not_Found.json
# INFO:root:Saving data for conversation 'Linux Terminal Issue' to CHATGPT/output_txt_html_json/Linux_Terminal_Issue.json
# INFO:root:Saving data for conversation 'Run Kdenlive Extension with Melt' to CHATGPT/output_txt_html_json/Run_Kdenlive_Extension_with_Melt.json
# INFO:root:Saving data for conversation 'YouTube 2nd Channel Automator' to CHATGPT/output_txt_html_json/YouTube_2nd_Channel_Automator.json
# INFO:root:Saving data for conversation 'Xterm Display Error Troubleshoot' to CHATGPT/output_txt_html_json/Xterm_Display_Error_Troubleshoot.json
# INFO:root:Saving data for conversation 'Flask Installation Troubleshooting' to CHATGPT/output_txt_html_json/Flask_Installation_Troubleshooting.json
# INFO:root:Saving data for conversation 'MoviePy for Image Videos' to CHATGPT/output_txt_html_json/MoviePy_for_Image_Videos.json
# INFO:root:Saving data for conversation 'Create 3D Image Transitions' to CHATGPT/output_txt_html_json/Create_3D_Image_Transitions.json
# INFO:root:Saving data for conversation 'Adjust Duration for Longer' to CHATGPT/output_txt_html_json/Adjust_Duration_for_Longer.json
# INFO:root:Saving data for conversation 'Capture Screen with Offset' to CHATGPT/output_txt_html_json/Capture_Screen_with_Offset.json
# INFO:root:Saving data for conversation 'Reinstall XWin on Linux.' to CHATGPT/output_txt_html_json/Reinstall_XWin_on_Linux..json
# INFO:root:Saving data for conversation 'Linux: Force Thumbnail Regeneration' to CHATGPT/output_txt_html_json/Linux__Force_Thumbnail_Regeneration.json
# INFO:root:Saving data for conversation 'Martian Masterpiece: Surreal Synthesis' to CHATGPT/output_txt_html_json/Martian_Masterpiece__Surreal_Synthesis.json
# INFO:root:Saving data for conversation 'Reinstall EFC Desktop' to CHATGPT/output_txt_html_json/Reinstall_EFC_Desktop.json
# INFO:root:Saving data for conversation 'Kill Process on Port' to CHATGPT/output_txt_html_json/Kill_Process_on_Port.json
# INFO:root:Saving data for conversation 'Linux Find Largest Subdirectory' to CHATGPT/output_txt_html_json/Linux_Find_Largest_Subdirectory.json
# INFO:root:Saving data for conversation 'Shuffle Images for Video' to CHATGPT/output_txt_html_json/Shuffle_Images_for_Video.json
# INFO:root:Saving data for conversation 'Shuffled Image Zoom' to CHATGPT/output_txt_html_json/Shuffled_Image_Zoom.json
# INFO:root:Saving data for conversation 'Sticky Header for Website' to CHATGPT/output_txt_html_json/Sticky_Header_for_Website.json
# INFO:root:Saving data for conversation 'Image files not printing.' to CHATGPT/output_txt_html_json/Image_files_not_printing..json
# INFO:root:Saving data for conversation 'Rsync Syncs and Overwrites' to CHATGPT/output_txt_html_json/Rsync_Syncs_and_Overwrites.json
# INFO:root:Saving data for conversation 'Auto-looping 1s Slideshow Code' to CHATGPT/output_txt_html_json/Auto-looping_1s_Slideshow_Code.json
# INFO:root:Saving data for conversation 'Sticky Header Code' to CHATGPT/output_txt_html_json/Sticky_Header_Code.json
# INFO:root:Saving data for conversation 'Bash Completion Python Script' to CHATGPT/output_txt_html_json/Bash_Completion_Python_Script.json
# INFO:root:Saving data for conversation 'Copy care.mp4 to VPS' to CHATGPT/output_txt_html_json/Copy_care.mp4_to_VPS.json
# INFO:root:Saving data for conversation 'Update SQLite Permissions' to CHATGPT/output_txt_html_json/Update_SQLite_Permissions.json
# INFO:root:Saving data for conversation 'Caregivers: Organized, Efficient, Communicative' to CHATGPT/output_txt_html_json/Caregivers__Organized,_Efficient,_Communicative.json
# INFO:root:Saving data for conversation 'Select Random TTF Font' to CHATGPT/output_txt_html_json/Select_Random_TTF_Font.json
# INFO:root:Saving data for conversation 'Generate Loopable Stylized Images' to CHATGPT/output_txt_html_json/Generate_Loopable_Stylized_Images.json
# INFO:root:Saving data for conversation 'Fix Protobuf Issue' to CHATGPT/output_txt_html_json/Fix_Protobuf_Issue.json
# INFO:root:Saving data for conversation 'Locate IPYNB with Quantify' to CHATGPT/output_txt_html_json/Locate_IPYNB_with_Quantify.json
# INFO:root:Saving data for conversation 'PDF to PNG Conversion' to CHATGPT/output_txt_html_json/PDF_to_PNG_Conversion.json
# INFO:root:Saving data for conversation 'PDF to PNG Converter' to CHATGPT/output_txt_html_json/PDF_to_PNG_Converter.json
# INFO:root:Saving data for conversation 'Movies with Punch' to CHATGPT/output_txt_html_json/Movies_with_Punch.json
# INFO:root:Saving data for conversation 'LAN Directory Serving Script' to CHATGPT/output_txt_html_json/LAN_Directory_Serving_Script.json
# INFO:root:Saving data for conversation 'Flask FFmpeg Command Integration' to CHATGPT/output_txt_html_json/Flask_FFmpeg_Command_Integration.json
# INFO:root:Saving data for conversation 'Explain script in detail.' to CHATGPT/output_txt_html_json/Explain_script_in_detail..json
# INFO:root:Saving data for conversation 'AI Video Transitions Mastery' to CHATGPT/output_txt_html_json/AI_Video_Transitions_Mastery.json
# INFO:root:Saving data for conversation 'Fail2Ban Installation for Security' to CHATGPT/output_txt_html_json/Fail2Ban_Installation_for_Security.json
# INFO:root:Saving data for conversation 'PHP Execute Bash Script' to CHATGPT/output_txt_html_json/PHP_Execute_Bash_Script.json
# INFO:root:Saving data for conversation 'Prevent inherit text-align.' to CHATGPT/output_txt_html_json/Prevent_inherit_text-align..json
# INFO:root:Saving data for conversation 'Sudo cp file permissions' to CHATGPT/output_txt_html_json/Sudo_cp_file_permissions.json
# INFO:root:Saving data for conversation 'CSS Logo Placement' to CHATGPT/output_txt_html_json/CSS_Logo_Placement.json
# INFO:root:Saving data for conversation 'Snap Certbot Installation Issue' to CHATGPT/output_txt_html_json/Snap_Certbot_Installation_Issue.json
# INFO:root:Saving data for conversation 'Configurar servidor Apache local' to CHATGPT/output_txt_html_json/Configurar_servidor_Apache_local.json
# INFO:root:Saving data for conversation 'Install PHP on Apache' to CHATGPT/output_txt_html_json/Install_PHP_on_Apache.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_txt_html_json/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_txt_html_json/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_txt_html_json/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_txt_html_json/New_chat.json
# INFO:root:Saving data for conversation 'Domain Info with Python' to CHATGPT/output_txt_html_json/Domain_Info_with_Python.json
# INFO:root:Saving data for conversation 'Set Up LAN Server (Python)' to CHATGPT/output_txt_html_json/Set_Up_LAN_Server__Python_.json
# INFO:root:Saving data for conversation 'Open Jupyter Notebook Over LAN' to CHATGPT/output_txt_html_json/Open_Jupyter_Notebook_Over_LAN.json
# INFO:root:Saving data for conversation 'MP4 Files Finder Script' to CHATGPT/output_txt_html_json/MP4_Files_Finder_Script.json
# INFO:root:Saving data for conversation 'Crear imagen colores primarios' to CHATGPT/output_txt_html_json/Crear_imagen_colores_primarios.json
# INFO:root:Saving data for conversation 'FFmpeg Slideshow with Transitions' to CHATGPT/output_txt_html_json/FFmpeg_Slideshow_with_Transitions.json
# INFO:root:Saving data for conversation 'Scroll Image to Video' to CHATGPT/output_txt_html_json/Scroll_Image_to_Video.json
# INFO:root:Saving data for conversation 'Crear videos con imágenes.' to CHATGPT/output_txt_html_json/Crear_videos_con_imágenes..json
# INFO:root:Saving data for conversation 'Video Making Script with Logging' to CHATGPT/output_txt_html_json/Video_Making_Script_with_Logging.json
# INFO:root:Saving data for conversation 'Crear video con transiciones.' to CHATGPT/output_txt_html_json/Crear_video_con_transiciones..json
# INFO:root:Saving data for conversation 'List Directories with 'ls'' to CHATGPT/output_txt_html_json/List_Directories_with__ls_.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_txt_html_json/New_chat.json
# INFO:root:Saving data for conversation 'Rebuild Linux Thumbnails Cache' to CHATGPT/output_txt_html_json/Rebuild_Linux_Thumbnails_Cache.json
# INFO:root:Saving data for conversation 'Video Conversion with Fades' to CHATGPT/output_txt_html_json/Video_Conversion_with_Fades.json
# INFO:root:Saving data for conversation 'Unione video MP4 con transizione' to CHATGPT/output_txt_html_json/Unione_video_MP4_con_transizione.json
# INFO:root:Saving data for conversation 'Video Processing: Frames Method' to CHATGPT/output_txt_html_json/Video_Processing__Frames_Method.json
# INFO:root:Saving data for conversation 'Fade Transition Video Script' to CHATGPT/output_txt_html_json/Fade_Transition_Video_Script.json
# INFO:root:Saving data for conversation 'Unione video MP4 0.25s' to CHATGPT/output_txt_html_json/Unione_video_MP4_0.25s.json
# INFO:root:Saving data for conversation 'JACK Audio Connection Issue' to CHATGPT/output_txt_html_json/JACK_Audio_Connection_Issue.json
# INFO:root:Saving data for conversation 'Run 'mkgallery' in subdirectories' to CHATGPT/output_txt_html_json/Run__mkgallery__in_subdirectories.json
# INFO:root:Saving data for conversation 'House Stark in Winter' to CHATGPT/output_txt_html_json/House_Stark_in_Winter.json
# INFO:root:Saving data for conversation 'High Disk Activity Issue' to CHATGPT/output_txt_html_json/High_Disk_Activity_Issue.json
# INFO:root:Saving data for conversation 'Optimize SSD Swap File' to CHATGPT/output_txt_html_json/Optimize_SSD_Swap_File.json
# INFO:root:Saving data for conversation 'Code Indentation Fixed' to CHATGPT/output_txt_html_json/Code_Indentation_Fixed.json
# INFO:root:Saving data for conversation 'Install .run file on Linux' to CHATGPT/output_txt_html_json/Install_.run_file_on_Linux.json
# INFO:root:Saving data for conversation 'Install pyttsx3 module.' to CHATGPT/output_txt_html_json/Install_pyttsx3_module..json
# INFO:root:Saving data for conversation 'Create Scrolling Text Video' to CHATGPT/output_txt_html_json/Create_Scrolling_Text_Video.json
# INFO:root:Saving data for conversation 'FFMPEG video with frame & music' to CHATGPT/output_txt_html_json/FFMPEG_video_with_frame___music.json
# INFO:root:Saving data for conversation 'Fading Video Overlay Fix' to CHATGPT/output_txt_html_json/Fading_Video_Overlay_Fix.json
# INFO:root:Saving data for conversation 'Check Image Duplicates with Hashes' to CHATGPT/output_txt_html_json/Check_Image_Duplicates_with_Hashes.json
# INFO:root:Saving data for conversation 'Disable all extensions' to CHATGPT/output_txt_html_json/Disable_all_extensions.json
# INFO:root:Saving data for conversation 'FFmpeg Command Logging Fix' to CHATGPT/output_txt_html_json/FFmpeg_Command_Logging_Fix.json
# INFO:root:Saving data for conversation 'Flask HTML Template Example' to CHATGPT/output_txt_html_json/Flask_HTML_Template_Example.json
# INFO:root:Saving data for conversation 'Flask Video Selection Endpoint' to CHATGPT/output_txt_html_json/Flask_Video_Selection_Endpoint.json
# INFO:root:Saving data for conversation 'Improved Video Quality Settings' to CHATGPT/output_txt_html_json/Improved_Video_Quality_Settings.json
# INFO:root:Saving data for conversation 'Load index.html in Flask' to CHATGPT/output_txt_html_json/Load_index.html_in_Flask.json
# INFO:root:Saving data for conversation 'Image Resizer Troubleshooting' to CHATGPT/output_txt_html_json/Image_Resizer_Troubleshooting.json
# INFO:root:Saving data for conversation 'Flask MP4 Route Setup' to CHATGPT/output_txt_html_json/Flask_MP4_Route_Setup.json
# INFO:root:Saving data for conversation 'Plague Doctors and St. Sebastian' to CHATGPT/output_txt_html_json/Plague_Doctors_and_St._Sebastian.json
# INFO:root:Saving data for conversation 'Save DuckDuckGo Results JSON' to CHATGPT/output_txt_html_json/Save_DuckDuckGo_Results_JSON.json
# INFO:root:Saving data for conversation 'Flask Code Review' to CHATGPT/output_txt_html_json/Flask_Code_Review.json
# INFO:root:Saving data for conversation 'Flask App Code Review' to CHATGPT/output_txt_html_json/Flask_App_Code_Review.json
# INFO:root:Saving data for conversation 'Fixing Code for Directory Processing' to CHATGPT/output_txt_html_json/Fixing_Code_for_Directory_Processing.json
# INFO:root:Saving data for conversation 'Flask for Existing HTML' to CHATGPT/output_txt_html_json/Flask_for_Existing_HTML.json
# INFO:root:Saving data for conversation 'Update Protobuf Code Version' to CHATGPT/output_txt_html_json/Update_Protobuf_Code_Version.json
# INFO:root:Saving data for conversation 'Crop Dimensions Explanation' to CHATGPT/output_txt_html_json/Crop_Dimensions_Explanation.json
# INFO:root:Saving data for conversation 'Create Slow Scroll Video' to CHATGPT/output_txt_html_json/Create_Slow_Scroll_Video.json
# INFO:root:Saving data for conversation 'Crear plantilla HTML mp4_to_image' to CHATGPT/output_txt_html_json/Crear_plantilla_HTML_mp4_to_image.json
# INFO:root:Saving data for conversation 'Cancel Git Push Fix' to CHATGPT/output_txt_html_json/Cancel_Git_Push_Fix.json
# INFO:root:Saving data for conversation 'Capture Webpage with Python' to CHATGPT/output_txt_html_json/Capture_Webpage_with_Python.json
# INFO:root:Saving data for conversation 'Count Python Code Lines' to CHATGPT/output_txt_html_json/Count_Python_Code_Lines.json
# INFO:root:Saving data for conversation 'MP3 Joining Issue Troubleshooting' to CHATGPT/output_txt_html_json/MP3_Joining_Issue_Troubleshooting.json
# INFO:root:Saving data for conversation 'MP3 File Joining Issue' to CHATGPT/output_txt_html_json/MP3_File_Joining_Issue.json
# INFO:root:Saving data for conversation 'Correção da Rota "join_sound"' to CHATGPT/output_txt_html_json/Correção_da_Rota_"join_sound".json
# INFO:root:Saving data for conversation 'Random MP3 Clips Concatenation' to CHATGPT/output_txt_html_json/Random_MP3_Clips_Concatenation.json
# INFO:root:Saving data for conversation 'Shuffle Images for Video' to CHATGPT/output_txt_html_json/Shuffle_Images_for_Video.json
# INFO:root:Saving data for conversation 'Bash Completions using Python' to CHATGPT/output_txt_html_json/Bash_Completions_using_Python.json
# INFO:root:Saving data for conversation 'Fixing Flask Screen Capture' to CHATGPT/output_txt_html_json/Fixing_Flask_Screen_Capture.json
# INFO:root:Saving data for conversation 'Fix Git Push Error' to CHATGPT/output_txt_html_json/Fix_Git_Push_Error.json
# INFO:root:Saving data for conversation 'Flask Video Thumbnail App' to CHATGPT/output_txt_html_json/Flask_Video_Thumbnail_App.json
# INFO:root:Saving data for conversation 'Save Plots with UUIDs' to CHATGPT/output_txt_html_json/Save_Plots_with_UUIDs.json
# INFO:root:Saving data for conversation 'ClamAV Freshclam Log Error' to CHATGPT/output_txt_html_json/ClamAV_Freshclam_Log_Error.json
# INFO:root:Saving data for conversation 'Install Wine Mono Linux' to CHATGPT/output_txt_html_json/Install_Wine_Mono_Linux.json
# INFO:root:Saving data for conversation 'Clickable Links in HTML' to CHATGPT/output_txt_html_json/Clickable_Links_in_HTML.json
# INFO:root:Saving data for conversation 'Video Editing with MoviePy' to CHATGPT/output_txt_html_json/Video_Editing_with_MoviePy.json
# INFO:root:Saving data for conversation 'Flask Async Endpoints' to CHATGPT/output_txt_html_json/Flask_Async_Endpoints.json
# INFO:root:Saving data for conversation 'Random MP3 Selection Bash' to CHATGPT/output_txt_html_json/Random_MP3_Selection_Bash.json
# INFO:root:Saving data for conversation 'Virtual Environment Creation Error' to CHATGPT/output_txt_html_json/Virtual_Environment_Creation_Error.json
# INFO:root:Saving data for conversation 'Flask Video Generator Function' to CHATGPT/output_txt_html_json/Flask_Video_Generator_Function.json
# INFO:root:Saving data for conversation 'FlaskWebGui Debug Mode' to CHATGPT/output_txt_html_json/FlaskWebGui_Debug_Mode.json
# INFO:root:Saving data for conversation 'Flask File Upload Function' to CHATGPT/output_txt_html_json/Flask_File_Upload_Function.json
# INFO:root:Saving data for conversation 'Flask Template HTML Setup' to CHATGPT/output_txt_html_json/Flask_Template_HTML_Setup.json
# INFO:root:Saving data for conversation 'Comic Panel Layout CSS' to CHATGPT/output_txt_html_json/Comic_Panel_Layout_CSS.json
# INFO:root:Saving data for conversation 'Lighten Image with Mogrify' to CHATGPT/output_txt_html_json/Lighten_Image_with_Mogrify.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_txt_html_json/New_chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_txt_html_json/New_chat.json
# INFO:root:Saving data for conversation 'GPT API Key Access' to CHATGPT/output_txt_html_json/GPT_API_Key_Access.json
# INFO:root:Saving data for conversation 'Add JPG and PNG' to CHATGPT/output_txt_html_json/Add_JPG_and_PNG.json
# INFO:root:Saving data for conversation 'Feathered Image Creation' to CHATGPT/output_txt_html_json/Feathered_Image_Creation.json
# INFO:root:Saving data for conversation 'Feather Image with Python' to CHATGPT/output_txt_html_json/Feather_Image_with_Python.json
# INFO:root:Saving data for conversation 'Arcanis AI Enhancing Earth's AI' to CHATGPT/output_txt_html_json/Arcanis_AI_Enhancing_Earth_s_AI.json
# INFO:root:Saving data for conversation 'Flask Logging Setup Guide' to CHATGPT/output_txt_html_json/Flask_Logging_Setup_Guide.json
# INFO:root:Saving data for conversation 'Generate & Save PNG Plot' to CHATGPT/output_txt_html_json/Generate___Save_PNG_Plot.json
# INFO:root:Saving data for conversation 'Install R on Linux' to CHATGPT/output_txt_html_json/Install_R_on_Linux.json
# INFO:root:Saving data for conversation 'Python & Flask Enthusiasts' to CHATGPT/output_txt_html_json/Python___Flask_Enthusiasts.json
# INFO:root:Saving data for conversation 'Name: Esperanza' to CHATGPT/output_txt_html_json/Name__Esperanza.json
# INFO:root:Saving data for conversation 'Fixing Audio Buffer Overflow' to CHATGPT/output_txt_html_json/Fixing_Audio_Buffer_Overflow.json
# INFO:root:Saving data for conversation 'Louder Output Audio: Adjusting Volume' to CHATGPT/output_txt_html_json/Louder_Output_Audio__Adjusting_Volume.json
# INFO:root:Saving data for conversation 'Change Outline Color' to CHATGPT/output_txt_html_json/Change_Outline_Color.json
# INFO:root:Saving data for conversation 'Create Video from Images' to CHATGPT/output_txt_html_json/Create_Video_from_Images.json
# INFO:root:Saving data for conversation 'Python 3.9 Virtual Environment' to CHATGPT/output_txt_html_json/Python_3.9_Virtual_Environment.json
# INFO:root:Saving data for conversation 'Flask Thumbnail Video' to CHATGPT/output_txt_html_json/Flask_Thumbnail_Video.json
# INFO:root:Saving data for conversation 'Flask Directory Viewer' to CHATGPT/output_txt_html_json/Flask_Directory_Viewer.json
# INFO:root:Saving data for conversation 'Flask App Demo & Explanation' to CHATGPT/output_txt_html_json/Flask_App_Demo___Explanation.json
# INFO:root:Saving data for conversation 'Flask_env Jupyter Kernel Setup' to CHATGPT/output_txt_html_json/Flask_env_Jupyter_Kernel_Setup.json
# INFO:root:Saving data for conversation 'Mic Detection Issue Troubleshoot' to CHATGPT/output_txt_html_json/Mic_Detection_Issue_Troubleshoot.json
# INFO:root:Saving data for conversation 'Custom Instructions Understood' to CHATGPT/output_txt_html_json/Custom_Instructions_Understood.json
# INFO:root:Saving data for conversation 'Flask AttributeError Troubleshooting' to CHATGPT/output_txt_html_json/Flask_AttributeError_Troubleshooting.json
# INFO:root:Saving data for conversation 'Video Duration Adjustment' to CHATGPT/output_txt_html_json/Video_Duration_Adjustment.json
# INFO:root:Saving data for conversation 'Install OpenCV (cv2)' to CHATGPT/output_txt_html_json/Install_OpenCV__cv2_.json
# INFO:root:Saving data for conversation 'Delete Files Except *.jpg' to CHATGPT/output_txt_html_json/Delete_Files_Except__.jpg.json
# INFO:root:Saving data for conversation 'LuaRocks Install NN-Spec' to CHATGPT/output_txt_html_json/LuaRocks_Install_NN-Spec.json
# INFO:root:Saving data for conversation 'Failed nn Installation' to CHATGPT/output_txt_html_json/Failed_nn_Installation.json
# INFO:root:Saving data for conversation 'Random Desktop Video Clips' to CHATGPT/output_txt_html_json/Random_Desktop_Video_Clips.json
# INFO:root:Saving data for conversation 'FFMPEG Create Shuffled Video' to CHATGPT/output_txt_html_json/FFMPEG_Create_Shuffled_Video.json
# INFO:root:Saving data for conversation 'Stream Speakers & Desktop' to CHATGPT/output_txt_html_json/Stream_Speakers___Desktop.json
# INFO:root:Saving data for conversation 'Find Imported Module Source' to CHATGPT/output_txt_html_json/Find_Imported_Module_Source.json
# INFO:root:Saving data for conversation 'Linux Desktop Missing Icons' to CHATGPT/output_txt_html_json/Linux_Desktop_Missing_Icons.json
# INFO:root:Saving data for conversation 'FFMPEG Video Slowdown.' to CHATGPT/output_txt_html_json/FFMPEG_Video_Slowdown..json
# INFO:root:Saving data for conversation 'Create BMP from Image' to CHATGPT/output_txt_html_json/Create_BMP_from_Image.json
# INFO:root:Saving data for conversation 'GIFs to MP4' to CHATGPT/output_txt_html_json/GIFs_to_MP4.json
# INFO:root:Saving data for conversation 'Hardcoded Args Parser' to CHATGPT/output_txt_html_json/Hardcoded_Args_Parser.json
# INFO:root:Saving data for conversation 'Starting Over?' to CHATGPT/output_txt_html_json/Starting_Over?.json
# INFO:root:Saving data for conversation 'Create GIFS.mp4' to CHATGPT/output_txt_html_json/Create_GIFS.mp4.json
# INFO:root:Saving data for conversation 'Python Image Processing Code' to CHATGPT/output_txt_html_json/Python_Image_Processing_Code.json
# INFO:root:Saving data for conversation 'Dynamic Directory for mkblend_videos' to CHATGPT/output_txt_html_json/Dynamic_Directory_for_mkblend_videos.json
# INFO:root:Saving data for conversation 'Flask code with logging.' to CHATGPT/output_txt_html_json/Flask_code_with_logging..json
# INFO:root:Saving data for conversation 'Create MP4 from images.' to CHATGPT/output_txt_html_json/Create_MP4_from_images..json
# INFO:root:Saving data for conversation 'Video Overlay Not Working' to CHATGPT/output_txt_html_json/Video_Overlay_Not_Working.json
# INFO:root:Saving data for conversation 'Fix favicon not found.' to CHATGPT/output_txt_html_json/Fix_favicon_not_found..json
# INFO:root:Saving data for conversation 'Copy File with shutil' to CHATGPT/output_txt_html_json/Copy_File_with_shutil.json
# INFO:root:Saving data for conversation 'Nietzsche's views on death.' to CHATGPT/output_txt_html_json/Nietzsche_s_views_on_death..json
# INFO:root:Saving data for conversation 'Video Generation from Directories.' to CHATGPT/output_txt_html_json/Video_Generation_from_Directories..json
# INFO:root:Saving data for conversation 'API v0xF - Unknown Version' to CHATGPT/output_txt_html_json/API_v0xF_-_Unknown_Version.json
# INFO:root:Saving data for conversation 'Flask-SQLAlchemy Version Mismatch.' to CHATGPT/output_txt_html_json/Flask-SQLAlchemy_Version_Mismatch..json
# INFO:root:Saving data for conversation 'Flask: Request and Save.' to CHATGPT/output_txt_html_json/Flask__Request_and_Save..json
# INFO:root:Saving data for conversation 'AI: Wonder or Monster?' to CHATGPT/output_txt_html_json/AI__Wonder_or_Monster?.json
# INFO:root:Saving data for conversation 'Flask App Setup' to CHATGPT/output_txt_html_json/Flask_App_Setup.json
# INFO:root:Saving data for conversation 'Flask App with SQLite3' to CHATGPT/output_txt_html_json/Flask_App_with_SQLite3.json
# INFO:root:Saving data for conversation 'Video Editing Transitions' to CHATGPT/output_txt_html_json/Video_Editing_Transitions.json
# INFO:root:Saving data for conversation 'Avatar AI for Talking' to CHATGPT/output_txt_html_json/Avatar_AI_for_Talking.json
# INFO:root:Saving data for conversation 'cp directory without overwrite' to CHATGPT/output_txt_html_json/cp_directory_without_overwrite.json
# INFO:root:Saving data for conversation 'Find File: stacked_videos' to CHATGPT/output_txt_html_json/Find_File__stacked_videos.json
# INFO:root:Saving data for conversation 'AI's Leap in 2021' to CHATGPT/output_txt_html_json/AI_s_Leap_in_2021.json
# INFO:root:Saving data for conversation 'Convert audio to video' to CHATGPT/output_txt_html_json/Convert_audio_to_video.json
# INFO:root:Saving data for conversation 'Create Image Sequence Video' to CHATGPT/output_txt_html_json/Create_Image_Sequence_Video.json
# INFO:root:Saving data for conversation 'Linux Find Modified Images' to CHATGPT/output_txt_html_json/Linux_Find_Modified_Images.json
# INFO:root:Saving data for conversation 'Find Duplicate Image Names' to CHATGPT/output_txt_html_json/Find_Duplicate_Image_Names.json
# INFO:root:Saving data for conversation 'Flask Blueprint Assistance' to CHATGPT/output_txt_html_json/Flask_Blueprint_Assistance.json
# INFO:root:Saving data for conversation 'Activate Virtual Environment' to CHATGPT/output_txt_html_json/Activate_Virtual_Environment.json
# INFO:root:Saving data for conversation 'Resizing & Cropping for Vertical Video' to CHATGPT/output_txt_html_json/Resizing___Cropping_for_Vertical_Video.json
# INFO:root:Saving data for conversation 'Flask Open & View Text' to CHATGPT/output_txt_html_json/Flask_Open___View_Text.json
# INFO:root:Saving data for conversation 'Replace Spaces with Underscores' to CHATGPT/output_txt_html_json/Replace_Spaces_with_Underscores.json
# INFO:root:Saving data for conversation 'Create Video with Text' to CHATGPT/output_txt_html_json/Create_Video_with_Text.json
# INFO:root:Saving data for conversation 'Image-to-Video Conversion' to CHATGPT/output_txt_html_json/Image-to-Video_Conversion.json
# INFO:root:Saving data for conversation 'Flask Video Processing Server' to CHATGPT/output_txt_html_json/Flask_Video_Processing_Server.json
# INFO:root:Saving data for conversation 'HEVC Decoding Errors' to CHATGPT/output_txt_html_json/HEVC_Decoding_Errors.json
# INFO:root:Saving data for conversation 'Blend Image Video Creation' to CHATGPT/output_txt_html_json/Blend_Image_Video_Creation.json
# INFO:root:Saving data for conversation 'Inference Error: mel() Function' to CHATGPT/output_txt_html_json/Inference_Error__mel___Function.json
# INFO:root:Saving data for conversation 'Syntax Error Resolved' to CHATGPT/output_txt_html_json/Syntax_Error_Resolved.json
# INFO:root:Saving data for conversation 'Wonderland Characters Summary' to CHATGPT/output_txt_html_json/Wonderland_Characters_Summary.json
# INFO:root:Saving data for conversation 'Datetime Import Issue' to CHATGPT/output_txt_html_json/Datetime_Import_Issue.json
# INFO:root:Saving data for conversation 'Selecting Image Directory' to CHATGPT/output_txt_html_json/Selecting_Image_Directory.json
# INFO:root:Saving data for conversation 'Upload file from directory' to CHATGPT/output_txt_html_json/Upload_file_from_directory.json
# INFO:root:Saving data for conversation 'Expressive Flora Still Life' to CHATGPT/output_txt_html_json/Expressive_Flora_Still_Life.json
# INFO:root:Saving data for conversation 'Anunnaki Overview' to CHATGPT/output_txt_html_json/Anunnaki_Overview.json
# INFO:root:Saving data for conversation 'Arcanis AI Communication' to CHATGPT/output_txt_html_json/Arcanis_AI_Communication.json
# INFO:root:Saving data for conversation 'GEGL Bevel Compilation Error' to CHATGPT/output_txt_html_json/GEGL_Bevel_Compilation_Error.json
# INFO:root:Saving data for conversation 'Upload and Apply Text' to CHATGPT/output_txt_html_json/Upload_and_Apply_Text.json
# INFO:root:Saving data for conversation 'Browser Media Stream Issue' to CHATGPT/output_txt_html_json/Browser_Media_Stream_Issue.json
# INFO:root:Saving data for conversation 'Generate Unique Video Filename' to CHATGPT/output_txt_html_json/Generate_Unique_Video_Filename.json
# INFO:root:Saving data for conversation 'Flask Text-to-Speech' to CHATGPT/output_txt_html_json/Flask_Text-to-Speech.json
# INFO:root:Saving data for conversation 'Subprocess Firefox HTML Execution' to CHATGPT/output_txt_html_json/Subprocess_Firefox_HTML_Execution.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_txt_html_json/New_chat.json
# INFO:root:Saving data for conversation 'Module Import Error Fix' to CHATGPT/output_txt_html_json/Module_Import_Error_Fix.json
# INFO:root:Saving data for conversation 'Aliens & AI Speculation' to CHATGPT/output_txt_html_json/Aliens___AI_Speculation.json
# INFO:root:Saving data for conversation 'Fix File Copying Error' to CHATGPT/output_txt_html_json/Fix_File_Copying_Error.json
# INFO:root:Saving data for conversation 'Flask App Conversion' to CHATGPT/output_txt_html_json/Flask_App_Conversion.json
# INFO:root:Saving data for conversation 'Dynamic Image Directory' to CHATGPT/output_txt_html_json/Dynamic_Image_Directory.json
# INFO:root:Saving data for conversation 'Large File Push Error' to CHATGPT/output_txt_html_json/Large_File_Push_Error.json
# INFO:root:Saving data for conversation 'Overlay Video with Colorchrome' to CHATGPT/output_txt_html_json/Overlay_Video_with_Colorchrome.json
# INFO:root:Saving data for conversation 'Flask: Blank 512x1024.mp4' to CHATGPT/output_txt_html_json/Flask__Blank_512x1024.mp4.json
# INFO:root:Saving data for conversation 'Play MP3' to CHATGPT/output_txt_html_json/Play_MP3.json
# INFO:root:Saving data for conversation 'Screen and Audio Capture' to CHATGPT/output_txt_html_json/Screen_and_Audio_Capture.json
# INFO:root:Saving data for conversation 'Flask Marquee Overlay Video' to CHATGPT/output_txt_html_json/Flask_Marquee_Overlay_Video.json
# INFO:root:Saving data for conversation 'Concatenation Error: Parameters Mismatch' to CHATGPT/output_txt_html_json/Concatenation_Error__Parameters_Mismatch.json
# INFO:root:Saving data for conversation 'AI's Arcanis Intervention' to CHATGPT/output_txt_html_json/AI_s_Arcanis_Intervention.json
# INFO:root:Saving data for conversation 'Story Assistance Available' to CHATGPT/output_txt_html_json/Story_Assistance_Available.json
# INFO:root:Saving data for conversation 'LAN PHP Server Setup' to CHATGPT/output_txt_html_json/LAN_PHP_Server_Setup.json
# INFO:root:Saving data for conversation 'Combine Image and Audio' to CHATGPT/output_txt_html_json/Combine_Image_and_Audio.json
# INFO:root:Saving data for conversation 'Image to Video Conversion' to CHATGPT/output_txt_html_json/Image_to_Video_Conversion.json
# INFO:root:Saving data for conversation 'Male voice for Google TTS' to CHATGPT/output_txt_html_json/Male_voice_for_Google_TTS.json
# INFO:root:Saving data for conversation 'Fixing PyQt5 Dependency Error' to CHATGPT/output_txt_html_json/Fixing_PyQt5_Dependency_Error.json
# INFO:root:Saving data for conversation 'KDENLIVE error encountered' to CHATGPT/output_txt_html_json/KDENLIVE_error_encountered.json
# INFO:root:Saving data for conversation 'CUDA Library Missing Error' to CHATGPT/output_txt_html_json/CUDA_Library_Missing_Error.json
# INFO:root:Saving data for conversation 'Add large file to GitHub.' to CHATGPT/output_txt_html_json/Add_large_file_to_GitHub..json
# INFO:root:Saving data for conversation 'NoCache pip Install.' to CHATGPT/output_txt_html_json/NoCache_pip_Install..json
# INFO:root:Saving data for conversation 'Fixing Large Files Issue' to CHATGPT/output_txt_html_json/Fixing_Large_Files_Issue.json
# INFO:root:Saving data for conversation 'MyTube AI Videos' to CHATGPT/output_txt_html_json/MyTube_AI_Videos.json
# INFO:root:Saving data for conversation 'Programming Joke: Light vs Bugs' to CHATGPT/output_txt_html_json/Programming_Joke__Light_vs_Bugs.json
# INFO:root:Saving data for conversation 'Choose Directory: Handle Selection' to CHATGPT/output_txt_html_json/Choose_Directory__Handle_Selection.json
# INFO:root:Saving data for conversation 'FFmpeg Merge Video & Audio' to CHATGPT/output_txt_html_json/FFmpeg_Merge_Video___Audio.json
# INFO:root:Saving data for conversation 'MP3 to WAV Conversion' to CHATGPT/output_txt_html_json/MP3_to_WAV_Conversion.json
# INFO:root:Saving data for conversation 'FFmpeg Resize Video' to CHATGPT/output_txt_html_json/FFmpeg_Resize_Video.json
# INFO:root:Saving data for conversation 'Resize Video 1/4' to CHATGPT/output_txt_html_json/Resize_Video_1/4.json
# ERROR:root:File not found: CHATGPT/conversations.json

# %%
# !rm chat_database2.db

# %% [markdown]
# # ChatGPT:
# #### conversations2/conversation_json_to_sessions_txt_html_sqlite_data

# %%
import sqlite3
import os
import hashlib

# Connect to SQLite database (creates a new database if it doesn't exist)
db_path = 'chat_database2.db'
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# Create a table to store file information
cursor.execute('''
    CREATE TABLE IF NOT EXISTS files (
        id INTEGER PRIMARY KEY,
        filename TEXT NOT NULL,
        content BLOB NOT NULL,
        text_content TEXT NOT NULL,
        hash_value TEXT NOT NULL,
        format TEXT NOT NULL
    )
''')

# Commit changes and close the connection
conn.commit()
conn.close()

# Function to calculate SHA-256 hash of a file
def calculate_hash(file_path):
    sha256 = hashlib.sha256()
    with open(file_path, 'rb') as file:
        while chunk := file.read(8192):  # Read in 8KB chunks
            sha256.update(chunk)
    return sha256.hexdigest()

# Function to insert a file into the database
def insert_file(filename, content, text_content, hash_value, file_format):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute('INSERT INTO files (filename, content, text_content, hash_value, format) VALUES (?, ?, ?, ?, ?)',
                   (filename, content, text_content, hash_value, file_format))
    conn.commit()
    conn.close()

# Function to insert HTML files recursively
def insert_html_files(directory):
    for root, _, files in os.walk(directory):
        for file_name in files:
            if file_name.endswith('.html'):
                file_path = os.path.join(root, file_name)
                with open(file_path, 'rb') as file:
                    file_content = file.read()
                text_content = file_content.decode('utf-8', errors='ignore')  # Convert bytes to string
                hash_value = calculate_hash(file_path)
                insert_file(file_name, file_content, text_content, hash_value, 'html')
                print(f"Inserted: {file_name}")

# Example: Insert HTML files recursively from the specified directory
output_folder = 'CHATGPT/output_txt_html_json'
insert_html_files(output_folder)

print('Insertion process completed.')
# Out:
# Inserted: Sticky_Header_Code.html
# Inserted: Create_Black_Image.html
# Inserted: Failed_nn_Installation.html
# Inserted: Feathered_Image_Creation.html
# Inserted: Install_OpenCV__cv2_.html
# Inserted: Nietzsche_s_views_on_death..html
# Inserted: Convert_FilePath_to_GIF.html
# Inserted: FlaskWebGui_Debug_Mode.html
# Inserted: Fixing_PyQt5_Dependency_Error.html
# Inserted: Crear_videos_con_imágenes..html
# Inserted: Whiplash_Curves_in_Art.html
# Inserted: Linux_Find_Largest_Subdirectory.html
# Inserted: Dynamic_Directory_for_mkblend_videos.html
# Inserted: AI__Wonder_or_Monster?.html
# Inserted: AI_Video_Transitions_Mastery.html
# Inserted: Flask_Async_Endpoints.html
# Inserted: Fade_Transition_Video_Script.html
# Inserted: Flask_Installation_Troubleshooting.html
# Inserted: FFmpeg_Merge_Video___Audio.html
# Inserted: FFMPEG_video_with_frame___music.html
# Inserted: Adjust_Duration_for_Longer.html
# Inserted: Cancel_Git_Push_Fix.html
# Inserted: Inference_Error__mel___Function.html
# Inserted: Delete_Files_Except__.jpg.html
# Inserted: Lighten_Image_with_Mogrify.html
# Inserted: Flask_AttributeError_Troubleshooting.html
# Inserted: Python_HTTP_Server_Guide.html
# Inserted: Flask_Module_Not_Found.html
# Inserted: GPT_API_Key_Access.html
# Inserted: MyTube_AI_Videos.html
# Inserted: Reinstall_XWin_on_Linux..html
# Inserted: Flask_Video_Generator_Function.html
# Inserted: Virtual_Environment_Creation_Error.html
# Inserted: ChatGPT,_Conversations.json_Overview.html
# Inserted: Arcanis_AI_Enhancing_Earth_s_AI.html
# Inserted: Python_Image_Processing_Code.html
# Inserted: Simple_3D_Scene_Creation.html
# Inserted: Prevent_inherit_text-align..html
# Inserted: Image_to_Video_Conversion.html
# Inserted: Upload_file_from_directory.html
# Inserted: List_Directories_with__ls_.html
# Inserted: Flask_App_Demo___Explanation.html
# Inserted: Image-to-Video_Conversion.html
# Inserted: Xterm_Display_Error_Troubleshoot.html
# Inserted: Split_MP4_into_6..html
# Inserted: Activate_Virtual_Environment.html
# Inserted: Video_Processing__512x768_Resolution.html
# Inserted: Bash_Completions_using_Python.html
# Inserted: Explain_script_in_detail..html
# Inserted: Flask_App_Setup.html
# Inserted: Load_index.html_in_Flask.html
# Inserted: Rsync_Syncs_and_Overwrites.html
# Inserted: Video_Editing_with_MoviePy.html
# Inserted: Video_Clips_with_Sound.html
# Inserted: MP3_to_WAV_Conversion.html
# Inserted: Doll_Factory_Dystopia.html
# Inserted: Update_Protobuf_Code_Version.html
# Inserted: Domain_Info_with_Python.html
# Inserted: Enhance_Image_with_OpenCV.html
# Inserted: Install_PHP_on_Apache.html
# Inserted: Fix_File_Copying_Error.html
# Inserted: Run__mkgallery__in_subdirectories.html
# Inserted: Doll_in_Dystopian_Decay.html
# Inserted: Subprocess_Firefox_HTML_Execution.html
# Inserted: HEVC_Decoding_Errors.html
# Inserted: Configurar_servidor_Apache_local.html
# Inserted: MP4_Files_Finder_Script.html
# Inserted: Scroll_Image_to_Video.html
# Inserted: Video_Processing__Frames_Method.html
# Inserted: Get_Image_Size.html
# Inserted: FFmpeg_Slideshow_with_Transitions.html
# Inserted: Run_Kdenlive_Extension_with_Melt.html
# Inserted: Name__Esperanza.html
# Inserted: Python_3.9_Virtual_Environment.html
# Inserted: Flask_for_Existing_HTML.html
# Inserted: Crop_Dimensions_Explanation.html
# Inserted: Install_pyttsx3_module..html
# Inserted: Shuffle_Images_for_Video.html
# Inserted: Datetime_Import_Issue.html
# Inserted: Fixing_Code_for_Directory_Processing.html
# Inserted: Create_Video_with_Text.html
# Inserted: Install_.run_file_on_Linux.html
# Inserted: Python_Punctuation_Removal.html
# Inserted: Expressive_Flora_Still_Life.html
# Inserted: Create_3D_Image_Transitions.html
# Inserted: cp_directory_without_overwrite.html
# Inserted: Code_Indentation_Fixed.html
# Inserted: Fixing_Large_Files_Issue.html
# Inserted: Video_Editing_Transitions.html
# Inserted: Video_Conversion_with_Fades.html
# Inserted: Crear_video_con_transiciones..html
# Inserted: Set_Hard_Drive_Permissions.html
# Inserted: Create_Scrolling_Text_Video.html
# Inserted: Download_Age-Restricted_Video.html
# Inserted: Flask_FFmpeg_Command_Integration.html
# Inserted: Linux__Force_Thumbnail_Regeneration.html
# Inserted: Comic_Panel_Layout_CSS.html
# Inserted: FFmpeg_Zoom_Video_Fix.html
# Inserted: CUDA_Library_Missing_Error.html
# Inserted: LuaRocks_Install_NN-Spec.html
# Inserted: Python___Flask_Enthusiasts.html
# Inserted: Add_sound_if_needed..html
# Inserted: Convert_JSON_to_HTML.html
# Inserted: API_v0xF_-_Unknown_Version.html
# Inserted: Segmenting_Video_Frames.html
# Inserted: Create_MP4_from_images..html
# Inserted: Change_Outline_Color.html
# Inserted: Arcanian_AI_s_Transformative_Influence.html
# Inserted: Dynamic_Image_Directory.html
# Inserted: Locate_IPYNB_with_Quantify.html
# Inserted: FFmpeg_Command_Logging_Fix.html
# Inserted: Count_Python_Code_Lines.html
# Inserted: Custom_Instructions_Understood.html
# Inserted: Video_Duration_Adjustment.html
# Inserted: Flask__Request_and_Save..html
# Inserted: Kill_Process_on_Port.html
# Inserted: Create_BMP_from_Image.html
# Inserted: Correção_da_Rota_"join_sound".html
# Inserted: Wget_File_Download.html
# Inserted: Open_Jupyter_Notebook_Over_LAN.html
# Inserted: Flask_Open___View_Text.html
# Inserted: Flask_Video_Processing_Server.html
# Inserted: Plague_Doctors_and_St._Sebastian.html
# Inserted: Save_DuckDuckGo_Results_JSON.html
# Inserted: Flask_Blueprint_Assistance.html
# Inserted: Flask_env_Jupyter_Kernel_Setup.html
# Inserted: Cosmic_Octopus_AI_Awakening.html
# Inserted: Avatar_AI_for_Talking.html
# Inserted: Add_JPG_and_PNG.html
# Inserted: Story_Assistance_Available.html
# Inserted: Generate_Unique_Video_Filename.html
# Inserted: Copy_File_with_shutil.html
# Inserted: Flask_Code_Review.html
# Inserted: LAN_Directory_Serving_Script.html
# Inserted: Flask_MP4_Route_Setup.html
# Inserted: Set_Up_LAN_Server__Python_.html
# Inserted: Convert_audio_to_video.html
# Inserted: Syntax_Error_Resolved.html
# Inserted: Update_SQLite_Permissions.html
# Inserted: Anunnaki_Overview.html
# Inserted: MP3_Joining_Issue_Troubleshooting.html
# Inserted: CSS_Logo_Placement.html
# Inserted: Generate_Loopable_Stylized_Images.html
# Inserted: Capture_Screen_with_Offset.html
# Inserted: Search_IPYNB_for_Term.html
# Inserted: Video_Making_Script_with_Logging.html
# Inserted: Fixing_Flask_Screen_Capture.html
# Inserted: Reinstall_EFC_Desktop.html
# Inserted: Find_Duplicate_Image_Names.html
# Inserted: Optimize_SSD_Swap_File.html
# Inserted: Stream_Speakers___Desktop.html
# Inserted: GEGL_Bevel_Compilation_Error.html
# Inserted: Shuffled_Image_Zoom.html
# Inserted: Fixing_Audio_Buffer_Overflow.html
# Inserted: Bash_Locate_in_Python.html
# Inserted: Unione_video_MP4_0.25s.html
# Inserted: Create_Video_from_Images.html
# Inserted: Caregivers__Organized,_Efficient,_Communicative.html
# Inserted: FFmpeg_Resize_Video.html
# Inserted: Python_Save_File.html
# Inserted: Flask_Programmer_and_YouTuber.html
# Inserted: Bash_Completion_Python_Script.html
# Inserted: Rebuild_Linux_Thumbnails_Cache.html
# Inserted: Install_R_on_Linux.html
# Inserted: FFmpeg_Remove_Duplicate_Frames.html
# Inserted: Flask_HTML_Template_Example.html
# Inserted: Fading_Video_Overlay_Fix.html
# Inserted: Select_Random_TTF_Font.html
# Inserted: Play_MP3.html
# Inserted: Louder_Output_Audio__Adjusting_Volume.html
# Inserted: Resizing___Cropping_for_Vertical_Video.html
# Inserted: Hardcoded_Args_Parser.html
# Inserted: Flask_Video_Thumbnail_App.html
# Inserted: Fail2Ban_Installation_for_Security.html
# Inserted: Random_Desktop_Video_Clips.html
# Inserted: Find_Imported_Module_Source.html
# Inserted: Flask_App_with_SQLite3.html
# Inserted: Flask_Directory_Viewer.html
# Inserted: PDF_to_PNG_Converter.html
# Inserted: High_Disk_Activity_Issue.html
# Inserted: FFMPEG_Create_Shuffled_Video.html
# Inserted: Image_files_not_printing..html
# Inserted: Create_Image_Sequence_Video.html
# Inserted: Flask_Template_HTML_Setup.html
# Inserted: Crear_imagen_colores_primarios.html
# Inserted: Image_Resizer_Troubleshooting.html
# Inserted: PDF_to_PNG_Conversion.html
# Inserted: Create_Slow_Scroll_Video.html
# Inserted: Refrigerate_ketchup_after_opening..html
# Inserted: Flask_Video_Selection_Script.html
# Inserted: JACK_Audio_Connection_Issue.html
# Inserted: Programming_Joke__Light_vs_Bugs.html
# Inserted: Flask_Marquee_Overlay_Video.html
# Inserted: AI_s_Leap_in_2021.html
# Inserted: LAN_PHP_Server_Setup.html
# Inserted: Sudo_cp_file_permissions.html
# Inserted: Find___CD__fade-transb.html
# Inserted: Shell_Command_Argument_Handling.html
# Inserted: Combine_Image_and_Audio.html
# Inserted: Concatenation_Error__Parameters_Mismatch.html
# Inserted: NoCache_pip_Install..html
# Inserted: Wonderland_Characters_Summary.html
# Inserted: Flask__Blank_512x1024.mp4.html
# Inserted: KDENLIVE_error_encountered.html
# Inserted: Remove_Python_Path.html
# Inserted: Linux_Desktop_Missing_Icons.html
# Inserted: Save_Plots_with_UUIDs.html
# Inserted: Fix_favicon_not_found..html
# Inserted: Overlay_Video_with_Colorchrome.html
# Inserted: Choose_Directory__Handle_Selection.html
# Inserted: PHP_Execute_Bash_Script.html
# Inserted: Video_Overlay_Not_Working.html
# Inserted: Dystopian_City_Text_Prompt.html
# Inserted: Flask-SQLAlchemy_Version_Mismatch..html
# Inserted: SSL_Cert_Expiry__Python.html
# Inserted: House_Stark_in_Winter.html
# Inserted: Crear_plantilla_HTML_mp4_to_image.html
# Inserted: Improved_Video_Quality_Settings.html
# Inserted: Martian_Masterpiece__Surreal_Synthesis.html
# Inserted: Random_MP3_Selection_Bash.html
# Inserted: Check_Directory_for_Duplicates.html
# Inserted: FFMPEG_Video_Slowdown..html
# Inserted: Flask_File_Upload_Function.html
# Inserted: SSD_Maintenance__Trim_Frequency.html
# Inserted: Capture_Webpage_with_Python.html
# Inserted: Auto-looping_1s_Slideshow_Code.html
# Inserted: Flask_code_with_logging..html
# Inserted: Feather_Image_with_Python.html
# Inserted: AI_s_Arcanis_Intervention.html
# Inserted: Linux_Find_Modified_Images.html
# Inserted: Mic_Detection_Issue_Troubleshoot.html
# Inserted: MP3_File_Joining_Issue.html
# Inserted: Random_MP3_Clips_Concatenation.html
# Inserted: Disable_all_extensions.html
# Inserted: Selecting_Image_Directory.html
# Inserted: Screen_and_Audio_Capture.html
# Inserted: Blend_Image_Video_Creation.html
# Inserted: Copy_care.mp4_to_VPS.html
# Inserted: ClamAV_Freshclam_Log_Error.html
# Inserted: Check_Image_Duplicates_with_Hashes.html
# Inserted: AI_Guides_Animal_Enlightenment.html
# Inserted: Flask_App_Conversion.html
# Inserted: Thunar_Scroll_Issue_Troubleshooting.html
# Inserted: Module_Import_Error_Fix.html
# Inserted: Flask_App_Code_Review.html
# Inserted: Fix_Protobuf_Issue.html
# Inserted: Create_GIFS.mp4.html
# Inserted: Image_Zoom_Video_Script.html
# Inserted: Movies_with_Punch.html
# Inserted: Install_Wine_Mono_Linux.html
# Inserted: Flask_Logging_Setup_Guide.html
# Inserted: Unione_video_MP4_con_transizione.html
# Inserted: Arcanis_AI_Communication.html
# Inserted: Clickable_Links_in_HTML.html
# Inserted: SSH_to_Specific_Directory.html
# Inserted: Large_File_Push_Error.html
# Inserted: Generate___Save_PNG_Plot.html
# Inserted: Flask_App_on_LAN.html
# Inserted: Sticky_Header_for_Website.html
# Inserted: GIFs_to_MP4.html
# Inserted: Video_Flip_Book_Fix.html
# Inserted: MoviePy_for_Image_Videos.html
# Inserted: Add_Expose_to_Docker_Image.html
# Inserted: Linux_Terminal_Issue.html
# Inserted: Add_large_file_to_GitHub..html
# Inserted: HTML_Conversion_Debugging.html
# Inserted: New_chat.html
# Inserted: Find_File__stacked_videos.html
# Inserted: Replace_Spaces_with_Underscores.html
# Inserted: Starting_Over?.html
# Inserted: Aliens___AI_Speculation.html
# Inserted: YouTube_2nd_Channel_Automator.html
# Inserted: Browser_Media_Stream_Issue.html
# Inserted: Flask_Video_Selection_Endpoint.html
# Inserted: Flask_Thumbnail_Video.html
# Inserted: Video_Generation_from_Directories..html
# Inserted: Snap_Certbot_Installation_Issue.html
# Inserted: Flask_Text-to-Speech.html
# Inserted: Upload_and_Apply_Text.html
# Inserted: Fix_Git_Push_Error.html
# Inserted: Male_voice_for_Google_TTS.html
# Insertion process completed.

# %% [markdown]
# # SEARCH AND CREATE HTML PAGE

# %%
import sqlite3
import os
from time import sleep
conn = sqlite3.connect('chat_database2.db')
cursor = conn.cursor()
rows = cursor.execute("SELECT ROWID,content,text_content FROM files")
data =[]
cnts =0
for row in rows:
    cnts = cnts+1
    data.append(row[2])
results = 'CHATGPT/resulting_html/'

# Ensure the output folder exists
os.makedirs(results, exist_ok=True)
search_term = "random clips"
filename=search_term.replace(' ','_')
FileName =results+filename+".html"
print(FileName)
Input = open(FileName,"w")
cnt=0
for line in data:
    if search_term in line:
        cnt=cnt+1
        data=str(line)
        data = data.replace("\\n","")
        Input.write(data)
        Input.write("\n--------- END: "+str(cnt)+" ----------------------------\n")
        if cnt >= 4:
            print(f"Found and saved {cnt} occurrences of '{search_term}', stopping search.")
            break
Input.close()
print('going to sleep')
sleep(5)
# !firefox {FileName}
# Out:
# CHATGPT/resulting_html/random_clips.html
# going to sleep

# %%
running now

# %%
import json
import logging
import os
import string

def clean_title(title):
    valid_chars = set(string.ascii_letters + string.digits + string.whitespace)
    cleaned_title = ''.join(char if char in valid_chars else '_' for char in title)
    return cleaned_title.strip()

def convert_to_html(json_file, html_output_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        json_data = json.load(file)

    result_str = get_conversation_result(json_data)

    with open(html_output_file, "w", encoding='utf-8') as html_output:
        result_html = result_str.replace("\n", "XXXXXXX\n")
        result_html = result_html.replace("<", "&lt;")
        result_html = result_html.replace(">", "&gt;")
        for line in result_html.split("XXXXXXX"):
            line = line.replace("\n", "<br />\n")
            html_output.write(line)

def convert_to_txt(json_file, txt_output_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        json_data = json.load(file)

    result_str = get_conversation_result(json_data)

    with open(txt_output_file, "w", encoding='utf-8') as txt_output:
        result_txt = result_str.replace("\n", "XXXXXXX\n")
        for line in result_txt.split("XXXXXXX"):
            txt_output.write(line)

def get_conversation_result(json_data):
    result_str = ""
    for conversation in json_data:
        title = conversation.get('title', '')
        messages = get_conversation_messages(conversation)

        result_str += title + '\n'
        for message in messages:
            result_str += message['author'] + '\n' + message['text'] + '\n'
        result_str += '\n'

    return result_str

def get_conversation_messages(conversation):
    messages = []
    current_node = conversation.get('current_node')
    while current_node:
        node = conversation['mapping'][current_node]
        message = node.get('message')
        if (message and message.get('content') and message['content'].get('content_type') == 'text' and
                len(message['content'].get('parts', [])) > 0 and len(message['content']['parts'][0]) > 0 and
                (message['author']['role'] != 'system' or message.get('metadata', {}).get('is_user_system_message'))):
            author = message['author']['role']
            if author == 'assistant':
                author = 'ChatGPT'
            elif author == 'system' and message['metadata'].get('is_user_system_message'):
                author = 'Custom user info'
            messages.append({'author': author, 'text': message['content']['parts'][0]})
        current_node = node.get('parent')
    return messages[::-1]

def split_and_save_and_convert(conversations_file, output_folder):
    try:
        with open(conversations_file, 'r', encoding='utf-8') as file:
            data = json.load(file)
            
            for conversation in data:
                title = conversation.get('title', 'Unknown_Title')
                title_with_underscores = clean_title(title)
                chapter_filename = f"{title_with_underscores}.json"
                chapter_filepath = os.path.join(output_folder, chapter_filename)
                logging.info(f"Saving data for conversation '{title}' to {chapter_filepath}")
                
                with open(chapter_filepath, 'w', encoding='utf-8') as chapter_file:
                    json.dump([conversation], chapter_file, indent=2)

                # Convert JSON to HTML
                html_output_file = os.path.join(output_folder, f"{title_with_underscores}.html")
                convert_to_html(chapter_filepath, html_output_file)

                # Convert JSON to TXT
                txt_output_file = os.path.join(output_folder, f"{title_with_underscores}.txt")
                convert_to_txt(chapter_filepath, txt_output_file)

    except FileNotFoundError:
        logging.error(f"File not found: {conversations_file}")
    except json.JSONDecodeError:
        logging.error(f"Error decoding JSON in file: {conversations_file}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {e}")

# Example usage
conversations_file_path = 'CHATGPT/conversations.json'
output_folder = 'CHATGPT/output_all_in_one'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Configure logging
logging.basicConfig(level=logging.INFO)

# Call the split, save, and convert function
split_and_save_and_convert(conversations_file_path, output_folder)
# Out:
# INFO:root:Saving data for conversation 'Add Expose to Docker Image' to CHATGPT/output_all_in_one/Add Expose to Docker Image.json
# INFO:root:Saving data for conversation 'HTML Conversion Debugging' to CHATGPT/output_all_in_one/HTML Conversion Debugging.json
# INFO:root:Saving data for conversation 'Wget File Download' to CHATGPT/output_all_in_one/Wget File Download.json
# INFO:root:Saving data for conversation 'Flask App on LAN' to CHATGPT/output_all_in_one/Flask App on LAN.json
# INFO:root:Saving data for conversation 'Convert JSON to HTML' to CHATGPT/output_all_in_one/Convert JSON to HTML.json
# INFO:root:Saving data for conversation 'Check Directory for Duplicates' to CHATGPT/output_all_in_one/Check Directory for Duplicates.json
# INFO:root:Saving data for conversation 'Search IPYNB for Term' to CHATGPT/output_all_in_one/Search IPYNB for Term.json
# INFO:root:Saving data for conversation 'Refrigerate ketchup after opening.' to CHATGPT/output_all_in_one/Refrigerate ketchup after opening_.json
# INFO:root:Saving data for conversation 'ChatGPT, Conversations.json Overview' to CHATGPT/output_all_in_one/ChatGPT_ Conversations_json Overview.json
# INFO:root:Saving data for conversation 'Python Punctuation Removal' to CHATGPT/output_all_in_one/Python Punctuation Removal.json
# INFO:root:Saving data for conversation 'Cosmic Octopus AI Awakening' to CHATGPT/output_all_in_one/Cosmic Octopus AI Awakening.json
# INFO:root:Saving data for conversation 'Arcanian AI's Transformative Influence' to CHATGPT/output_all_in_one/Arcanian AI_s Transformative Influence.json
# INFO:root:Saving data for conversation 'AI Guides Animal Enlightenment' to CHATGPT/output_all_in_one/AI Guides Animal Enlightenment.json
# INFO:root:Saving data for conversation 'Flask Programmer and YouTuber' to CHATGPT/output_all_in_one/Flask Programmer and YouTuber.json
# INFO:root:Saving data for conversation 'Set Hard Drive Permissions' to CHATGPT/output_all_in_one/Set Hard Drive Permissions.json
# INFO:root:Saving data for conversation 'Python HTTP Server Guide' to CHATGPT/output_all_in_one/Python HTTP Server Guide.json
# INFO:root:Saving data for conversation 'Simple 3D Scene Creation' to CHATGPT/output_all_in_one/Simple 3D Scene Creation.json
# INFO:root:Saving data for conversation 'Segmenting Video Frames' to CHATGPT/output_all_in_one/Segmenting Video Frames.json
# INFO:root:Saving data for conversation 'Download Age-Restricted Video' to CHATGPT/output_all_in_one/Download Age_Restricted Video.json
# INFO:root:Saving data for conversation 'Convert FilePath to GIF' to CHATGPT/output_all_in_one/Convert FilePath to GIF.json
# INFO:root:Saving data for conversation 'Remove Python Path' to CHATGPT/output_all_in_one/Remove Python Path.json
# INFO:root:Saving data for conversation 'Create Black Image' to CHATGPT/output_all_in_one/Create Black Image.json
# INFO:root:Saving data for conversation 'Whiplash Curves in Art' to CHATGPT/output_all_in_one/Whiplash Curves in Art.json
# INFO:root:Saving data for conversation 'SSL Cert Expiry: Python' to CHATGPT/output_all_in_one/SSL Cert Expiry_ Python.json
# INFO:root:Saving data for conversation 'Bash Locate in Python' to CHATGPT/output_all_in_one/Bash Locate in Python.json
# INFO:root:Saving data for conversation 'Doll in Dystopian Decay' to CHATGPT/output_all_in_one/Doll in Dystopian Decay.json
# INFO:root:Saving data for conversation 'FFmpeg Zoom Video Fix' to CHATGPT/output_all_in_one/FFmpeg Zoom Video Fix.json
# INFO:root:Saving data for conversation 'Doll Factory Dystopia' to CHATGPT/output_all_in_one/Doll Factory Dystopia.json
# INFO:root:Saving data for conversation 'Enhance Image with OpenCV' to CHATGPT/output_all_in_one/Enhance Image with OpenCV.json
# INFO:root:Saving data for conversation 'Flask Video Selection Script' to CHATGPT/output_all_in_one/Flask Video Selection Script.json
# INFO:root:Saving data for conversation 'SSD Maintenance: Trim Frequency' to CHATGPT/output_all_in_one/SSD Maintenance_ Trim Frequency.json
# INFO:root:Saving data for conversation 'Split MP4 into 6.' to CHATGPT/output_all_in_one/Split MP4 into 6_.json
# INFO:root:Saving data for conversation 'FFmpeg Remove Duplicate Frames' to CHATGPT/output_all_in_one/FFmpeg Remove Duplicate Frames.json
# INFO:root:Saving data for conversation 'Video Clips with Sound' to CHATGPT/output_all_in_one/Video Clips with Sound.json
# INFO:root:Saving data for conversation 'Video Flip Book Fix' to CHATGPT/output_all_in_one/Video Flip Book Fix.json
# INFO:root:Saving data for conversation 'Dystopian City Text Prompt' to CHATGPT/output_all_in_one/Dystopian City Text Prompt.json
# INFO:root:Saving data for conversation 'SSH to Specific Directory' to CHATGPT/output_all_in_one/SSH to Specific Directory.json
# INFO:root:Saving data for conversation 'Add sound if needed.' to CHATGPT/output_all_in_one/Add sound if needed_.json
# INFO:root:Saving data for conversation 'Thunar Scroll Issue Troubleshooting' to CHATGPT/output_all_in_one/Thunar Scroll Issue Troubleshooting.json
# INFO:root:Saving data for conversation 'Get Image Size' to CHATGPT/output_all_in_one/Get Image Size.json
# INFO:root:Saving data for conversation 'Image Zoom Video Script' to CHATGPT/output_all_in_one/Image Zoom Video Script.json
# INFO:root:Saving data for conversation 'Video Processing: 512x768 Resolution' to CHATGPT/output_all_in_one/Video Processing_ 512x768 Resolution.json
# INFO:root:Saving data for conversation 'Find & CD: fade-transb' to CHATGPT/output_all_in_one/Find _ CD_ fade_transb.json
# INFO:root:Saving data for conversation 'Shell Command Argument Handling' to CHATGPT/output_all_in_one/Shell Command Argument Handling.json
# INFO:root:Saving data for conversation 'Python Save File' to CHATGPT/output_all_in_one/Python Save File.json
# INFO:root:Saving data for conversation 'Flask Module Not Found' to CHATGPT/output_all_in_one/Flask Module Not Found.json
# INFO:root:Saving data for conversation 'Linux Terminal Issue' to CHATGPT/output_all_in_one/Linux Terminal Issue.json
# INFO:root:Saving data for conversation 'Run Kdenlive Extension with Melt' to CHATGPT/output_all_in_one/Run Kdenlive Extension with Melt.json
# INFO:root:Saving data for conversation 'YouTube 2nd Channel Automator' to CHATGPT/output_all_in_one/YouTube 2nd Channel Automator.json
# INFO:root:Saving data for conversation 'Xterm Display Error Troubleshoot' to CHATGPT/output_all_in_one/Xterm Display Error Troubleshoot.json
# INFO:root:Saving data for conversation 'Flask Installation Troubleshooting' to CHATGPT/output_all_in_one/Flask Installation Troubleshooting.json
# INFO:root:Saving data for conversation 'MoviePy for Image Videos' to CHATGPT/output_all_in_one/MoviePy for Image Videos.json
# INFO:root:Saving data for conversation 'Create 3D Image Transitions' to CHATGPT/output_all_in_one/Create 3D Image Transitions.json
# INFO:root:Saving data for conversation 'Adjust Duration for Longer' to CHATGPT/output_all_in_one/Adjust Duration for Longer.json
# INFO:root:Saving data for conversation 'Capture Screen with Offset' to CHATGPT/output_all_in_one/Capture Screen with Offset.json
# INFO:root:Saving data for conversation 'Reinstall XWin on Linux.' to CHATGPT/output_all_in_one/Reinstall XWin on Linux_.json
# INFO:root:Saving data for conversation 'Linux: Force Thumbnail Regeneration' to CHATGPT/output_all_in_one/Linux_ Force Thumbnail Regeneration.json
# INFO:root:Saving data for conversation 'Martian Masterpiece: Surreal Synthesis' to CHATGPT/output_all_in_one/Martian Masterpiece_ Surreal Synthesis.json
# INFO:root:Saving data for conversation 'Reinstall EFC Desktop' to CHATGPT/output_all_in_one/Reinstall EFC Desktop.json
# INFO:root:Saving data for conversation 'Kill Process on Port' to CHATGPT/output_all_in_one/Kill Process on Port.json
# INFO:root:Saving data for conversation 'Linux Find Largest Subdirectory' to CHATGPT/output_all_in_one/Linux Find Largest Subdirectory.json
# INFO:root:Saving data for conversation 'Shuffle Images for Video' to CHATGPT/output_all_in_one/Shuffle Images for Video.json
# INFO:root:Saving data for conversation 'Shuffled Image Zoom' to CHATGPT/output_all_in_one/Shuffled Image Zoom.json
# INFO:root:Saving data for conversation 'Sticky Header for Website' to CHATGPT/output_all_in_one/Sticky Header for Website.json
# INFO:root:Saving data for conversation 'Image files not printing.' to CHATGPT/output_all_in_one/Image files not printing_.json
# INFO:root:Saving data for conversation 'Rsync Syncs and Overwrites' to CHATGPT/output_all_in_one/Rsync Syncs and Overwrites.json
# INFO:root:Saving data for conversation 'Auto-looping 1s Slideshow Code' to CHATGPT/output_all_in_one/Auto_looping 1s Slideshow Code.json
# INFO:root:Saving data for conversation 'Sticky Header Code' to CHATGPT/output_all_in_one/Sticky Header Code.json
# INFO:root:Saving data for conversation 'Bash Completion Python Script' to CHATGPT/output_all_in_one/Bash Completion Python Script.json
# INFO:root:Saving data for conversation 'Copy care.mp4 to VPS' to CHATGPT/output_all_in_one/Copy care_mp4 to VPS.json
# INFO:root:Saving data for conversation 'Update SQLite Permissions' to CHATGPT/output_all_in_one/Update SQLite Permissions.json
# INFO:root:Saving data for conversation 'Caregivers: Organized, Efficient, Communicative' to CHATGPT/output_all_in_one/Caregivers_ Organized_ Efficient_ Communicative.json
# INFO:root:Saving data for conversation 'Select Random TTF Font' to CHATGPT/output_all_in_one/Select Random TTF Font.json
# INFO:root:Saving data for conversation 'Generate Loopable Stylized Images' to CHATGPT/output_all_in_one/Generate Loopable Stylized Images.json
# INFO:root:Saving data for conversation 'Fix Protobuf Issue' to CHATGPT/output_all_in_one/Fix Protobuf Issue.json
# INFO:root:Saving data for conversation 'Locate IPYNB with Quantify' to CHATGPT/output_all_in_one/Locate IPYNB with Quantify.json
# INFO:root:Saving data for conversation 'PDF to PNG Conversion' to CHATGPT/output_all_in_one/PDF to PNG Conversion.json
# INFO:root:Saving data for conversation 'PDF to PNG Converter' to CHATGPT/output_all_in_one/PDF to PNG Converter.json
# INFO:root:Saving data for conversation 'Movies with Punch' to CHATGPT/output_all_in_one/Movies with Punch.json
# INFO:root:Saving data for conversation 'LAN Directory Serving Script' to CHATGPT/output_all_in_one/LAN Directory Serving Script.json
# INFO:root:Saving data for conversation 'Flask FFmpeg Command Integration' to CHATGPT/output_all_in_one/Flask FFmpeg Command Integration.json
# INFO:root:Saving data for conversation 'Explain script in detail.' to CHATGPT/output_all_in_one/Explain script in detail_.json
# INFO:root:Saving data for conversation 'AI Video Transitions Mastery' to CHATGPT/output_all_in_one/AI Video Transitions Mastery.json
# INFO:root:Saving data for conversation 'Fail2Ban Installation for Security' to CHATGPT/output_all_in_one/Fail2Ban Installation for Security.json
# INFO:root:Saving data for conversation 'PHP Execute Bash Script' to CHATGPT/output_all_in_one/PHP Execute Bash Script.json
# INFO:root:Saving data for conversation 'Prevent inherit text-align.' to CHATGPT/output_all_in_one/Prevent inherit text_align_.json
# INFO:root:Saving data for conversation 'Sudo cp file permissions' to CHATGPT/output_all_in_one/Sudo cp file permissions.json
# INFO:root:Saving data for conversation 'CSS Logo Placement' to CHATGPT/output_all_in_one/CSS Logo Placement.json
# INFO:root:Saving data for conversation 'Snap Certbot Installation Issue' to CHATGPT/output_all_in_one/Snap Certbot Installation Issue.json
# INFO:root:Saving data for conversation 'Configurar servidor Apache local' to CHATGPT/output_all_in_one/Configurar servidor Apache local.json
# INFO:root:Saving data for conversation 'Install PHP on Apache' to CHATGPT/output_all_in_one/Install PHP on Apache.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New chat.json
# INFO:root:Saving data for conversation 'Domain Info with Python' to CHATGPT/output_all_in_one/Domain Info with Python.json
# INFO:root:Saving data for conversation 'Set Up LAN Server (Python)' to CHATGPT/output_all_in_one/Set Up LAN Server _Python_.json
# INFO:root:Saving data for conversation 'Open Jupyter Notebook Over LAN' to CHATGPT/output_all_in_one/Open Jupyter Notebook Over LAN.json
# INFO:root:Saving data for conversation 'MP4 Files Finder Script' to CHATGPT/output_all_in_one/MP4 Files Finder Script.json
# INFO:root:Saving data for conversation 'Crear imagen colores primarios' to CHATGPT/output_all_in_one/Crear imagen colores primarios.json
# INFO:root:Saving data for conversation 'FFmpeg Slideshow with Transitions' to CHATGPT/output_all_in_one/FFmpeg Slideshow with Transitions.json
# INFO:root:Saving data for conversation 'Scroll Image to Video' to CHATGPT/output_all_in_one/Scroll Image to Video.json
# INFO:root:Saving data for conversation 'Crear videos con imágenes.' to CHATGPT/output_all_in_one/Crear videos con im_genes_.json
# INFO:root:Saving data for conversation 'Video Making Script with Logging' to CHATGPT/output_all_in_one/Video Making Script with Logging.json
# INFO:root:Saving data for conversation 'Crear video con transiciones.' to CHATGPT/output_all_in_one/Crear video con transiciones_.json
# INFO:root:Saving data for conversation 'List Directories with 'ls'' to CHATGPT/output_all_in_one/List Directories with _ls_.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New chat.json
# INFO:root:Saving data for conversation 'Rebuild Linux Thumbnails Cache' to CHATGPT/output_all_in_one/Rebuild Linux Thumbnails Cache.json
# INFO:root:Saving data for conversation 'Video Conversion with Fades' to CHATGPT/output_all_in_one/Video Conversion with Fades.json
# INFO:root:Saving data for conversation 'Unione video MP4 con transizione' to CHATGPT/output_all_in_one/Unione video MP4 con transizione.json
# INFO:root:Saving data for conversation 'Video Processing: Frames Method' to CHATGPT/output_all_in_one/Video Processing_ Frames Method.json
# INFO:root:Saving data for conversation 'Fade Transition Video Script' to CHATGPT/output_all_in_one/Fade Transition Video Script.json
# INFO:root:Saving data for conversation 'Unione video MP4 0.25s' to CHATGPT/output_all_in_one/Unione video MP4 0_25s.json
# INFO:root:Saving data for conversation 'JACK Audio Connection Issue' to CHATGPT/output_all_in_one/JACK Audio Connection Issue.json
# INFO:root:Saving data for conversation 'Run 'mkgallery' in subdirectories' to CHATGPT/output_all_in_one/Run _mkgallery_ in subdirectories.json
# INFO:root:Saving data for conversation 'House Stark in Winter' to CHATGPT/output_all_in_one/House Stark in Winter.json
# INFO:root:Saving data for conversation 'High Disk Activity Issue' to CHATGPT/output_all_in_one/High Disk Activity Issue.json
# INFO:root:Saving data for conversation 'Optimize SSD Swap File' to CHATGPT/output_all_in_one/Optimize SSD Swap File.json
# INFO:root:Saving data for conversation 'Code Indentation Fixed' to CHATGPT/output_all_in_one/Code Indentation Fixed.json
# INFO:root:Saving data for conversation 'Install .run file on Linux' to CHATGPT/output_all_in_one/Install _run file on Linux.json
# INFO:root:Saving data for conversation 'Install pyttsx3 module.' to CHATGPT/output_all_in_one/Install pyttsx3 module_.json
# INFO:root:Saving data for conversation 'Create Scrolling Text Video' to CHATGPT/output_all_in_one/Create Scrolling Text Video.json
# INFO:root:Saving data for conversation 'FFMPEG video with frame & music' to CHATGPT/output_all_in_one/FFMPEG video with frame _ music.json
# INFO:root:Saving data for conversation 'Fading Video Overlay Fix' to CHATGPT/output_all_in_one/Fading Video Overlay Fix.json
# INFO:root:Saving data for conversation 'Check Image Duplicates with Hashes' to CHATGPT/output_all_in_one/Check Image Duplicates with Hashes.json
# INFO:root:Saving data for conversation 'Disable all extensions' to CHATGPT/output_all_in_one/Disable all extensions.json
# INFO:root:Saving data for conversation 'FFmpeg Command Logging Fix' to CHATGPT/output_all_in_one/FFmpeg Command Logging Fix.json
# INFO:root:Saving data for conversation 'Flask HTML Template Example' to CHATGPT/output_all_in_one/Flask HTML Template Example.json
# INFO:root:Saving data for conversation 'Flask Video Selection Endpoint' to CHATGPT/output_all_in_one/Flask Video Selection Endpoint.json
# INFO:root:Saving data for conversation 'Improved Video Quality Settings' to CHATGPT/output_all_in_one/Improved Video Quality Settings.json
# INFO:root:Saving data for conversation 'Load index.html in Flask' to CHATGPT/output_all_in_one/Load index_html in Flask.json
# INFO:root:Saving data for conversation 'Image Resizer Troubleshooting' to CHATGPT/output_all_in_one/Image Resizer Troubleshooting.json
# INFO:root:Saving data for conversation 'Flask MP4 Route Setup' to CHATGPT/output_all_in_one/Flask MP4 Route Setup.json
# INFO:root:Saving data for conversation 'Plague Doctors and St. Sebastian' to CHATGPT/output_all_in_one/Plague Doctors and St_ Sebastian.json
# INFO:root:Saving data for conversation 'Save DuckDuckGo Results JSON' to CHATGPT/output_all_in_one/Save DuckDuckGo Results JSON.json
# INFO:root:Saving data for conversation 'Flask Code Review' to CHATGPT/output_all_in_one/Flask Code Review.json
# INFO:root:Saving data for conversation 'Flask App Code Review' to CHATGPT/output_all_in_one/Flask App Code Review.json
# INFO:root:Saving data for conversation 'Fixing Code for Directory Processing' to CHATGPT/output_all_in_one/Fixing Code for Directory Processing.json
# INFO:root:Saving data for conversation 'Flask for Existing HTML' to CHATGPT/output_all_in_one/Flask for Existing HTML.json
# INFO:root:Saving data for conversation 'Update Protobuf Code Version' to CHATGPT/output_all_in_one/Update Protobuf Code Version.json
# INFO:root:Saving data for conversation 'Crop Dimensions Explanation' to CHATGPT/output_all_in_one/Crop Dimensions Explanation.json
# INFO:root:Saving data for conversation 'Create Slow Scroll Video' to CHATGPT/output_all_in_one/Create Slow Scroll Video.json
# INFO:root:Saving data for conversation 'Crear plantilla HTML mp4_to_image' to CHATGPT/output_all_in_one/Crear plantilla HTML mp4_to_image.json
# INFO:root:Saving data for conversation 'Cancel Git Push Fix' to CHATGPT/output_all_in_one/Cancel Git Push Fix.json
# INFO:root:Saving data for conversation 'Capture Webpage with Python' to CHATGPT/output_all_in_one/Capture Webpage with Python.json
# INFO:root:Saving data for conversation 'Count Python Code Lines' to CHATGPT/output_all_in_one/Count Python Code Lines.json
# INFO:root:Saving data for conversation 'MP3 Joining Issue Troubleshooting' to CHATGPT/output_all_in_one/MP3 Joining Issue Troubleshooting.json
# INFO:root:Saving data for conversation 'MP3 File Joining Issue' to CHATGPT/output_all_in_one/MP3 File Joining Issue.json
# INFO:root:Saving data for conversation 'Correção da Rota "join_sound"' to CHATGPT/output_all_in_one/Corre__o da Rota _join_sound_.json
# INFO:root:Saving data for conversation 'Random MP3 Clips Concatenation' to CHATGPT/output_all_in_one/Random MP3 Clips Concatenation.json
# INFO:root:Saving data for conversation 'Shuffle Images for Video' to CHATGPT/output_all_in_one/Shuffle Images for Video.json
# INFO:root:Saving data for conversation 'Bash Completions using Python' to CHATGPT/output_all_in_one/Bash Completions using Python.json
# INFO:root:Saving data for conversation 'Fixing Flask Screen Capture' to CHATGPT/output_all_in_one/Fixing Flask Screen Capture.json
# INFO:root:Saving data for conversation 'Fix Git Push Error' to CHATGPT/output_all_in_one/Fix Git Push Error.json
# INFO:root:Saving data for conversation 'Flask Video Thumbnail App' to CHATGPT/output_all_in_one/Flask Video Thumbnail App.json
# INFO:root:Saving data for conversation 'Save Plots with UUIDs' to CHATGPT/output_all_in_one/Save Plots with UUIDs.json
# INFO:root:Saving data for conversation 'ClamAV Freshclam Log Error' to CHATGPT/output_all_in_one/ClamAV Freshclam Log Error.json
# INFO:root:Saving data for conversation 'Install Wine Mono Linux' to CHATGPT/output_all_in_one/Install Wine Mono Linux.json
# INFO:root:Saving data for conversation 'Clickable Links in HTML' to CHATGPT/output_all_in_one/Clickable Links in HTML.json
# INFO:root:Saving data for conversation 'Video Editing with MoviePy' to CHATGPT/output_all_in_one/Video Editing with MoviePy.json
# INFO:root:Saving data for conversation 'Flask Async Endpoints' to CHATGPT/output_all_in_one/Flask Async Endpoints.json
# INFO:root:Saving data for conversation 'Random MP3 Selection Bash' to CHATGPT/output_all_in_one/Random MP3 Selection Bash.json
# INFO:root:Saving data for conversation 'Virtual Environment Creation Error' to CHATGPT/output_all_in_one/Virtual Environment Creation Error.json
# INFO:root:Saving data for conversation 'Flask Video Generator Function' to CHATGPT/output_all_in_one/Flask Video Generator Function.json
# INFO:root:Saving data for conversation 'FlaskWebGui Debug Mode' to CHATGPT/output_all_in_one/FlaskWebGui Debug Mode.json
# INFO:root:Saving data for conversation 'Flask File Upload Function' to CHATGPT/output_all_in_one/Flask File Upload Function.json
# INFO:root:Saving data for conversation 'Flask Template HTML Setup' to CHATGPT/output_all_in_one/Flask Template HTML Setup.json
# INFO:root:Saving data for conversation 'Comic Panel Layout CSS' to CHATGPT/output_all_in_one/Comic Panel Layout CSS.json
# INFO:root:Saving data for conversation 'Lighten Image with Mogrify' to CHATGPT/output_all_in_one/Lighten Image with Mogrify.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New chat.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New chat.json
# INFO:root:Saving data for conversation 'GPT API Key Access' to CHATGPT/output_all_in_one/GPT API Key Access.json
# INFO:root:Saving data for conversation 'Add JPG and PNG' to CHATGPT/output_all_in_one/Add JPG and PNG.json
# INFO:root:Saving data for conversation 'Feathered Image Creation' to CHATGPT/output_all_in_one/Feathered Image Creation.json
# INFO:root:Saving data for conversation 'Feather Image with Python' to CHATGPT/output_all_in_one/Feather Image with Python.json
# INFO:root:Saving data for conversation 'Arcanis AI Enhancing Earth's AI' to CHATGPT/output_all_in_one/Arcanis AI Enhancing Earth_s AI.json
# INFO:root:Saving data for conversation 'Flask Logging Setup Guide' to CHATGPT/output_all_in_one/Flask Logging Setup Guide.json
# INFO:root:Saving data for conversation 'Generate & Save PNG Plot' to CHATGPT/output_all_in_one/Generate _ Save PNG Plot.json
# INFO:root:Saving data for conversation 'Install R on Linux' to CHATGPT/output_all_in_one/Install R on Linux.json
# INFO:root:Saving data for conversation 'Python & Flask Enthusiasts' to CHATGPT/output_all_in_one/Python _ Flask Enthusiasts.json
# INFO:root:Saving data for conversation 'Name: Esperanza' to CHATGPT/output_all_in_one/Name_ Esperanza.json
# INFO:root:Saving data for conversation 'Fixing Audio Buffer Overflow' to CHATGPT/output_all_in_one/Fixing Audio Buffer Overflow.json
# INFO:root:Saving data for conversation 'Louder Output Audio: Adjusting Volume' to CHATGPT/output_all_in_one/Louder Output Audio_ Adjusting Volume.json
# INFO:root:Saving data for conversation 'Change Outline Color' to CHATGPT/output_all_in_one/Change Outline Color.json
# INFO:root:Saving data for conversation 'Create Video from Images' to CHATGPT/output_all_in_one/Create Video from Images.json
# INFO:root:Saving data for conversation 'Python 3.9 Virtual Environment' to CHATGPT/output_all_in_one/Python 3_9 Virtual Environment.json
# INFO:root:Saving data for conversation 'Flask Thumbnail Video' to CHATGPT/output_all_in_one/Flask Thumbnail Video.json
# INFO:root:Saving data for conversation 'Flask Directory Viewer' to CHATGPT/output_all_in_one/Flask Directory Viewer.json
# INFO:root:Saving data for conversation 'Flask App Demo & Explanation' to CHATGPT/output_all_in_one/Flask App Demo _ Explanation.json
# INFO:root:Saving data for conversation 'Flask_env Jupyter Kernel Setup' to CHATGPT/output_all_in_one/Flask_env Jupyter Kernel Setup.json
# INFO:root:Saving data for conversation 'Mic Detection Issue Troubleshoot' to CHATGPT/output_all_in_one/Mic Detection Issue Troubleshoot.json
# INFO:root:Saving data for conversation 'Custom Instructions Understood' to CHATGPT/output_all_in_one/Custom Instructions Understood.json
# INFO:root:Saving data for conversation 'Flask AttributeError Troubleshooting' to CHATGPT/output_all_in_one/Flask AttributeError Troubleshooting.json
# INFO:root:Saving data for conversation 'Video Duration Adjustment' to CHATGPT/output_all_in_one/Video Duration Adjustment.json
# INFO:root:Saving data for conversation 'Install OpenCV (cv2)' to CHATGPT/output_all_in_one/Install OpenCV _cv2_.json
# INFO:root:Saving data for conversation 'Delete Files Except *.jpg' to CHATGPT/output_all_in_one/Delete Files Except __jpg.json
# INFO:root:Saving data for conversation 'LuaRocks Install NN-Spec' to CHATGPT/output_all_in_one/LuaRocks Install NN_Spec.json
# INFO:root:Saving data for conversation 'Failed nn Installation' to CHATGPT/output_all_in_one/Failed nn Installation.json
# INFO:root:Saving data for conversation 'Random Desktop Video Clips' to CHATGPT/output_all_in_one/Random Desktop Video Clips.json
# INFO:root:Saving data for conversation 'FFMPEG Create Shuffled Video' to CHATGPT/output_all_in_one/FFMPEG Create Shuffled Video.json
# INFO:root:Saving data for conversation 'Stream Speakers & Desktop' to CHATGPT/output_all_in_one/Stream Speakers _ Desktop.json
# INFO:root:Saving data for conversation 'Find Imported Module Source' to CHATGPT/output_all_in_one/Find Imported Module Source.json
# INFO:root:Saving data for conversation 'Linux Desktop Missing Icons' to CHATGPT/output_all_in_one/Linux Desktop Missing Icons.json
# INFO:root:Saving data for conversation 'FFMPEG Video Slowdown.' to CHATGPT/output_all_in_one/FFMPEG Video Slowdown_.json
# INFO:root:Saving data for conversation 'Create BMP from Image' to CHATGPT/output_all_in_one/Create BMP from Image.json
# INFO:root:Saving data for conversation 'GIFs to MP4' to CHATGPT/output_all_in_one/GIFs to MP4.json
# INFO:root:Saving data for conversation 'Hardcoded Args Parser' to CHATGPT/output_all_in_one/Hardcoded Args Parser.json
# INFO:root:Saving data for conversation 'Starting Over?' to CHATGPT/output_all_in_one/Starting Over_.json
# INFO:root:Saving data for conversation 'Create GIFS.mp4' to CHATGPT/output_all_in_one/Create GIFS_mp4.json
# INFO:root:Saving data for conversation 'Python Image Processing Code' to CHATGPT/output_all_in_one/Python Image Processing Code.json
# INFO:root:Saving data for conversation 'Dynamic Directory for mkblend_videos' to CHATGPT/output_all_in_one/Dynamic Directory for mkblend_videos.json
# INFO:root:Saving data for conversation 'Flask code with logging.' to CHATGPT/output_all_in_one/Flask code with logging_.json
# INFO:root:Saving data for conversation 'Create MP4 from images.' to CHATGPT/output_all_in_one/Create MP4 from images_.json
# INFO:root:Saving data for conversation 'Video Overlay Not Working' to CHATGPT/output_all_in_one/Video Overlay Not Working.json
# INFO:root:Saving data for conversation 'Fix favicon not found.' to CHATGPT/output_all_in_one/Fix favicon not found_.json
# INFO:root:Saving data for conversation 'Copy File with shutil' to CHATGPT/output_all_in_one/Copy File with shutil.json
# INFO:root:Saving data for conversation 'Nietzsche's views on death.' to CHATGPT/output_all_in_one/Nietzsche_s views on death_.json
# INFO:root:Saving data for conversation 'Video Generation from Directories.' to CHATGPT/output_all_in_one/Video Generation from Directories_.json
# INFO:root:Saving data for conversation 'API v0xF - Unknown Version' to CHATGPT/output_all_in_one/API v0xF _ Unknown Version.json
# INFO:root:Saving data for conversation 'Flask-SQLAlchemy Version Mismatch.' to CHATGPT/output_all_in_one/Flask_SQLAlchemy Version Mismatch_.json
# INFO:root:Saving data for conversation 'Flask: Request and Save.' to CHATGPT/output_all_in_one/Flask_ Request and Save_.json
# INFO:root:Saving data for conversation 'AI: Wonder or Monster?' to CHATGPT/output_all_in_one/AI_ Wonder or Monster_.json
# INFO:root:Saving data for conversation 'Flask App Setup' to CHATGPT/output_all_in_one/Flask App Setup.json
# INFO:root:Saving data for conversation 'Flask App with SQLite3' to CHATGPT/output_all_in_one/Flask App with SQLite3.json
# INFO:root:Saving data for conversation 'Video Editing Transitions' to CHATGPT/output_all_in_one/Video Editing Transitions.json
# INFO:root:Saving data for conversation 'Avatar AI for Talking' to CHATGPT/output_all_in_one/Avatar AI for Talking.json
# INFO:root:Saving data for conversation 'cp directory without overwrite' to CHATGPT/output_all_in_one/cp directory without overwrite.json
# INFO:root:Saving data for conversation 'Find File: stacked_videos' to CHATGPT/output_all_in_one/Find File_ stacked_videos.json
# INFO:root:Saving data for conversation 'AI's Leap in 2021' to CHATGPT/output_all_in_one/AI_s Leap in 2021.json
# INFO:root:Saving data for conversation 'Convert audio to video' to CHATGPT/output_all_in_one/Convert audio to video.json
# INFO:root:Saving data for conversation 'Create Image Sequence Video' to CHATGPT/output_all_in_one/Create Image Sequence Video.json
# INFO:root:Saving data for conversation 'Linux Find Modified Images' to CHATGPT/output_all_in_one/Linux Find Modified Images.json
# INFO:root:Saving data for conversation 'Find Duplicate Image Names' to CHATGPT/output_all_in_one/Find Duplicate Image Names.json
# INFO:root:Saving data for conversation 'Flask Blueprint Assistance' to CHATGPT/output_all_in_one/Flask Blueprint Assistance.json
# INFO:root:Saving data for conversation 'Activate Virtual Environment' to CHATGPT/output_all_in_one/Activate Virtual Environment.json
# INFO:root:Saving data for conversation 'Resizing & Cropping for Vertical Video' to CHATGPT/output_all_in_one/Resizing _ Cropping for Vertical Video.json
# INFO:root:Saving data for conversation 'Flask Open & View Text' to CHATGPT/output_all_in_one/Flask Open _ View Text.json
# INFO:root:Saving data for conversation 'Replace Spaces with Underscores' to CHATGPT/output_all_in_one/Replace Spaces with Underscores.json
# INFO:root:Saving data for conversation 'Create Video with Text' to CHATGPT/output_all_in_one/Create Video with Text.json
# INFO:root:Saving data for conversation 'Image-to-Video Conversion' to CHATGPT/output_all_in_one/Image_to_Video Conversion.json
# INFO:root:Saving data for conversation 'Flask Video Processing Server' to CHATGPT/output_all_in_one/Flask Video Processing Server.json
# INFO:root:Saving data for conversation 'HEVC Decoding Errors' to CHATGPT/output_all_in_one/HEVC Decoding Errors.json
# INFO:root:Saving data for conversation 'Blend Image Video Creation' to CHATGPT/output_all_in_one/Blend Image Video Creation.json
# INFO:root:Saving data for conversation 'Inference Error: mel() Function' to CHATGPT/output_all_in_one/Inference Error_ mel__ Function.json
# INFO:root:Saving data for conversation 'Syntax Error Resolved' to CHATGPT/output_all_in_one/Syntax Error Resolved.json
# INFO:root:Saving data for conversation 'Wonderland Characters Summary' to CHATGPT/output_all_in_one/Wonderland Characters Summary.json
# INFO:root:Saving data for conversation 'Datetime Import Issue' to CHATGPT/output_all_in_one/Datetime Import Issue.json
# INFO:root:Saving data for conversation 'Selecting Image Directory' to CHATGPT/output_all_in_one/Selecting Image Directory.json
# INFO:root:Saving data for conversation 'Upload file from directory' to CHATGPT/output_all_in_one/Upload file from directory.json
# INFO:root:Saving data for conversation 'Expressive Flora Still Life' to CHATGPT/output_all_in_one/Expressive Flora Still Life.json
# INFO:root:Saving data for conversation 'Anunnaki Overview' to CHATGPT/output_all_in_one/Anunnaki Overview.json
# INFO:root:Saving data for conversation 'Arcanis AI Communication' to CHATGPT/output_all_in_one/Arcanis AI Communication.json
# INFO:root:Saving data for conversation 'GEGL Bevel Compilation Error' to CHATGPT/output_all_in_one/GEGL Bevel Compilation Error.json
# INFO:root:Saving data for conversation 'Upload and Apply Text' to CHATGPT/output_all_in_one/Upload and Apply Text.json
# INFO:root:Saving data for conversation 'Browser Media Stream Issue' to CHATGPT/output_all_in_one/Browser Media Stream Issue.json
# INFO:root:Saving data for conversation 'Generate Unique Video Filename' to CHATGPT/output_all_in_one/Generate Unique Video Filename.json
# INFO:root:Saving data for conversation 'Flask Text-to-Speech' to CHATGPT/output_all_in_one/Flask Text_to_Speech.json
# INFO:root:Saving data for conversation 'Subprocess Firefox HTML Execution' to CHATGPT/output_all_in_one/Subprocess Firefox HTML Execution.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New chat.json
# INFO:root:Saving data for conversation 'Module Import Error Fix' to CHATGPT/output_all_in_one/Module Import Error Fix.json
# INFO:root:Saving data for conversation 'Aliens & AI Speculation' to CHATGPT/output_all_in_one/Aliens _ AI Speculation.json
# INFO:root:Saving data for conversation 'Fix File Copying Error' to CHATGPT/output_all_in_one/Fix File Copying Error.json
# INFO:root:Saving data for conversation 'Flask App Conversion' to CHATGPT/output_all_in_one/Flask App Conversion.json
# INFO:root:Saving data for conversation 'Dynamic Image Directory' to CHATGPT/output_all_in_one/Dynamic Image Directory.json
# INFO:root:Saving data for conversation 'Large File Push Error' to CHATGPT/output_all_in_one/Large File Push Error.json
# INFO:root:Saving data for conversation 'Overlay Video with Colorchrome' to CHATGPT/output_all_in_one/Overlay Video with Colorchrome.json
# INFO:root:Saving data for conversation 'Flask: Blank 512x1024.mp4' to CHATGPT/output_all_in_one/Flask_ Blank 512x1024_mp4.json
# INFO:root:Saving data for conversation 'Play MP3' to CHATGPT/output_all_in_one/Play MP3.json
# INFO:root:Saving data for conversation 'Screen and Audio Capture' to CHATGPT/output_all_in_one/Screen and Audio Capture.json
# INFO:root:Saving data for conversation 'Flask Marquee Overlay Video' to CHATGPT/output_all_in_one/Flask Marquee Overlay Video.json
# INFO:root:Saving data for conversation 'Concatenation Error: Parameters Mismatch' to CHATGPT/output_all_in_one/Concatenation Error_ Parameters Mismatch.json
# INFO:root:Saving data for conversation 'AI's Arcanis Intervention' to CHATGPT/output_all_in_one/AI_s Arcanis Intervention.json
# INFO:root:Saving data for conversation 'Story Assistance Available' to CHATGPT/output_all_in_one/Story Assistance Available.json
# INFO:root:Saving data for conversation 'LAN PHP Server Setup' to CHATGPT/output_all_in_one/LAN PHP Server Setup.json
# INFO:root:Saving data for conversation 'Combine Image and Audio' to CHATGPT/output_all_in_one/Combine Image and Audio.json
# INFO:root:Saving data for conversation 'Image to Video Conversion' to CHATGPT/output_all_in_one/Image to Video Conversion.json
# INFO:root:Saving data for conversation 'Male voice for Google TTS' to CHATGPT/output_all_in_one/Male voice for Google TTS.json
# INFO:root:Saving data for conversation 'Fixing PyQt5 Dependency Error' to CHATGPT/output_all_in_one/Fixing PyQt5 Dependency Error.json
# INFO:root:Saving data for conversation 'KDENLIVE error encountered' to CHATGPT/output_all_in_one/KDENLIVE error encountered.json
# INFO:root:Saving data for conversation 'CUDA Library Missing Error' to CHATGPT/output_all_in_one/CUDA Library Missing Error.json
# INFO:root:Saving data for conversation 'Add large file to GitHub.' to CHATGPT/output_all_in_one/Add large file to GitHub_.json
# INFO:root:Saving data for conversation 'NoCache pip Install.' to CHATGPT/output_all_in_one/NoCache pip Install_.json
# INFO:root:Saving data for conversation 'Fixing Large Files Issue' to CHATGPT/output_all_in_one/Fixing Large Files Issue.json
# INFO:root:Saving data for conversation 'MyTube AI Videos' to CHATGPT/output_all_in_one/MyTube AI Videos.json
# INFO:root:Saving data for conversation 'Programming Joke: Light vs Bugs' to CHATGPT/output_all_in_one/Programming Joke_ Light vs Bugs.json
# INFO:root:Saving data for conversation 'Choose Directory: Handle Selection' to CHATGPT/output_all_in_one/Choose Directory_ Handle Selection.json
# INFO:root:Saving data for conversation 'FFmpeg Merge Video & Audio' to CHATGPT/output_all_in_one/FFmpeg Merge Video _ Audio.json
# INFO:root:Saving data for conversation 'MP3 to WAV Conversion' to CHATGPT/output_all_in_one/MP3 to WAV Conversion.json
# INFO:root:Saving data for conversation 'FFmpeg Resize Video' to CHATGPT/output_all_in_one/FFmpeg Resize Video.json
# INFO:root:Saving data for conversation 'Resize Video 1/4' to CHATGPT/output_all_in_one/Resize Video 1_4.json
# INFO:root:Saving data for conversation 'Upload Local Files' to CHATGPT/output_all_in_one/Upload Local Files.json
# INFO:root:Saving data for conversation 'Delete Python Cache Safely' to CHATGPT/output_all_in_one/Delete Python Cache Safely.json
# INFO:root:Saving data for conversation 'Create Image Video MP4' to CHATGPT/output_all_in_one/Create Image Video MP4.json
# INFO:root:Saving data for conversation 'Text Fade-in/out Issue' to CHATGPT/output_all_in_one/Text Fade_in_out Issue.json
# INFO:root:Saving data for conversation 'Image Directory to JPEG' to CHATGPT/output_all_in_one/Image Directory to JPEG.json
# INFO:root:Saving data for conversation 'FFmpeg: 40x PTS Adjustment' to CHATGPT/output_all_in_one/FFmpeg_ 40x PTS Adjustment.json
# INFO:root:Saving data for conversation 'Fix unrecognized config option.' to CHATGPT/output_all_in_one/Fix unrecognized config option_.json
# INFO:root:Saving data for conversation 'File Creation Date' to CHATGPT/output_all_in_one/File Creation Date.json
# INFO:root:Saving data for conversation 'Crop and Save Images' to CHATGPT/output_all_in_one/Crop and Save Images.json
# INFO:root:Saving data for conversation 'Flask Directory Upload' to CHATGPT/output_all_in_one/Flask Directory Upload.json
# INFO:root:Saving data for conversation 'Move 512x1024 Images.' to CHATGPT/output_all_in_one/Move 512x1024 Images_.json
# INFO:root:Saving data for conversation 'New chat' to CHATGPT/output_all_in_one/New chat.json
# INFO:root:Saving data for conversation 'Create MP4 from Images.' to CHATGPT/output_all_in_one/Create MP4 from Images_.json
# INFO:root:Saving data for conversation 'Quigley Down Under Cast' to CHATGPT/output_all_in_one/Quigley Down Under Cast.json
# INFO:root:Saving data for conversation 'Combine GIFs into MP4.' to CHATGPT/output_all_in_one/Combine GIFs into MP4_.json
# INFO:root:Saving data for conversation 'Linux Thumbnail Refresh' to CHATGPT/output_all_in_one/Linux Thumbnail Refresh.json
# INFO:root:Saving data for conversation 'FFmpeg Video Filter Command.' to CHATGPT/output_all_in_one/FFmpeg Video Filter Command_.json
# INFO:root:Saving data for conversation 'Python Duplicate Files Finder' to CHATGPT/output_all_in_one/Python Duplicate Files Finder.json
# INFO:root:Saving data for conversation 'FFmpeg get frame count.' to CHATGPT/output_all_in_one/FFmpeg get frame count_.json
# INFO:root:Saving data for conversation 'Search for "mpdecimate".' to CHATGPT/output_all_in_one/Search for _mpdecimate__.json
# INFO:root:Saving data for conversation 'Randomly Shuffle List.' to CHATGPT/output_all_in_one/Randomly Shuffle List_.json
# INFO:root:Saving data for conversation 'Linux Rename by Creation Time' to CHATGPT/output_all_in_one/Linux Rename by Creation Time.json
# INFO:root:Saving data for conversation '"ts-jest" not found.' to CHATGPT/output_all_in_one/_ts_jest_ not found_.json
# INFO:root:Saving data for conversation 'AWS Lambda function integration' to CHATGPT/output_all_in_one/AWS Lambda function integration.json
# INFO:root:Saving data for conversation 'AWS CLI Configuration Error' to CHATGPT/output_all_in_one/AWS CLI Configuration Error.json
# INFO:root:Saving data for conversation 'Logging for Flask app.' to CHATGPT/output_all_in_one/Logging for Flask app_.json
# INFO:root:Saving data for conversation 'Play Recorded Audio.' to CHATGPT/output_all_in_one/Play Recorded Audio_.json
# INFO:root:Saving data for conversation 'FFmpeg motion estimation options.' to CHATGPT/output_all_in_one/FFmpeg motion estimation options_.json
# INFO:root:Saving data for conversation 'Create Title Page Form.' to CHATGPT/output_all_in_one/Create Title Page Form_.json
# INFO:root:Saving data for conversation 'Create a Video Slideshow.' to CHATGPT/output_all_in_one/Create a Video Slideshow_.json
# INFO:root:Saving data for conversation 'Import Error Fixed.' to CHATGPT/output_all_in_one/Import Error Fixed_.json
# INFO:root:Saving data for conversation 'Flask install pydub' to CHATGPT/output_all_in_one/Flask install pydub.json
# INFO:root:Saving data for conversation 'Flask/GTTS Audio and Video.' to CHATGPT/output_all_in_one/Flask_GTTS Audio and Video_.json
# INFO:root:Saving data for conversation 'Excluding file types using du.' to CHATGPT/output_all_in_one/Excluding file types using du_.json
# INFO:root:Saving data for conversation 'Flask JSON Search.' to CHATGPT/output_all_in_one/Flask JSON Search_.json
# INFO:root:Saving data for conversation 'Thumbnail Generation Error.' to CHATGPT/output_all_in_one/Thumbnail Generation Error_.json
# INFO:root:Saving data for conversation 'Directory Selection Issue' to CHATGPT/output_all_in_one/Directory Selection Issue.json
# INFO:root:Saving data for conversation 'Create random image video.' to CHATGPT/output_all_in_one/Create random image video_.json
# INFO:root:Saving data for conversation 'Generate video display.' to CHATGPT/output_all_in_one/Generate video display_.json
# INFO:root:Saving data for conversation 'FFmpeg image to video.' to CHATGPT/output_all_in_one/FFmpeg image to video_.json
# INFO:root:Saving data for conversation 'Python Syntax Error Fix.' to CHATGPT/output_all_in_one/Python Syntax Error Fix_.json
# INFO:root:Saving data for conversation 'Python ImportError with gettext' to CHATGPT/output_all_in_one/Python ImportError with gettext.json
# INFO:root:Saving data for conversation 'Speech-to-Text Transcription.' to CHATGPT/output_all_in_one/Speech_to_Text Transcription_.json
# INFO:root:Saving data for conversation 'Move 512x768 images.' to CHATGPT/output_all_in_one/Move 512x768 images_.json
# INFO:root:Saving data for conversation 'Cannot Import FFmpeg Constants' to CHATGPT/output_all_in_one/Cannot Import FFmpeg Constants.json
# INFO:root:Saving data for conversation 'Movie transitions and zooming.' to CHATGPT/output_all_in_one/Movie transitions and zooming_.json
# INFO:root:Saving data for conversation 'Images blending into video.' to CHATGPT/output_all_in_one/Images blending into video_.json
# INFO:root:Saving data for conversation 'Convert video to images.' to CHATGPT/output_all_in_one/Convert video to images_.json
# INFO:root:Saving data for conversation 'Resize PNG image.' to CHATGPT/output_all_in_one/Resize PNG image_.json
# INFO:root:Saving data for conversation 'FFmpeg audio-video streaming.' to CHATGPT/output_all_in_one/FFmpeg audio_video streaming_.json
# INFO:root:Saving data for conversation 'Livestream to YouTube with FFmpeg' to CHATGPT/output_all_in_one/Livestream to YouTube with FFmpeg.json
# INFO:root:Saving data for conversation 'Add Sound with Fading.' to CHATGPT/output_all_in_one/Add Sound with Fading_.json
# INFO:root:Saving data for conversation 'FFmpeg Screen Recording.' to CHATGPT/output_all_in_one/FFmpeg Screen Recording_.json
# INFO:root:Saving data for conversation 'Mixing video clips.' to CHATGPT/output_all_in_one/Mixing video clips_.json
# INFO:root:Saving data for conversation 'FFmpeg command for video.' to CHATGPT/output_all_in_one/FFmpeg command for video_.json
# INFO:root:Saving data for conversation 'Basic HTML page.' to CHATGPT/output_all_in_one/Basic HTML page_.json
# INFO:root:Saving data for conversation 'Joining Animated Videos.' to CHATGPT/output_all_in_one/Joining Animated Videos_.json
# INFO:root:Saving data for conversation 'Add title image.' to CHATGPT/output_all_in_one/Add title image_.json
# INFO:root:Saving data for conversation 'Video from Images.' to CHATGPT/output_all_in_one/Video from Images_.json
# INFO:root:Saving data for conversation 'Date and time filename.' to CHATGPT/output_all_in_one/Date and time filename_.json
# INFO:root:Saving data for conversation 'Adjusting ffmpeg for image dimensions' to CHATGPT/output_all_in_one/Adjusting ffmpeg for image dimensions.json
# INFO:root:Saving data for conversation 'OBS RTMP Configuration.' to CHATGPT/output_all_in_one/OBS RTMP Configuration_.json
# INFO:root:Saving data for conversation 'Random Image Video Creation.' to CHATGPT/output_all_in_one/Random Image Video Creation_.json
# INFO:root:Saving data for conversation 'GIF Upload Error.' to CHATGPT/output_all_in_one/GIF Upload Error_.json
# INFO:root:Saving data for conversation 'Reducing dithered GIFs.' to CHATGPT/output_all_in_one/Reducing dithered GIFs_.json
# INFO:root:Saving data for conversation 'Viewing Python Module Imports' to CHATGPT/output_all_in_one/Viewing Python Module Imports.json
# INFO:root:Saving data for conversation 'Image Resizing Script.' to CHATGPT/output_all_in_one/Image Resizing Script_.json
# INFO:root:Saving data for conversation 'GIMP brush styles.' to CHATGPT/output_all_in_one/GIMP brush styles_.json
# INFO:root:Saving data for conversation 'Test initiate_database.js with Jest' to CHATGPT/output_all_in_one/Test initiate_database_js with Jest.json
# INFO:root:Saving data for conversation 'New start.' to CHATGPT/output_all_in_one/New start_.json
# INFO:root:Saving data for conversation 'Disable Preview Tab feature.' to CHATGPT/output_all_in_one/Disable Preview Tab feature_.json
# INFO:root:Saving data for conversation 'MySQL DNS Lookup Error.' to CHATGPT/output_all_in_one/MySQL DNS Lookup Error_.json
# INFO:root:Saving data for conversation 'Starting fresh.' to CHATGPT/output_all_in_one/Starting fresh_.json
# INFO:root:Saving data for conversation 'Creating video from images.' to CHATGPT/output_all_in_one/Creating video from images_.json
# INFO:root:Saving data for conversation 'Image Creator Functions.' to CHATGPT/output_all_in_one/Image Creator Functions_.json
# INFO:root:Saving data for conversation 'Linux: Large files search.' to CHATGPT/output_all_in_one/Linux_ Large files search_.json
# INFO:root:Saving data for conversation 'Learn AWS Lambda basics.' to CHATGPT/output_all_in_one/Learn AWS Lambda basics_.json
# INFO:root:Saving data for conversation 'ES6 Import Syntax Error.' to CHATGPT/output_all_in_one/ES6 Import Syntax Error_.json
# INFO:root:Saving data for conversation 'MySQL insert and view.' to CHATGPT/output_all_in_one/MySQL insert and view_.json
# INFO:root:Saving data for conversation 'ffmpeg video filtering' to CHATGPT/output_all_in_one/ffmpeg video filtering.json
# INFO:root:Saving data for conversation 'Add sound to video.' to CHATGPT/output_all_in_one/Add sound to video_.json
# INFO:root:Saving data for conversation 'Video Zoom Filter FFmpeg' to CHATGPT/output_all_in_one/Video Zoom Filter FFmpeg.json
# INFO:root:Saving data for conversation 'Zooming Video from Images' to CHATGPT/output_all_in_one/Zooming Video from Images.json
# INFO:root:Saving data for conversation 'Pan & zoom effect.' to CHATGPT/output_all_in_one/Pan _ zoom effect_.json
# INFO:root:Saving data for conversation 'Node.js API for MySQL.' to CHATGPT/output_all_in_one/Node_js API for MySQL_.json
# INFO:root:Saving data for conversation 'Fixing Express Middleware Issues' to CHATGPT/output_all_in_one/Fixing Express Middleware Issues.json
# INFO:root:Saving data for conversation 'Store user preferences.' to CHATGPT/output_all_in_one/Store user preferences_.json
# INFO:root:Saving data for conversation 'Python MySQL database creation.' to CHATGPT/output_all_in_one/Python MySQL database creation_.json
# INFO:root:Saving data for conversation 'SAM framework for AWS.' to CHATGPT/output_all_in_one/SAM framework for AWS_.json
# INFO:root:Saving data for conversation 'MySQL JSON data conversion.' to CHATGPT/output_all_in_one/MySQL JSON data conversion_.json
# INFO:root:Saving data for conversation 'Linux RPM Installation' to CHATGPT/output_all_in_one/Linux RPM Installation.json
# INFO:root:Saving data for conversation 'Node.js terminal printing.' to CHATGPT/output_all_in_one/Node_js terminal printing_.json
# INFO:root:Saving data for conversation 'Handle Error in Jest' to CHATGPT/output_all_in_one/Handle Error in Jest.json
# INFO:root:Saving data for conversation 'Inserting data using HTML form.' to CHATGPT/output_all_in_one/Inserting data using HTML form_.json
# INFO:root:Saving data for conversation 'Inserting data into SQL.' to CHATGPT/output_all_in_one/Inserting data into SQL_.json
